# %% [markdown]
# ###### XGBOOST Parameter tuning
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
#http://drivendata.co/blog/worldbank-poverty-benchmark/

# %matplotlib inline

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
import category_encoders as ce

# data directory
DATA_DIR = os.path.join(r'C:\Users\piush\Desktop\Dataset\world_bank_poverty_data\household')

# %%
data_paths = {'A': {'train': os.path.join(DATA_DIR,  'A_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'A_hhold_test.csv')}, 
              
              'B': {'train': os.path.join(DATA_DIR,  'B_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'B_hhold_test.csv')}, 
              
              'C': {'train': os.path.join(DATA_DIR,  'C_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'C_hhold_test.csv')}}

# %%
# load training data
a_train = pd.read_csv(data_paths['A']['train'], index_col='id')
b_train = pd.read_csv(data_paths['B']['train'], index_col='id')
c_train = pd.read_csv(data_paths['C']['train'], index_col='id')

# %%
# load test data
a_test = pd.read_csv(data_paths['A']['test'], index_col='id')
b_test = pd.read_csv(data_paths['B']['test'], index_col='id')
c_test = pd.read_csv(data_paths['C']['test'], index_col='id')

# %%
a_train.shape
# Out:
# (8203, 345)

# %%
a_test.shape
# Out:
# (4041, 344)

# %%
df = pd.concat([a_train,a_test])

# %%
y = a_train['poor']

# %%
df = df.drop(['poor','country'], axis = 1)

# %%
#Convert only the categorical values

encoder = ce.SumEncoder(cols= list(df.columns.values))
encoder.fit(df, y)
aX_cleaned = encoder.transform(df)

# %%
train_c = aX_cleaned[:len(a_train)]

# %%
train_c.shape
# Out:
# (8203, 907)

# %%
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

X_minmax = MinMaxScaler(feature_range=(0,1)).fit_transform(train_c)
X_scored = SelectKBest(score_func=chi2, k='all').fit(X_minmax, y)
feature_scoring = pd.DataFrame({
        'feature': train_c.columns,
        'score': X_scored.scores_
    })

impt_chi = feature_scoring.sort_values('score', ascending=False).head(100)['feature'].values

# %%
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, VotingClassifier, RandomForestClassifier, AdaBoostClassifier

model = RandomForestClassifier()
model.fit(train_c, y)

feature_imp = pd.DataFrame(model.feature_importances_, index=train_c.columns, columns=["importance"])
impt_features = list(feature_imp.sort_values("importance", ascending=False).head(500).index)

# %%
df_c = aX_cleaned[impt_features]

# %%
df_c['sum_columns'] = df_c.sum(axis = 1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#df_c.drop("Total", inplace=True)

# %%
df_c['mean'] = df_c['sum_columns'].div(df_c['sum_columns'].sum())
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
train = df_c[:len(a_train)]

# %%
train.head(2)
# Out:
#        col_QyBloWXZ_1  col_qgxmqJKa_1  col_TiwRslOh_7  col_GIMIxlmv_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0            -1.0             0.0             1.0
#
#        col_TiwRslOh_4  col_phwExnuQ_1  col_nEsgxvAq_3  col_xkUFKUoW_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             0.0             1.0             0.0             1.0
#
#        col_vRIvQXtC_1  col_IZFarbPw_1  col_wEbmsuJO_1  col_GhJKwVWC_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0            -1.0            -1.0
#
#        col_AtGRGAYi_2  col_ktBqxSwa_1  col_ZRrposmO_1  col_UXhTXbuS_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_LjvKYNON_2  col_bMudmjzJ_1  col_uJYGhXqG_1  col_tHFrzjai_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             1.0            -1.0            -1.0             1.0
#
#        col_FmSlImli_1  col_vRIvQXtC_2  col_AsEmHUzj_1  col_AtGRGAYi_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739            -1.0             0.0             0.0             1.0
#
#        col_CNkSTLvx_1  col_DbUNVFwv_1  col_PWShFLnY_1  col_YlZCqMNw_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_UXfyiodk_1  col_TiwRslOh_2  col_jdetlNNF_1  col_UaXLYMMh_3  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_ggNglVqE_1  col_XDDOZFWf_1  col_YTdCRVJt_2  col_ltcNxFzI_3  \
# id
# 46107             1.0             1.0             0.0             0.0
# 82739            -1.0             1.0             0.0             0.0
#
#        col_kLkPtNnh_1  col_galsfNtg_1  col_KjkrfGLD_5  col_HHAeIHna_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0             0.0
#
#        col_TiwRslOh_6  col_gfmfEyjQ_2  col_rAkSnhJF_1  col_FlBqizNL_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             0.0            -1.0
#
#        col_pKPTBZZq_2  col_JMNvdasy_2  col_bPOwgKnT_2  col_QZiSWCCB_1  \
# id
# 46107             0.0             0.0             0.0             1.0
# 82739             1.0             1.0             1.0            -1.0
#
#        col_ltcNxFzI_1  col_bPOwgKnT_3  col_SqGRfEuW_1  col_HfKRIwMb_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             0.0             0.0             0.0            -1.0
#
#        col_TiwRslOh_1  col_TiwRslOh_3  col_HHAeIHna_2  col_DxLvCGgv_1  \
# id
# 46107             1.0             0.0             0.0             1.0
# 82739             0.0             0.0             1.0            -1.0
#
#        col_ltcNxFzI_2  col_uRFXnNKV_2  col_OMtioXZZ_1  col_ZnBLVaqz_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             1.0             0.0             0.0            -1.0
#
#        col_mycoyYwl_1  col_CrfscGZl_1  col_JwtIxvKg_1  col_ihGjxdDj_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739            -1.0             1.0             1.0            -1.0
#
#        col_UaXLYMMh_2  col_YFMZwKrU_3  col_SzUcfjnr_1  col_gfmfEyjQ_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             1.0             1.0
#
#        col_muIetHMK_2  col_rAkSnhJF_4  col_UsENDgsH_1  col_dCGNTMiG_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_yaHLJxDD_2  col_YlZCqMNw_2  col_SqGRfEuW_2  col_rAkSnhJF_2  \
# id
# 46107             0.0             0.0             0.0             0.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_znHDEHZP_1  col_lOujHrCk_1  col_bPOwgKnT_4  col_KjkrfGLD_3  \
# id
# 46107             1.0             1.0             0.0             0.0
# 82739             1.0             1.0             0.0             0.0
#
#        col_rAkSnhJF_3  col_uRFXnNKV_1  col_mvgxfsRb_1  col_nGTepfos_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0            -1.0            -1.0
#
#        col_RJQbcmKy_1  col_BfGjiYom_2  col_KjkrfGLD_1  col_dkPWxwSF_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739            -1.0             1.0             1.0             1.0
#
#        col_OybQOufM_1  col_ptEAnCSs_1  col_OLpGAaEu_1  col_xZBEXWPR_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739            -1.0            -1.0             0.0             1.0
#
#        col_UaXLYMMh_1  col_NanLCXEI_1  col_qgMygRvX_2  col_pCgBHqsR_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0            -1.0
#
#        col_zFkComtB_1  col_nEsgxvAq_2  col_BCehjxAl_1  col_OMtioXZZ_2  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_CsGvKKBJ_1  col_bCYWWTxH_1  col_dkPWxwSF_4  col_DNAfxPzs_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0             1.0
#
#        col_NRVuZwXK_1  col_dkPWxwSF_3  col_muIetHMK_1  col_aWlBVrkK_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_EuJrVjyG_1  col_YFMZwKrU_2  col_UXhTXbuS_2  col_zFkComtB_2  \
# id
# 46107             1.0             0.0             0.0             0.0
# 82739            -1.0             1.0             0.0             0.0
#
#        col_ucXrHdoC_2  col_JCDeZBXq_1  col_glEjrMIg_1  col_VIRwrkXp_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0            -1.0             1.0             1.0
#
#        col_UCAmikjV_1  col_TiwRslOh_5  col_wxDnGIwN_1  col_EQKKRGkR_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0            -1.0            -1.0
#
#        col_CtHqaXhY_2  col_IKqsuNvV_1  col_ishdUooQ_2  col_SeZULMCT_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0            -1.0
#
#        col_YKwvJgoP_1  col_dqRtXzav_1  col_MKozKLvT_1  col_YTdCRVJt_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739            -1.0            -1.0             1.0             1.0
#
#        col_ANBCxZzU_1  col_SlDKnCuu_1  col_TiwRslOh_8  col_gllMXToa_2  \
# id
# 46107             1.0             1.0             0.0             0.0
# 82739             1.0             1.0             0.0             1.0
#
#        col_wKVwRQIp_1  col_AlDbXTlZ_1  col_OLpGAaEu_2  col_kWFVfHWP_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0            -1.0             1.0            -1.0
#
#        col_ucXrHdoC_1  col_VBjVVDwp_2  col_qgMygRvX_1  col_HKMQJANN_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_rYvVKPAF_1  col_wnESwOiN_2  col_EJgrQqET_1  col_NRVuZwXK_2  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             0.0            -1.0             0.0
#
#        col_TiwRslOh_10  col_ngwuvaCV_1  col_CtHqaXhY_1  col_kZVpcgJL_1  \
# id
# 46107              0.0             1.0             1.0             1.0
# 82739              0.0            -1.0             0.0             1.0
#
#        col_OMtioXZZ_4  col_tbsBPHFD_1  col_hnrnuMte_1  col_UaXLYMMh_4  \
# id
# 46107             0.0             1.0             1.0             0.0
# 82739             0.0             1.0             1.0             0.0
#
#        col_CIGUXrRQ_1  col_bPOwgKnT_1  col_gllMXToa_1  col_uSKnVaKV_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_RJFKdmYJ_1  col_iBQXwnGC_1  col_WAFKMNwv_1  col_wakWLjkG_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0            -1.0            -1.0
#
#        col_pjHvJhoZ_1  col_bIBQTaHw_2  col_lFcfBRGd_1  col_XSgHIFXD_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739            -1.0             0.0             1.0             1.0
#
#        col_AsEmHUzj_2  col_bgoWYRMQ_1  col_qTginJts_1  col_vwpsXRGk_30  \
# id
# 46107             0.0             1.0             1.0              0.0
# 82739             1.0             1.0             1.0              0.0
#
#        col_KcArMKAe_1  col_lVHmBCmb_1  col_UCnazcxd_1  col_cqUmYeAp_2  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0            -1.0             1.0
#
#        col_HKMQJANN_2  col_VBjVVDwp_1  col_YXkrVgqt_1  col_jwEuQQve_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_YFMZwKrU_1  col_naDKOzdk_1  col_BfGjiYom_4  col_pKPTBZZq_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             0.0             1.0             0.0             0.0
#
#        col_sslNoPlw_1  col_NRVuZwXK_3  col_uVnApIlJ_1  col_nqndbwXP_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0            -1.0             1.0
#
#        col_zzwlWZZC_1  col_LjvKYNON_1  col_OKMtkqdQ_1  col_bxKGlBYX_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_BfGjiYom_8  col_IIEHQNUc_1  col_eoNxXdlZ_1  col_OMtioXZZ_3  \
# id
# 46107             0.0             1.0             1.0             0.0
# 82739             0.0             1.0             1.0             0.0
#
#        col_dkPWxwSF_2  col_vwpsXRGk_22  col_tlxXCDiW_1  col_HmDAlkAH_1  \
# id
# 46107             0.0              0.0             1.0             1.0
# 82739             0.0              0.0             1.0             1.0
#
#        col_KjkrfGLD_4  col_wnESwOiN_1  col_gfurxECf_1  col_WuwrCsIY_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_ErggjCIN_1  col_vwpsXRGk_21  col_ZzUrQSMj_1  col_VZtBaoXL_1  \
# id
# 46107             1.0              0.0             1.0             1.0
# 82739             1.0              0.0            -1.0             1.0
#
#        col_UGbBCHRE_1  col_TnWhKowI_1  col_NIRMacrk_1  col_UXSJUVwD_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0            -1.0             1.0
#
#        col_vwpsXRGk_14  col_vwpsXRGk_9  col_wwfmpuWA_1  col_vwpsXRGk_18  \
# id
# 46107              0.0             0.0             1.0              0.0
# 82739              0.0             0.0             1.0              0.0
#
#        col_ytYMzOlW_1  col_KAJOWiiw_2  col_ishdUooQ_1  col_QayGNSmS_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_nSzbETYS_1  col_vwpsXRGk_25  col_VXXLUaXP_1  col_yeHQSlwg_1  \
# id
# 46107             1.0              0.0             1.0             1.0
# 82739             1.0              0.0             1.0             1.0
#
#        col_UBanubTh_2  col_BfGjiYom_1  col_gOGWzlYC_1  col_ULMvnWcn_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_vwpsXRGk_29  col_MARfVwUE_1  col_CqqwKRSn_1  col_bIBQTaHw_1  \
# id
# 46107              0.0             1.0             1.0             1.0
# 82739              0.0             1.0             0.0             1.0
#
#        col_tHFrzjai_3  col_dEpQghsA_1  col_NrUWfvEq_2  col_ncjMNgfp_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             0.0             1.0             0.0             1.0
#
#        col_cDkXTaWP_1  col_tAYCAXge_1  col_vwpsXRGk_11  col_UXSJUVwD_2  \
# id
# 46107             1.0             1.0              0.0             0.0
# 82739             1.0             1.0              0.0             0.0
#
#        col_pWyRKfsb_1  col_KjkrfGLD_6  col_duayPuvk_1  col_ogHwwdzc_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739            -1.0             0.0             1.0             1.0
#
#        col_AsEmHUzj_5  col_vwpsXRGk_24  col_ZmJZXnoA_1  col_vwpsXRGk_27  \
# id
# 46107             0.0              0.0             1.0              0.0
# 82739             0.0              0.0             1.0              0.0
#
#        col_NrUWfvEq_1  col_bEPKkJXP_1  col_maLAYXwi_1  col_vwpsXRGk_12  \
# id
# 46107             1.0             1.0             1.0              0.0
# 82739             1.0             1.0             0.0              0.0
#
#        col_hESBInAl_2  col_vwpsXRGk_15    ...     col_rQAsGegu_1  \
# id                                        ...
# 46107             0.0              0.0    ...                1.0
# 82739             0.0              0.0    ...                1.0
#
#        col_vwpsXRGk_6  col_NRVuZwXK_4  col_HhKXJWno_1  col_ItpCDLDM_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             1.0             1.0
#
#        col_fpHOwfAs_1  col_WiwmbjGW_1  col_vwpsXRGk_13  col_vwpsXRGk_28  \
# id
# 46107             1.0             1.0              0.0              0.0
# 82739             1.0             1.0              0.0              0.0
#
#        col_qlZMvcWc_1  col_vwpsXRGk_7  col_vwpsXRGk_2  col_UHGnBrNt_2  \
# id
# 46107             1.0             0.0             0.0             0.0
# 82739             1.0             0.0             1.0             0.0
#
#        col_AsEmHUzj_4  col_vwpsXRGk_8  col_UjuNwfjv_1  col_QBJeqwPF_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             1.0             1.0
#
#        col_dyGFeFAg_1  col_KAJOWiiw_1  col_qgMygRvX_5  col_JzhdOhzb_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0             1.0
#
#        col_mRgnuJVE_2  col_lQQeVmCa_1  col_srPNUgVy_1  col_bgfNZfcj_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             0.0             1.0
#
#        col_QNLOXNwj_1  col_vwpsXRGk_17  col_KjkrfGLD_2  col_wKcZtLNv_1  \
# id
# 46107             1.0              0.0             0.0             1.0
# 82739             1.0              0.0             0.0             1.0
#
#        col_maLAYXwi_2  col_cqUmYeAp_3  col_nuwxPLMe_1  col_nEsgxvAq_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             0.0
#
#        col_vwpsXRGk_5  col_UHGnBrNt_1  col_GHmAeUhZ_2  col_rtPrBBPl_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_vwpsXRGk_20  col_VZtBaoXL_2  col_jVDpuAmP_1  col_NBfffJUe_1  \
# id
# 46107              0.0             0.0             1.0             1.0
# 82739              0.0             0.0             1.0            -1.0
#
#        col_srPNUgVy_2  col_cqUmYeAp_1  col_qgMygRvX_4  col_btgWptTG_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_nSzbETYS_2  col_lnfulcWk_1  col_tHFrzjai_2  col_vwpsXRGk_16  \
# id
# 46107             0.0             1.0             0.0              0.0
# 82739             0.0             1.0             0.0              0.0
#
#        col_szowPwNq_1  col_BMmgMRvd_1  col_ePtrWTFd_1  col_HmDAlkAH_2  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_lFExzVaF_1  col_vwpsXRGk_3  col_hESBInAl_1  col_BbKZUYsB_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0            -1.0
#
#        col_GnUDarun_1  col_tMJrvvut_1  col_mvGdZZcs_2  col_eeYoszDM_1  \
# id
# 46107             1.0             1.0             0.0             1.0
# 82739             1.0             1.0             0.0             1.0
#
#        col_YWwNfVtR_1  col_qgMygRvX_3  col_YXkrVgqt_2  col_mDTcQhdH_1  \
# id
# 46107             1.0             0.0             0.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_TWXCrjor_2  col_KjkrfGLD_7  col_TWXCrjor_1  col_hnmsRSvN_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             1.0             1.0
#
#        col_wgWdGBOp_1  col_uZGqTQUP_2  col_ccAHraiP_1  col_vwpsXRGk_19  \
# id
# 46107             1.0             0.0             1.0              0.0
# 82739             1.0             1.0             1.0              0.0
#
#        col_BfGjiYom_5  col_yeHQSlwg_3  col_uZGqTQUP_1  col_BIofZdtd_1  \
# id
# 46107             0.0             0.0             1.0             1.0
# 82739             0.0             0.0             0.0             1.0
#
#        col_sFWbFEso_1  col_orfSPOJX_1  col_vwpsXRGk_4  col_BfGjiYom_7  \
# id
# 46107             1.0             1.0             0.0             0.0
# 82739             1.0             1.0             0.0             0.0
#
#        col_mNrEOmgq_1  col_dsIjcEFe_1  col_mRgnuJVE_1  col_vwpsXRGk_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_fhKiXuMY_1  col_WiwmbjGW_2  col_mHzqKSuN_1  col_udzhtHIr_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_SsZAZLma_1  col_QqoiIXtI_1  col_DsKacCdL_1  col_qgMygRvX_6  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739            -1.0             1.0             1.0             0.0
#
#        col_vwpsXRGk_26  col_UjuNwfjv_2  col_mvGdZZcs_1  col_UXSJUVwD_4  \
# id
# 46107              0.0             0.0             1.0             0.0
# 82739              0.0             0.0             1.0             0.0
#
#        col_fxbqfEWb_1  col_LjvKYNON_3  col_ySkAFOzx_2  col_UjuNwfjv_5  \
# id
# 46107             1.0             0.0             0.0             0.0
# 82739             1.0             0.0             1.0             0.0
#
#        col_CVCsOVew_1  col_OMtioXZZ_5  col_XVwajTfe_1  col_zuMWFXax_2  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             0.0             1.0             0.0
#
#        col_TJUYOoXU_1  col_NmAVTtfA_1  col_HGPWuGlV_1  col_NRVuZwXK_5  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_GHmAeUhZ_1  col_zuMWFXax_1  col_nzTeWUeM_1  col_TqrXZaOw_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             0.0             1.0             0.0             1.0
#
#        col_OMtioXZZ_7  col_tZKoAqgl_1  col_YUExUvhq_1  col_zkbPtFyO_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_CbABToOI_2  col_FGDcbVBN_1  col_vwpsXRGk_10  col_AsEmHUzj_6  \
# id
# 46107             0.0             1.0              0.0             0.0
# 82739             1.0             1.0              0.0             0.0
#
#        col_yHbEDILT_1  col_LrQXqVUj_1  col_cqUmYeAp_4  col_yeHQSlwg_2  \
# id
# 46107             1.0             1.0             0.0             0.0
# 82739             1.0             1.0             0.0             0.0
#
#        col_TFrimNtw_1  col_NRVuZwXK_7  col_MxOgekdE_1  col_JbjHTYUM_2  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_dkPWxwSF_5  col_BfGjiYom_9  col_CbABToOI_1  col_TiwRslOh_12  \
# id
# 46107             0.0             0.0             1.0              0.0
# 82739             0.0             0.0             0.0              0.0
#
#        col_TYhoEiNm_1  col_NrvxpdMQ_1  col_ALbGNqKm_1  col_yeHQSlwg_4  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_QzqNzAJE_1  col_WTFJilSZ_1  col_vwpsXRGk_23  col_LoYIbglA_1  \
# id
# 46107             1.0             1.0              0.0             1.0
# 82739             1.0             1.0              0.0             1.0
#
#        col_yeHQSlwg_6  col_yeHQSlwg_5  col_ySkAFOzx_1  col_BfGjiYom_12  \
# id
# 46107             0.0             0.0             1.0              0.0
# 82739             0.0             0.0             0.0              0.0
#
#        col_UBanubTh_1  col_FcekeISI_2  col_nzTeWUeM_2  col_BfGjiYom_10  \
# id
# 46107             1.0             0.0             0.0              0.0
# 82739             0.0             1.0             1.0              0.0
#
#        col_UXSJUVwD_5  col_YFMZwKrU_4  col_qgMygRvX_7  col_rfDBJtIz_1  \
# id
# 46107             0.0             0.0             0.0             1.0
# 82739             0.0             0.0             0.0             0.0
#
#        col_InULRrrv_1  col_BfGjiYom_6  col_UXSJUVwD_6  col_cWNZCMRB_1  \
# id
# 46107             1.0             0.0             0.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_NRVuZwXK_8  col_XwVALSPR_1  col_NRVuZwXK_6  col_yaHLJxDD_1  \
# id
# 46107             0.0             1.0             0.0             1.0
# 82739             0.0             1.0             0.0             0.0
#
#        col_MBQcYnjc_1  col_iWEFJYkR_1  col_iVscWZyL_1  col_EftwspgZ_2  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_hTraVEWP_1  col_JeydMEpC_1  col_ofhkZaYa_1  col_GKUhYLAE_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_FcekeISI_1  col_rfDBJtIz_2  col_bSaLisbO_1  col_AsEmHUzj_3  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             0.0             1.0             1.0             0.0
#
#        col_TiwRslOh_13  col_PXtHzrqw_2  col_OMtioXZZ_6  col_bhFgAObo_1  \
# id
# 46107              0.0             0.0             0.0             1.0
# 82739              0.0             1.0             0.0             1.0
#
#        col_sYIButva_1  col_XqURHMoh_1  col_dlyiMEQt_1  col_bKtkhUWD_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_GKUhYLAE_2  col_UXSJUVwD_3  col_BfGjiYom_11  col_BfGjiYom_3  \
# id
# 46107             0.0             0.0              0.0             0.0
# 82739             1.0             0.0              0.0             0.0
#
#        col_pyBSpOoN_1  col_WqhniYIc_1  col_VFTkSOrq_1  col_UjuNwfjv_8  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_benRXROb_1  col_fHUZugEd_1  col_CHAQHqqr_1  col_TzPdCEPV_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_THDtJuYh_1  col_tHFrzjai_4  col_UjuNwfjv_6  col_aCfsveTu_1  \
# id
# 46107             1.0             0.0             0.0             1.0
# 82739             1.0             0.0             0.0             1.0
#
#        col_mBlWbDmc_1  col_vRIvQXtC_5  col_KHzKOKPw_1  col_hJrMTBVd_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_TvShZEBA_1  col_TiwRslOh_9  col_pQmBvlkz_1  col_UjuNwfjv_4  \
# id
# 46107             1.0             0.0             1.0             0.0
# 82739             1.0             0.0             1.0             0.0
#
#        col_EfkPrfXa_1  col_JbjHTYUM_1  col_zvjiUrCR_1  col_sDGibZrP_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_cqUmYeAp_5  col_sArDRIyX_1  col_EftwspgZ_1  col_IBPMYJlv_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             0.0             1.0
#
#        col_tOWnWxYe_1  col_SqEqFZsM_1  col_nCzVgxgY_1  col_JMNvdasy_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_OMtioXZZ_8  col_OMtioXZZ_10  col_nEsgxvAq_11  col_NGOnRdqc_1  \
# id
# 46107             0.0              0.0              0.0             1.0
# 82739             0.0              0.0              0.0             1.0
#
#        col_PXtHzrqw_1  col_WbxAxHul_1  col_LrDrWRjC_1  col_nGMEgWyl_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_yeHQSlwg_8  col_TiwRslOh_15  col_VtcDnwsf_1  col_mnIQKNOM_1  \
# id
# 46107             0.0              0.0             1.0             1.0
# 82739             0.0              0.0             1.0             1.0
#
#        col_GYTJWlaF_1  col_fsXLyyco_1  col_MOIscfCf_1  col_UjuNwfjv_3  \
# id
# 46107             1.0             1.0             1.0             0.0
# 82739             1.0             1.0             1.0             0.0
#
#        col_lTAXSTys_1  col_dAaIakDk_1  col_enTUTSQi_1  col_lybuQXPm_1  \
# id
# 46107             1.0             1.0             1.0             1.0
# 82739             1.0             1.0             1.0             1.0
#
#        col_gwhBRami_1  col_vRIvQXtC_3  col_jxSUvflR_1  col_HfOrdgBo_1  \
# id
# 46107             1.0             0.0             1.0             1.0
# 82739             1.0             0.0             1.0             1.0
#
#        col_tHFrzjai_5  col_CbzSWtkF_1  col_NqPjMmKP_1  col_CpqWSQcW_1  \
# id
# 46107             0.0             1.0             1.0             1.0
# 82739             0.0             1.0             1.0             1.0
#
#        col_vRIvQXtC_0  col_BMmgMRvd_0  col_zkbPtFyO_0  sum_columns      mean
# id
# 46107             1.0             1.0             1.0        314.0  0.000124
# 82739             1.0             1.0             1.0        230.0  0.000091
#
# [2 rows x 502 columns]

# %%
test = df_c[len(a_train):]

# %% [markdown]
# ##### Standard Scalar processing

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
scaler = MinMaxScaler()
scaler.fit(df_c)

train_data_scaled = scaler.transform(train)
test_data_scaled = scaler.transform(test)

# %%
from sklearn import model_selection
from sklearn.metrics import log_loss

#from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from xgboost import XGBClassifier

test_size = 0.33

seed = 7

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(train, y, test_size=test_size, random_state=seed)

#model = LogisticRegression()
model = RandomForestClassifier(n_estimators=10, random_state=0)
# model = XGBClassifier(max_depth=3, learning_rate=0.5, n_estimators=50, 
#                       silent=True, objective='binary:logistic',  
#                       gamma=0, min_child_weight=1, max_delta_step=1, 
#                       subsample=1, colsample_bytree=1, colsample_bylevel=1, 
#                       reg_alpha=0, reg_lambda=1, scale_pos_weight= 1, 
#                       base_score= 0.3)

#model =  GaussianProcessClassifier(1.0 * RBF(1.0))
model.fit(X_train, Y_train)

y_pred = model.predict_proba(X_test)

log_loss(Y_test, y_pred)

#print("f1_score: {}".format(f1_score(, average='micro')))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac570133b050> in <module>()
#      20 seed = 7
#      21
# ---> 22 X_train, X_test, Y_train, Y_test = model_selection.train_test_split(train, y, test_size=test_size, random_state=seed)
#      23
#      24 #model = LogisticRegression()
#
# NameError: name 'train' is not defined

# %%
#k-fold 

# num_instances = len(train)
# seed = 7

# kfold = model_selection.KFold(n_splits=5, random_state=seed)
# #model = LogisticRegression()
# model = XGBClassifier(max_depth=3, n_estimators=300, learning_rate=0.05, objective= "binary:logistic",min_child_weight = 1,scale_pos_weight = 1)


# model_selection.cross_val_score(model, train, y, cv=kfold, scoring='neg_log_loss').mean()

# %%
model.fit(train_data_scaled,y)
# Out:
# XGBClassifier(base_score=0.3, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.4, max_delta_step=1, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=50, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
a_preds = model.predict_proba(test_data_scaled)

# %%
def make_country_sub(preds, test_feat, country):
    # make sure we code the country correctly
    country_codes = ['A', 'B', 'C']
    
    # get just the poor probabilities
    country_sub = pd.DataFrame(data=preds[:, 1],  # proba p=1
                               columns=['poor'], 
                               index=test_feat.index)

    
    # add the country code for joining later
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
# convert preds to data frames
a_sub = make_country_sub(a_preds, a_test, 'A')

# %%
a_sub.to_csv("a_sub_6.csv")

# %%
# b_sub = pd.read_csv("b_sub.csv")

# %%
# b_sub = b_sub.set_index("id")

# %%
b_sub
# Out:
#       country      poor
# id
# 9135        B  0.035659
# 117         B  0.064033
# 29085       B  0.008225
# 55442       B  0.028141
# 29281       B  0.008137
# 63854       B  0.003112
# 87565       B  0.020042
# 64033       B  0.007160
# 395         B  0.009856
# 64544       B  0.029994
# 66639       B  0.083347
# 8102        B  0.012897
# 60204       B  0.354505
# 14800       B  0.266207
# 3254        B  0.024141
# 92365       B  0.002075
# 93034       B  0.066377
# 71941       B  0.064178
# 3649        B  0.083612
# 87286       B  0.013091
# 37584       B  0.279285
# 93445       B  0.081678
# 92873       B  0.033308
# 95767       B  0.004783
# 85656       B  0.076861
# 53963       B  0.022831
# 96140       B  0.109399
# 9833        B  0.063132
# 15852       B  0.013782
# 38703       B  0.018011
# 40541       B  0.002910
# 11159       B  0.011968
# 25303       B  0.004485
# 26206       B  0.021666
# 57805       B  0.036606
# 3091        B  0.304903
# 60085       B  0.010571
# 22917       B  0.004944
# 60823       B  0.011524
# 28459       B  0.022172
# 84905       B  0.005933
# 64211       B  0.037355
# 89937       B  0.020663
# 63777       B  0.065821
# 80118       B  0.024281
# 60349       B  0.014754
# 20591       B  0.002451
# 6049        B  0.034550
# 46303       B  0.034343
# 15377       B  0.032933
# 54737       B  0.098781
# 94306       B  0.018310
# 41586       B  0.026367
# 73365       B  0.454604
# 8022        B  0.001439
# 90940       B  0.038053
# 85068       B  0.025310
# 77750       B  0.014716
# 14092       B  0.003656
# 58714       B  0.035036
# 22202       B  0.035610
# 85467       B  0.020890
# 42493       B  0.033979
# 5207        B  0.007072
# 73604       B  0.016003
# 66781       B  0.012445
# 99801       B  0.142069
# 38525       B  0.004603
# 70201       B  0.012707
# 36381       B  0.003013
# 89792       B  0.108956
# 63025       B  0.195050
# 14133       B  0.025864
# 80496       B  0.050175
# 36166       B  0.042539
# 30626       B  0.013437
# 74906       B  0.069186
# 29532       B  0.014350
# 85839       B  0.029493
# 30103       B  0.028124
# 49964       B  0.005012
# 88410       B  0.035755
# 26794       B  0.129105
# 78070       B  0.038717
# 96802       B  0.013293
# 55615       B  0.352163
# 42382       B  0.004808
# 45506       B  0.038500
# 16963       B  0.012253
# 27452       B  0.026936
# 44221       B  0.014070
# 15712       B  0.007919
# 55561       B  0.042218
# 86841       B  0.010014
# 24333       B  0.028441
# 3092        B  0.016224
# 36013       B  0.106979
# 51583       B  0.007818
# 75343       B  0.017594
# 77160       B  0.015091
# 69734       B  0.042997
# 65303       B  0.018254
# 45834       B  0.013117
# 80366       B  0.032160
# 71375       B  0.076323
# 35744       B  0.036337
# 46099       B  0.006167
# 30519       B  0.013344
# 64794       B  0.091222
# 33971       B  0.004598
# 28104       B  0.046966
# 52739       B  0.051552
#
# [1604 rows x 2 columns]

# %%
c_sub = pd.read_csv("c_sub.csv")

# %%
C_sub = c_sub.set_index("id")

# %%
c_sub.tail()
# Out:
#          id country      poor
# 3182   6775       C  0.000034
# 3183  88300       C  0.000013
# 3184  35424       C  0.000176
# 3185  81668       C  0.000035
# 3186  98377       C  0.000068

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
#submission = submission.drop("id", axis = 1)

# %%
submission.shape
# Out:
# (8832, 3)

# %%
submission.to_csv('submission_X_G_tr2.csv')

# %%
submission.tail()
# Out:
#      country       id      poor
# 3182       C   6775.0  0.000034
# 3183       C  88300.0  0.000013
# 3184       C  35424.0  0.000176
# 3185       C  81668.0  0.000035
# 3186       C  98377.0  0.000068
