# %%
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
a_sub = pd.read_csv("a_sub_1.csv")

# %%
a_sub.shape
# Out:
# (4041, 4)

# %%
b_sub = pd.read_csv("b_sub_1.csv")
b_sub.shape
# Out:
# (1604, 4)

# %%
c_sub = pd.read_csv("c_sub_1.csv")
c_sub
# Out:
#       Unnamed: 0     id country      mean
# 0              0   6211       C  0.152242
# 1              1  77549       C  0.150067
# 2              2  34834       C  0.149581
# 3              3  74650       C  0.149027
# 4              4  65375       C  0.150694
# 5              5  68425       C  0.149723
# 6              6   6142       C  0.150667
# 7              7  95572       C  0.151038
# 8              8  73658       C  0.150117
# 9              9  31069       C  0.151377
# 10            10   9024       C  0.150686
# 11            11  27893       C  0.151529
# 12            12  74166       C  0.151051
# 13            13  47343       C  0.150388
# 14            14  21254       C  0.150657
# 15            15  64173       C  0.150287
# 16            16  76702       C  0.149681
# 17            17  70905       C  0.151520
# 18            18  59402       C  0.149705
# 19            19   3184       C  0.151838
# 20            20  60940       C  0.151748
# 21            21   5321       C  0.152196
# 22            22  53921       C  0.150956
# 23            23  22329       C  0.151482
# 24            24  64979       C  0.151557
# 25            25  62337       C  0.149308
# 26            26  28357       C  0.150907
# 27            27  94493       C  0.151696
# 28            28  67078       C  0.150376
# 29            29  15625       C  0.150457
# 30            30  92784       C  0.150944
# 31            31  89328       C  0.150162
# 32            32  40556       C  0.149911
# 33            33  43770       C  0.150041
# 34            34  71745       C  0.150056
# 35            35  90045       C  0.150098
# 36            36  79335       C  0.150740
# 37            37  17909       C  0.151173
# 38            38  36803       C       NaN
# 39            39  72962       C       NaN
# 40            40  46015       C       NaN
# 41            41   3995       C       NaN
# 42            42  85194       C       NaN
# 43            43  41992       C       NaN
# 44            44    602       C       NaN
# 45            45  13092       C       NaN
# 46            46  89172       C       NaN
# 47            47  78886       C       NaN
# 48            48  17546       C       NaN
# 49            49  25937       C       NaN
# 50            50  92159       C       NaN
# 51            51  84509       C       NaN
# 52            52  15136       C       NaN
# 53            53  14157       C       NaN
# 54            54  49185       C       NaN
# 55            55  45307       C       NaN
# 56            56  42239       C       NaN
# 57            57  76311       C       NaN
# 58            58   9311       C       NaN
# 59            59  27146       C       NaN
# 60            60  52338       C       NaN
# 61            61  70341       C       NaN
# 62            62  65457       C       NaN
# 63            63  54121       C       NaN
# 64            64  35786       C       NaN
# 65            65  87786       C       NaN
# 66            66  88819       C       NaN
# 67            67   6143       C       NaN
# 68            68  90762       C       NaN
# 69            69  61057       C       NaN
# 70            70  11848       C       NaN
# 71            71   9083       C       NaN
# 72            72  55716       C       NaN
# 73            73  54366       C       NaN
# 74            74   1120       C       NaN
# 75            75  97659       C       NaN
# 76            76  90036       C       NaN
# 77            77  66777       C       NaN
# 78            78  55925       C       NaN
# 79            79  25890       C       NaN
# 80            80  35122       C       NaN
# 81            81  75936       C       NaN
# 82            82  56267       C       NaN
# 83            83  19797       C       NaN
# 84            84  47430       C       NaN
# 85            85   3881       C       NaN
# 86            86  70509       C       NaN
# 87            87  94943       C       NaN
# 88            88  12598       C       NaN
# 89            89   1453       C       NaN
# 90            90  56238       C       NaN
# 91            91   3982       C       NaN
# 92            92  33829       C       NaN
# 93            93  89082       C       NaN
# 94            94  19233       C       NaN
# 95            95  24425       C       NaN
# 96            96  29839       C       NaN
# 97            97  27882       C       NaN
# 98            98  30268       C       NaN
# 99            99   5884       C       NaN
# 100          100  56862       C       NaN
# 101          101  45255       C       NaN
# 102          102  25616       C       NaN
# 103          103   4110       C       NaN
# 104          104  76875       C       NaN
# 105          105  85032       C       NaN
# 106          106   3001       C       NaN
# 107          107  39933       C       NaN
# 108          108  90245       C       NaN
# 109          109  34358       C       NaN
# 110          110  94041       C       NaN
# 111          111  24548       C       NaN
# 112          112  37852       C       NaN
# 113          113  54094       C       NaN
# 114          114  85968       C       NaN
# 115          115  63083       C       NaN
# 116          116   9513       C       NaN
# 117          117  78457       C       NaN
# 118          118  63337       C       NaN
# 119          119  62703       C       NaN
# 120          120  42488       C       NaN
# 121          121   5186       C       NaN
# 122          122  15091       C       NaN
# 123          123   7661       C       NaN
# 124          124  47899       C       NaN
# 125          125  78995       C       NaN
# 126          126  76672       C       NaN
# 127          127  25428       C       NaN
# 128          128  19844       C       NaN
# 129          129  91719       C       NaN
# 130          130  44442       C       NaN
# 131          131  88876       C       NaN
# 132          132  14416       C       NaN
# 133          133  79708       C       NaN
# 134          134  71281       C       NaN
# 135          135  65448       C       NaN
# 136          136  90672       C       NaN
# 137          137  95949       C       NaN
# 138          138  90886       C       NaN
# 139          139  85676       C       NaN
# 140          140  33273       C       NaN
# 141          141  70697       C       NaN
# 142          142  29101       C       NaN
# 143          143  62431       C       NaN
# 144          144  52242       C       NaN
# 145          145  45093       C       NaN
# 146          146  35018       C       NaN
# 147          147  30792       C       NaN
# 148          148  39546       C       NaN
# 149          149  21870       C       NaN
# 150          150  32975       C       NaN
# 151          151  92018       C       NaN
# 152          152  80666       C       NaN
# 153          153  25843       C       NaN
# 154          154  99486       C       NaN
# 155          155  41512       C       NaN
# 156          156  24253       C       NaN
# 157          157  46358       C       NaN
# 158          158  52505       C       NaN
# 159          159  79901       C       NaN
# 160          160  22446       C       NaN
# 161          161  57997       C       NaN
# 162          162  26433       C       NaN
# 163          163  97560       C       NaN
# 164          164  52035       C       NaN
# 165          165  85389       C       NaN
# 166          166  60733       C       NaN
# 167          167  16015       C       NaN
# 168          168  37058       C       NaN
# 169          169  44143       C       NaN
# 170          170   8607       C       NaN
# 171          171  88527       C       NaN
# 172          172  70824       C       NaN
# 173          173  99845       C       NaN
# 174          174  45600       C       NaN
# 175          175  64487       C       NaN
# 176          176  60529       C       NaN
# 177          177  84101       C       NaN
# 178          178  36188       C       NaN
# 179          179  98371       C       NaN
# 180          180  10766       C       NaN
# 181          181  46597       C       NaN
# 182          182  62417       C       NaN
# 183          183  68907       C       NaN
# 184          184  49641       C       NaN
# 185          185  99350       C       NaN
# 186          186  14154       C       NaN
# 187          187  34520       C       NaN
# 188          188  40238       C       NaN
# 189          189  35105       C       NaN
# 190          190  31113       C       NaN
# 191          191  76542       C       NaN
# 192          192  41483       C       NaN
# 193          193  66005       C       NaN
# 194          194  12783       C       NaN
# 195          195  58448       C       NaN
# 196          196  63398       C       NaN
# 197          197  97435       C       NaN
# 198          198  36978       C       NaN
# 199          199  58931       C       NaN
# 200          200  76597       C       NaN
# 201          201  41131       C       NaN
# 202          202  42757       C       NaN
# 203          203  89904       C       NaN
# 204          204  61925       C       NaN
# 205          205  42948       C       NaN
# 206          206  48616       C       NaN
# 207          207  37981       C       NaN
# 208          208  24212       C       NaN
# 209          209  71821       C       NaN
# 210          210  20460       C       NaN
# 211          211  72436       C       NaN
# 212          212  48372       C       NaN
# 213          213   4643       C       NaN
# 214          214   3744       C       NaN
# 215          215  22280       C       NaN
# 216          216  39860       C       NaN
# 217          217  31095       C       NaN
# 218          218   4889       C       NaN
# 219          219  56147       C       NaN
# 220          220    692       C       NaN
# 221          221  74933       C       NaN
# 222          222  70832       C       NaN
# 223          223  83874       C       NaN
# 224          224  20145       C       NaN
# 225          225  33215       C       NaN
# 226          226  64512       C       NaN
# 227          227  78604       C       NaN
# 228          228  45733       C       NaN
# 229          229  54754       C       NaN
# 230          230  84722       C       NaN
# 231          231   8303       C       NaN
# 232          232  19707       C       NaN
# 233          233  74219       C       NaN
# 234          234  47448       C       NaN
# 235          235  81803       C       NaN
# 236          236  71373       C       NaN
# 237          237  87167       C       NaN
# 238          238  11932       C       NaN
# 239          239  77129       C       NaN
# 240          240  75818       C       NaN
# 241          241   3277       C       NaN
# 242          242  63696       C       NaN
# 243          243  36929       C       NaN
# 244          244  88381       C       NaN
# 245          245   8869       C       NaN
# 246          246   7856       C       NaN
# 247          247  76501       C       NaN
# 248          248  45256       C       NaN
# 249          249  83072       C       NaN
# ...          ...    ...     ...       ...
# 2937        2937  79581       C       NaN
# 2938        2938  81631       C       NaN
# 2939        2939   8134       C       NaN
# 2940        2940   8497       C       NaN
# 2941        2941  90958       C       NaN
# 2942        2942  87117       C       NaN
# 2943        2943  70634       C       NaN
# 2944        2944  41054       C       NaN
# 2945        2945  11211       C       NaN
# 2946        2946  75170       C       NaN
# 2947        2947  38474       C       NaN
# 2948        2948   7703       C       NaN
# 2949        2949  68992       C       NaN
# 2950        2950   1111       C       NaN
# 2951        2951  48704       C       NaN
# 2952        2952  72616       C       NaN
# 2953        2953  92505       C       NaN
# 2954        2954  34182       C       NaN
# 2955        2955  47916       C       NaN
# 2956        2956  71702       C       NaN
# 2957        2957  75932       C       NaN
# 2958        2958  72513       C       NaN
# 2959        2959  43776       C       NaN
# 2960        2960  84621       C       NaN
# 2961        2961  52181       C       NaN
# 2962        2962  76855       C       NaN
# 2963        2963  56448       C       NaN
# 2964        2964  67641       C       NaN
# 2965        2965     38       C       NaN
# 2966        2966  95822       C       NaN
# 2967        2967  41720       C       NaN
# 2968        2968  31612       C       NaN
# 2969        2969  16647       C       NaN
# 2970        2970   4190       C       NaN
# 2971        2971  11702       C       NaN
# 2972        2972  15026       C       NaN
# 2973        2973  17575       C       NaN
# 2974        2974  38557       C       NaN
# 2975        2975  73605       C       NaN
# 2976        2976  11114       C       NaN
# 2977        2977  24877       C       NaN
# 2978        2978  21921       C       NaN
# 2979        2979  83267       C       NaN
# 2980        2980  86962       C       NaN
# 2981        2981  69241       C       NaN
# 2982        2982  14447       C       NaN
# 2983        2983  43091       C       NaN
# 2984        2984    183       C       NaN
# 2985        2985  93332       C       NaN
# 2986        2986  65363       C       NaN
# 2987        2987  66340       C       NaN
# 2988        2988  79021       C       NaN
# 2989        2989  51785       C       NaN
# 2990        2990  29419       C       NaN
# 2991        2991  36989       C       NaN
# 2992        2992  32329       C       NaN
# 2993        2993  23170       C       NaN
# 2994        2994  79426       C       NaN
# 2995        2995  74621       C       NaN
# 2996        2996  70361       C       NaN
# 2997        2997  31596       C       NaN
# 2998        2998   7540       C       NaN
# 2999        2999  41261       C       NaN
# 3000        3000  53331       C       NaN
# 3001        3001  59445       C       NaN
# 3002        3002   9244       C       NaN
# 3003        3003  48100       C       NaN
# 3004        3004  87312       C       NaN
# 3005        3005  61074       C       NaN
# 3006        3006  72527       C       NaN
# 3007        3007   3632       C       NaN
# 3008        3008  56445       C       NaN
# 3009        3009  71508       C       NaN
# 3010        3010  96477       C       NaN
# 3011        3011  81914       C       NaN
# 3012        3012  81643       C       NaN
# 3013        3013  14656       C       NaN
# 3014        3014  13503       C       NaN
# 3015        3015   8684       C       NaN
# 3016        3016  60040       C       NaN
# 3017        3017  94861       C       NaN
# 3018        3018  12595       C       NaN
# 3019        3019   5121       C       NaN
# 3020        3020  20441       C       NaN
# 3021        3021  20865       C       NaN
# 3022        3022  19508       C       NaN
# 3023        3023  96234       C       NaN
# 3024        3024  79043       C       NaN
# 3025        3025  72491       C       NaN
# 3026        3026  39493       C       NaN
# 3027        3027  89353       C       NaN
# 3028        3028  11310       C       NaN
# 3029        3029  26009       C       NaN
# 3030        3030  90274       C       NaN
# 3031        3031  60568       C       NaN
# 3032        3032  32319       C       NaN
# 3033        3033  67793       C       NaN
# 3034        3034  23393       C       NaN
# 3035        3035  93527       C       NaN
# 3036        3036  72809       C       NaN
# 3037        3037  63298       C       NaN
# 3038        3038  14325       C       NaN
# 3039        3039  42669       C       NaN
# 3040        3040   7300       C       NaN
# 3041        3041  21614       C       NaN
# 3042        3042  50221       C       NaN
# 3043        3043  49673       C       NaN
# 3044        3044  31970       C       NaN
# 3045        3045  23817       C       NaN
# 3046        3046    430       C       NaN
# 3047        3047  63454       C       NaN
# 3048        3048  56968       C       NaN
# 3049        3049  82131       C       NaN
# 3050        3050  96634       C       NaN
# 3051        3051  66893       C       NaN
# 3052        3052  22350       C       NaN
# 3053        3053  65938       C       NaN
# 3054        3054  64276       C       NaN
# 3055        3055  57937       C       NaN
# 3056        3056  21771       C       NaN
# 3057        3057   6144       C       NaN
# 3058        3058  23525       C       NaN
# 3059        3059  32092       C       NaN
# 3060        3060  51504       C       NaN
# 3061        3061  33525       C       NaN
# 3062        3062  82851       C       NaN
# 3063        3063  90510       C       NaN
# 3064        3064  66562       C       NaN
# 3065        3065  83298       C       NaN
# 3066        3066  13545       C       NaN
# 3067        3067   2226       C       NaN
# 3068        3068  15840       C       NaN
# 3069        3069  37765       C       NaN
# 3070        3070   2945       C       NaN
# 3071        3071  20579       C       NaN
# 3072        3072  20073       C       NaN
# 3073        3073  45142       C       NaN
# 3074        3074  79375       C       NaN
# 3075        3075  70325       C       NaN
# 3076        3076  86449       C       NaN
# 3077        3077  99943       C       NaN
# 3078        3078   1011       C       NaN
# 3079        3079  90187       C       NaN
# 3080        3080  92264       C       NaN
# 3081        3081  95059       C       NaN
# 3082        3082   5187       C       NaN
# 3083        3083  67982       C       NaN
# 3084        3084  93981       C       NaN
# 3085        3085   2170       C       NaN
# 3086        3086  10791       C       NaN
# 3087        3087  82179       C       NaN
# 3088        3088  73337       C       NaN
# 3089        3089  13605       C       NaN
# 3090        3090  94346       C       NaN
# 3091        3091  28261       C       NaN
# 3092        3092  68306       C       NaN
# 3093        3093   4229       C       NaN
# 3094        3094   8125       C       NaN
# 3095        3095   6973       C       NaN
# 3096        3096   9015       C       NaN
# 3097        3097  81763       C       NaN
# 3098        3098  54133       C       NaN
# 3099        3099  96065       C       NaN
# 3100        3100  43781       C       NaN
# 3101        3101  64513       C       NaN
# 3102        3102  13993       C       NaN
# 3103        3103  32812       C       NaN
# 3104        3104  86788       C       NaN
# 3105        3105  87986       C       NaN
# 3106        3106  94519       C       NaN
# 3107        3107  51838       C       NaN
# 3108        3108  44911       C       NaN
# 3109        3109   8143       C       NaN
# 3110        3110  29080       C       NaN
# 3111        3111   9454       C       NaN
# 3112        3112  26062       C       NaN
# 3113        3113  12246       C       NaN
# 3114        3114  81510       C       NaN
# 3115        3115  11563       C       NaN
# 3116        3116  92206       C       NaN
# 3117        3117  76896       C       NaN
# 3118        3118  84855       C       NaN
# 3119        3119  24183       C       NaN
# 3120        3120  89763       C       NaN
# 3121        3121  68638       C       NaN
# 3122        3122  34419       C       NaN
# 3123        3123  51721       C       NaN
# 3124        3124  94158       C       NaN
# 3125        3125  49841       C       NaN
# 3126        3126  13991       C       NaN
# 3127        3127  20000       C       NaN
# 3128        3128  51909       C       NaN
# 3129        3129   7716       C       NaN
# 3130        3130  91966       C       NaN
# 3131        3131  48839       C       NaN
# 3132        3132  50681       C       NaN
# 3133        3133  34822       C       NaN
# 3134        3134  79746       C       NaN
# 3135        3135  12985       C       NaN
# 3136        3136  70373       C       NaN
# 3137        3137  23167       C       NaN
# 3138        3138  65818       C       NaN
# 3139        3139  14343       C       NaN
# 3140        3140  92063       C       NaN
# 3141        3141  28090       C       NaN
# 3142        3142  31434       C       NaN
# 3143        3143  41958       C       NaN
# 3144        3144  14236       C       NaN
# 3145        3145  31374       C       NaN
# 3146        3146  49380       C       NaN
# 3147        3147  75595       C       NaN
# 3148        3148  89113       C       NaN
# 3149        3149  28383       C       NaN
# 3150        3150  56900       C       NaN
# 3151        3151  50720       C       NaN
# 3152        3152  17696       C       NaN
# 3153        3153  33986       C       NaN
# 3154        3154  80676       C       NaN
# 3155        3155  21035       C       NaN
# 3156        3156  16281       C       NaN
# 3157        3157  51512       C       NaN
# 3158        3158  52284       C       NaN
# 3159        3159   2281       C       NaN
# 3160        3160  50913       C       NaN
# 3161        3161  37129       C       NaN
# 3162        3162  64351       C       NaN
# 3163        3163  89726       C       NaN
# 3164        3164  91465       C       NaN
# 3165        3165  30676       C       NaN
# 3166        3166  98493       C       NaN
# 3167        3167  88475       C       NaN
# 3168        3168  96504       C       NaN
# 3169        3169  51200       C       NaN
# 3170        3170  94912       C       NaN
# 3171        3171   7588       C       NaN
# 3172        3172  35668       C       NaN
# 3173        3173   6137       C       NaN
# 3174        3174  87474       C       NaN
# 3175        3175  99992       C       NaN
# 3176        3176   8544       C       NaN
# 3177        3177  63899       C       NaN
# 3178        3178  72790       C       NaN
# 3179        3179   1588       C       NaN
# 3180        3180    254       C       NaN
# 3181        3181  68171       C       NaN
# 3182        3182   6775       C       NaN
# 3183        3183  88300       C       NaN
# 3184        3184  35424       C       NaN
# 3185        3185  81668       C       NaN
# 3186        3186  98377       C       NaN
#
# [3187 rows x 4 columns]

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
submission.to_csv('submission_40.csv')

# %%
pwd
# Out:
# 'C:\\Users\\piush\\Desktop\\World Bank Poverty\\Country_wise'
