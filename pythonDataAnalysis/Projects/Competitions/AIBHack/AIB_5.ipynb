# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def warn(*args, **kwargs): pass
import warnings
warnings.warn = warn

from sklearn.preprocessing import LabelEncoder
from sklearn.cross_validation import StratifiedShuffleSplit

# %%
train_1 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\training.txt", sep="\t", encoding = 'iso-8859-1')
test_1 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\testing.txt", sep="\t", encoding = 'iso-8859-1')

# %%
def is_outlier(points, thresh = 3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
df_train = df_train[pd.notnull(df_train['EnergyRatingCat'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-79bf3f1be17c> in <module>()
# ----> 1 df_train = df_train[pd.notnull(df_train['EnergyRatingCat'])]
#
# NameError: name 'df_train' is not defined

# %%
df_train = train_1.ix[:, train_1.columns != 'EnergyRatingCat']

# %%
df = df_train.append(test_1, ignore_index = True)

# %%
df.head()
# Out:
#    AreaAperture  AreaFirstFloor  AreaGroundFloor  AreaSecondFloor  \
# 0           NaN            0.00            33.69              0.0
# 1           NaN           50.67            96.77              0.0
# 2           NaN            0.00           104.84              0.0
# 3           NaN           42.90            52.41              0.0
# 4           NaN          110.66           173.21              0.0
#
#         AssessmentDate  AvgDoorU  AvgFloorU  AvgRoofU  AvgWallU  AvgWindowU  \
# 0  Jun 17 2011 12:00AM      3.00       0.61      2.30      2.10        2.71
# 1  Apr 14 2015 12:00AM      3.96       0.94      0.75      2.01        2.63
# 2  Jun 28 2012 12:00AM      0.00       0.68      0.13      0.38        2.81
# 3  Nov 25 2015 12:00AM      3.03       0.34      0.26      0.55        2.80
# 4  May 30 2016 12:00AM      3.01       0.41      0.26      0.55        3.10
#
#         ...       TotWindowArea                 Type  Underfloor  UpgradeHES  \
# 0       ...                7.08    Mid-terrace house         NO          0.0
# 1       ...               37.00       Detached house         NO          0.0
# 2       ...               17.90       Detached house         NO          0.0
# 3       ...               13.92  Semi-detached house         NO          1.0
# 4       ...               42.86       Detached house         NO          0.0
#
#       VentMethod VolWaterStorage                   WallStructure WarmAir  \
# 0  Natural vent.           110.0  Masonry                            NO
# 1  Natural vent.            95.0  Masonry                            NO
# 2  Natural vent.           110.0  Masonry                            NO
# 3  Natural vent.            95.0  Masonry                            NO
# 4  Natural vent.           144.0  Masonry                            NO
#
#       Year ZeroLossCollEff
# 0  Y1890.0             NaN
# 1  Y1901.0             NaN
# 2  Y1968.0             NaN
# 3  Y2002.0             NaN
# 4  Y2002.0             NaN
#
# [5 rows x 141 columns]

# %%
cats = []
for col in df.columns.values:
    if df[col].dtype == 'object':
        cats.append(col)

# %%
df_cont = df.drop(cats, axis=1)
df_cat = df[cats]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from scipy.stats import skew

for col in df_cont.columns.values:
    if np.sum(df_cont[col].isnull()) > 50:
        #print("Removing Column: {}".format(col))
        df_cont = df_cont.drop(col, axis = 1)
    elif np.sum(df_cont[col].isnull()) > 0:
        #print("Replacing with Median: {}".format(col))
        median = df_cont[col].median()
        idx = np.where(df_cont[col].isnull())[0]
        df_cont[col].iloc[idx] = median
        
        
        outliers = np.where(is_outlier(df_cont[col]))
        df_cont[col].iloc[outliers] = median
        
               
        if skew(df_cont[col]) > 0.75:
            #print("Skewness Detected: {}".format(col))
            df_cont[col] = np.log(df_cont[col])
            df_cont[col] = df_cont[col].apply(lambda x: 0 if x == -np.inf else x)
        
        df_cont[col] = Normalizer().fit_transform(df_cont[col].reshape(1,-1))[0]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:22: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: divide by zero encountered in true_divide
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: invalid value encountered in true_divide
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: RuntimeWarning: invalid value encountered in greater

# %%
for col in df_cat.columns.values:
    if np.sum(df_cat[col].isnull()) > 50:
        df_cat = df_cat.drop(col, axis = 1)
        continue
    elif np.sum(df_cat[col].isnull()) > 0:
        df_cat[col] = df_cat[col].fillna('MIA')
        
    df_cat[col] = LabelEncoder().fit_transform(df_cat[col])
    
    num_cols = df_cat[col].max()
    for i in range(num_cols):
        col_name = col + '_' + str(i)
        df_cat[col_name] = df_cat[col].apply(lambda x: 1 if x == i else 0)
        
    df_cat = df_cat.drop(col, axis = 1)

# %% [markdown]
# ##### Merge Numeric and Categorical Datasets and Create Training and Testing Data

# %%
target = train_1['EnergyRatingCat']

# %%
target = train_1[pd.notnull(train_1['EnergyRatingCat'])]
target = train_1['EnergyRatingCat']
target = target.dropna()
target = target.values

# %%
train_1.head()
# Out:
#    BuildingID       County                 Type     Year       RatingType  \
# 0      190835  Co. Wexford    Mid-terrace house  Y1890.0  Existing
# 1      523113    Co. Clare       Detached house  Y1901.0  Existing
# 2      271393    Co. Kerry       Detached house  Y1968.0  Existing
# 3      585961     Co. Cork  Semi-detached house  Y2002.0  Existing
# 4      624083    Co. Laois       Detached house  Y2002.0  Existing
#
#   EnergyRatingCat  EnergyRatingCont GroundFloorArea  AvgWallU  AvgRoofU  \
# 0              F             418.42     52.04 sq. m      2.10      2.30
# 1              G             520.35    147.44 sq. m      2.01      0.75
# 2              D2            281.33    104.84 sq. m      0.38      0.13
# 3              C2            188.17     95.31 sq. m      0.55      0.26
# 4              B3            134.95    283.87 sq. m      0.55      0.26
#
#         ...        EffSecondHeatGenPlant  PercSecondHeat  FuelTypeThirdBoiler  \
# 0       ...                          NaN             NaN                  NaN
# 1       ...                          NaN             NaN                  NaN
# 2       ...                          NaN             NaN                  NaN
# 3       ...                          NaN             NaN                  NaN
# 4       ...                          NaN             NaN                  NaN
#
#    EffThirdHeatGenPlant  PercThirdHeat  HeatingSystemSolarSpace  \
# 0                   NaN            NaN                      NaN
# 1                   NaN            NaN                      NaN
# 2                   NaN            NaN                      NaN
# 3                   NaN            NaN                      NaN
# 4                   NaN            NaN                      NaN
#
#    TotPrimaryEnergyFac  TotCO2Emissions  PrimaryEnergySecondarySpace  \
# 0                  NaN              NaN                        0.000
# 1                  NaN              NaN                     7144.838
# 2                  NaN              NaN                     2127.347
# 3                  NaN              NaN                     2771.886
# 4                  NaN              NaN                        0.000
#
#   EnergyMainWater
# 0       2335.6809
# 1       4470.0759
# 2       5837.4729
# 3       3769.6248
# 4       5296.5828
#
# [5 rows x 141 columns]

# %%
target = train_1['EnergyRatingCat'].replace({"Nan" : -1, "A1" : 15 , "A3" : 13, "A2" : 14,"B1" : 12, "B2" : 11, "B3" : 10, "C1" : 9 , "C2" : 8, "C3" : 7,"D1" : 6, "D2" : 5,"D3" : 4, "E1" : 3 , "E2" : 2 , "F " : 1 ,"G " : 0})

# %%
target = train_1['EnergyRatingCat'].replace({"Nan" : -1, "A1" : 15 , "A3" : 13, "A2" : 14,"B1" : 12, "B2" : 11, "B3" : 10, "C1" : 9 , "C2" : 8, "C3" : 7,"D1" : 6, "D2" : 5,"D3" : 4, "E1" : 3 , "E2" : 2 , "F" : 1 ,"G" : 0})

# %%
train = df_cont[:train_1.shape[0]]
test = df_cont[train_1.shape[0]:]

# %%
# sk learn import 
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cross_validation import KFold, cross_val_score
from sklearn.metrics import make_scorer
from sklearn.grid_search import GridSearchCV
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, VotingClassifier, RandomForestClassifier, AdaBoostClassifier

# %%
print (str(len(train))+" rows for training set")
print (str(len(test))+" rows for test set")
print (str(len(target))+" rows for test set")
# Out:
# 464514 rows for training set
# 159262 rows for test set
# 464514 rows for test set

# %%
train = df_cont[:train_1.shape[0]]
test = df_cont[train_1.shape[0]:]

# %%
from sklearn.preprocessing import LabelEncoder
class_le = LabelEncoder()
target = class_le.fit_transform(train[target].values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-2c84cc29cea8> in <module>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 class_le = LabelEncoder()
# ----> 3 target = class_le.fit_transform(train[target].values)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2049         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2050             # either boolean or fancy integer index
# -> 2051             return self._getitem_array(key)
#    2052         elif isinstance(key, DataFrame):
#    2053             return self._getitem_frame(key)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2093             return self.take(indexer, axis=0, convert=False)
#    2094         else:
# -> 2095             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2096             return self.take(indexer, axis=1, convert=True)
#    2097
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1227                 mask = check == -1
#    1228                 if mask.any():
# -> 1229                     raise KeyError('%s not in index' % objarr[mask])
#    1230
#    1231                 return _values_from_object(indexer)
#
# KeyError: "['F ' 'G ' 'D2' ..., 'C2' 'B3' 'D1'] not in index"

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train, target)
#predictions = model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e83ec7a54a60> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.fit(train, target)
#       4 #predictions = model.predict(test)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1172
#    1173         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1174                          order="C")
#    1175         check_classification_targets(y)
#    1176         self.classes_ = np.unique(y)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     525     else:
#     526         y = column_or_1d(y, warn=True)
# --> 527         _assert_all_finite(y)
#     528     if y_numeric and y.dtype.kind == 'O':
#     529         y = y.astype(np.float64)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
df_cont = df_cont.drop('BuildingID',axis =1)

# %%
df_cont = df_cont.dropna()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7285bae11ca3> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.fit(train, target)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1172
#    1173         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1174                          order="C")
#    1175         check_classification_targets(y)
#    1176         self.classes_ = np.unique(y)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     525     else:
#     526         y = column_or_1d(y, warn=True)
# --> 527         _assert_all_finite(y)
#     528     if y_numeric and y.dtype.kind == 'O':
#     529         y = y.astype(np.float64)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
df_cont.columns
# Out:
# Index(['AreaFirstFloor', 'AreaGroundFloor', 'AreaSecondFloor', 'AvgDoorU',
#        'AvgFloorU', 'AvgRoofU', 'AvgWindowU', 'BridgingFac', 'BuildingReg',
#        'ControlCat', 'DistLoss', 'EnergyMainWater', 'ExposedRoofArea',
#        'ExposedWallArea', 'HeightFirstFloor', 'HeightGroundFloor',
#        'LightingCO2', 'LightingEnergy', 'MainWaterEnergy', 'NCHPumps',
#        'NChimneys', 'NFansVents', 'NGasFans', 'NOpenFlues', 'NShelteredSides',
#        'NStoreys', 'PercDraughtStripped', 'PermTestResult',
#        'PrimaryLightingEnergy', 'PrimaryPumpsFansEnergy', 'PumpsAndFansCO2',
#        'PumpsAndFansEnergy', 'ResponseCat', 'RoofAreaRoom', 'SecWaterCO2',
#        'SecWaterEnergy', 'SecWaterPrimaryEnergy', 'TempAdj', 'TotDoorArea',
#        'TotFloorArea', 'TotWindowArea', 'UpgradeHES'],
#       dtype='object')

# %%
df = df[np.isfinite(df['AreaFirstFloor'])]

# %%
df.dropna(how='any',axis = 0)
# Out:
# Empty DataFrame
# Columns: [AreaAperture, AreaFirstFloor, AreaGroundFloor, AreaSecondFloor, AssessmentDate, AvgDoorU, AvgFloorU, AvgRoofU, AvgWallU, AvgWindowU, BoilerStat1, BoilerStat2, BridgingFac, BuildingID, BuildingReg, Charging, CollHeatLoss, Combi, CombiCylinder, ConsFirstEnerComment, ConsSecondEnerComment, ConsThirdEnerComment, ControlCat, County, CylinderThermostat, DLobby, DeclaredLoss, DedicatedSolarVol, DistLoss, EffFirstHeatGenPlant, EffSecondHeatGenPlant, EffThirdHeatGenPlant, EnergyMainWater, EnergyRatingCat, EnergyRatingCont, ExposedRoofArea, ExposedWallArea, FirstEnerType, FirstEnerTypeDescr, FuelTypeFirstBoiler, FuelTypeSecondBoiler, FuelTypeThirdBoiler, GroundFloorArea, HWInsulationThickness, HWInsulationType, HeatingSystemSolarSpace, HeightFirstFloor, HeightGroundFloor, KeepHot, LargestRoofType, LargestRoofTypeArea, LightingCO2, LightingEnergy, MainSHAdj, MainSHEfficiency, MainSHFuel, MainSpaceCO2, MainSpaceEnergy, MainWHAdj, MainWHEfficiency, MainWHFuel, MainWaterCO2, MainWaterEnergy, MassCat, NCHPumps, NChimneys, NFansVents, NGasFans, NOpenFlues, NShelteredSides, NStoreys, OilPumpIn, Overshading, PercDraughtStripped, PercFirstHeat, PercLivingArea, PercLowEnergy, PercSecondHeat, PercThirdHeat, PermTest, PermTestResult, PrimaryEnergySecondarySpace, PrimaryLightingEnergy, PrimaryLoss, PrimaryMainSpaceEnergy, PrimaryMainWaterEnergy, PrimaryPumpsFansEnergy, ProdFirstEnerComment, ProdFirstEnerConvFac, ProdFirstEnerDelivered, ProdSecondEnerComment, ProdSecondEnerConvFac, ProdSecondEnerDelivered, ProdThirdEnerComment, ProdThirdEnerConvFac, ProdThirdEnerDelivered, PumpsAndFansCO2, PumpsAndFansEnergy, RatingPurpose, RatingType, ...]
# Index: []
#
# [0 rows x 141 columns]

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAIN SET INFORMATION")
print ("========================\n")

for column in train:
    # Find all the unique feature values
    uniq = train[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 17):
        print("~~Listing up to 17 unique values~~")
    print (uniq[0:17])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAIN SET INFORMATION
# ========================
#
# 'AreaFirstFloor' has 13991 unique values
# ~~Listing up to 17 unique values~~
# [ 0.          0.00141651  0.0011993   0.00309358  0.00116547  0.00168517
#   0.00211988  0.00097398  0.00157978  0.00131867  0.00075732  0.00011182
#   0.00125856  0.00115988  0.00186464  0.00104219  0.00164128]
#
# -----------------------------------------------------------------------
#
# 'AreaGroundFloor' has 15108 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00108386  0.00140901  0.00143369  0.00122004  0.00126503  0.00140137
#   0.00133517  0.0012038   0.00148939  0.00128343  0.00135037  0.00136858
#   0.0010942   0.00123146  0.00121833  0.0011396   0.00132875]
#
# -----------------------------------------------------------------------
#
# 'AreaSecondFloor' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'AvgDoorU' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'AvgFloorU' has 112 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00152266  0.00234639  0.00169739  0.0008487   0.00102343  0.00059908
#   0.          0.00109831  0.00142281  0.00172235  0.00159755  0.00104839
#   0.00127304  0.00119816  0.0018222   0.00089862  0.00209678]
#
# -----------------------------------------------------------------------
#
# 'AvgRoofU' has 69 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00106827  0.00063125  0.0012625   0.          0.00072837  0.00194231
#   0.00237933  0.0021851   0.00121394  0.00160241  0.00296202  0.00179664
#   0.00131106  0.00111683  0.00082548  0.00262212  0.00097116]
#
# -----------------------------------------------------------------------
#
# 'AvgWindowU' has 363 unique values
# ~~Listing up to 17 unique values~~
# [ 0.0012666   0.00122921  0.00131334  0.00130866  0.00144888  0.00085063
#   0.00126193  0.00158909  0.00128529  0.00138344  0.00152833  0.00155637
#   0.00103291  0.00070574  0.00143486  0.00121519  0.00109834]
#
# -----------------------------------------------------------------------
#
# 'BridgingFac' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'BuildingID' has 464514 unique values
# ~~Listing up to 17 unique values~~
# [190835 523113 271393 585961 624083  30231 350444 592196 365924 303002
#  634938 300824 449623 379988  68299 597104 163298]
#
# -----------------------------------------------------------------------
#
# 'BuildingReg' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'ControlCat' has 4 unique values
# [ 0.00066511  0.00199532  0.00133021  0.        ]
#
# -----------------------------------------------------------------------
#
# 'DistLoss' has 5951 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00118083  0.0013224   0.00127439  0.00126103  0.00126058  0.00125968
#   0.00123015  0.00125524  0.00129988  0.00129879  0.00123688  0.00133433
#   0.00121828  0.0013332   0.00126678  0.00136925  0.00115087]
#
# -----------------------------------------------------------------------
#
# 'EnergyMainWater' has 331067 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00076452  0.00146315  0.00191073  0.00123388  0.00173368  0.00069627
#   0.00119417  0.00167572  0.00190368  0.00123045  0.00166718  0.00133511
#   0.00096808  0.00155127  0.0013485   0.00118607  0.00101721]
#
# -----------------------------------------------------------------------
#
# 'ExposedRoofArea' has 15952 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00130177  0.00166373  0.00186751  0.00076418  0.001023    0.
#   0.00088459  0.00223748  0.00110797  0.00142504  0.00151178  0.0006206
#   0.00102816  0.00092841  0.00071911  0.00194161  0.00080194]
#
# -----------------------------------------------------------------------
#
# 'ExposedWallArea' has 23037 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00101192  0.00155214  0.00131865  0.00130316  0.00128783  0.00107898
#   0.0011685   0.0013419   0.0013173   0.00133819  0.00130459  0.00148459
#   0.00124148  0.00122609  0.00131447  0.00146769  0.0009375 ]
#
# -----------------------------------------------------------------------
#
# 'HeightFirstFloor' has 207 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00124587  0.00122191  0.00126982  0.00130337  0.00131295  0.00128899
#   0.00136087  0.00126503  0.00127941  0.0012842   0.00115482  0.00117399
#   0.00133691  0.00088169  0.00132733  0.00125545  0.00129857]
#
# -----------------------------------------------------------------------
#
# 'HeightGroundFloor' has 51 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00113066  0.00125507  0.00123796  0.00124369  0.00127756  0.00133224
#   0.00126072  0.00132147  0.00123221  0.00124939  0.00129419  0.00133759
#   0.00134824  0.00138486  0.00136405  0.00132687  0.0012031 ]
#
# -----------------------------------------------------------------------
#
# 'LightingCO2' has 174775 unique values
# ~~Listing up to 17 unique values~~
# [ 0.0010757   0.00138406  0.00131431  0.00119056  0.00145189  0.00131097
#   0.00126631  0.00117999  0.00127594  0.00133129  0.0012488   0.00140648
#   0.00110375  0.00140478  0.00119718  0.0014282   0.00106022]
#
# -----------------------------------------------------------------------
#
# 'LightingEnergy' has 181537 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00108879  0.00137636  0.00131131  0.0011959   0.00143962  0.0013082
#   0.00126655  0.00118605  0.00127553  0.00132714  0.00125022  0.00139727
#   0.00111494  0.00139568  0.00120208  0.00141752  0.00107436]
#
# -----------------------------------------------------------------------
#
# 'MainWaterEnergy' has 331067 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00076452  0.00146315  0.00191073  0.00123388  0.00173368  0.00069627
#   0.00119417  0.00167572  0.00190368  0.00123045  0.00166718  0.00133511
#   0.00096808  0.00155127  0.0013485   0.00118607  0.00101721]
#
# -----------------------------------------------------------------------
#
# 'NCHPumps' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'NChimneys' has 6 unique values
# [ 0.          0.00315704  0.00631408  0.00500379  0.00816084  0.00733042]
#
# -----------------------------------------------------------------------
#
# 'NFansVents' has 8 unique values
# [ 0.0004156   0.          0.00207802  0.00124681  0.00290923  0.00083121
#   0.00249363  0.00166242]
#
# -----------------------------------------------------------------------
#
# 'NGasFans' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'NOpenFlues' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'NShelteredSides' has 5 unique values
# [ 0.00152406  0.          0.00050802  0.00101604  0.00203208]
#
# -----------------------------------------------------------------------
#
# 'NStoreys' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'PercDraughtStripped' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'PermTestResult' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'PrimaryLightingEnergy' has 181537 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00111255  0.00136223  0.00130575  0.00120555  0.00141716  0.00130305
#   0.00126689  0.001197    0.00127469  0.0013195   0.00125271  0.00138039
#   0.00113526  0.00137901  0.00121092  0.00139797  0.00110002]
#
# -----------------------------------------------------------------------
#
# 'PrimaryPumpsFansEnergy' has 2646 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00151877  0.00115559  0.00085844  0.00237721  0.          0.00257531
#   0.00181593  0.00029715  0.00066034  0.00124419  0.00201403  0.00145274
#   0.00261015  0.00245677  0.00171688  0.00278249  0.00280931]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansCO2' has 2640 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00151877  0.00115559  0.00085844  0.00237721  0.          0.00257531
#   0.00181593  0.00029715  0.00066034  0.00124419  0.00201403  0.00145274
#   0.00261015  0.00245678  0.00171688  0.00278249  0.00280931]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansEnergy' has 2646 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00151877  0.00115559  0.00085844  0.00237721  0.          0.00257531
#   0.00181593  0.00029715  0.00066034  0.00124419  0.00201403  0.00145274
#   0.00261015  0.00245678  0.00171688  0.00278249  0.00280931]
#
# -----------------------------------------------------------------------
#
# 'ResponseCat' has 1 unique values
# [ 0.00126615]
#
# -----------------------------------------------------------------------
#
# 'RoofAreaRoom' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'SecWaterCO2' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'SecWaterEnergy' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'SecWaterPrimaryEnergy' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'TempAdj' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
# 'TotDoorArea' has 952 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00080919  0.00234864  0.          0.00102629  0.00216706  0.00082893
#   0.00073025  0.00239995  0.0014605   0.00168549  0.00147629  0.0014526
#   0.00136181  0.00179996  0.00071051  0.00087235  0.0034144 ]
#
# -----------------------------------------------------------------------
#
# 'TotFloorArea' has 15121 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00061088  0.00175466  0.00190099  0.00095031  0.00103082  0.00171169
#   0.          0.00090154  0.00227759  0.00116736  0.00145058  0.00153889
#   0.00063173  0.00138966  0.00094505  0.0013523   0.00197642]
#
# -----------------------------------------------------------------------
#
# 'TotWindowArea' has 4547 unique values
# ~~Listing up to 17 unique values~~
# [ 0.00089334  0.0016481   0.00131669  0.00120191  0.00171521  0.00120939
#   0.00112066  0.00090102  0.0013581   0.00128529  0.00118248  0.00156142
#   0.00127479  0.00111909  0.00125128  0.00167026  0.00076376]
#
# -----------------------------------------------------------------------
#
# 'UpgradeHES' has 1 unique values
# [ 0.]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# []
#
#
# Features with non-numeric values:
# ['AreaFirstFloor', 'AreaGroundFloor', 'AvgFloorU', 'AvgRoofU', 'EnergyMainWater', 'ExposedRoofArea', 'ExposedWallArea', 'MainWaterEnergy', 'TotDoorArea', 'TotFloorArea', 'TotWindowArea']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
train = df[:train_1.shape[0]]
test = df[train_1.shape[0]:]

# %%
train
# Out:
#         AreaAperture  AreaFirstFloor  AreaGroundFloor  AreaSecondFloor  \
# 0                NaN            0.00            33.69             0.00
# 1                NaN           50.67            96.77             0.00
# 2                NaN            0.00           104.84             0.00
# 3                NaN           42.90            52.41             0.00
# 4                NaN          110.66           173.21             0.00
# 5                NaN            0.00            94.40             0.00
# 6                NaN            0.00            76.15             0.00
# 7                NaN           41.69            49.72             0.00
# 8                NaN            0.00           125.61             0.00
# 9                NaN           60.28            64.38             0.00
# 10               NaN            0.00            80.00             0.00
# 11             3.680           75.83            84.87             0.00
# 12               NaN           34.84            34.84             0.00
# 13               NaN           56.51            54.39            48.49
# 14               NaN           47.17            52.12             0.00
# 15               NaN           27.09           181.60             0.00
# 16               NaN            0.00            40.37             0.00
# 17               NaN            0.00            74.58             0.00
# 18               NaN            4.00           105.00             0.00
# 19               NaN           45.02            43.69             0.00
# 20               NaN           41.49            41.49             0.00
# 21               NaN           66.70            96.50             0.00
# 22               NaN           37.28            29.94             0.00
# 23               NaN           58.71            58.71             0.00
# 24               NaN           53.10            60.00             0.00
# 25               NaN           41.67            41.67             0.00
# 26               NaN           90.34           130.00            30.50
# 27               NaN           41.51            47.06             0.00
# 28               NaN           54.51            65.04             0.00
# 29               NaN            0.00            43.46             0.00
# ...              ...             ...              ...              ...
# 464496           NaN           42.86            42.86             0.00
# 464497           NaN           42.00            44.99             0.00
# 464498           NaN           84.02            18.59            59.05
# 464499           NaN            0.00            75.99             0.00
# 464500           NaN            0.00            87.78             0.00
# 464501           NaN            0.00           138.21             0.00
# 464502           NaN           44.68            42.39             0.00
# 464503           NaN           46.47            46.21             0.00
# 464504         4.640           45.81            66.40             0.00
# 464505           NaN           40.30            70.24             0.00
# 464506           NaN           46.80            56.00             0.00
# 464507           NaN            0.00           111.88             0.00
# 464508         2.791           61.94            61.94             0.00
# 464509           NaN           43.80            43.65             0.00
# 464510           NaN            0.00           126.92             0.00
# 464511           NaN           42.75            42.20             0.00
# 464512           NaN           40.09            39.00             0.00
# 464513           NaN           40.50            40.50             0.00
# 464514           NaN            0.00            74.00             0.00
# 464515           NaN           27.06            33.59             0.00
# 464516           NaN            0.00            38.30             0.00
# 464517           NaN            0.00            67.70             0.00
# 464518           NaN           81.81           113.54             0.00
# 464519           NaN           47.68            52.68             0.00
# 464520           NaN           44.04            63.19             0.00
# 464521           NaN           42.50            41.00             0.00
# 464522           NaN            0.00           144.19             0.00
# 464523           NaN           72.00            81.90             0.00
# 464524           NaN           76.10            77.24             0.00
# 464525           NaN           44.50             5.50            44.50
#
#              AssessmentDate  AvgDoorU  AvgFloorU  AvgRoofU  AvgWallU  \
# 0       Jun 17 2011 12:00AM      3.00       0.61      2.30      2.10
# 1       Apr 14 2015 12:00AM      3.96       0.94      0.75      2.01
# 2       Jun 28 2012 12:00AM      0.00       0.68      0.13      0.38
# 3       Nov 25 2015 12:00AM      3.03       0.34      0.26      0.55
# 4       May 30 2016 12:00AM      3.01       0.41      0.26      0.55
# 5       May 13 2009 12:00AM      3.00       0.24      0.00      0.34
# 6       Jun 29 2013 12:00AM      3.00       0.00      0.00      0.55
# 7       Jan 21 2016 12:00AM      3.11       0.44      0.15      0.55
# 8       Sep 10 2013 12:00AM      3.00       0.57      0.13      0.31
# 9       Dec 12 2012 12:00AM      3.00       0.44      0.40      0.55
# 10      Jun 27 2016 12:00AM      3.00       0.69      0.40      1.94
# 11      Nov 19 2012 12:00AM      3.00       0.64      0.49      1.09
# 12      Jul 29 2014 12:00AM      3.00       0.44      0.13      0.29
# 13      Nov  1 2013 12:00AM      3.00       0.42      0.45      0.58
# 14      Oct 30 2009 12:00AM      3.00       0.44      0.13       NaN
# 15      Feb 10 2016 12:00AM      3.00       0.51      0.72       NaN
# 16      Feb 28 2011 12:00AM      3.00       0.00      0.25       NaN
# 17      Apr 27 2009 12:00AM      1.31       0.48      0.00      0.57
# 18      Oct 13 2011 12:00AM      0.00       0.73      0.33      1.76
# 19      Jun 16 2016 12:00AM      3.00       0.36      0.13      0.30
# 20      Jan 12 2016 12:00AM      2.85       0.41      0.13      0.30
# 21      Sep  2 2014 12:00AM      4.69       0.64      0.61       NaN
# 22      Apr 28 2014 12:00AM      0.00       0.84      0.13      0.55
# 23      Oct 18 2016 12:00AM      3.00       0.70      0.37      1.25
# 24      Jun  4 2014 12:00AM      3.00       0.41      0.27      0.55
# 25      Sep  5 2014 12:00AM      1.96       0.48      0.13      0.35
# 26      Aug 20 2013 12:00AM      3.00       0.41      0.23      0.21
# 27      Dec 13 2013 12:00AM      3.07       0.64      0.17      0.60
# 28      May 27 2011 12:00AM      0.00       0.73      0.54      0.88
# 29      Feb  3 2010 12:00AM      1.36       0.37      0.00      0.31
# ...                     ...       ...        ...       ...       ...
# 464496  Jul 26 2011 12:00AM      0.00       0.57      0.68      1.10
# 464497  Oct 24 2013 12:00AM      2.90       0.47      0.15      0.32
# 464498  May  2 2013 12:00AM      3.00       0.53      1.66      1.40
# 464499  Oct 14 2016 12:00AM      3.00       0.94      2.30      1.99
# 464500  May  1 2014 12:00AM      3.00       0.64      0.20      0.28
# 464501  Jul 28 2015 12:00AM      3.00       0.42      0.15      0.27
# 464502  Aug 21 2013 12:00AM      3.00       0.45      0.13      0.30
# 464503  Sep 24 2009 12:00AM      3.00       0.65      0.43      1.93
# 464504  Aug 15 2013 12:00AM      0.00       0.53      0.20      0.59
# 464505  Jul  9 2010 12:00AM      0.00       0.41      0.13      0.31
# 464506  Nov 16 2012 12:00AM      3.00       0.85      0.71      2.40
# 464507  Feb 25 2013 12:00AM      3.00       0.44      0.18      0.55
# 464508  Jun 23 2015 12:00AM      0.79       0.13      0.10      0.16
# 464509  Oct 29 2014 12:00AM      0.00       0.65      2.30      2.20
# 464510  Apr 19 2014 12:00AM      2.96       0.54      0.26       NaN
# 464511  Jan  8 2011 12:00AM      3.00       0.70      0.16      0.27
# 464512  Mar  4 2013 12:00AM      3.00       0.49      0.13      0.27
# 464513  Apr 10 2014 12:00AM      0.00       0.44      0.40       NaN
# 464514  May 31 2010 12:00AM      3.00       0.00      0.00      0.61
# 464515  Nov 16 2012 12:00AM      2.78       0.52      0.33      1.25
# 464516  Nov 25 2011 12:00AM      0.00       0.00      0.00      0.55
# 464517  Aug 26 2016 12:00AM      1.36       0.00      0.00      0.33
# 464518  Dec 19 2014 12:00AM      3.00       0.57      0.33      0.37
# 464519  Sep 28 2016 12:00AM      3.00       0.41      0.40      0.55
# 464520  Nov 21 2015 12:00AM      3.00       0.57      0.40      0.25
# 464521  Sep 30 2009 12:00AM      3.00       0.20      0.00      0.23
# 464522  Aug 22 2012 12:00AM      3.00       0.41      0.36      0.55
# 464523  Aug 27 2012 12:00AM      3.05       0.44      0.27      0.54
# 464524  Aug 17 2013 12:00AM      3.00       0.44      0.38      0.49
# 464525  May 30 2016 12:00AM      0.00       0.60      0.27      0.55
#
#         AvgWindowU       ...       TotWindowArea                    Type  \
# 0             2.71       ...                7.08       Mid-terrace house
# 1             2.63       ...               37.00          Detached house
# 2             2.81       ...               17.90          Detached house
# 3             2.80       ...               13.92     Semi-detached house
# 4             3.10       ...               42.86          Detached house
# 5             1.82       ...               14.15  Ground-floor apartment
# 6             2.70       ...               11.65     Mid-floor apartment
# 7             3.40       ...                7.20    End of terrace house
# 8             4.80       ...               19.60          Detached house
# 9             2.96       ...               16.71     Semi-detached house
# 10            2.80       ...               13.34          Detached house
# 11            4.80       ...               30.60          Detached house
# 12            2.80       ...               16.33     Semi-detached house
# 13            3.27       ...               11.61       Mid-terrace house
# 14            2.80       ...               15.51     Semi-detached house
# 15            3.33       ...               38.84          Detached house
# 16            2.70       ...                5.33     Top-floor apartment
# 17            2.70       ...                7.39  Ground-floor apartment
# 18            4.80       ...               21.49                   House
# 19            3.10       ...               10.03       Mid-terrace house
# 20            2.21       ...               12.85     Semi-detached house
# 21            4.80       ...               22.91          Detached house
# 22            2.80       ...               12.36    End of terrace house
# 23            4.63       ...               15.51          Detached house
# 24            2.71       ...               12.44     Semi-detached house
# 25            2.70       ...               13.04       Mid-terrace house
# 26            1.51       ...               40.45          Detached house
# 27            3.40       ...               12.26     Semi-detached house
# 28            3.07       ...               16.34     Semi-detached house
# 29            2.60       ...                5.25     Mid-floor apartment
# ...            ...       ...                 ...                     ...
# 464496        2.70       ...               14.08     Semi-detached house
# 464497        2.30       ...               11.03     Semi-detached house
# 464498        2.10       ...               23.65    End of terrace house
# 464499        4.80       ...                8.17          Detached house
# 464500        2.72       ...               20.32          Detached house
# 464501        2.44       ...               32.01          Detached house
# 464502        2.80       ...               11.81     Semi-detached house
# 464503        2.80       ...               22.79     Semi-detached house
# 464504        2.87       ...               25.09     Semi-detached house
# 464505        2.88       ...               22.84     Semi-detached house
# 464506        3.40       ...               19.82     Semi-detached house
# 464507        1.90       ...               18.23          Detached house
# 464508        0.74       ...               18.07     Semi-detached house
# 464509        3.04       ...               17.01       Mid-terrace house
# 464510        2.70       ...               18.86          Detached house
# 464511        2.80       ...               17.95    End of terrace house
# 464512        1.65       ...               11.39       Mid-terrace house
# 464513        2.89       ...               14.08    End of terrace house
# 464514        1.50       ...               25.00               Apartment
# 464515        2.80       ...                4.66       Mid-terrace house
# 464516        2.80       ...                8.78     Mid-floor apartment
# 464517        2.00       ...               22.71     Mid-floor apartment
# 464518        3.13       ...               34.32          Detached house
# 464519        2.72       ...               13.10     Semi-detached house
# 464520        2.33       ...               16.72     Semi-detached house
# 464521        1.10       ...               20.50  Ground-floor apartment
# 464522        2.70       ...               35.13          Detached house
# 464523        3.21       ...               20.90          Detached house
# 464524        3.10       ...               15.56          Detached house
# 464525        2.20       ...               19.30              Maisonette
#
#         Underfloor  UpgradeHES                      VentMethod  \
# 0              NO          0.0                   Natural vent.
# 1              NO          0.0                   Natural vent.
# 2              NO          0.0                   Natural vent.
# 3              NO          1.0                   Natural vent.
# 4              NO          0.0                   Natural vent.
# 5              NO          0.0                   Natural vent.
# 6              NO          0.0                   Natural vent.
# 7              NO          0.0                   Natural vent.
# 8              NO          0.0                   Natural vent.
# 9              NO          0.0                   Natural vent.
# 10             NO          0.0                   Natural vent.
# 11             NO          1.0                   Natural vent.
# 12             NO          1.0                   Natural vent.
# 13             NO          0.0                   Natural vent.
# 14             NO          1.0                   Natural vent.
# 15             NO          0.0                   Natural vent.
# 16             NO          0.0                   Natural vent.
# 17             NO          0.0                   Natural vent.
# 18             NO          0.0                   Natural vent.
# 19             NO          1.0                   Natural vent.
# 20             NO          1.0                   Natural vent.
# 21             NO          0.0                   Natural vent.
# 22             NO          0.0                   Natural vent.
# 23             NO          0.0                   Natural vent.
# 24             NO          0.0                   Natural vent.
# 25             NO          0.0                   Natural vent.
# 26             NO          1.0                   Natural vent.
# 27             NO          0.0                   Natural vent.
# 28             NO          1.0                   Natural vent.
# 29             NO          0.0                   Natural vent.
# ...            ...         ...                             ...
# 464496         NO          0.0                   Natural vent.
# 464497         NO          0.0                   Natural vent.
# 464498         NO          0.0                   Natural vent.
# 464499         NO          0.0                   Natural vent.
# 464500         NO          0.0                   Natural vent.
# 464501         NO          1.0                   Natural vent.
# 464502         NO          0.0                   Natural vent.
# 464503         NO          0.0                   Natural vent.
# 464504         NO          1.0                   Natural vent.
# 464505         NO          1.0                   Natural vent.
# 464506         NO          0.0                   Natural vent.
# 464507         NO          1.0                   Natural vent.
# 464508         NO          0.0                   Natural vent.
# 464509         NO          0.0                   Natural vent.
# 464510         NO          0.0                   Natural vent.
# 464511         NO          1.0                   Natural vent.
# 464512         NO          0.0                   Natural vent.
# 464513         NO          0.0                   Natural vent.
# 464514         NO          0.0                   Natural vent.
# 464515         NO          0.0                   Natural vent.
# 464516         NO          0.0                   Natural vent.
# 464517         NO          0.0                   Natural vent.
# 464518         NO          1.0                   Natural vent.
# 464519         NO          0.0                   Natural vent.
# 464520         NO          1.0                   Natural vent.
# 464521         NO          0.0  Bal.whole mech.vent heat recvr
# 464522         NO          0.0                   Natural vent.
# 464523         NO          0.0                   Natural vent.
# 464524         NO          0.0                   Natural vent.
# 464525         NO          0.0                   Natural vent.
#
#        VolWaterStorage                   WallStructure WarmAir     Year  \
# 0                110.0  Masonry                            NO   Y1890.0
# 1                 95.0  Masonry                            NO   Y1901.0
# 2                110.0  Masonry                            NO   Y1968.0
# 3                 95.0  Masonry                            NO   Y2002.0
# 4                144.0  Masonry                            NO   Y2002.0
# 5                  0.0  Masonry                            NO   Y2007.0
# 6                  NaN  Masonry                            NO   Y2003.0
# 7                 95.0  Masonry                            NO   Y2000.0
# 8                100.0  Masonry                            NO   Y1989.0
# 9                120.0  Insulated Conctete Form            NO   Y2002.0
# 10                95.0  Masonry                            NO   Y1900.0
# 11               353.0  Masonry                            NO   Y1980.0
# 12               150.0  Masonry                            NO   Y2001.0
# 13               117.0  Masonry                            NO   Y1990.0
# 14               119.0  Masonry                            NO   Y2003.0
# 15               106.0  Masonry                            NO   Y1950.0
# 16                68.0  Masonry                            NO   Y2005.0
# 17                80.0  Masonry                            NO   Y1987.0
# 18                98.0  Masonry                            NO   Y1965.0
# 19                95.0  Masonry                            NO   Y2000.0
# 20                96.0  Masonry                            NO   Y1999.0
# 21                 NaN  Masonry                            NO   Y1980.0
# 22                90.0  Masonry                            NO   Y1974.0
# 23                84.0  Masonry                            NO   Y1954.0
# 24                98.0  Masonry                            NO   Y2004.0
# 25                96.0  Masonry                            NO   Y1986.0
# 26               300.0  Masonry                            NO   Y1998.0
# 27                72.0  Masonry                            NO   Y1992.0
# 28               200.0  Masonry                            NO   Y1932.0
# 29               110.0  Masonry                            NO   Y2006.0
# ...                ...                             ...     ...      ...
# 464496           140.0  Masonry                            NO   Y1980.0
# 464497            72.0  Masonry                            NO   Y2004.0
# 464498           200.0  Masonry                            NO   Y1890.0
# 464499             NaN  Masonry                            NO   Y1900.0
# 464500           120.0  Masonry                            NO   Y1980.0
# 464501           114.0  Masonry                            NO   Y2001.0
# 464502            85.0  Masonry                            NO   Y1999.0
# 464503           100.0  Masonry                            NO   Y1964.0
# 464504           200.0  Masonry                            NO   Y1975.0
# 464505            98.0  Masonry                            NO   Y1999.0
# 464506           155.0  Masonry                            NO   Y1960.0
# 464507           150.0  Masonry                            NO   Y2004.0
# 464508           246.0  Masonry                            NO   Y2015.0
# 464509           110.0  Masonry                            NO   Y1965.0
# 464510             NaN  Masonry                            NO   Y2001.0
# 464511           110.0  Masonry                            NO   Y1980.0
# 464512            64.0  Masonry                            NO   Y1984.0
# 464513           114.0  Masonry                            NO   Y2003.0
# 464514             0.0  Masonry                            NO   Y2007.0
# 464515           103.0  Masonry                            NO   Y1886.0
# 464516            95.0  Masonry                            NO   Y1999.0
# 464517            40.0  Insulated Conctete Form            NO   Y2005.0
# 464518            95.0  Masonry                            NO   Y1992.0
# 464519            95.0  Masonry                            NO   Y1999.0
# 464520            95.0  Masonry                            NO   Y1975.0
# 464521           144.0  Masonry                            YES  Y2009.0
# 464522           120.0  Timber or Steel Frame              NO   Y2001.0
# 464523           113.0  Masonry                            NO   Y2003.0
# 464524           106.0  Masonry                            NO   Y1920.0
# 464525            84.0  Timber or Steel Frame              NO   Y2004.0
#
#        ZeroLossCollEff
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11               0.780
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# ...                ...
# 464496             NaN
# 464497             NaN
# 464498             NaN
# 464499             NaN
# 464500             NaN
# 464501             NaN
# 464502             NaN
# 464503             NaN
# 464504           0.776
# 464505             NaN
# 464506             NaN
# 464507             NaN
# 464508           0.734
# 464509             NaN
# 464510             NaN
# 464511             NaN
# 464512             NaN
# 464513             NaN
# 464514             NaN
# 464515             NaN
# 464516             NaN
# 464517             NaN
# 464518             NaN
# 464519             NaN
# 464520             NaN
# 464521             NaN
# 464522             NaN
# 464523             NaN
# 464524             NaN
# 464525             NaN
#
# [464514 rows x 141 columns]

# %%
target.isnull().values.any()
# Out:
# True

# %%
target = target.dropna()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-7285bae11ca3> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.fit(train, target)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1172
#    1173         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1174                          order="C")
#    1175         check_classification_targets(y)
#    1176         self.classes_ = np.unique(y)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'Y2004.0'

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAIN SET INFORMATION")
print ("========================\n")

for column in train:
    # Find all the unique feature values
    uniq = train[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 17):
        print("~~Listing up to 17 unique values~~")
    print (uniq[0:17])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAIN SET INFORMATION
# ========================
#
# 'AreaFirstFloor' has 14998 unique values
# ~~Listing up to 17 unique values~~
# [   0.     50.67   42.9   110.66   41.69   60.28   75.83   34.84   56.51
#    47.17   27.09    4.     45.02   41.49   66.7    37.28   58.71]
#
# -----------------------------------------------------------------------
#
# 'AreaGroundFloor' has 22629 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4    76.15   49.72  125.61
#    64.38   80.     84.87   34.84   54.39   52.12  181.6    40.37]
#
# -----------------------------------------------------------------------
#
# 'AreaSecondFloor' has 6553 unique values
# ~~Listing up to 17 unique values~~
# [  0.    48.49  30.5   84.72  48.25  23.    52.44  11.76  59.74  20.83
#   15.45  52.93  47.8   37.64  44.27  32.15  60.9 ]
#
# -----------------------------------------------------------------------
#
# 'AvgDoorU' has 549 unique values
# ~~Listing up to 17 unique values~~
# [ 3.    3.96  0.    3.03  3.01  3.11  1.31  2.85  4.69  1.96  3.07  1.36
#   2.7   1.52  2.75  3.38  3.45]
#
# -----------------------------------------------------------------------
#
# 'AvgFloorU' has 140 unique values
# ~~Listing up to 17 unique values~~
# [ 0.61  0.94  0.68  0.34  0.41  0.24  0.    0.44  0.57  0.69  0.64  0.42
#   0.51  0.48  0.73  0.36  0.84]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# ['AreaFirstFloor has 12 missing', 'AreaGroundFloor has 12 missing', 'AreaSecondFloor has 12 missing', 'AvgDoorU has 12 missing', 'AvgFloorU has 12 missing']
#
#
# Features with non-numeric values:
# []
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7285bae11ca3> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 model.fit(train, target)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1172
#    1173         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1174                          order="C")
#    1175         check_classification_targets(y)
#    1176         self.classes_ = np.unique(y)
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'Y2004.0'
