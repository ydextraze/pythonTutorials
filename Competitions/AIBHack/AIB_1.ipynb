# %%
import sys
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Supress unnecessary warnings so that presentation looks clean
import warnings
warnings.filterwarnings('ignore')

# sk learn import 
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cross_validation import KFold, cross_val_score
from sklearn.metrics import make_scorer
from sklearn.grid_search import GridSearchCV
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, VotingClassifier, RandomForestClassifier, AdaBoostClassifier

sns.set_style('whitegrid')
pd.set_option('display.max_columns', None) # display all columns

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import Imputer

from scipy.stats import skew

# %%
train = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\training.txt", sep="\t", encoding = 'iso-8859-1')
test = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\testing.txt", sep="\t", encoding = 'iso-8859-1')

# %%
# Out:
#    BuildingID       County               Type     Year       RatingType  \
# 0      190835  Co. Wexford  Mid-terrace house  Y1890.0  Existing
# 1      523113    Co. Clare     Detached house  Y1901.0  Existing
#
#   EnergyRatingCat  EnergyRatingCont GroundFloorArea  AvgWallU  AvgRoofU  \
# 0              F             418.42     52.04 sq. m      2.10      2.30
# 1              G             520.35    147.44 sq. m      2.01      0.75
#
#         ...        EffSecondHeatGenPlant  PercSecondHeat  FuelTypeThirdBoiler  \
# 0       ...                          NaN             NaN                  NaN
# 1       ...                          NaN             NaN                  NaN
#
#    EffThirdHeatGenPlant  PercThirdHeat  HeatingSystemSolarSpace  \
# 0                   NaN            NaN                      NaN
# 1                   NaN            NaN                      NaN
#
#    TotPrimaryEnergyFac  TotCO2Emissions  PrimaryEnergySecondarySpace  \
# 0                  NaN              NaN                        0.000
# 1                  NaN              NaN                     7144.838
#
#   EnergyMainWater
# 0       2335.6809
# 1       4470.0759
#
# [2 rows x 141 columns]

# %%
print ('data loaded')
print (str(len(train))+" rows for training set")
print (str(len(test))+" rows for test set")
print(train.columns)
print(test.columns)
# Out:
# data loaded
# 464514 rows for training set
# 159262 rows for test set
# Index(['BuildingID', 'County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat',
#        'EnergyRatingCont', 'GroundFloorArea', 'AvgWallU', 'AvgRoofU',
#        ...
#        'EffSecondHeatGenPlant', 'PercSecondHeat', 'FuelTypeThirdBoiler',
#        'EffThirdHeatGenPlant', 'PercThirdHeat', 'HeatingSystemSolarSpace',
#        'TotPrimaryEnergyFac', 'TotCO2Emissions', 'PrimaryEnergySecondarySpace',
#        'EnergyMainWater'],
#       dtype='object', length=141)
# Index(['BuildingID', 'County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat',
#        'EnergyRatingCont', 'GroundFloorArea', 'AvgWallU', 'AvgRoofU',
#        ...
#        'EffSecondHeatGenPlant', 'PercSecondHeat', 'FuelTypeThirdBoiler',
#        'EffThirdHeatGenPlant', 'PercThirdHeat', 'HeatingSystemSolarSpace',
#        'TotPrimaryEnergyFac', 'TotCO2Emissions', 'PrimaryEnergySecondarySpace',
#        'EnergyMainWater'],
#       dtype='object', length=141)

# %%
print ("\n\n---------------------")
print ("TRAIN SET INFORMATION")
print ("---------------------")
print ("Shape of data set:", train.shape, "\n")
print ("Column Headers:", list(train.columns.values), "\n")
print (train.dtypes)
# Out:
# ---------------------
# TRAIN SET INFORMATION
# ---------------------
# Shape of data set: (464514, 141)
#
# Column Headers: ['BuildingID', 'County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat', 'EnergyRatingCont', 'GroundFloorArea', 'AvgWallU', 'AvgRoofU', 'AvgFloorU', 'AvgWindowU', 'AvgDoorU', 'ExposedWallArea', 'ExposedRoofArea', 'TotFloorArea', 'TotWindowArea', 'TotDoorArea', 'NStoreys', 'MainSHFuel', 'MainWHFuel', 'MainSHEfficiency', 'SharedMPRN', 'BuildingReg', 'MainSHAdj', 'SecSHFrac', 'SecSHEfficiency', 'MainWHEfficiency', 'MainWHAdj', 'SecSHFuel', 'SecWHFuel', 'NChimneys', 'NOpenFlues', 'NFansVents', 'DLobby', 'VentMethod', 'WallStructure', 'SuspWoodFloor', 'PercDraughtStripped', 'NShelteredSides', 'PermTest', 'PermTestResult', 'TempAdj', 'ControlCat', 'ResponseCat', 'NCHPumps', 'BoilerStat1', 'BoilerStat2', 'OilPumpIn', 'NGasFans', 'WarmAir', 'Underfloor', 'DistLoss', 'StorageLoss', 'DeclaredLoss', 'SolarWaterHeating', 'SummerElectricImm', 'Combi', 'KeepHot', 'VolWaterStorage', 'TempFac', 'TempFacMult', 'HWInsulationType', 'HWInsulationThickness', 'PrimaryLoss', 'AreaAperture', 'ZeroLossCollEff', 'CollHeatLoss', 'SolarRadiation', 'Overshading', 'CylinderThermostat', 'DedicatedSolarVol', 'CombiCylinder', 'SolarPumpElect', 'SolarPumpPower', 'Charging', 'SolarHeatFrac', 'LightingEnergy', 'PumpsAndFansEnergy', 'MainWaterEnergy', 'MainSpaceEnergy', 'PrimaryLightingEnergy', 'PrimaryPumpsFansEnergy', 'PrimaryMainWaterEnergy', 'PrimaryMainSpaceEnergy', 'LightingCO2', 'PumpsAndFansCO2', 'MainWaterCO2', 'MainSpaceCO2', 'AreaGroundFloor', 'HeightGroundFloor', 'AreaFirstFloor', 'HeightFirstFloor', 'AreaSecondFloor', 'BridgingFac', 'MassCat', 'LargestRoofTypeArea', 'LargestRoofType', 'PercLowEnergy', 'TotEnergy', 'SecSpaceEnergy', 'SecWaterEnergy', 'PercLivingArea', 'SecSpaceCO2', 'SecWaterCO2', 'SecSpacePrimaryEnergy', 'SecWaterPrimaryEnergy', 'UpgradeHES', 'RoofAreaRoom', 'RatingPurpose', 'AssessmentDate', 'FirstEnerType', 'FirstEnerTypeDescr', 'ProdFirstEnerComment', 'ProdFirstEnerDelivered', 'ProdFirstEnerConvFac', 'ConsFirstEnerComment', 'SecondEnerTypeDescr', 'ProdSecondEnerComment', 'ProdSecondEnerDelivered', 'ProdSecondEnerConvFac', 'ConsSecondEnerComment', 'ThirdEnerTypeDescr', 'ProdThirdEnerComment', 'ProdThirdEnerDelivered', 'ProdThirdEnerConvFac', 'ConsThirdEnerComment', 'FuelTypeFirstBoiler', 'EffFirstHeatGenPlant', 'PercFirstHeat', 'FuelTypeSecondBoiler', 'EffSecondHeatGenPlant', 'PercSecondHeat', 'FuelTypeThirdBoiler', 'EffThirdHeatGenPlant', 'PercThirdHeat', 'HeatingSystemSolarSpace', 'TotPrimaryEnergyFac', 'TotCO2Emissions', 'PrimaryEnergySecondarySpace', 'EnergyMainWater']
#
# BuildingID                       int64
# County                          object
# Type                            object
# Year                            object
# RatingType                      object
# EnergyRatingCat                 object
# EnergyRatingCont               float64
# GroundFloorArea                 object
# AvgWallU                       float64
# AvgRoofU                       float64
# AvgFloorU                      float64
# AvgWindowU                     float64
# AvgDoorU                       float64
# ExposedWallArea                float64
# ExposedRoofArea                float64
# TotFloorArea                   float64
# TotWindowArea                  float64
# TotDoorArea                    float64
# NStoreys                       float64
# MainSHFuel                      object
# MainWHFuel                      object
# MainSHEfficiency               float64
# SharedMPRN                      object
# BuildingReg                    float64
# MainSHAdj                      float64
# SecSHFrac                      float64
# SecSHEfficiency                float64
# MainWHEfficiency               float64
# MainWHAdj                      float64
# SecSHFuel                      float64
#                                 ...
# FirstEnerType                   object
# FirstEnerTypeDescr              object
# ProdFirstEnerComment            object
# ProdFirstEnerDelivered          object
# ProdFirstEnerConvFac            object
# ConsFirstEnerComment            object
# SecondEnerTypeDescr             object
# ProdSecondEnerComment           object
# ProdSecondEnerDelivered         object
# ProdSecondEnerConvFac           object
# ConsSecondEnerComment           object
# ThirdEnerTypeDescr              object
# ProdThirdEnerComment            object
# ProdThirdEnerDelivered          object
# ProdThirdEnerConvFac            object
# ConsThirdEnerComment            object
# FuelTypeFirstBoiler            float64
# EffFirstHeatGenPlant           float64
# PercFirstHeat                  float64
# FuelTypeSecondBoiler           float64
# EffSecondHeatGenPlant          float64
# PercSecondHeat                 float64
# FuelTypeThirdBoiler            float64
# EffThirdHeatGenPlant           float64
# PercThirdHeat                  float64
# HeatingSystemSolarSpace        float64
# TotPrimaryEnergyFac            float64
# TotCO2Emissions                float64
# PrimaryEnergySecondarySpace    float64
# EnergyMainWater                float64
# dtype: object

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAIN SET INFORMATION")
print ("========================\n")

for column in train:
    # Find all the unique feature values
    uniq = train[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 17):
        print("~~Listing up to 17 unique values~~")
    print (uniq[0:17])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAIN SET INFORMATION
# ========================
#
# 'BuildingID' has 464514 unique values
# ~~Listing up to 17 unique values~~
# [190835 523113 271393 585961 624083  30231 350444 592196 365924 303002
#  634938 300824 449623 379988  68299 597104 163298]
#
# -----------------------------------------------------------------------
#
# 'County' has 56 unique values
# ~~Listing up to 17 unique values~~
# ['Co. Wexford' 'Co. Clare' 'Co. Kerry' 'Co. Cork' 'Co. Laois' 'Cork City'
#  'Co. Carlow' 'Co. Offaly' 'Co. Donegal' 'Co. Meath' 'Co. Cavan' 'Dublin 4'
#  'Co. Galway' 'Dublin 14' 'Dublin 6' 'Co. Roscommon' 'Dublin 17']
#
# -----------------------------------------------------------------------
#
# 'Type' has 12 unique values
# ['Mid-terrace house' 'Detached house' 'Semi-detached house'
#  'Ground-floor apartment' 'Mid-floor apartment' 'End of terrace house'
#  'Top-floor apartment' 'House' 'Maisonette' 'Apartment' 'Basement Dwelling'
#  nan]
#
# -----------------------------------------------------------------------
#
# 'Year' has 249 unique values
# ~~Listing up to 17 unique values~~
# ['Y1890.0' 'Y1901.0' 'Y1968.0' 'Y2002.0' 'Y2007.0' 'Y2003.0' 'Y2000.0'
#  'Y1989.0' 'Y1900.0' 'Y1980.0' 'Y2001.0' 'Y1990.0' 'Y1950.0' 'Y2005.0'
#  'Y1987.0' 'Y1965.0' 'Y1999.0']
#
# -----------------------------------------------------------------------
#
# 'RatingType' has 4 unique values
# ['Existing       ' 'Final          ' 'Provisional    ' nan]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCat' has 16 unique values
# ['F ' 'G ' 'D2' 'C2' 'B3' 'B2' 'C1' 'E2' 'C3' 'E1' 'D1' 'B1' 'A3' 'A2' 'A1'
#  nan]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCont' has 62484 unique values
# ~~Listing up to 17 unique values~~
# [ 418.42  520.35  281.33  188.17  134.95  108.77  156.65  369.22  287.42
#   219.05  747.86  329.39  242.38  171.26  191.7   394.69  175.42]
#
# -----------------------------------------------------------------------
#
# 'GroundFloorArea' has 30695 unique values
# ~~Listing up to 17 unique values~~
# ['52.04 sq. m' '147.44 sq. m' '104.84 sq. m' '95.31 sq. m' '283.87 sq. m'
#  '94.4 sq. m' '76.15 sq. m' '91.41 sq. m' '125.61 sq. m' '124.66 sq. m'
#  '80.0 sq. m' '160.7 sq. m' '69.68 sq. m' '159.39 sq. m' '99.29 sq. m'
#  '208.69 sq. m' '40.37 sq. m']
#
# -----------------------------------------------------------------------
#
# 'AvgWallU' has 271 unique values
# ~~Listing up to 17 unique values~~
# [ 2.1   2.01  0.38  0.55  0.34  0.31  1.94  1.09  0.29  0.58   nan  0.57
#   1.76  0.3   1.25  0.35  0.21]
#
# -----------------------------------------------------------------------
#
# 'AvgRoofU' has 280 unique values
# ~~Listing up to 17 unique values~~
# [ 2.3   0.75  0.13  0.26  0.    0.15  0.4   0.49  0.45  0.72  0.25  0.33
#   0.61  0.37  0.27  0.23  0.17]
#
# -----------------------------------------------------------------------
#
# 'AvgFloorU' has 140 unique values
# ~~Listing up to 17 unique values~~
# [ 0.61  0.94  0.68  0.34  0.41  0.24  0.    0.44  0.57  0.69  0.64  0.42
#   0.51  0.48  0.73  0.36  0.84]
#
# -----------------------------------------------------------------------
#
# 'AvgWindowU' has 529 unique values
# ~~Listing up to 17 unique values~~
# [ 2.71  2.63  2.81  2.8   3.1   1.82  2.7   3.4   4.8   2.96  3.27  3.33
#   2.21  4.63  1.51  3.07  2.6 ]
#
# -----------------------------------------------------------------------
#
# 'AvgDoorU' has 549 unique values
# ~~Listing up to 17 unique values~~
# [ 3.    3.96  0.    3.03  3.01  3.11  1.31  2.85  4.69  1.96  3.07  1.36
#   2.7   1.52  2.75  3.38  3.45]
#
# -----------------------------------------------------------------------
#
# 'ExposedWallArea' has 28005 unique values
# ~~Listing up to 17 unique values~~
# [  32.78  211.22   94.41   89.5   254.15   41.31   56.25  102.29   93.97
#   100.99   89.94  167.32   72.35   68.61   93.06  157.85   25.36]
#
# -----------------------------------------------------------------------
#
# 'ExposedRoofArea' has 25837 unique values
# ~~Listing up to 17 unique values~~
# [  73.08   93.4   104.84   42.9   173.21    0.     49.66  125.61   62.2
#    80.     84.87   34.84   57.72   52.12  181.68   40.37  109.  ]
#
# -----------------------------------------------------------------------
#
# 'TotFloorArea' has 22950 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4     0.     49.72  125.61
#    64.38   80.     84.87   34.84   76.64   52.12  181.68   74.58]
#
# -----------------------------------------------------------------------
#
# 'TotWindowArea' has 9163 unique values
# ~~Listing up to 17 unique values~~
# [  7.08  37.    17.9   13.92  42.86  14.15  11.65   7.2   19.6   16.71
#   13.34  30.6   16.33  11.61  15.51  38.84   5.33]
#
# -----------------------------------------------------------------------
#
# 'TotDoorArea' has 1694 unique values
# ~~Listing up to 17 unique values~~
# [ 2.05  5.95  0.    2.6   5.49  2.1   1.85  6.08  3.7   4.27  3.74  3.68
#   3.45  4.56  1.8   2.21  8.65]
#
# -----------------------------------------------------------------------
#
# 'NStoreys' has 10 unique values
# [  2.   1.   3.   4.   5.   0.  nan   6.   8.   7.]
#
# -----------------------------------------------------------------------
#
# 'MainSHFuel' has 20 unique values
# ~~Listing up to 17 unique values~~
# ['Heating Oil                   ' 'Mains Gas                     '
#  'Solid Multi-Fuel              ' 'Electricity                   '
#  'Bulk LPG (propane or butane)  ' 'Bottled LPG                   '
#  'Sod Peat                      ' 'Wood Pellets (bulk supply for '
#  'Manufactured Smokeless Fuel   ' nan 'House Coal                    '
#  'Wood Logs                     ' 'Wood Pellets (in bags for seco'
#  'Peat Briquettes               ' 'Electricity - Standard Domesti'
#  'Anthracite                    ' 'Electricity - Off-peak Night-R']
#
# -----------------------------------------------------------------------
#
# 'MainWHFuel' has 21 unique values
# ~~Listing up to 17 unique values~~
# ['Heating Oil                   ' 'Mains Gas                     '
#  'Solid Multi-Fuel              ' 'Electricity                   '
#  'Bulk LPG (propane or butane)  ' 'Bottled LPG                   '
#  'Wood Pellets (bulk supply for ' 'Wood Logs                     '
#  'Manufactured Smokeless Fuel   ' nan 'House Coal                    '
#  'Sod Peat                      ' 'Wood Pellets (in bags for seco'
#  'Anthracite                    ' 'Peat Briquettes               '
#  'Electricity - Standard Domesti' 'Electricity - Off-peak Night-R']
#
# -----------------------------------------------------------------------
#
# 'MainSHEfficiency' has 817 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.     nan   90.7   80.3   45.    79.1   78.1
#    79.9  100.    85.    90.3   78.9   90.1   85.3]
#
# -----------------------------------------------------------------------
#
# 'SharedMPRN' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'BuildingReg' has 5 unique values
# [  0.   1.   2.   3.  nan]
#
# -----------------------------------------------------------------------
#
# 'MainSHAdj' has 56 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969  0.7      nan  1.01   1.02   0.85   0.9    0.75
#   0.956  0.957  0.965  0.96   1.03   1.007  0.86 ]
#
# -----------------------------------------------------------------------
#
# 'SecSHFrac' has 33 unique values
# ~~Listing up to 17 unique values~~
# [ 0.1   0.    0.2   0.15   nan  0.5   0.05  0.01  0.3   0.35  0.25  0.19
#   0.02  0.17  0.27  0.13  0.33]
#
# -----------------------------------------------------------------------
#
# 'SecSHEfficiency' has 489 unique values
# ~~Listing up to 17 unique values~~
# [  65.   55.   60.   30.    0.   20.   90.   63.   72.  100.   40.   50.
#    70.   45.   58.   79.   nan]
#
# -----------------------------------------------------------------------
#
# 'MainWHEfficiency' has 962 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.    92.4   90.7   80.3   45.    79.1   78.1
#    79.9  100.    85.    90.3   85.3   78.9   90.1]
#
# -----------------------------------------------------------------------
#
# 'MainWHAdj' has 39 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969    nan  1.01   1.02   0.7    0.9    0.75   0.94   0.96
#   1.03   0.86   0.     0.97   1.05   0.8  ]
#
# -----------------------------------------------------------------------
#
# 'SecSHFuel' has 21 unique values
# ~~Listing up to 17 unique values~~
# [  1.  15.   8.   2.   6.  11.  28.   5.   4.   9.   3.  nan  10.   7.  12.
#   14.  16.]
#
# -----------------------------------------------------------------------
#
# 'SecWHFuel' has 5 unique values
# [ 28.   1.  nan  16.  18.]
#
# -----------------------------------------------------------------------
#
# 'NChimneys' has 12 unique values
# [  0.   1.   2.   4.   3.   6.   5.   7.   9.  nan   8.  10.]
#
# -----------------------------------------------------------------------
#
# 'NOpenFlues' has 12 unique values
# [  1.   0.   2.   3.   4.   6.  10.   5.   7.   9.  nan   8.]
#
# -----------------------------------------------------------------------
#
# 'NFansVents' has 32 unique values
# ~~Listing up to 17 unique values~~
# [  1.   0.   5.   3.   7.   9.   2.   6.   4.  10.  20.  12.   8.  13.  11.
#   14.  26.]
#
# -----------------------------------------------------------------------
#
# 'DLobby' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'VentMethod' has 7 unique values
# ['Natural vent.' 'Bal.whole mech.vent heat recvr'
#  'Whole house extract vent.' 'Bal.whole mech.vent no heat re'
#  'Pos input vent.- loft' 'Pos input vent.- outside' nan]
#
# -----------------------------------------------------------------------
#
# 'WallStructure' has 5 unique values
# ['Masonry                       ' 'Insulated Conctete Form       '
#  'Timber or Steel Frame         ' 'Please select                 ' nan]
#
# -----------------------------------------------------------------------
#
# 'SuspWoodFloor' has 4 unique values
# ['No                            ' 'Yes (Unsealed)                '
#  'Yes (Sealed)                  ' nan]
#
# -----------------------------------------------------------------------
#
# 'PercDraughtStripped' has 102 unique values
# ~~Listing up to 17 unique values~~
# [ 100.   80.   92.    6.   83.   50.   94.   93.   97.   89.   90.   95.
#    66.    0.   91.   85.   88.]
#
# -----------------------------------------------------------------------
#
# 'NShelteredSides' has 6 unique values
# [  3.   0.   1.   2.   4.  nan]
#
# -----------------------------------------------------------------------
#
# 'PermTest' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'PermTestResult' has 421 unique values
# ~~Listing up to 17 unique values~~
# [ 0.     0.16   0.135  0.08   0.21   0.116  0.44   0.167  0.19   0.3    0.25
#   0.149  0.15   0.068  0.056  0.14   0.1  ]
#
# -----------------------------------------------------------------------
#
# 'TempAdj' has 39 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    0.6   0.3   0.45 -0.15 -0.1  -0.25  0.1   0.5   1.    0.06  0.95
#   0.08  2.    0.35   nan  0.03]
#
# -----------------------------------------------------------------------
#
# 'ControlCat' has 5 unique values
# [  1.   3.   2.  nan   0.]
#
# -----------------------------------------------------------------------
#
# 'ResponseCat' has 7 unique values
# [  1.   3.   4.   2.   5.   0.  nan]
#
# -----------------------------------------------------------------------
#
# 'NCHPumps' has 17 unique values
# [  1.   2.   0.   4.   3.   5.   9.  nan  10.   6.   8.   7.  11.  20.  12.
#   17.  13.]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat1' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat2' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'OilPumpIn' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'NGasFans' has 8 unique values
# [  0.   1.   2.  nan   9.   3.   4.  11.]
#
# -----------------------------------------------------------------------
#
# 'WarmAir' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'Underfloor' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'DistLoss' has 6570 unique values
# ~~Listing up to 17 unique values~~
# [ 224.033  428.635  343.987  323.551  626.674  321.558  280.853  315.078
#   386.601  384.691  289.659  452.725  265.984  450.399  332.191  531.309
#   195.291]
#
# -----------------------------------------------------------------------
#
# 'StorageLoss' has 3 unique values
# ['YES' 'NO ' nan]
#
# -----------------------------------------------------------------------
#
# 'DeclaredLoss' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'SolarWaterHeating' has 3 unique values
# ['NO ' nan 'YES']
#
# -----------------------------------------------------------------------
#
# 'SummerElectricImm' has 3 unique values
# ['YES' 'NO ' nan]
#
# -----------------------------------------------------------------------
#
# 'Combi' has 5 unique values
# ['None                          ' 'Instantaneous, without keep-ho' nan
#  'Storage combi boiler store vol' 'Instantaneous, with keep-hot f']
#
# -----------------------------------------------------------------------
#
# 'KeepHot' has 4 unique values
# ['None                          ' nan 'keep-hot facility, controlled '
#  'keep-hot facility, not control']
#
# -----------------------------------------------------------------------
#
# 'VolWaterStorage' has 663 unique values
# ~~Listing up to 17 unique values~~
# [ 110.   95.  144.    0.   nan  100.  120.  353.  150.  117.  119.  106.
#    68.   80.   98.   96.   90.]
#
# -----------------------------------------------------------------------
#
# 'TempFac' has 56 unique values
# ~~Listing up to 17 unique values~~
# [ 0.6   0.     nan  0.78  0.94  1.08  0.82  1.    0.77  0.66  0.71  1.01
#   1.06  0.9   0.96  1.07  0.89]
#
# -----------------------------------------------------------------------
#
# 'TempFacMult' has 25 unique values
# ~~Listing up to 17 unique values~~
# [ 0.9   1.3   0.     nan  1.    1.17  0.81  0.6   1.1   0.89  0.78  1.13
#   0.54  0.95  0.09  1.2   0.13]
#
# -----------------------------------------------------------------------
#
# 'HWInsulationType' has 3 unique values
# ['Loose Jacket                  ' 'Factory Insulated             ' nan]
#
# -----------------------------------------------------------------------
#
# 'HWInsulationThickness' has 155 unique values
# ~~Listing up to 17 unique values~~
# [  20.   35.   50.   80.   25.    0.   nan   30.   40.   45.  100.   90.
#    15.   23.   70.   60.   10.]
#
# -----------------------------------------------------------------------
#
# 'PrimaryLoss' has 10 unique values
# ['Boiler with insulated primary ' 'Boiler with uninsulated primar'
#  'Combi boiler                  ' nan 'Electric immersion heater     '
#  'Separate boiler and thermal st' 'Community heating             '
#  'CPSU (including electric CPSU)' 'None                          '
#  'Boiler and thermal store withi']
#
# -----------------------------------------------------------------------
#
# 'AreaAperture' has 1030 unique values
# ~~Listing up to 17 unique values~~
# [   nan  3.68   5.72   6.96   7.76   3.23   4.3    3.     3.72   5.5    6.
#   4.4    3.2    2.79   7.164  5.96   2.6  ]
#
# -----------------------------------------------------------------------
#
# 'ZeroLossCollEff' has 176 unique values
# ~~Listing up to 17 unique values~~
# [   nan  0.78   0.799  0.75   0.768  0.6    0.582  0.63   0.74   0.8    0.9
#   0.734  0.73   0.85   0.776  0.65   0.786]
#
# -----------------------------------------------------------------------
#
# 'CollHeatLoss' has 413 unique values
# ~~Listing up to 17 unique values~~
# [    nan   1.06    4.17    3.796   3.77    1.07    1.36    6.      3.
#    0.91    1.673   0.94    1.18    1.53    4.01   20.      1.529]
#
# -----------------------------------------------------------------------
#
# 'SolarRadiation' has 223 unique values
# ~~Listing up to 17 unique values~~
# [   nan  1021.  1074.   886.   837.  1005.  1072.  1020.  1073.   736.
#    929.  1071.   464.   862.   644.   950.  1010.]
#
# -----------------------------------------------------------------------
#
# 'Overshading' has 15 unique values
# [  nan  1.    0.8   0.    0.9   0.65  0.5   0.95  0.6   0.82  0.1   0.08
#   0.2   0.63  0.7 ]
#
# -----------------------------------------------------------------------
#
# 'CylinderThermostat' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'DedicatedSolarVol' has 578 unique values
# ~~Listing up to 17 unique values~~
# [   nan  120.   150.   105.   162.5   50.   180.   100.   160.   116.   125.
#   175.   133.   119.   255.   200.   130. ]
#
# -----------------------------------------------------------------------
#
# 'CombiCylinder' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'SolarPumpElect' has 3 unique values
# [ nan  75.   0.]
#
# -----------------------------------------------------------------------
#
# 'SolarPumpPower' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'Charging' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'SolarHeatFrac' has 19 unique values
# ~~Listing up to 17 unique values~~
# [ nan   0.  10.  13.  12.  15.  18.  14.  16.  25.  24.  19.  33.  35.  20.
#   30.  11.]
#
# -----------------------------------------------------------------------
#
# 'LightingEnergy' has 194742 unique values
# ~~Listing up to 17 unique values~~
# [  274.752  1210.888   865.756   477.396  1678.062   851.96    687.254
#    453.736   719.855   939.422   631.75   1348.795   314.431  1337.8
#    492.851  1497.325   255.037]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansEnergy' has 6260 unique values
# ~~Listing up to 17 unique values~~
# [  230.      175.      130.      360.        0.      565.     2229.02
#    757.019   390.      275.       45.      576.961   100.      188.417
#    490.      305.      758.984]
#
# -----------------------------------------------------------------------
#
# 'MainWaterEnergy' has 355021 unique values
# ~~Listing up to 17 unique values~~
# [ 2595.201  4966.751  6486.081  4188.472  5885.092  2363.526  4053.687
#   5688.331  6462.168  4176.838  5659.353  4532.1    3286.202  5265.891
#   4577.569  9817.104  3452.983]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceEnergy' has 444314 unique values
# ~~Listing up to 17 unique values~~
# ['13700.589' '"52025.518"' '15704.271999999999' '7995.825' '24401.932'
#  '4449.424' '4673.279' '19807.038' '"19272.466"' '10660.1' '38369.354'
#  '34178.684' '6518.878000000001' '12034.993999999999' '8654.046999999999'
#  '48668.757000000005' '1930.009']
#
# -----------------------------------------------------------------------
#
# 'PrimaryLightingEnergy' has 194742 unique values
# ~~Listing up to 17 unique values~~
# [  741.83   3269.398  2337.541  1288.969  4530.767  2300.292  1855.586
#   1225.087  1943.609  2536.439  1705.725  3641.747   848.964  3612.06
#   1330.698  4042.778   688.6  ]
#
# -----------------------------------------------------------------------
#
# 'PrimaryPumpsFansEnergy' has 6260 unique values
# ~~Listing up to 17 unique values~~
# [  621.      472.5     351.      972.        0.     1525.5    6018.354
#   2043.951  1053.      742.5     121.5    1557.795   270.      508.726
#   1323.      823.5    2049.257]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainWaterEnergy' has 355269 unique values
# ~~Listing up to 17 unique values~~
# [  2854.721   5463.426   7134.689   4607.319   6473.601   2599.879
#    4459.056   6257.164   7108.385   4594.522   6225.288   4985.31
#    3614.822   5792.48    5035.326  10798.814   3798.281]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainSpaceEnergy' has 398592 unique values
# ~~Listing up to 17 unique values~~
# [ 15070.648  57228.07   17274.699        nan  26842.125   4894.366
#    5140.607  21787.742  21199.713  11726.11   42206.289  37596.552
#    7170.766  13238.493   9519.452  53535.633   2123.01 ]
#
# -----------------------------------------------------------------------
#
# 'LightingCO2' has 187949 unique values
# ~~Listing up to 17 unique values~~
# [  176.666   778.601   556.681   306.966  1078.994   547.81    441.904
#    291.752   462.867   604.048   406.215   867.275   202.179   860.205
#    316.903   962.78    163.989]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansCO2' has 6248 unique values
# ~~Listing up to 17 unique values~~
# [  147.89    112.525    83.59    231.48      0.      363.295  1433.26
#    486.763   250.77    176.825    28.935   370.986    64.3     121.152
#    315.07    196.115   488.027]
#
# -----------------------------------------------------------------------
#
# 'MainWaterCO2' has 330175 unique values
# ~~Listing up to 17 unique values~~
# [  705.895  1350.956  1764.214   850.26   1194.674   479.796   822.898
#   2098.994  1757.71    847.898  2088.301  1232.731   893.847  1068.976
#    929.247  2670.252   700.956]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceCO2' has 431656 unique values
# ~~Listing up to 17 unique values~~
# [  3726.56   14150.941   4271.562   1623.152   4953.592    903.233
#     948.676   7308.797   5242.111   2164.     14158.292   9296.602
#    1773.135   2443.104   1756.772  13237.902    391.792]
#
# -----------------------------------------------------------------------
#
# 'AreaGroundFloor' has 22629 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4    76.15   49.72  125.61
#    64.38   80.     84.87   34.84   54.39   52.12  181.6    40.37]
#
# -----------------------------------------------------------------------
#
# 'HeightGroundFloor' has 471 unique values
# ~~Listing up to 17 unique values~~
# [ 2.25  2.85  2.43  2.44  2.5   2.6   2.47  2.58  2.42  2.45  2.53  2.61
#   2.63  2.7   2.66  2.59  2.46]
#
# -----------------------------------------------------------------------
#
# 'AreaFirstFloor' has 14998 unique values
# ~~Listing up to 17 unique values~~
# [   0.     50.67   42.9   110.66   41.69   60.28   75.83   34.84   56.51
#    47.17   27.09    4.     45.02   41.49   66.7    37.28   58.71]
#
# -----------------------------------------------------------------------
#
# 'HeightFirstFloor' has 475 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    2.55  2.65  2.72  2.74  2.69  2.84  2.64  2.67  2.68  2.41  2.45
#   2.79  1.84  2.77  2.62  2.71]
#
# -----------------------------------------------------------------------
#
# 'AreaSecondFloor' has 6553 unique values
# ~~Listing up to 17 unique values~~
# [  0.    48.49  30.5   84.72  48.25  23.    52.44  11.76  59.74  20.83
#   15.45  52.93  47.8   37.64  44.27  32.15  60.9 ]
#
# -----------------------------------------------------------------------
#
# 'BridgingFac' has 75 unique values
# ~~Listing up to 17 unique values~~
# [ 0.15   0.11   0.08   0.033  0.09   0.04   0.032  0.052  0.055  0.043
#   0.05   0.06   0.057  0.049  0.051  0.063  0.035]
#
# -----------------------------------------------------------------------
#
# 'MassCat' has 6 unique values
# ['Medium              ' 'Medium-high         ' 'High                '
#  'Medium-low          ' 'Low                 ' nan]
#
# -----------------------------------------------------------------------
#
# 'LargestRoofTypeArea' has 33851 unique values
# ~~Listing up to 17 unique values~~
# [  56.82   75.96   61.76   42.9   171.95     nan   41.3   125.61   58.1
#    47.     84.87   34.84   27.92   52.12   77.81   40.37  105.  ]
#
# -----------------------------------------------------------------------
#
# 'LargestRoofType' has 56918 unique values
# ~~Listing up to 17 unique values~~
# ['Pre 1900 house Renovated      ' '100mm fibreglass between joist'
#  'new                           ' nan 'Cold roof with insulation     '
#  '2 rolls 300mm fibreglass - att' 'Fibre wool                    '
#  'Roof 1                        ' '1900                          '
#  'NEW                           ' 'Type 2                        '
#  'Cold roof construction (up-gra' '50mm fiberglass               '
#  '1st Floor - 300mm Quilt Insula' 'TOTAL HEAT LOSS FLOOR         '
#  'Attic space ceiling area      ' '150mm Insulation between joist']
#
# -----------------------------------------------------------------------
#
# 'PercLowEnergy' has 204 unique values
# ~~Listing up to 17 unique values~~
# [83.0 18.0 17.0 89.0 69.0 0.0 90.0 73.0 33.0 25.0 14.0 100.0 41.0 60.0 24.0
#  63.0 20.0]
#
# -----------------------------------------------------------------------
#
# 'TotEnergy' has 447949 unique values
# ~~Listing up to 17 unique values~~
# [19628.788 66036.461 25220.061 15146.598 32140.086 7839.91 9589.22
#  28587.863999999998 31431.226000000002 21542.311 52037.098 44685.685
#  13229.996000000001 22294.917999999998 16332.216 71352.924 5813.029]
#
# -----------------------------------------------------------------------
#
# 'SecSpaceEnergy' has 373376 unique values
# ~~Listing up to 17 unique values~~
# [1906.3729999999998 6495.307 1933.9520000000002 2309.905 0.0
#  1650.5870000000002 4746.737 4447.630999999999 6394.892 3610.671
#  1965.3210000000001 3481.2329999999997 2432.749 11139.738000000001 2666.1
#  5855.486999999999 746.377]
#
# -----------------------------------------------------------------------
#
# 'SecWaterEnergy' has 44024 unique values
# ~~Listing up to 17 unique values~~
# [  9.21873000e+02   1.10799700e+03   0.00000000e+00   8.58172000e+02
#    1.14332000e+03   8.51749000e+02   6.55435000e+02   9.15164000e+02
#    9.77014000e+02   1.38624909e+07   7.37554000e+02   1.05878300e+03
#    1.10828300e+03   1.11943100e+03   1.42805100e+03   1.25467700e+03
#    8.61461000e+02]
#
# -----------------------------------------------------------------------
#
# 'PercLivingArea' has 225238 unique values
# ~~Listing up to 17 unique values~~
# ['33.4935%' '11.0079%' '18.0465%' '18.1513%' '12.1887%' '37.2881%'
#  '30.8601%' '14.1888%' '15.0864%' '17.8485%' '19.125%' '18.463%' '32.9219%'
#  '13.6771%' '17.9575%' '21.1222%' '32.7966%']
#
# -----------------------------------------------------------------------
#
# 'SecSpaceCO2' has 351341 unique values
# ~~Listing up to 17 unique values~~
# [    0.     2396.768   713.628   905.483   609.067  1751.546   902.869
#   2359.715  1332.338   725.203  1364.643   897.684  4366.777   983.791
#   2160.675   275.413   509.179]
#
# -----------------------------------------------------------------------
#
# 'SecWaterCO2' has 42369 unique values
# ~~Listing up to 17 unique values~~
# [  5.92764000e+02   7.12442000e+02   0.00000000e+00   5.51805000e+02
#    7.35155000e+02   5.47675000e+02   4.21445000e+02   5.88450000e+02
#    6.28220000e+02   8.91358163e+06   4.74247000e+02   6.80797000e+02
#    7.12626000e+02   7.19794000e+02   9.18237000e+02   8.06757000e+02
#    5.53919000e+02]
#
# -----------------------------------------------------------------------
#
# 'SecSpacePrimaryEnergy' has 333910 unique values
# ~~Listing up to 17 unique values~~
# [     0.      7144.838   2127.347   2771.886   1815.646   5221.411
#    4892.394   7034.381   3971.738   2161.853   4177.48    2676.024
#   13367.686   2932.71    6441.036    821.015   1517.878]
#
# -----------------------------------------------------------------------
#
# 'SecWaterPrimaryEnergy' has 44022 unique values
# ~~Listing up to 17 unique values~~
# [  2.48905700e+03   2.99159200e+03   0.00000000e+00   2.31706400e+03
#    3.08696400e+03   2.29972200e+03   1.76967500e+03   2.47094300e+03
#    2.63793800e+03   3.74287253e+07   1.99139600e+03   2.85871400e+03
#    2.99236400e+03   3.02246400e+03   3.85573800e+03   3.38762800e+03
#    2.32594500e+03]
#
# -----------------------------------------------------------------------
#
# 'UpgradeHES' has 12 unique values
# [  0.00000000e+00   1.00000000e+00   2.53170900e+03   2.19522000e+02
#               nan   1.22509600e+03   1.93064600e+03   1.13734000e+03
#    3.67538500e+03   5.59848800e+03   1.58066100e+03   2.88868700e+03]
#
# -----------------------------------------------------------------------
#
# 'RoofAreaRoom' has 8844 unique values
# ~~Listing up to 17 unique values~~
# [ 18.35   0.    28.42  20.08  91.42  80.94  15.89  48.75  14.81  18.97
#   18.06  62.1   19.74  49.47  44.66  85.    51.47]
#
# -----------------------------------------------------------------------
#
# 'RatingPurpose' has 15 unique values
# ['Unknown' 'Sale' 'Grant Support' 'Private Letting'
#  'Social housing letting' 'Other' 'New dwelling for owner occupat' '0.000'
#  '1189.526' nan '5144.259' '1' '5910.142' '0' '4816.418']
#
# -----------------------------------------------------------------------
#
# 'AssessmentDate' has 3196 unique values
# ~~Listing up to 17 unique values~~
# ['Jun 17 2011 12:00AM' 'Apr 14 2015 12:00AM' 'Jun 28 2012 12:00AM'
#  'Nov 25 2015 12:00AM' 'May 30 2016 12:00AM' 'May 13 2009 12:00AM'
#  'Jun 29 2013 12:00AM' 'Jan 21 2016 12:00AM' 'Sep 10 2013 12:00AM'
#  'Dec 12 2012 12:00AM' 'Jun 27 2016 12:00AM' 'Nov 19 2012 12:00AM'
#  'Jul 29 2014 12:00AM' 'Nov  1 2013 12:00AM' 'Oct 30 2009 12:00AM'
#  'Feb 10 2016 12:00AM' 'Feb 28 2011 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'FirstEnerType' has 12 unique values
# [1.0 2.0 3.0 nan '1' '2' '3' 'Feb 20 2014 12:00AM' 0.0 'Other' 'Unknown'
#  'Mar 18 2014 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'FirstEnerTypeDescr' has 11 unique values
# ['Renewable Thermal' 'Renewable Electrical' 'Not Renewable' nan '1' '0.000'
#  'Feb 19 2014 12:00AM' 'Apr  2 2014 12:00AM' 'Apr 20 2010 12:00AM'
#  'Mar 24 2014 12:00AM' 'Nov 12 2009 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerComment' has 1012 unique values
# ~~Listing up to 17 unique values~~
# [nan 'Solar PV' 'solar' 'PV S 30deg 4  panel 1289' 'PV'
#  'Suntech 5 Panel PV System' 'Solar PV array' 'Renewable Contribution'
#  'solar space' '1.3  kWp Photovoltaic' '3 Joule Pulsa 260 PV Panels' 'pv'
#  '1.04 kWp (4# 260Wp) PV - South' 'PV panels' 'Photovoltaic'
#  'HEAT PUMP RENEWABLE CONTRIB' '3 No. Suntech 250w PV cells']
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerDelivered' has 1356 unique values
# ~~Listing up to 17 unique values~~
# [0.0 723.0 525.0 nan 118.0 859.0 708.8 804.0 766.0 817.0 556.0 670.2 414.0
#  474.0 737.1519999999999 627.1 531.6]
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerConvFac' has 28 unique values
# ~~Listing up to 17 unique values~~
# [0.0 2.45 1.0 nan 1.1 2.19 2.37 2.42 2.7 '0' '2.37' '2.19' '2.42' '2.45'
#  '1.1' '2.7' 'Renewable Thermal']
#
# -----------------------------------------------------------------------
#
# 'ConsFirstEnerComment' has 69 unique values
# ~~Listing up to 17 unique values~~
# [nan 'solar' '0' 'None' 'Heat Pump' 'Solar' 'Pup' '75' 'none'
#  'By electric pump' 'electricity' 'solar thermal' 'Heat pump' 'Electricity'
#  '1289' 'NONE' 'PS260M-20/U']
#
# -----------------------------------------------------------------------
#
# 'SecondEnerTypeDescr' has 6 unique values
# ['Renewable Thermal' nan 'Not Renewable' 'Renewable Electrical' '1' '0']
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerComment' has 85 unique values
# ~~Listing up to 17 unique values~~
# [nan 'PV e/w 30deg  4 panels 709' 'Heat Pump' 'Solar PV'
#  'Renewable Thermal' 0.0 'heat pump' '0' 'HP contribution'
#  'PV 2 panels W 30deg ' '1# 250Wp West Facing' '2PV'
#  'PV 2 PANELS SOUTH @ 45 429' 'Add Part L Contribution from H'
#  'PV S 30deg  5 panels 1074' '8 Panels   45 Deg E/W 1339' 'Heat Recovery']
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerDelivered' has 64 unique values
# ~~Listing up to 17 unique values~~
# [0.0 nan 1040.0 865.0 738.0 368.0 709.0 177.2 561.86 429.6 429.0 375.0
#  1339.0 '0' 'Renewable Thermal' '709' 2538.0]
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerConvFac' has 15 unique values
# [0.0 nan 2.19 1.1 2.7 '0' 'Renewable Thermal' '2.19' 0.1 2.18 2.37 2.42
#  2.45 '2.37' '2.13']
#
# -----------------------------------------------------------------------
#
# 'ConsSecondEnerComment' has 17 unique values
# [nan 0.0 '6 Panels   45 Deg E/W 1004' 'Electricity' '859 (5 panels 1074)'
#  893.0 'None' '260w' '893' 'none' '1  panels 201' 532.0 '613' '0' 'Solar'
#  '5 panels 1206' 613.0]
#
# -----------------------------------------------------------------------
#
# 'ThirdEnerTypeDescr' has 6 unique values
# ['Renewable Thermal' nan 'Not Renewable' 'Renewable Electrical' '1' '0']
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerComment' has 32 unique values
# ~~Listing up to 17 unique values~~
# [nan 'PV e/w 30deg  2 panels 354' 'm' 'Renewable Thermal' 0.0 'heat pump'
#  'Add Part L Contribution from H' 'PV 30deg  2 panels ' '1' '0'
#  'PV 1 panels se 30deg' 'PV ne 2 panels ' 'PV 1 panel S 30deg' 'cooker c'
#  'Sunstream 3.7 Wind Turbine' 'e' 1.0]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerDelivered' has 16 unique values
# [0.0 nan 354.0 385.65 '0' 'Renewable Thermal' '354' 741.0 204.0 258.0 530.0
#  394.0 485.0 201.0 7171.0 615.65]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerConvFac' has 8 unique values
# [0.0 nan 2.19 '0' 'Renewable Thermal' 2.37 2.45 2.7]
#
# -----------------------------------------------------------------------
#
# 'ConsThirdEnerComment' has 5 unique values
# [nan 0.0 '1592  6 panels 1327 for 5 pane' '1592  6 panels' 'none']
#
# -----------------------------------------------------------------------
#
# 'FuelTypeFirstBoiler' has 12 unique values
# [ nan  13.   2.   5.  28.  21.  14.   3.   0.  12.  15.  10.]
#
# -----------------------------------------------------------------------
#
# 'EffFirstHeatGenPlant' has 146 unique values
# ~~Listing up to 17 unique values~~
# [    nan   90.     80.     75.     83.     94.    385.     90.1    80.4
#    93.     73.    449.    300.     88.    372.6    83.54   91.72]
#
# -----------------------------------------------------------------------
#
# 'PercFirstHeat' has 68 unique values
# ~~Listing up to 17 unique values~~
# [  nan   90.  100.   31.   50.   62.   70.   35.   80.   66.   52.   40.
#     0.   86.   54.   87.   76.]
#
# -----------------------------------------------------------------------
#
# 'FuelTypeSecondBoiler' has 16 unique values
# [ nan   2.   1.  21.  28.  13.   3.   0.  14.  15.   6.   8.   5.  10.   9.
#   11.]
#
# -----------------------------------------------------------------------
#
# 'EffSecondHeatGenPlant' has 40 unique values
# ~~Listing up to 17 unique values~~
# [   nan   85.     0.    92.   270.    75.   150.    80.    63.   100.    20.
#   294.    91.1  105.    65.    30.    91.9]
#
# -----------------------------------------------------------------------
#
# 'PercSecondHeat' has 59 unique values
# ~~Listing up to 17 unique values~~
# [ nan  10.   0.  62.  50.  38.  30.  58.  20.  34.  36.  53.  14.  28.  46.
#   24.  40.]
#
# -----------------------------------------------------------------------
#
# 'FuelTypeThirdBoiler' has 6 unique values
# [ nan   1.   2.  15.  28.   3.]
#
# -----------------------------------------------------------------------
#
# 'EffThirdHeatGenPlant' has 7 unique values
# [  nan    0.   90.   85.   75.   91.  100.]
#
# -----------------------------------------------------------------------
#
# 'PercThirdHeat' has 9 unique values
# [ nan   0.   7.  12.  20.  34.  33.  41.  10.]
#
# -----------------------------------------------------------------------
#
# 'HeatingSystemSolarSpace' has 19 unique values
# ~~Listing up to 17 unique values~~
# [ nan   0.  10.  13.  12.  15.  18.  14.  16.  25.  24.  19.  33.  35.  20.
#   30.  11.]
#
# -----------------------------------------------------------------------
#
# 'TotPrimaryEnergyFac' has 344 unique values
# ~~Listing up to 17 unique values~~
# [   nan  1.291  1.513  1.54   1.392  1.231  1.051  1.343  1.283  1.642
#   1.242  1.658  1.309  0.904  1.246  1.352  0.762]
#
# -----------------------------------------------------------------------
#
# 'TotCO2Emissions' has 252 unique values
# ~~Listing up to 17 unique values~~
# [   nan  0.029  0.279  0.284  0.344  0.227  0.198  0.248  0.237  0.303
#   0.229  0.306  0.03   0.195  0.269  0.031  0.164]
#
# -----------------------------------------------------------------------
#
# 'PrimaryEnergySecondarySpace' has 333910 unique values
# ~~Listing up to 17 unique values~~
# [     0.      7144.838   2127.347   2771.886   1815.646   5221.411
#    4892.394   7034.381   3971.738   2161.853   4177.48    2676.024
#   13367.686   2932.71    6441.036    821.015   1517.878]
#
# -----------------------------------------------------------------------
#
# 'EnergyMainWater' has 355021 unique values
# ~~Listing up to 17 unique values~~
# [ 2335.6809  4470.0759  5837.4729  3769.6248  5296.5828  2127.1734
#   3648.3183  5119.4979  5815.9512  3759.1542  5093.4177  4078.89    2957.5818
#   4739.3019  4119.8121  8835.3936  3107.6847]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# ['County has 12 missing', 'Type has 12 missing', 'RatingType has 12 missing', 'EnergyRatingCat has 12 missing', 'EnergyRatingCont has 12 missing', 'AvgWallU has 46457 missing', 'AvgRoofU has 12 missing', 'AvgFloorU has 12 missing', 'AvgWindowU has 12 missing', 'AvgDoorU has 12 missing', 'ExposedWallArea has 12 missing', 'ExposedRoofArea has 12 missing', 'TotFloorArea has 12 missing', 'TotWindowArea has 12 missing', 'TotDoorArea has 12 missing', 'NStoreys has 12 missing', 'MainSHFuel has 5658 missing', 'MainWHFuel has 5658 missing', 'MainSHEfficiency has 51574 missing', 'SharedMPRN has 12 missing', 'BuildingReg has 12 missing', 'MainSHAdj has 5658 missing', 'SecSHFrac has 5658 missing', 'SecSHEfficiency has 5658 missing', 'MainWHEfficiency has 5658 missing', 'MainWHAdj has 5658 missing', 'SecSHFuel has 5658 missing', 'SecWHFuel has 5658 missing', 'NChimneys has 12 missing', 'NOpenFlues has 12 missing', 'NFansVents has 12 missing', 'DLobby has 12 missing', 'VentMethod has 12 missing', 'WallStructure has 12 missing', 'SuspWoodFloor has 12 missing', 'PercDraughtStripped has 12 missing', 'NShelteredSides has 12 missing', 'PermTest has 12 missing', 'PermTestResult has 12 missing', 'TempAdj has 13 missing', 'ControlCat has 12 missing', 'ResponseCat has 12 missing', 'NCHPumps has 12 missing', 'BoilerStat1 has 12 missing', 'BoilerStat2 has 12 missing', 'OilPumpIn has 12 missing', 'NGasFans has 12 missing', 'WarmAir has 12 missing', 'Underfloor has 12 missing', 'DistLoss has 12 missing', 'StorageLoss has 42548 missing', 'DeclaredLoss has 42548 missing', 'SolarWaterHeating has 42548 missing', 'SummerElectricImm has 42548 missing', 'Combi has 42548 missing', 'KeepHot has 42548 missing', 'VolWaterStorage has 42548 missing', 'TempFac has 42548 missing', 'TempFacMult has 42548 missing', 'HWInsulationType has 42548 missing', 'HWInsulationThickness has 42548 missing', 'PrimaryLoss has 42548 missing', 'AreaAperture has 442089 missing', 'ZeroLossCollEff has 442089 missing', 'CollHeatLoss has 442089 missing', 'SolarRadiation has 442089 missing', 'Overshading has 442089 missing', 'CylinderThermostat has 12 missing', 'DedicatedSolarVol has 442089 missing', 'CombiCylinder has 12 missing', 'SolarPumpElect has 442089 missing', 'SolarPumpPower has 12 missing', 'Charging has 12 missing', 'SolarHeatFrac has 458892 missing', 'LightingEnergy has 12 missing', 'PumpsAndFansEnergy has 12 missing', 'MainWaterEnergy has 12 missing', 'MainSpaceEnergy has 9 missing', 'PrimaryLightingEnergy has 12 missing', 'PrimaryPumpsFansEnergy has 12 missing', 'PrimaryMainWaterEnergy has 5658 missing', 'PrimaryMainSpaceEnergy has 51699 missing', 'LightingCO2 has 12 missing', 'PumpsAndFansCO2 has 12 missing', 'MainWaterCO2 has 5658 missing', 'MainSpaceCO2 has 5658 missing', 'AreaGroundFloor has 12 missing', 'HeightGroundFloor has 12 missing', 'AreaFirstFloor has 12 missing', 'HeightFirstFloor has 12 missing', 'AreaSecondFloor has 12 missing', 'BridgingFac has 12 missing', 'MassCat has 12 missing', 'LargestRoofTypeArea has 48655 missing', 'LargestRoofType has 225461 missing', 'PercLowEnergy has 23 missing', 'TotEnergy has 16 missing', 'SecSpaceEnergy has 13 missing', 'SecWaterEnergy has 13 missing', 'SecSpaceCO2 has 5658 missing', 'SecWaterCO2 has 12 missing', 'SecSpacePrimaryEnergy has 51734 missing', 'SecWaterPrimaryEnergy has 12 missing', 'UpgradeHES has 12 missing', 'RoofAreaRoom has 12 missing', 'RatingPurpose has 12 missing', 'AssessmentDate has 12 missing', 'FirstEnerType has 5658 missing', 'FirstEnerTypeDescr has 5658 missing', 'ProdFirstEnerComment has 459191 missing', 'ProdFirstEnerDelivered has 5660 missing', 'ProdFirstEnerConvFac has 5658 missing', 'ConsFirstEnerComment has 464070 missing', 'SecondEnerTypeDescr has 7124 missing', 'ProdSecondEnerComment has 464309 missing', 'ProdSecondEnerDelivered has 7126 missing', 'ProdSecondEnerConvFac has 7124 missing', 'ConsSecondEnerComment has 464469 missing', 'ThirdEnerTypeDescr has 7124 missing', 'ProdThirdEnerComment has 46 ...
#
#
# Features with non-numeric values:
# ['County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat', 'GroundFloorArea', 'MainSHFuel', 'MainWHFuel', 'SharedMPRN', 'DLobby', 'VentMethod', 'WallStructure', 'SuspWoodFloor', 'PermTest', 'TempAdj', 'BoilerStat1', 'BoilerStat2', 'OilPumpIn', 'WarmAir', 'Underfloor', 'StorageLoss', 'DeclaredLoss', 'SummerElectricImm', 'Combi', 'HWInsulationType', 'PrimaryLoss', 'CylinderThermostat', 'CombiCylinder', 'SolarPumpPower', 'Charging', 'MainWaterEnergy', 'MainSpaceEnergy', 'MainSpaceCO2', 'MassCat', 'LargestRoofType', 'TotEnergy', 'SecSpaceEnergy', 'SecWaterEnergy', 'PercLivingArea', 'SecSpaceCO2', 'SecWaterCO2', 'SecSpacePrimaryEnergy', 'SecWaterPrimaryEnergy', 'RatingPurpose', 'AssessmentDate', 'FirstEnerTypeDescr', 'ProdFirstEnerComment', 'ConsFirstEnerComment', 'ProdSecondEnerComment', 'ConsSecondEnerComment', 'ProdThirdEnerComment', 'ConsThirdEnerComment', 'PrimaryEnergySecondarySpace', 'EnergyMainWater']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
def is_outlier(points, thresh = 3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
 df = train.append(test,ignore_index = True)

# %%
cats = []
for col in df.columns.values:
    if df[col].dtype == 'object':
        cats.append(col)

# %%
df_cont = df.drop(cats, axis=1)
df_cat = df[cats]

# %%
for col in df_cont.columns.values:
    if np.sum(df_cont[col].isnull()) > 50:
        #print("Removing Column: {}".format(col))
        df_cont = df_cont.drop(col, axis = 1)
    elif np.sum(df_cont[col].isnull()) > 0:
        #print("Replacing with Median: {}".format(col))
        median = df_cont[col].median()
        idx = np.where(df_cont[col].isnull())[0]
        df_cont[col].iloc[idx] = median
        
        
        outliers = np.where(is_outlier(df_cont[col]))
        df_cont[col].iloc[outliers] = median
        
               
        if skew(df_cont[col]) > 0.75:
            #print("Skewness Detected: {}".format(col))
            df_cont[col] = np.log(df_cont[col])
            df_cont[col] = df_cont[col].apply(lambda x: 0 if x == -np.inf else x)
        
        df_cont[col] = Normalizer().fit_transform(df_cont[col].reshape(1,-1))[0]

# %%
for col in df_cat.columns.values:
    if np.sum(df_cat[col].isnull()) > 50:
        df_cat = df_cat.drop(col, axis = 1)
        continue
    elif np.sum(df_cat[col].isnull()) > 0:
        df_cat[col] = df_cat[col].fillna('MIA')
        
    df_cat[col] = LabelEncoder().fit_transform(df_cat[col])
    
    num_cols = df_cat[col].max()
    for i in range(num_cols):
        col_name = col + '_' + str(i)
        df_cat[col_name] = df_cat[col].apply(lambda x: 1 if x == i else 0)
        
    df_cat = df_cat.drop(col, axis = 1)

# %% [markdown]
# #### 2. Summarize data
# Descriptive statistics

# %%
#Let's take a brief look at all numerical columns statistcs:
train.describe(include =['number'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3bdf257e5a9> in <module>()
#       1 #Let's take a brief look at all numerical columns statistcs:
# ----> 2 train.describe(include =['number'])
#
# NameError: name 'train' is not defined

# %%
f = lambda x : x.strip('sq. m')
train['GroundFloorArea'] = list(map(f,train['GroundFloorArea']))
