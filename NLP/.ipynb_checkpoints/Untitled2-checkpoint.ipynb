# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
# %config InlineBackend.figure_format = 'png' #set 'png' here when working on notebook
warnings.filterwarnings('ignore') 

plt.rcParams['figure.figsize'] = (4, 3)

# %%
#load the file
df = pd.read_excel(r"C:\Users\piush\Desktop\CSV_Files\jobSkills.xlsx")

# %%
print ("Information for Dataset")
print ("------------------")
print ("Shape of dataset set:", df.shape, "\n")
print ("Column Headers:", list(df.columns.values), "\n")
print (df.dtypes)
print("=" * 60)

missing_values = []
for column in df:
    # Find all the unique feature values
    uniq = df[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 10):
        print("Listing up to 10 unique values")
    print (uniq[0:10])
    print ("=" * 60)
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(df[column]).sum())
        missing_values.append(s)
print ("*" * 60)
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print("=" * 60)
#get summary of numerical variables
print("Summary")
print(df.describe())
# Out:
# Information for Dataset
# ------------------
# Shape of dataset set: (3000, 5)
#
# Column Headers: ['Position', 'Location', 'Minimum_salary', 'Maximum_salary', 'Skills']
#
# Position           object
# Location           object
# Minimum_salary    float64
# Maximum_salary    float64
# Skills             object
# dtype: object
# ============================================================
# 'Position' has 2448 unique values
# Listing up to 10 unique values
# ['Senior Java Developer' 'Project Manager - Infrastructure'
#  'Mobile Developer - iOS'
#  'Agile Java Developer  Worthing  Digital  £45 - £80K'
#  '4th Line Technical Engineer - Network - Juniper - CCNP - CCIE'
#  'IT Security Sales - Business Development Manager'
#  'Lead Data Strategy Analyst' '.Net Developer'
#  'Fullstack JavaScript Developer - Mongo' 'IT Support Assistant']
# ============================================================
# 'Location' has 317 unique values
# Listing up to 10 unique values
# ['Hatfield' 'Peterborough' 'London' 'Worthing' 'Reigate' 'Beckenham'
#  'Ruislip' 'Feltham' 'East Grinstead' 'Burton']
# ============================================================
# 'Minimum_salary' has 162 unique values
# Listing up to 10 unique values
# [ 500.   nan   40.   45.   55.   50.   65.  325.   27.   70.]
# ============================================================
# 'Maximum_salary' has 218 unique values
# Listing up to 10 unique values
# [ 550.   nan   60.   80.   50.   90.   45.  450.   27.   75.]
# ============================================================
# 'Skills' has 1644 unique values
# Listing up to 10 unique values
# ['Pair,Java,TDD,MySQL,8,Programming' nan
#  'Mobile,Architecture,Software,Agile'
#  'Juniper,Line,Network,Engineer,CCNP,-,CCIE,4th,Technical'
#  'SIEM,Information,Security,Risk' 'MongoDB,Node.js,Express,Angular'
#  "'Full,Stack,'Software,Developer',IT."
#  'Solving,ITIL,Leadership,Europe,Problem,Agile'
#  'SQL,C#,Framework,Software,Server,TDD,Entity,C#.NET,WPF,MVVM,Developer,ORM'
#  'Pages,Websites,Web']
# ============================================================
# ************************************************************
# Features with missing values:
# ['Minimum_salary has 409 missing', 'Maximum_salary has 409 missing', 'Skills has 1293 missing']
#
#
# ============================================================
# Summary
#        Minimum_salary  Maximum_salary
# count     2591.000000     2591.000000
# mean        77.839601       94.802081
# std        116.899064      137.349868
# min          6.000000        1.000000
# 25%         25.000000       32.889000
# 50%         35.000000       45.000000
# 75%         50.000000       65.000000
# max        750.000000      900.000000

# %%
df[df['Minimum_salary'].isnull()]
# Out:
#                                                Position             Location  \
# 1                      Project Manager - Infrastructure         Peterborough
# 11                                 Full Stack Developer              Feltham
# 16                               Network Analyst - CCNA           Chippenham
# 20                  Pensions Systems Analyst - Contract              Crawley
# 46                             SharePoint Administrator          Basingstoke
# 47       Senior Network & Security Consultant - BERMUDA               London
# 48                           Test Analyst - Performance             Coventry
# 56                             Java Technical Architect              Ipswich
# 57                             Multi-lingual IT Support           Nottingham
# 59                          Technical Programme Manager   Welwyn Garden City
# 65                                       Data Archtiect               London
# 69        Trail Blazing HADOOP Software Engineer - Hive            Edinburgh
# 72                         Mac 2nd Line Desktop Support          Leatherhead
# 121                         Mid Level C# .Net Developer        Milton Keynes
# 122                                  Group Data Manager            Cambridge
# 131                            .Net Developer - Cardiff              Cardiff
# 140               Outsystems / C# ASP.Net MVC Developer             Dartford
# 151                                      Java Developer                 Hove
# 163                         Principal Software Engineer               London
# 169   Business Development - Sales - IT - Telecom B2...            Cambridge
# 171               Technology Programme Manager - SK2800               London
# 182                                    Security Analyst               London
# 184                                Project Co-ordinator               London
# 188                                 Servicedesk Analyst         Peterborough
# 193         1st and 2nd Line Technical Support Engineer            Guildford
# 204                            Infrastructure Architect                Leeds
# 212                    Remote Support Engineer contract                Poole
# 224                                      Data Architect               London
# 227                               IT Support Technician              Lincoln
# 246                            Infrastructure Architect               London
# ...                                                 ...                  ...
# 2756                                Technical Architect  Newcastle Upon Tyne
# 2759                            Mid to Senior Developer          Bournemouth
# 2762                                      Sales Manager               London
# 2768                       Enterprise Architect InfoSec                Corby
# 2774                                 IT Support Analyst            Edinburgh
# 2778     Microsoft Dynamics NAV/AX Consultant - Bermuda               Dublin
# 2781                       Advanced Threat Investigator              Reading
# 2793  Forensic Services IT Asset Management - Senior...               London
# 2796              Polaris Development Team Lead - Essex                Essex
# 2797        IT and Change Project Manager - Basingstoke          Basingstoke
# 2811             Service Desk Analyst- 3 Month Contract              Ashford
# 2825                                     Data Scientist              Watford
# 2838                               Repairing Technician               Slough
# 2853                              Windows C++ Developer            Cambridge
# 2865                                       QA Team Lead            Harpenden
# 2867                     Infrastructure Support Analyst               Dudley
# 2909  PRODUCT SUPPORT SERVER SUPPORTED GAMING - Brid...             Bridgend
# 2914                    Renewals Account Manager - EMEA           Maidenhead
# 2932                            Lending Product Analyst               Durham
# 2939                                     .NET Developer             Brighton
# 2941  1st/2nd Helpdesk Analyst - South Yorkshire - 3...            Doncaster
# 2951       VP Strategy and Operations - Global Services               Slough
# 2957                                      Web Developer           Cheltenham
# 2962                          Junior Software Developer            Liverpool
# 2967                               Service Desk Manager          Basingstoke
# 2975            Temporary/Interim IT Support - 2nd Line           Maidenhead
# 2977                           Configuration Consultant               Oldham
# 2983                         Strategic Projects Manager               London
# 2990  Data Management Specialist - CDO / DATA MANAGE...               London
# 2999                          Senior Software Developer               London
#
#       Minimum_salary  Maximum_salary  \
# 1                NaN             NaN
# 11               NaN             NaN
# 16               NaN             NaN
# 20               NaN             NaN
# 46               NaN             NaN
# 47               NaN             NaN
# 48               NaN             NaN
# 56               NaN             NaN
# 57               NaN             NaN
# 59               NaN             NaN
# 65               NaN             NaN
# 69               NaN             NaN
# 72               NaN             NaN
# 121              NaN             NaN
# 122              NaN             NaN
# 131              NaN             NaN
# 140              NaN             NaN
# 151              NaN             NaN
# 163              NaN             NaN
# 169              NaN             NaN
# 171              NaN             NaN
# 182              NaN             NaN
# 184              NaN             NaN
# 188              NaN             NaN
# 193              NaN             NaN
# 204              NaN             NaN
# 212              NaN             NaN
# 224              NaN             NaN
# 227              NaN             NaN
# 246              NaN             NaN
# ...              ...             ...
# 2756             NaN             NaN
# 2759             NaN             NaN
# 2762             NaN             NaN
# 2768             NaN             NaN
# 2774             NaN             NaN
# 2778             NaN             NaN
# 2781             NaN             NaN
# 2793             NaN             NaN
# 2796             NaN             NaN
# 2797             NaN             NaN
# 2811             NaN             NaN
# 2825             NaN             NaN
# 2838             NaN             NaN
# 2853             NaN             NaN
# 2865             NaN             NaN
# 2867             NaN             NaN
# 2909             NaN             NaN
# 2914             NaN             NaN
# 2932             NaN             NaN
# 2939             NaN             NaN
# 2941             NaN             NaN
# 2951             NaN             NaN
# 2957             NaN             NaN
# 2962             NaN             NaN
# 2967             NaN             NaN
# 2975             NaN             NaN
# 2977             NaN             NaN
# 2983             NaN             NaN
# 2990             NaN             NaN
# 2999             NaN             NaN
#
#                                                  Skills
# 1                                                   NaN
# 11                 'Full,Stack,'Software,Developer',IT.
# 16                              CCNA,Networking,Analyst
# 20                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                          Performance,Test,Automation
# 56                                                  NaN
# 57                                                  NaN
# 59                                                  NaN
# 65    Modelling,Services,Financial,Data,Oracle,Archi...
# 69                          hbase,Hive,Hadoop,API,Spark
# 72                 Environment,Line,2nd,Desktop,Mac,Car
# 121                 Visual,C#,Software,.NET,House,Basic
# 122                                                 NaN
# 131   SQL,Visual,Asp.net,Bootstrap,Server,framework,...
# 140                                                 NaN
# 151                          SQL,Scrum,Java,TDD,-,Agile
# 163                                                 NaN
# 169                           sales,Sales,Marketing,B2B
# 171                                                 NaN
# 182                                                 NaN
# 184                                                 NaN
# 188                                                 NaN
# 193          1st,&,Line,2nd,Support,Engineers,Technical
# 204                                                 NaN
# 212                                                 NaN
# 224                                                 NaN
# 227                                                 NaN
# 246                                                 NaN
# ...                                                 ...
# 2756  Infrastructure,C#,Software,Methodologies,HTML5...
# 2759                                                NaN
# 2762                                                NaN
# 2768                            Enterprise,Architect,IT
# 2774  1st,Helpdesk,/,German,Support,2nd,support,-,li...
# 2778          Microsoft,365,AX,Dynamics,Navision,Office
# 2781                                                NaN
# 2793                                                NaN
# 2796              Development,Team,Essex,-,Lead,Polaris
# 2797                                                NaN
# 2811                                                NaN
# 2825                                                NaN
# 2838                                                NaN
# 2853  Browsers,Network,Windows,Security,C++,Virtuali...
# 2865                                                NaN
# 2867                                                NaN
# 2909  Helpdesk,Product,Support,Testing,support,Syste...
# 2914                                                NaN
# 2932                           Analysis,Lending,Analyst
# 2939                  SQL,C#,TDD,WCF,-,MVC,.Net,ASP.Net
# 2941                                                NaN
# 2951  Professional,operations,research,Service,deal,...
# 2957                                                NaN
# 2962          Web,Applications,Software,Technology,.NET
# 2967                                                NaN
# 2975  Line,Support,2nd,Technical,Troubleshooting,sup...
# 2977                                          VB,Sql,C#
# 2983                                                NaN
# 2990  /,MANAGEMENT,FINANACIAL,Data,Management,CDO,DA...
# 2999                                   React,JavaScript
#
# [409 rows x 5 columns]

# %%
df = df[pd.notnull(df['Skills'])]

# %%
df = df[pd.notnull(df['Minimum_salary'])]

# %%
print ("Information for Dataset")
print ("------------------")
print ("Shape of dataset set:", df.shape, "\n")
print ("Column Headers:", list(df.columns.values), "\n")
print (df.dtypes)
print("=" * 60)

missing_values = []
for column in df:
    # Find all the unique feature values
    uniq = df[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 10):
        print("Listing up to 10 unique values")
    print (uniq[0:10])
    print ("=" * 60)
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(df[column]).sum())
        missing_values.append(s)
print ("*" * 60)
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print("=" * 60)
#get summary of numerical variables
print("Summary")
print(df.describe())
# Out:
# Information for Dataset
# ------------------
# Shape of dataset set: (1502, 5)
#
# Column Headers: ['Position', 'Location', 'Minimum_salary', 'Maximum_salary', 'Skills']
#
# Position           object
# Location           object
# Minimum_salary    float64
# Maximum_salary    float64
# Skills             object
# dtype: object
# ============================================================
# 'Position' has 1293 unique values
# Listing up to 10 unique values
# ['Senior Java Developer' 'Mobile Developer - iOS'
#  '4th Line Technical Engineer - Network - Juniper - CCNP - CCIE'
#  'IT Security Sales - Business Development Manager'
#  'Fullstack JavaScript Developer - Mongo' 'Service Delivery Manager'
#  'C# Developer - WPF' 'Web Assistant'
#  'Data Analytics Consultant (Business Intelligence' 'Software Developer']
# ============================================================
# 'Location' has 251 unique values
# Listing up to 10 unique values
# ['Hatfield' 'London' 'Reigate' 'East Grinstead' 'Burton' 'Falmouth'
#  'Stevenage' 'Derby' 'Reading' 'Stockport']
# ============================================================
# 'Minimum_salary' has 117 unique values
# Listing up to 10 unique values
# [ 500.   40.   55.   50.  325.   45.   11.   35.   25.   38.]
# ============================================================
# 'Maximum_salary' has 156 unique values
# Listing up to 10 unique values
# [ 550.   60.   50.  450.   12.   65.   45.   30.   75.   70.]
# ============================================================
# 'Skills' has 1446 unique values
# Listing up to 10 unique values
# ['Pair,Java,TDD,MySQL,8,Programming' 'Mobile,Architecture,Software,Agile'
#  'Juniper,Line,Network,Engineer,CCNP,-,CCIE,4th,Technical'
#  'SIEM,Information,Security,Risk' 'MongoDB,Node.js,Express,Angular'
#  'Solving,ITIL,Leadership,Europe,Problem,Agile'
#  'SQL,C#,Framework,Software,Server,TDD,Entity,C#.NET,WPF,MVVM,Developer,ORM'
#  'Pages,Websites,Web'
#  'SQL,Intelligence,Visualization,Data,Analytics,Big,Business'
#  'Forms,Oracle,Software,PL/SQL,Programming']
# ============================================================
# ************************************************************
# Features with missing values:
# []
#
#
# ============================================================
# Summary
#        Minimum_salary  Maximum_salary
# count     1502.000000     1502.000000
# mean        72.693658       89.749980
# std        106.629777      127.323256
# min          6.000000        7.300000
# 25%         25.000000       33.000000
# 50%         35.000000       45.000000
# 75%         50.000000       65.000000
# max        700.000000      750.000000

# %%
df['Skills'].str.join(sep='*').str.get_dummies(sep='*')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-5c71543a3ec1> in <module>()
# ----> 1 df['Skills'].str.join(sep='*').str.get_dummies(sep='*')
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2738         if (name in self._internal_names_set or name in self._metadata or
#    2739                 name in self._accessors):
# -> 2740             return object.__getattribute__(self, name)
#    2741         else:
#    2742             if name in self._info_axis:
#
# C:\Anaconda3\lib\site-packages\pandas\core\base.py in __get__(self, instance, owner)
#     239             # this ensures that Series.str.<method> is well defined
#     240             return self.accessor_cls
# --> 241         return self.construct_accessor(instance)
#     242
#     243     def __set__(self, instance, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\strings.py in _make_str_accessor(self)
#    1839             # (instead of test for object dtype), but that isn't practical for
#    1840             # performance reasons until we have a str dtype (GH 9343)
# -> 1841             raise AttributeError("Can only use .str accessor with string "
#    1842                                  "values, which use np.object_ dtype in "
#    1843                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
df.head()
# Out:
#                                             Position  Location  \
# 0                              Senior Java Developer  Hatfield
# 2                             Mobile Developer - iOS    London
# 4  4th Line Technical Engineer - Network - Junipe...   Reigate
# 5   IT Security Sales - Business Development Manager    London
# 8             Fullstack JavaScript Developer - Mongo    London
#
#    Minimum_salary  Maximum_salary  Skills
# 0           500.0           550.0       0
# 2            40.0            60.0       0
# 4            55.0            60.0       0
# 5            50.0            50.0       0
# 8           325.0           450.0       0

# %%
sentences = df['Skills']

# %%
model = gensim.models.Word2Vec(sentences, min_count=1)
# Out:
# 2017-02-18 23:34:31,244 : INFO : collecting all words and their counts
# 2017-02-18 23:34:31,245 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-15595ae006ad> in <module>()
# ----> 1 model = gensim.models.Word2Vec(sentences, min_count=1)
#
# C:\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words)
#     442             if isinstance(sentences, GeneratorType):
#     443                 raise TypeError("You can't pass a generator as the sentences argument. Try an iterator.")
# --> 444             self.build_vocab(sentences, trim_rule=trim_rule)
#     445             self.train(sentences)
#     446
#
# C:\Anaconda3\lib\site-packages\gensim\models\word2vec.py in build_vocab(self, sentences, keep_raw_vocab, trim_rule)
#     506
#     507         """
# --> 508         self.scan_vocab(sentences, trim_rule=trim_rule)  # initial survey
#     509         self.scale_vocab(keep_raw_vocab=keep_raw_vocab, trim_rule=trim_rule)  # trim by min_count & precalculate downsampling
#     510         self.finalize_vocab()  # build tables & arrays
#
# C:\Anaconda3\lib\site-packages\gensim\models\word2vec.py in scan_vocab(self, sentences, progress_per, trim_rule)
#     521                 logger.info("PROGRESS: at sentence #%i, processed %i words, keeping %i word types",
#     522                             sentence_no, sum(itervalues(vocab)) + total_words, len(vocab))
# --> 523             for word in sentence:
#     524                 vocab[word] += 1
#     525
#
# TypeError: 'float' object is not iterable
