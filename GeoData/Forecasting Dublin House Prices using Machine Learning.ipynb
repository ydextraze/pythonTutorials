# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set(style="darkgrid", color_codes=True)

# %matplotlib inline

import warnings
# %config InlineBackend.figure_format = 'png' #set 'png' here when working on notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# http://www.cso.ie/webserviceclient/DatasetListing.aspx

# %%
from pyjstat import pyjstat
# read from json-stat
url = 'http://www.cso.ie/StatbankServices/StatbankServices.svc/jsonservice/responseinstance/HPM02'
dataset = pyjstat.Dataset.read(url)
df = dataset.write('dataframe')
print(df)
# Out:
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTP connection (1): www.cso.ie
#                County        Dwelling Status Stamp Duty Event  \
# 0        All Counties  All Dwelling Statuses          Filings
# 1        All Counties  All Dwelling Statuses          Filings
# 2        All Counties  All Dwelling Statuses          Filings
# 3        All Counties  All Dwelling Statuses          Filings
# 4        All Counties  All Dwelling Statuses          Filings
# 5        All Counties  All Dwelling Statuses          Filings
# 6        All Counties  All Dwelling Statuses          Filings
# 7        All Counties  All Dwelling Statuses          Filings
# 8        All Counties  All Dwelling Statuses          Filings
# 9        All Counties  All Dwelling Statuses          Filings
# 10       All Counties  All Dwelling Statuses          Filings
# 11       All Counties  All Dwelling Statuses          Filings
# 12       All Counties  All Dwelling Statuses          Filings
# 13       All Counties  All Dwelling Statuses          Filings
# 14       All Counties  All Dwelling Statuses          Filings
# 15       All Counties  All Dwelling Statuses          Filings
# 16       All Counties  All Dwelling Statuses          Filings
# 17       All Counties  All Dwelling Statuses          Filings
# 18       All Counties  All Dwelling Statuses          Filings
# 19       All Counties  All Dwelling Statuses          Filings
# 20       All Counties  All Dwelling Statuses          Filings
# 21       All Counties  All Dwelling Statuses          Filings
# 22       All Counties  All Dwelling Statuses          Filings
# 23       All Counties  All Dwelling Statuses          Filings
# 24       All Counties  All Dwelling Statuses          Filings
# 25       All Counties  All Dwelling Statuses          Filings
# 26       All Counties  All Dwelling Statuses          Filings
# 27       All Counties  All Dwelling Statuses          Filings
# 28       All Counties  All Dwelling Statuses          Filings
# 29       All Counties  All Dwelling Statuses          Filings
# ...               ...                    ...              ...
# 1014738      Monaghan               Existing       Executions
# 1014739      Monaghan               Existing       Executions
# 1014740      Monaghan               Existing       Executions
# 1014741      Monaghan               Existing       Executions
# 1014742      Monaghan               Existing       Executions
# 1014743      Monaghan               Existing       Executions
# 1014744      Monaghan               Existing       Executions
# 1014745      Monaghan               Existing       Executions
# 1014746      Monaghan               Existing       Executions
# 1014747      Monaghan               Existing       Executions
# 1014748      Monaghan               Existing       Executions
# 1014749      Monaghan               Existing       Executions
# 1014750      Monaghan               Existing       Executions
# 1014751      Monaghan               Existing       Executions
# 1014752      Monaghan               Existing       Executions
# 1014753      Monaghan               Existing       Executions
# 1014754      Monaghan               Existing       Executions
# 1014755      Monaghan               Existing       Executions
# 1014756      Monaghan               Existing       Executions
# 1014757      Monaghan               Existing       Executions
# 1014758      Monaghan               Existing       Executions
# 1014759      Monaghan               Existing       Executions
# 1014760      Monaghan               Existing       Executions
# 1014761      Monaghan               Existing       Executions
# 1014762      Monaghan               Existing       Executions
# 1014763      Monaghan               Existing       Executions
# 1014764      Monaghan               Existing       Executions
# 1014765      Monaghan               Existing       Executions
# 1014766      Monaghan               Existing       Executions
# 1014767      Monaghan               Existing       Executions
#
#                Type of Buyer    Type of Sale    Month  \
# 0            All Buyer Types  All Sale Types  2010M01
# 1            All Buyer Types  All Sale Types  2010M01
# 2            All Buyer Types  All Sale Types  2010M01
# 3            All Buyer Types  All Sale Types  2010M01
# 4            All Buyer Types  All Sale Types  2010M02
# 5            All Buyer Types  All Sale Types  2010M02
# 6            All Buyer Types  All Sale Types  2010M02
# 7            All Buyer Types  All Sale Types  2010M02
# 8            All Buyer Types  All Sale Types  2010M03
# 9            All Buyer Types  All Sale Types  2010M03
# 10           All Buyer Types  All Sale Types  2010M03
# 11           All Buyer Types  All Sale Types  2010M03
# 12           All Buyer Types  All Sale Types  2010M04
# 13           All Buyer Types  All Sale Types  2010M04
# 14           All Buyer Types  All Sale Types  2010M04
# 15           All Buyer Types  All Sale Types  2010M04
# 16           All Buyer Types  All Sale Types  2010M05
# 17           All Buyer Types  All Sale Types  2010M05
# 18           All Buyer Types  All Sale Types  2010M05
# 19           All Buyer Types  All Sale Types  2010M05
# 20           All Buyer Types  All Sale Types  2010M06
# 21           All Buyer Types  All Sale Types  2010M06
# 22           All Buyer Types  All Sale Types  2010M06
# 23           All Buyer Types  All Sale Types  2010M06
# 24           All Buyer Types  All Sale Types  2010M07
# 25           All Buyer Types  All Sale Types  2010M07
# 26           All Buyer Types  All Sale Types  2010M07
# 27           All Buyer Types  All Sale Types  2010M07
# 28           All Buyer Types  All Sale Types  2010M08
# 29           All Buyer Types  All Sale Types  2010M08
# ...                      ...             ...      ...
# 1014738  Non-Household Buyer      Non-Market  2016M08
# 1014739  Non-Household Buyer      Non-Market  2016M08
# 1014740  Non-Household Buyer      Non-Market  2016M09
# 1014741  Non-Household Buyer      Non-Market  2016M09
# 1014742  Non-Household Buyer      Non-Market  2016M09
# 1014743  Non-Household Buyer      Non-Market  2016M09
# 1014744  Non-Household Buyer      Non-Market  2016M10
# 1014745  Non-Household Buyer      Non-Market  2016M10
# 1014746  Non-Household Buyer      Non-Market  2016M10
# 1014747  Non-Household Buyer      Non-Market  2016M10
# 1014748  Non-Household Buyer      Non-Market  2016M11
# 1014749  Non-Household Buyer      Non-Market  2016M11
# 1014750  Non-Household Buyer      Non-Market  2016M11
# 1014751  Non-Household Buyer      Non-Market  2016M11
# 1014752  Non-Household Buyer      Non-Market  2016M12
# 1014753  Non-Household Buyer      Non-Market  2016M12
# 1014754  Non-Household Buyer      Non-Market  2016M12
# 1014755  Non-Household Buyer      Non-Market  2016M12
# 1014756  Non-Household Buyer      Non-Market  2017M01
# 1014757  Non-Household Buyer      Non-Market  2017M01
# 1014758  Non-Household Buyer      Non-Market  2017M01
# 1014759  Non-Household Buyer      Non-Market  2017M01
# 1014760  Non-Household Buyer      Non-Market  2017M02
# 1014761  Non-Household Buyer      Non-Market  2017M02
# 1014762  Non-Household Buyer      Non-Market  2017M02
# 1014763  Non-Household Buyer      Non-Market  2017M02
# 1014764  Non-Household Buyer      Non-Market  2017M03
# 1014765  Non-Household Buyer      Non-Market  2017M03
# 1014766  Non-Household Buyer      Non-Market  2017M03
# 1014767  Non-Household Buyer      Non-Market  2017M03
#
#                              Statistic     value
# 0             Volume of Sales (Number)    1051.0
# 1        Value of Sales (Euro Million)     236.1
# 2           Average Sale Price  (Euro)  224686.0
# 3                  Median Price (Euro)  190000.0
# 4             Volume of Sales (Number)    1599.0
# 5        Value of Sales (Euro Million)     312.4
# 6           Average Sale Price  (Euro)  195343.0
# 7                  Median Price (Euro)  179000.0
# 8             Volume of Sales (Number)    2020.0
# 9        Value of Sales (Euro Million)     374.4
# 10          Average Sale Price  (Euro)  185347.0
# 11                 Median Price (Euro)  170000.0
# 12            Volume of Sales (Number)    1809.0
# 13       Value of Sales (Euro Million)     347.5
# 14          Average Sale Price  (Euro)  192083.0
# 15                 Median Price (Euro)  171000.0
# 16            Volume of Sales (Number)    2052.0
# 17       Value of Sales (Euro Million)     386.4
# 18          Average Sale Price  (Euro)  188316.0
# 19                 Median Price (Euro)  172750.0
# 20            Volume of Sales (Number)    2062.0
# 21       Value of Sales (Euro Million)     393.6
# 22          Average Sale Price  (Euro)  190881.0
# 23                 Median Price (Euro)  170000.0
# 24            Volume of Sales (Number)    2249.0
# 25       Value of Sales (Euro Million)     446.2
# 26          Average Sale Price  (Euro)  198395.0
# 27                 Median Price (Euro)  177000.0
# 28            Volume of Sales (Number)    2324.0
# 29       Value of Sales (Euro Million)     456.7
# ...                                ...       ...
# 1014738     Average Sale Price  (Euro)       NaN
# 1014739            Median Price (Euro)       NaN
# 1014740       Volume of Sales (Number)       0.0
# 1014741  Value of Sales (Euro Million)       0.0
# 1014742     Average Sale Price  (Euro)       NaN
# 1014743            Median Price (Euro)       NaN
# 1014744       Volume of Sales (Number)       0.0
# 1014745  Value of Sales (Euro Million)       0.0
# 1014746     Average Sale Price  (Euro)       NaN
# 1014747            Median Price (Euro)       NaN
# 1014748       Volume of Sales (Number)       0.0
# 1014749  Value of Sales (Euro Million)       0.0
# 1014750     Average Sale Price  (Euro)       NaN
# 1014751            Median Price (Euro)       NaN
# 1014752       Volume of Sales (Number)       7.0
# 1014753  Value of Sales (Euro Million)       0.4
# 1014754     Average Sale Price  (Euro)   50714.0
# 1014755            Median Price (Euro)   40000.0
# 1014756       Volume of Sales (Number)       0.0
# 1014757  Value of Sales (Euro Million)       0.0
# 1014758     Average Sale Price  (Euro)       NaN
# 1014759            Median Price (Euro)       NaN
# 1014760       Volume of Sales (Number)       0.0
# 1014761  Value of Sales (Euro Million)       0.0
# 1014762     Average Sale Price  (Euro)       NaN
# 1014763            Median Price (Euro)       NaN
# 1014764       Volume of Sales (Number)       0.0
# 1014765  Value of Sales (Euro Million)       0.0
# 1014766     Average Sale Price  (Euro)       NaN
# 1014767            Median Price (Euro)       NaN
#
# [1014768 rows x 8 columns]

# %%
df1 = pd.DataFrame.from_records(df)

# %%
#select dublin and average house prices
df_dublin = df1.loc[(df1['County'] == 'Dublin') & (df1['Statistic'] == "Average Sale Price  (Euro)")]

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("deep")
sns.pointplot(x="value", y="Month", data=df_dublin,
            label="Average Sale Price (Euro)", color="r")
sns.despine()

plt.title("Volume of Sales (Number) from January 2010 - March 2017", fontsize= 15)
plt.xlabel('Volume of Sales (Number)', fontsize=13)
plt.ylabel('Month', fontsize= 13)

# %%
#drop county and statistic
df_dublin = df_dublin.drop(["County","Statistic"] , axis = 1)

# %%
#Basic analysis of dataset
print ("\n\n---------------------")
print ("TRAIN SET INFORMATION")
print ("---------------------")
print ("Shape of training set:", df_dublin.shape, "\n")
print ("Column Headers:", list(df_dublin.columns.values), "\n")
print (df_dublin.dtypes)
# Out:
# ---------------------
# TRAIN SET INFORMATION
# ---------------------
# Shape of training set: (9396, 6)
#
# Column Headers: ['Dwelling Status', 'Stamp Duty Event', 'Type of Buyer', 'Type of Sale', 'Month', 'value']
#
# Dwelling Status      object
# Stamp Duty Event     object
# Type of Buyer        object
# Type of Sale         object
# Month                object
# value               float64
# dtype: object

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAINING SET INFORMATION")
print ("========================\n")

for column in df_dublin:
    # Find all the unique feature values
    uniq = df_dublin[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 10):
        print("~~Listing up to 10 unique values~~")
    print (uniq[0:10])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(df_dublin[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAINING SET INFORMATION
# ========================
#
# 'Dwelling Status' has 3 unique values
# ['All Dwelling Statuses' 'New' 'Existing']
#
# -----------------------------------------------------------------------
#
# 'Stamp Duty Event' has 2 unique values
# ['Filings' 'Executions']
#
# -----------------------------------------------------------------------
#
# 'Type of Buyer' has 6 unique values
# ['All Buyer Types' 'Household Buyer - All'
#  'Household Buyer - First-Time Buyer Owner-Occupier'
#  'Household Buyer - Former Owner-Occupier' 'Household Buyer - Non-Occupier'
#  'Non-Household Buyer']
#
# -----------------------------------------------------------------------
#
# 'Type of Sale' has 3 unique values
# ['All Sale Types' 'Market' 'Non-Market']
#
# -----------------------------------------------------------------------
#
# 'Month' has 87 unique values
# ~~Listing up to 10 unique values~~
# ['2010M01' '2010M02' '2010M03' '2010M04' '2010M05' '2010M06' '2010M07'
#  '2010M08' '2010M09' '2010M10']
#
# -----------------------------------------------------------------------
#
# 'value' has 7762 unique values
# ~~Listing up to 10 unique values~~
# [ 330459.  296742.  282007.  280517.  277414.  276218.  282876.  294903.
#   363999.  263370.]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# ['value has 367 missing']
#
#
# Features with non-numeric values:
# ['Dwelling Status', 'Stamp Duty Event', 'Type of Buyer', 'Type of Sale', 'Month']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#there are 367 missing value in value
df_dublin[df_dublin.value.isnull()]
# Out:
#               Dwelling Status Stamp Duty Event  \
# 81086   All Dwelling Statuses          Filings
# 87358   All Dwelling Statuses       Executions
# 88670                     New          Filings
# 88686                     New          Filings
# 88694                     New          Filings
# 89650                     New          Filings
# 89714                     New          Filings
# 89730                     New          Filings
# 89738                     New          Filings
# 90522                     New          Filings
# 90570                     New          Filings
# 90582                     New          Filings
# 90598                     New          Filings
# 90610                     New          Filings
# 90622                     New          Filings
# 90634                     New          Filings
# 90642                     New          Filings
# 90662                     New          Filings
# 90666                     New          Filings
# 90670                     New          Filings
# 90674                     New          Filings
# 90678                     New          Filings
# 90682                     New          Filings
# 90694                     New          Filings
# 90702                     New          Filings
# 90710                     New          Filings
# 90730                     New          Filings
# 90734                     New          Filings
# 90750                     New          Filings
# 90754                     New          Filings
# ...                       ...              ...
# 100082                    New       Executions
# 100086                    New       Executions
# 100094                    New       Executions
# 100106                    New       Executions
# 100110                    New       Executions
# 100118                    New       Executions
# 100122                    New       Executions
# 100126                    New       Executions
# 100130                    New       Executions
# 100142                    New       Executions
# 100146                    New       Executions
# 100150                    New       Executions
# 100154                    New       Executions
# 100162                    New       Executions
# 100170                    New       Executions
# 100174                    New       Executions
# 100178                    New       Executions
# 100182                    New       Executions
# 100186                    New       Executions
# 100190                    New       Executions
# 100194                    New       Executions
# 100198                    New       Executions
# 100202                    New       Executions
# 100210                    New       Executions
# 100214                    New       Executions
# 100218                    New       Executions
# 100222                    New       Executions
# 106142               Existing          Filings
# 106154               Existing          Filings
# 112414               Existing       Executions
#
#                                             Type of Buyer Type of Sale  \
# 81086                                 Non-Household Buyer   Non-Market
# 87358                                 Non-Household Buyer   Non-Market
# 88670                                     All Buyer Types   Non-Market
# 88686                                     All Buyer Types   Non-Market
# 88694                                     All Buyer Types   Non-Market
# 89650                               Household Buyer - All   Non-Market
# 89714                               Household Buyer - All   Non-Market
# 89730                               Household Buyer - All   Non-Market
# 89738                               Household Buyer - All   Non-Market
# 90522   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90570   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90582   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90598   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90610   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90622   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90634   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90642   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90662   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90666   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90670   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90674   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90678   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90682   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90694   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90702   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90710   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90730   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90734   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90750   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# 90754   Household Buyer - First-Time Buyer Owner-Occupier   Non-Market
# ...                                                   ...          ...
# 100082                                Non-Household Buyer   Non-Market
# 100086                                Non-Household Buyer   Non-Market
# 100094                                Non-Household Buyer   Non-Market
# 100106                                Non-Household Buyer   Non-Market
# 100110                                Non-Household Buyer   Non-Market
# 100118                                Non-Household Buyer   Non-Market
# 100122                                Non-Household Buyer   Non-Market
# 100126                                Non-Household Buyer   Non-Market
# 100130                                Non-Household Buyer   Non-Market
# 100142                                Non-Household Buyer   Non-Market
# 100146                                Non-Household Buyer   Non-Market
# 100150                                Non-Household Buyer   Non-Market
# 100154                                Non-Household Buyer   Non-Market
# 100162                                Non-Household Buyer   Non-Market
# 100170                                Non-Household Buyer   Non-Market
# 100174                                Non-Household Buyer   Non-Market
# 100178                                Non-Household Buyer   Non-Market
# 100182                                Non-Household Buyer   Non-Market
# 100186                                Non-Household Buyer   Non-Market
# 100190                                Non-Household Buyer   Non-Market
# 100194                                Non-Household Buyer   Non-Market
# 100198                                Non-Household Buyer   Non-Market
# 100202                                Non-Household Buyer   Non-Market
# 100210                                Non-Household Buyer   Non-Market
# 100214                                Non-Household Buyer   Non-Market
# 100218                                Non-Household Buyer   Non-Market
# 100222                                Non-Household Buyer   Non-Market
# 106142                                Non-Household Buyer   Non-Market
# 106154                                Non-Household Buyer   Non-Market
# 112414                                Non-Household Buyer   Non-Market
#
#           Month  value
# 81086   2010M01    NaN
# 87358   2010M03    NaN
# 88670   2015M10    NaN
# 88686   2016M02    NaN
# 88694   2016M04    NaN
# 89650   2014M06    NaN
# 89714   2015M10    NaN
# 89730   2016M02    NaN
# 89738   2016M04    NaN
# 90522   2010M11    NaN
# 90570   2011M11    NaN
# 90582   2012M02    NaN
# 90598   2012M06    NaN
# 90610   2012M09    NaN
# 90622   2012M12    NaN
# 90634   2013M03    NaN
# 90642   2013M05    NaN
# 90662   2013M10    NaN
# 90666   2013M11    NaN
# 90670   2013M12    NaN
# 90674   2014M01    NaN
# 90678   2014M02    NaN
# 90682   2014M03    NaN
# 90694   2014M06    NaN
# 90702   2014M08    NaN
# 90710   2014M10    NaN
# 90730   2015M03    NaN
# 90734   2015M04    NaN
# 90750   2015M08    NaN
# 90754   2015M09    NaN
# ...         ...    ...
# 100082  2014M04    NaN
# 100086  2014M05    NaN
# 100094  2014M07    NaN
# 100106  2014M10    NaN
# 100110  2014M11    NaN
# 100118  2015M01    NaN
# 100122  2015M02    NaN
# 100126  2015M03    NaN
# 100130  2015M04    NaN
# 100142  2015M07    NaN
# 100146  2015M08    NaN
# 100150  2015M09    NaN
# 100154  2015M10    NaN
# 100162  2015M12    NaN
# 100170  2016M02    NaN
# 100174  2016M03    NaN
# 100178  2016M04    NaN
# 100182  2016M05    NaN
# 100186  2016M06    NaN
# 100190  2016M07    NaN
# 100194  2016M08    NaN
# 100198  2016M09    NaN
# 100202  2016M10    NaN
# 100210  2016M12    NaN
# 100214  2017M01    NaN
# 100218  2017M02    NaN
# 100222  2017M03    NaN
# 106142  2010M01    NaN
# 106154  2010M04    NaN
# 112414  2010M03    NaN
#
# [367 rows x 6 columns]

# %% [markdown]
# Looking at the table above it seems it belongs to Non-market. According to
# https://en.wikipedia.org/wiki/Nonmarket_forces
#
# Non market forces seems to have less effect on the values , hence we will delete these rows.

# %%
df_dublin = df_dublin[pd.notnull(df_dublin['value'])]

# %%
df_dublin.head()
# Out:
#              Dwelling Status Stamp Duty Event    Type of Buyer  \
# 75170  All Dwelling Statuses          Filings  All Buyer Types
# 75174  All Dwelling Statuses          Filings  All Buyer Types
# 75178  All Dwelling Statuses          Filings  All Buyer Types
# 75182  All Dwelling Statuses          Filings  All Buyer Types
# 75186  All Dwelling Statuses          Filings  All Buyer Types
#
#          Type of Sale    Month     value
# 75170  All Sale Types  2010M01  330459.0
# 75174  All Sale Types  2010M02  296742.0
# 75178  All Sale Types  2010M03  282007.0
# 75182  All Sale Types  2010M04  280517.0
# 75186  All Sale Types  2010M05  277414.0

# %%
plt.plot(df_dublin.value)
plt.xlabel('Average Sale Price  (Euro)')
plt.ylabel('Probability')
plt.title("Dublin'Average Sale Price  (Euro) from 2010 to 2017")

# %%
df_dublin.describe()
# Out:
#               value
# count  9.029000e+03
# mean   2.702339e+05
# std    4.472660e+05
# min    0.000000e+00
# 25%    1.320720e+05
# 50%    2.598000e+05
# 75%    3.399200e+05
# max    2.183083e+07

# %%
df_dublin.loc[(df_dublin['value'] == 0.0)]
# Out:
#               Dwelling Status Stamp Duty Event  \
# 81098   All Dwelling Statuses          Filings
# 81102   All Dwelling Statuses          Filings
# 81114   All Dwelling Statuses          Filings
# 81134   All Dwelling Statuses          Filings
# 81194   All Dwelling Statuses          Filings
# 81306   All Dwelling Statuses          Filings
# 87366   All Dwelling Statuses       Executions
# 87386   All Dwelling Statuses       Executions
# 87458   All Dwelling Statuses       Executions
# 88414                     New          Filings
# 88562                     New          Filings
# 88574                     New          Filings
# 88602                     New          Filings
# 88606                     New          Filings
# 88610                     New          Filings
# 88622                     New          Filings
# 88626                     New          Filings
# 88666                     New          Filings
# 88682                     New          Filings
# 88690                     New          Filings
# 88698                     New          Filings
# 88734                     New          Filings
# 88738                     New          Filings
# 89458                     New          Filings
# 89526                     New          Filings
# 89606                     New          Filings
# 89618                     New          Filings
# 89626                     New          Filings
# 89630                     New          Filings
# 89646                     New          Filings
# ...                       ...              ...
# 99130                     New       Executions
# 99138                     New       Executions
# 99146                     New       Executions
# 99154                     New       Executions
# 99162                     New       Executions
# 99174                     New       Executions
# 99206                     New       Executions
# 99334                     New       Executions
# 99406                     New       Executions
# 99470                     New       Executions
# 99898                     New       Executions
# 99902                     New       Executions
# 99934                     New       Executions
# 99938                     New       Executions
# 99942                     New       Executions
# 99990                     New       Executions
# 100030                    New       Executions
# 100090                    New       Executions
# 100102                    New       Executions
# 100166                    New       Executions
# 106158               Existing          Filings
# 106170               Existing          Filings
# 106190               Existing          Filings
# 106250               Existing          Filings
# 106362               Existing          Filings
# 112410               Existing       Executions
# 112422               Existing       Executions
# 112442               Existing       Executions
# 112514               Existing       Executions
# 112626               Existing       Executions
#
#                          Type of Buyer    Type of Sale    Month  value
# 81098              Non-Household Buyer      Non-Market  2010M04    0.0
# 81102              Non-Household Buyer      Non-Market  2010M05    0.0
# 81114              Non-Household Buyer      Non-Market  2010M08    0.0
# 81134              Non-Household Buyer      Non-Market  2011M01    0.0
# 81194              Non-Household Buyer      Non-Market  2012M04    0.0
# 81306              Non-Household Buyer      Non-Market  2014M08    0.0
# 87366              Non-Household Buyer      Non-Market  2010M05    0.0
# 87386              Non-Household Buyer      Non-Market  2010M10    0.0
# 87458              Non-Household Buyer      Non-Market  2012M04    0.0
# 88414                  All Buyer Types      Non-Market  2010M06    0.0
# 88562                  All Buyer Types      Non-Market  2013M07    0.0
# 88574                  All Buyer Types      Non-Market  2013M10    0.0
# 88602                  All Buyer Types      Non-Market  2014M05    0.0
# 88606                  All Buyer Types      Non-Market  2014M06    0.0
# 88610                  All Buyer Types      Non-Market  2014M07    0.0
# 88622                  All Buyer Types      Non-Market  2014M10    0.0
# 88626                  All Buyer Types      Non-Market  2014M11    0.0
# 88666                  All Buyer Types      Non-Market  2015M09    0.0
# 88682                  All Buyer Types      Non-Market  2016M01    0.0
# 88690                  All Buyer Types      Non-Market  2016M03    0.0
# 88698                  All Buyer Types      Non-Market  2016M05    0.0
# 88734                  All Buyer Types      Non-Market  2017M02    0.0
# 88738                  All Buyer Types      Non-Market  2017M03    0.0
# 89458            Household Buyer - All      Non-Market  2010M06    0.0
# 89526            Household Buyer - All      Non-Market  2011M11    0.0
# 89606            Household Buyer - All      Non-Market  2013M07    0.0
# 89618            Household Buyer - All      Non-Market  2013M10    0.0
# 89626            Household Buyer - All      Non-Market  2013M12    0.0
# 89630            Household Buyer - All      Non-Market  2014M01    0.0
# 89646            Household Buyer - All      Non-Market  2014M05    0.0
# ...                                ...             ...      ...    ...
# 99130   Household Buyer - Non-Occupier      Non-Market  2016M03    0.0
# 99138   Household Buyer - Non-Occupier      Non-Market  2016M05    0.0
# 99146   Household Buyer - Non-Occupier      Non-Market  2016M07    0.0
# 99154   Household Buyer - Non-Occupier      Non-Market  2016M09    0.0
# 99162   Household Buyer - Non-Occupier      Non-Market  2016M11    0.0
# 99174   Household Buyer - Non-Occupier      Non-Market  2017M02    0.0
# 99206              Non-Household Buyer  All Sale Types  2010M07    0.0
# 99334              Non-Household Buyer  All Sale Types  2013M03    0.0
# 99406              Non-Household Buyer  All Sale Types  2014M09    0.0
# 99470              Non-Household Buyer  All Sale Types  2016M01    0.0
# 99898              Non-Household Buyer      Non-Market  2010M06    0.0
# 99902              Non-Household Buyer      Non-Market  2010M07    0.0
# 99934              Non-Household Buyer      Non-Market  2011M03    0.0
# 99938              Non-Household Buyer      Non-Market  2011M04    0.0
# 99942              Non-Household Buyer      Non-Market  2011M05    0.0
# 99990              Non-Household Buyer      Non-Market  2012M05    0.0
# 100030             Non-Household Buyer      Non-Market  2013M03    0.0
# 100090             Non-Household Buyer      Non-Market  2014M06    0.0
# 100102             Non-Household Buyer      Non-Market  2014M09    0.0
# 100166             Non-Household Buyer      Non-Market  2016M01    0.0
# 106158             Non-Household Buyer      Non-Market  2010M05    0.0
# 106170             Non-Household Buyer      Non-Market  2010M08    0.0
# 106190             Non-Household Buyer      Non-Market  2011M01    0.0
# 106250             Non-Household Buyer      Non-Market  2012M04    0.0
# 106362             Non-Household Buyer      Non-Market  2014M08    0.0
# 112410             Non-Household Buyer      Non-Market  2010M02    0.0
# 112422             Non-Household Buyer      Non-Market  2010M05    0.0
# 112442             Non-Household Buyer      Non-Market  2010M10    0.0
# 112514             Non-Household Buyer      Non-Market  2012M04    0.0
# 112626             Non-Household Buyer      Non-Market  2014M08    0.0
#
# [236 rows x 6 columns]

# %%
no_outliers = df_dublin[np.abs(df_dublin.value-df_dublin.value.mean())<=(2*df_dublin.value.std())]

fig = plt.figure(figsize=(20, 10))
ax = plt.subplot(111)
ax.spines["top"].set_visible(False) 
ax.spines["right"].set_visible(False)
ax.spines['left'].set_color('#1a1a1a')
ax.spines['bottom'].set_color('#1a1a1a')

ax.get_xaxis().tick_bottom()  
ax.get_yaxis().tick_left()

plt.xticks(fontsize=14, color='#1a1a1a')  
plt.yticks(fontsize=14, color='#1a1a1a')

plt.title("Dublin's Average Sale Price distribution 2010 - 2017 (outliers removed)", fontsize=30)
plt.xlabel('Price (Euro)', fontsize=20)
plt.ylabel('Frequency', fontsize=20)

plt.hist(no_outliers.value, bins=100);

# %%
#draw a histogram and not fit a kernel density estimate (KDE).
sns.distplot(df_dublin['value'], kde = True, color = 'b', hist_kws={'alpha': 0.9})

# %%
df_dublin['Dwelling Status'].value_counts().plot.bar()

# %%
df_dublin['Stamp Duty Event'].value_counts()
# Out:
# Filings       4532
# Executions    4497
# Name: Stamp Duty Event, dtype: int64

# %%
df_dublin['Type of Buyer'].value_counts().plot.bar()

# %%
dwelling_buyer_table = pd.crosstab(index=df_dublin["Type of Buyer"], 
                          columns=df_dublin["Dwelling Status"])

dwelling_buyer_table.plot(kind="bar", 
                 figsize=(8,8),
                 stacked=True)

# %%
df_dublin['Type of Sale'].value_counts()
# Out:
# All Sale Types    3114
# Market            3103
# Non-Market        2812
# Name: Type of Sale, dtype: int64

# %%
df_dublin.boxplot(column= 'value')

# %%
sns.pairplot(df_dublin, size=2.5)

# %%
plt.figure(figsize = (6, 4))
sns.boxplot(x = 'Type of Buyer', y = 'value',  data = df_dublin)
xt = plt.xticks(rotation=90)

# %%
df_dublin.Month
# Out:
# 75170     2010M01
# 75174     2010M02
# 75178     2010M03
# 75182     2010M04
# 75186     2010M05
# 75190     2010M06
# 75194     2010M07
# 75198     2010M08
# 75202     2010M09
# 75206     2010M10
# 75210     2010M11
# 75214     2010M12
# 75218     2011M01
# 75222     2011M02
# 75226     2011M03
# 75230     2011M04
# 75234     2011M05
# 75238     2011M06
# 75242     2011M07
# 75246     2011M08
# 75250     2011M09
# 75254     2011M10
# 75258     2011M11
# 75262     2011M12
# 75266     2012M01
# 75270     2012M02
# 75274     2012M03
# 75278     2012M04
# 75282     2012M05
# 75286     2012M06
#            ...
# 112634    2014M10
# 112638    2014M11
# 112642    2014M12
# 112646    2015M01
# 112650    2015M02
# 112654    2015M03
# 112658    2015M04
# 112662    2015M05
# 112666    2015M06
# 112670    2015M07
# 112674    2015M08
# 112678    2015M09
# 112682    2015M10
# 112686    2015M11
# 112690    2015M12
# 112694    2016M01
# 112698    2016M02
# 112702    2016M03
# 112706    2016M04
# 112710    2016M05
# 112714    2016M06
# 112718    2016M07
# 112722    2016M08
# 112726    2016M09
# 112730    2016M10
# 112734    2016M11
# 112738    2016M12
# 112742    2017M01
# 112746    2017M02
# 112750    2017M03
# Name: Month, dtype: object

# %%
#https://stackoverflow.com/questions/31617845/how-to-select-rows-in-a-dataframe-between-two-values-in-python-pandas
df_10_106 = df_dublin[df_dublin['Month'].between('2010M01', '2010M06', inclusive=True)]

# %%
sns.barplot(x='Month', y='value', data=df_10_106)
sns.despine()

# %%
df_107_1012 = df_dublin[df_dublin['Month'].between('2010M07', '2010M12', inclusive=True)]

# %%
sns.barplot(x='Month', y='value', data=df_107_1012)
sns.despine()

# %%
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# Tell pointplot to plot on ax1 with the ax argument
sns.barplot(x="Month", y="value", data=df_10_106, ax=ax1)

# Tell pointplot to plot on ax2 with the ax argument
sns.barplot(x="Month", y="value", data=df_107_1012, ax=ax2)

# %%
#Year 2011
df_11_1106 = df_dublin[df_dublin['Month'].between('2011M01', '2011M06', inclusive=True)]
df_117_1112 = df_dublin[df_dublin['Month'].between('2011M07', '2011M12', inclusive=True)]
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# Tell pointplot to plot on ax1 with the ax argument
sns.barplot(x="Month", y="value", data=df_11_1106, ax=ax1)
sns.despine()

# Tell pointplot to plot on ax2 with the ax argument
sns.barplot(x="Month", y="value", data=df_117_1112, ax=ax2)
sns.despine()

# %%
#Year 2012
df_12_1206 = df_dublin[df_dublin['Month'].between('2012M01', '2012M06', inclusive=True)]
df_127_1212 = df_dublin[df_dublin['Month'].between('2012M07', '2012M12', inclusive=True)]
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)


# Tell pointplot to plot on ax1 with the ax argument
sns.barplot(x="Month", y="value", data=df_12_1206, ax=ax1)
sns.despine()

# Tell pointplot to plot on ax2 with the ax argument
sns.barplot(x="Month", y="value", data=df_127_1212, ax=ax2)
sns.despine()

# %%
#Year 2013
df_13_1306 = df_dublin[df_dublin['Month'].between('2013M01', '2013M06', inclusive=True)]
df_137_1312 = df_dublin[df_dublin['Month'].between('2013M07', '2013M12', inclusive=True)]
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)


# Tell pointplot to plot on ax1 with the ax argument
sns.barplot(x="Month", y="value", data=df_13_1306, ax=ax1)
sns.despine()

# Tell pointplot to plot on ax2 with the ax argument
sns.barplot(x="Month", y="value", data=df_137_1312, ax=ax2)
sns.despine()

# %%
#Year 2014
df_14_1406 = df_dublin[df_dublin['Month'].between('2014M01', '2014M06', inclusive=True)]
df_147_1412 = df_dublin[df_dublin['Month'].between('2014M07', '2014M12', inclusive=True)]
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)


# Tell pointplot to plot on ax1 with the ax argument
sns.barplot(x="Month", y="value", data=df_14_1406, ax=ax1)
sns.despine()

# Tell pointplot to plot on ax2 with the ax argument
sns.barplot(x="Month", y="value", data=df_147_1412, ax=ax2)
sns.despine()

# %% [markdown]
# # The Bar plot the mean value is not consistent

# %%
#Year 2015 - 17
df_15_1703 = df_dublin[df_dublin['Month'].between('2015M01', '2017M03', inclusive=True)]

# %%
df_15_1703.value.mean()
# Out:
# 306713.98568872985

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="value", y="Month", data=df_15_1703,
            label="Average Sale Price (Euro)", color="b")
sns.despine()
plt.title("Average Sale Price (Euro) from January 2015 - March 2017", fontsize= 15)
plt.xlabel('Average Sale Price', fontsize=14)
plt.ylabel('Month', fontsize= 14)

# %%
#Year 2016 - 17
df_16_1703 = df_dublin[df_dublin['Month'].between('2016M01', '2017M03', inclusive=True)]

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 6))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="value", y="Month", data=df_16_1703,
             color="b")
sns.despine(left=True, bottom=True)

plt.title("Average Sale Price (Euro) from January 2016 - March 2017", fontsize= 15)
plt.xlabel('Average Sale Price', fontsize=14)
plt.ylabel('Month', fontsize= 14)

# %%
#Year 2016 - 17 for first time buyers and new dwelling
df_16_1703_first = df_16_1703.loc[(df_16_1703['Type of Buyer'] == 'Household Buyer - First-Time Buyer Owner-Occupier') & (df_16_1703["Dwelling Status"] == "New")]
sns.set(style="ticks")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 6))

# Plot the total crashes
sns.set_color_codes("deep")
sns.barplot(x="value", y="Month", data=df_16_1703_first,
             color="g")
sns.despine(left=True, bottom=True)
plt.title("First Time Buyers from January 2016 - March 2017 for New Dwellings", fontsize= 12 )
plt.xlabel('Average Sale Price', fontsize=10)
plt.ylabel('Month', fontsize= 10)

# %%
#Year 2016 - 17 for first time buyers and new dwelling
df_16_1703_first = df_16_1703.loc[(df_16_1703['Type of Buyer'] == 'Household Buyer - First-Time Buyer Owner-Occupier') & (df_16_1703["Dwelling Status"] == "Existing")]
sns.set(style="ticks")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 6))

# Plot the total crashes
sns.set_color_codes("deep")
sns.barplot(x="value", y="Month", data=df_16_1703_first,
             color="m")
sns.despine(left=True, bottom=True)
plt.title("First Time Buyers from January 2016 - March 2017 for Existing Dwellings", fontsize= 12 )
plt.xlabel('Average Sale Price', fontsize=10)
plt.ylabel('Month', fontsize= 10)

# %% [markdown]
# sns.swarmplot(x="Month", y="value", data=df_10_106)

# %%
# plot with various axes scales
plt.figure()
sns.stripplot(x="Month", y="value", data=df_10_106,jitter = True)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# %%
df_107_1012 = df_dublin[df_dublin['Month'].between('2010M07', '2010M12', inclusive=True)]

# %%
# plot with various axes scales
plt.figure()
sns.pointplot(x="Month", y="value", data=df_107_1012)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# %%
# Create a figure instance, and the two subplots
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# Tell pointplot to plot on ax1 with the ax argument
sns.pointplot(x="Month", y="value", data=df_10_106, ax=ax1)

# Tell pointplot to plot on ax2 with the ax argument
sns.pointplot(x="Month", y="value", data=df_107_1012, ax=ax2)

# %%
df_11_1106 = df_dublin[df_dublin['Month'].between('2011M01', '2011M06', inclusive=True)]
df_117_1112 = df_dublin[df_dublin['Month'].between('2011M07', '2011M12', inclusive=True)]

# %%
g = sns.FacetGrid(df_107_1012, col="value",  row="Month")
g = g.map(sns.pointplot)

# %%
df_10_106 = df_dublin[df_dublin['Month'].between('2010M01', '2010M06', inclusive=True)]
