# %%
#http://drivendata.co/blog/worldbank-poverty-benchmark/

# %matplotlib inline

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# data directory
DATA_DIR = os.path.join(r'C:\Users\piush\Desktop\Dataset\world_bank_poverty_data\household')

# %%
data_paths = {'A': {'train': os.path.join(DATA_DIR,  'A_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'A_hhold_test.csv')}, 
              
              'B': {'train': os.path.join(DATA_DIR,  'B_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'B_hhold_test.csv')}, 
              
              'C': {'train': os.path.join(DATA_DIR,  'C_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'C_hhold_test.csv')}}

# %%
# load training data
a_train = pd.read_csv(data_paths['A']['train'], index_col='id')
b_train = pd.read_csv(data_paths['B']['train'], index_col='id')
c_train = pd.read_csv(data_paths['C']['train'], index_col='id')

# %%
class LabelCount(object):

    def __init__(self, columns, new_column=False):
        self.count_dict = {}
        self.columns = columns
        self.new_column = new_column
        
    
    def fit(self, df):

        for column in self.columns:
            count = df[column].value_counts()
            
            self.count_dict[column] = count.to_dict()
        
    def transform(self, df):
        for column in self.columns:
            
            new_column_name = column
            
            if self.new_column:
                new_column_name = column + "_label_count"

            missing = 1
            df[new_column_name] = df[column].apply(lambda x : self.count_dict[column].get(x, missing))

# %% [markdown]
# ###### Label Count

# %%
for i in a_train.columns:
    print(a_train[i].value_counts())
# Out:
# JhtDR    8095
# DkQlr     108
# Name: wBXbHZmp, dtype: int64
# GUusz    6015
# alLXR    2188
# Name: SlDKnCuu, dtype: int64
# TuovO    5252
# BIZns    2849
# rqUAG     102
# Name: KAJOWiiw, dtype: int64
# ZYabk    7728
# QGgpH     475
# Name: DsKacCdL, dtype: int64
# feupP    7560
# uxuSS     643
# Name: rtPrBBPl, dtype: int64
# PHMVg    7797
# VYpgU     406
# Name: tMJrvvut, dtype: int64
# NDTCU    6928
# PUBDZ    1275
# Name: jdetlNNF, dtype: int64
# sehIp    6860
# cLAGr     964
# TcuXF     379
# Name: maLAYXwi, dtype: int64
# sPNOc    398
# esAQH    381
# qcizG    272
# AjMVN    272
# mIqzL    267
# vVbnO    267
# IDkCg    267
# yygvO    266
# RpXJc    265
# bUhyU    263
# ARuYG    263
# XHmQd    259
# shPwO    258
# yKWYC    258
# lwCkE    256
# ZCIYy    256
# VJaVA    253
# qNABl    253
# QRKWz    253
# tXtkv    253
# SaVqO    252
# qXvRS    250
# hmAUm    250
# ZlqSm    249
# NdlDR    249
# xzgJe    248
# puHHm    248
# DBUky    247
# IJnCs    246
# BidgV    245
# XAmOF    239
# Name: vwpsXRGk, dtype: int64
# MwLvg    8139
# IVbQJ      64
# Name: sArDRIyX, dtype: int64
# wSMgG    8174
# HXAld      29
# Name: goxNwvnG, dtype: int64
# sdlSU    8058
# WQHDZ     145
# Name: TYhoEiNm, dtype: int64
# aSGQn    7941
# yqxGT     262
# Name: bgfNZfcj, dtype: int64
# nMLtq    8149
# iZuWM      54
# Name: sYIButva, dtype: int64
# AtADK    5252
# usVYt    2936
# TXVyB      15
# Name: VZtBaoXL, dtype: int64
# JGQEQ    8169
# Smcsc      34
# Name: GUvFHPNA, dtype: int64
# zlEqv    5485
# JETTQ    1741
# RnjPp     977
# Name: zFkComtB, dtype: int64
# WobIQ    7956
# UcpSR     247
# Name: fxbqfEWb, dtype: int64
# PSbhz    8191
# iTCRl      12
# Name: HDMHzGif, dtype: int64
# CtanB    6790
# Xtgis    1413
# Name: zzwlWZZC, dtype: int64
# nvuhC    7113
# ltpcC    1090
# Name: nGTepfos, dtype: int64
# GEOXc    4740
# VbCFp    3463
# Name: DxLvCGgv, dtype: int64
# tIJga    7129
# oHRvd     964
# VeoCE     110
# Name: CbABToOI, dtype: int64
# ffsLD    4091
# Bdpcw    2298
# mCgXS     748
# vswDo     393
# fqfAt     354
# NLzKp     222
# afxHM      74
# hGXsD      17
# pTCuA       6
# Name: qgMygRvX, dtype: int64
# nJuqx    8013
# XqDGz     190
# Name: fhKiXuMY, dtype: int64
# uPkpA    7019
# HNHAn    1184
# Name: uSKnVaKV, dtype: int64
# ZZLWA    5252
# qmAUD    2921
# tLvyF      30
# Name: hESBInAl, dtype: int64
# AMonU    7226
# oKdrT     964
# tWXrX      13
# Name: nzTeWUeM, dtype: int64
# cyHKs    7793
# VxayU     410
# Name: BbKZUYsB, dtype: int64
# GuzQO    7009
# GELir    1194
# Name: UCnazcxd, dtype: int64
# ZkQxz    8188
# SLlcX      15
# Name: hTraVEWP, dtype: int64
# kgmhs    8141
# PSJTO      62
# Name: aCfsveTu, dtype: int64
# vdDgH    7894
# HPKQV     309
# Name: EfkPrfXa, dtype: int64
# sdZwV    8139
# FExyX      64
# Name: NrvxpdMQ, dtype: int64
# -4.0     5077
# -10.0    1940
# -16.0     845
# -22.0     202
# -28.0      76
# -34.0      37
# -40.0      12
# -46.0       7
# -52.0       4
# -64.0       2
# -70.0       1
# Name: nEsgxvAq, dtype: int64
# AsSEW    7235
# jkpcP     964
# FdmMx       4
# Name: FcekeISI, dtype: int64
# buans    7835
# srfRJ     368
# Name: NmAVTtfA, dtype: int64
# dROpA    4631
# SDrXD    3338
# qdnoF     234
# Name: YTdCRVJt, dtype: int64
# LKzoc    5309
# WUJmr    2894
# Name: QyBloWXZ, dtype: int64
# aDHDh    8196
# HxWwl       7
# Name: NGOnRdqc, dtype: int64
# ObBVP    6263
# asAMg     976
# nqAId     964
# Name: HKMQJANN, dtype: int64
# ZMPHr    5003
# ywnPq    3200
# Name: ZRrposmO, dtype: int64
# DBYFB    5035
# AtJzc    3168
# Name: wakWLjkG, dtype: int64
# hACfi    8176
# sfcDZ      27
# Name: vmZttwFZ, dtype: int64
# fdbOn    8125
# YWmHv      78
# Name: dkoIJCbY, dtype: int64
# hWZvm    5252
# BnEzq    2896
# UFOVN      55
# Name: NrUWfvEq, dtype: int64
# IbIUY    8193
# ATBPa      10
# Name: WqhniYIc, dtype: int64
# vfweT    8129
# YScDp      74
# Name: yHbEDILT, dtype: int64
# wdCvs    6201
# KdnLw    2002
# Name: EJgrQqET, dtype: int64
# SokyU    8146
# UKOES      57
# Name: nGMEgWyl, dtype: int64
# uVrbm    7458
# DXLhU     745
# Name: IIEHQNUc, dtype: int64
# QFawF    6493
# UdKcj    1710
# Name: HfKRIwMb, dtype: int64
# Lgwgt    3800
# gLHsu    2485
# mkOIj    1097
# sbeOr     556
# AxwRL     177
# kiAJB      40
# qOgkL      34
# GqvRD      10
# rpEnA       4
# Name: NRVuZwXK, dtype: int64
# oRtiU    4537
# ycFDT    3666
# Name: UCAmikjV, dtype: int64
# UbtLs    7235
# CdOJh     968
# Name: UGbBCHRE, dtype: int64
# GJSmz    7268
# WQPIf     935
# Name: uJYGhXqG, dtype: int64
# FWMHx    7607
# bDOph     596
# Name: bxKGlBYX, dtype: int64
# DkINd    8108
# Bqyxs      95
# Name: nCzVgxgY, dtype: int64
# aaPgB    3655
# eGKYm    2054
# xoMGF    1775
# qfNQz     719
# Name: ltcNxFzI, dtype: int64
# QKdak    8182
# hNkZm      21
# Name: WbEDLWBH, dtype: int64
# ZUFtA    8181
# KlXHR      22
# Name: IBPMYJlv, dtype: int64
# Cttil    8047
# opKSl     156
# Name: MxOgekdE, dtype: int64
# nmBHL    4589
# vJxeZ    3614
# Name: ggNglVqE, dtype: int64
# ESZVQ    8189
# HspDh      14
# Name: YDgWYWcJ, dtype: int64
# jGNyr    5027
# QiWxT    2581
# KFwaq     595
# Name: SqGRfEuW, dtype: int64
# iHtOk    5252
# MLQXR    2726
# qmJHY     225
# Name: WiwmbjGW, dtype: int64
# jzcPS    8167
# coAxL      36
# Name: benRXROb, dtype: int64
# vLHhC    8172
# okNWr      31
# Name: cOSBrarW, dtype: int64
# WnTLO    4357
# kaiUF    3846
# Name: JwtIxvKg, dtype: int64
# mwImW    8137
# twDig      66
# Name: lRGpWehf, dtype: int64
# mbAAs    8150
# mlKLM      53
# Name: dSALvhyd, dtype: int64
# QLhGp    4932
# rPlHB    2538
# gWYrF     733
# Name: gfmfEyjQ, dtype: int64
# FnIvn    8176
# aaNTa      27
# Name: WbxAxHul, dtype: int64
# Zloxq    4902
# CalgA    3301
# Name: FlBqizNL, dtype: int64
# RJueq    7476
# JPmiP     727
# Name: bEPKkJXP, dtype: int64
# qzGkS    2655
# Lsuai    2163
# KfoTG    1876
# ljBjd     762
# GVYCk     323
# AfgYR     178
# tnDpM     166
# UhSVl      80
# Name: KjkrfGLD, dtype: int64
# btzNc    7196
# OsWDo     964
# YummV      43
# Name: JbjHTYUM, dtype: int64
# flaUT    5252
# XDRNN    2943
# DOsnH       8
# Name: HmDAlkAH, dtype: int64
# IXFlv    6539
# NdMeQ     990
# RZNMQ     405
# VFAuL     245
# UgFtF      16
# Hdfye       8
# Name: cqUmYeAp, dtype: int64
# UVHjq    7942
# rBNeu     261
# Name: sFWbFEso, dtype: int64
# AdsXN    8082
# CTJkE     121
# Name: fHUZugEd, dtype: int64
# WgZWE    7846
# ypOMV     357
# Name: tZKoAqgl, dtype: int64
# UVVLc    7975
# ihCpA     228
# Name: TqrXZaOw, dtype: int64
# AUjeY    7253
# mizNl     950
# Name: galsfNtg, dtype: int64
# DYJcq    5313
# TUHSx    2890
# Name: VIRwrkXp, dtype: int64
# TgJJO    7969
# oRMnJ     234
# Name: dsIjcEFe, dtype: int64
# gaKub    6181
# efFyt    2022
# Name: OybQOufM, dtype: int64
# dWjOX    6025
# cuIZH    2178
# Name: ihGjxdDj, dtype: int64
# txrXc    7758
# SrVwP     445
# Name: gwhBRami, dtype: int64
# QDLBV    8144
# snqZf      59
# Name: FGYOIJbC, dtype: int64
# THHLT    3974
# mDadf    1648
# zPfZR    1515
# WXYiE     542
# hMHca     315
# DnomH     209
# Name: bPOwgKnT, dtype: int64
# bTham    8170
# kvCsp      33
# Name: lybuQXPm, dtype: int64
# NfQSU    7072
# vlSxF     964
# PKIOC     167
# Name: UBanubTh, dtype: int64
# TGEpP    8130
# ufskM      73
# Name: JeydMEpC, dtype: int64
# JueeR    7481
# zZmVq     722
# Name: fpHOwfAs, dtype: int64
# AtMKj    7570
# qfRrQ     633
# Name: VXXLUaXP, dtype: int64
# KYiZb    7761
# zVFte     442
# Name: btgWptTG, dtype: int64
# mjTMV    7787
# rdvxf     416
# Name: NIRMacrk, dtype: int64
# WONMC    7670
# XOlpR     533
# Name: YWwNfVtR, dtype: int64
# XrqGT    7150
# eUtuh    1053
# Name: wxDnGIwN, dtype: int64
# DtMvg    3989
# qTmDg    1278
# rXCdD    1136
# zeYAm     933
# TKfyw     867
# Name: rAkSnhJF, dtype: int64
# dOgle    8113
# gmcLS      90
# Name: EMDSHIlJ, dtype: int64
# wKWZx    6999
# wpOnp    1204
# Name: bgoWYRMQ, dtype: int64
# bkswa    4687
# OcHBc    3516
# Name: glEjrMIg, dtype: int64
# uTgod    5985
# mOETh    2218
# Name: bMudmjzJ, dtype: int64
# DDOFi    7235
# fVvMw     964
# xOoQP       4
# Name: GKUhYLAE, dtype: int64
# LDyDX    8046
# sbxXu     157
# Name: OnTaJkLa, dtype: int64
# fSMSz    7842
# Hltat     361
# Name: SsZAZLma, dtype: int64
# QZujc    7643
# IjEdt     560
# Name: BMmgMRvd, dtype: int64
#  12     2856
#  21     2379
#  3      1250
#  30     1194
#  39      299
#  48      116
# -6        65
#  57       26
#  66        9
#  75        5
#  93        2
#  111       1
# -127       1
# Name: OMtioXZZ, dtype: int64
# wQABW    5252
# ALZyK    1754
# qqkkL    1197
# Name: bIBQTaHw, dtype: int64
# VFlsG    7103
# EbwxU    1100
# Name: KcArMKAe, dtype: int64
# ioccr    8023
# CUTFq     180
# Name: ofhkZaYa, dtype: int64
# ujSKY    8147
# vWcDA      56
# Name: VtcDnwsf, dtype: int64
# GttxB    7926
# UVunH     277
# Name: TFrimNtw, dtype: int64
# eTMbs    8102
# wRJec     101
# Name: enTUTSQi, dtype: int64
# ZHiRw    5978
# yVlbR    2065
# prLFI     134
# qQWKw      18
# fhqPC       7
# tFrTi       1
# Name: LjvKYNON, dtype: int64
# obtnu    7431
# SranW     772
# Name: wwfmpuWA, dtype: int64
# uDkol    6243
# OCLak    1960
# Name: znHDEHZP, dtype: int64
# InbSQ    6580
# ddRKR    1623
# Name: kWFVfHWP, dtype: int64
# ncoFd    8069
# vtHBY     134
# Name: XwVALSPR, dtype: int64
# xsqtn    8104
# ozBug      99
# Name: TvShZEBA, dtype: int64
# EyaLN    7812
# ZQDXs     391
# Name: nuwxPLMe, dtype: int64
# hHXMH    7726
# RQQsQ     477
# Name: eeYoszDM, dtype: int64
# llGfE    4505
# ExDLJ    3183
# ZhGcs     515
# Name: HHAeIHna, dtype: int64
# ccdEk    5089
# xtqoI    3114
# Name: CrfscGZl, dtype: int64
# SPzuq    7012
# ENNVU    1191
# Name: dCGNTMiG, dtype: int64
# auPiK    6983
# twMTS    1220
# Name: ngwuvaCV, dtype: int64
# oQxCJ    7573
# JqHcg     291
# LiSdw     176
# BELAV      74
# dujst      35
# CtlxI      24
# RitVm      14
# OrmPF      11
# QjxqO       5
# Name: yeHQSlwg, dtype: int64
# WkiLJ    7486
# OUJop     717
# Name: XSgHIFXD, dtype: int64
# STusI    7956
# lNXOe     247
# Name: GnUDarun, dtype: int64
# iwXUz    8184
# easnk      19
# Name: iwkvfFnL, dtype: int64
# AQdXQ    7526
# PpSAr     677
# Name: ANBCxZzU, dtype: int64
# yOWNA    6382
# VQqYa    1821
# Name: NanLCXEI, dtype: int64
# SsMkV    8134
# sYYqT      69
# Name: SqEqFZsM, dtype: int64
# XZCPn    4326
# GRlEi    3877
# Name: ZnBLVaqz, dtype: int64
# rDnbh    7147
# njLjB    1056
# Name: lQQeVmCa, dtype: int64
# USODW    7374
# ODGAT     829
# Name: lFcfBRGd, dtype: int64
# rKIUz    8194
# CiTCp       9
# Name: MOIscfCf, dtype: int64
# IRaac    4588
# GTHec    2160
# hwUPn     762
# Oqaht     450
# tTlgE     159
# usGeg      68
# DCAbS       9
# MrnuQ       7
# Name: AsEmHUzj, dtype: int64
# qxEvp    6875
# VrfVc     964
# daBsX     364
# Name: YXkrVgqt, dtype: int64
# lPYYk    8169
# VMvrK      34
# Name: pyBSpOoN, dtype: int64
# JeaWK    7032
# pkIrP     964
# xmRLH     207
# Name: srPNUgVy, dtype: int64
# IHJnm    7270
# VtTSc     723
# dDaSf     132
# sbwIo      30
# BQRJQ      23
# klEQr      15
# FJYAk      10
# Name: UXSJUVwD, dtype: int64
# uMicD    5099
# iVlle    3104
# Name: pCgBHqsR, dtype: int64
# lkvLr    5281
# MKsqC    2922
# Name: wEbmsuJO, dtype: int64
# IrGtT    5252
# jcWFw    2923
# hwivA      28
# Name: TWXCrjor, dtype: int64
# ZLoQH    7987
# iZVhn     216
# Name: wgWdGBOp, dtype: int64
# xFGRe    5252
# KkIYu    2945
# vnMwY       6
# Name: mRgnuJVE, dtype: int64
# ziMON    7694
# nQjzQ     509
# Name: pWyRKfsb, dtype: int64
# BZdVV    7972
# EFEdw     231
# Name: udzhtHIr, dtype: int64
# qyiux    7366
# BjHPw     837
# Name: ErggjCIN, dtype: int64
# XdgGs    8072
# ziwzG     131
# Name: iVscWZyL, dtype: int64
# Bgigt    5571
# YNtzq    2632
# Name: IZFarbPw, dtype: int64
# JrCtE    7772
# HodtS     431
# Name: lnfulcWk, dtype: int64
# Ovzte    5252
# YGDQb    2917
# ysuMQ      34
# Name: UHGnBrNt, dtype: int64
# bAsHK    7917
# wJZZG     286
# Name: QNLOXNwj, dtype: int64
# RAher    7635
# usARW     568
# Name: ytYMzOlW, dtype: int64
# -3.0    3324
# -4.0    2640
# -2.0    1786
# -1.0     398
#  0.0      44
#  1.0      11
# Name: YFMZwKrU, dtype: int64
# False    4500
# True     3703
# Name: poor, dtype: int64
# MGeNc    4471
# eaOHN    3732
# Name: RJQbcmKy, dtype: int64
# faIKi    8062
# lePWK     141
# Name: uizuNzbk, dtype: int64
# sTELG    7904
# kLAQg     299
# Name: dlyiMEQt, dtype: int64
# OCxeM    5252
# CouUl    1588
# gUrMw    1363
# Name: ucXrHdoC, dtype: int64
# hKOOZ    6857
# TCThD    1346
# Name: iBQXwnGC, dtype: int64
# umQWl    7427
# SyDCL     776
# Name: TnWhKowI, dtype: int64
# vHsxI    7344
# HBAfC     859
# Name: sslNoPlw, dtype: int64
# pxTwJ    8089
# mCLIw     114
# Name: InULRrrv, dtype: int64
# bNXgS    8138
# zJUXM      65
# Name: LoYIbglA, dtype: int64
# RBSxg    6510
# BZDbR    1693
# Name: GhJKwVWC, dtype: int64
# vHHYC    8105
# pTmLW      98
# Name: zXPyHBkn, dtype: int64
# pljjF    7346
# vmKoA     857
# Name: lVHmBCmb, dtype: int64
# uaNFE    5458
# bleFi    2745
# Name: EuJrVjyG, dtype: int64
# rUxTt    5252
# AhXJy    2947
# yTPHV       4
# Name: nSzbETYS, dtype: int64
# GHLFz    7868
# Nemmo     335
# Name: CpqWSQcW, dtype: int64
# KmUXh    7980
# uSmDB     223
# Name: jxSUvflR, dtype: int64
# WDkZe    8155
# UWgUE      48
# Name: XqURHMoh, dtype: int64
# EDTNy    7286
# jXJpO     917
# Name: eoNxXdlZ, dtype: int64
# lPMcV    5379
# CxUFg    2824
# Name: qgxmqJKa, dtype: int64
# CnUIQ    7904
# tSlww     299
# Name: mDTcQhdH, dtype: int64
# OwpgR    7505
# hUnoy     698
# Name: gfurxECf, dtype: int64
# BSkcT    8139
# IxhgC      64
# Name: RLKqBexO, dtype: int64
# NKTNl    5252
# dIDIn    2870
# EfseL      81
# Name: mvGdZZcs, dtype: int64
# BRnni    7991
# UsIbc     212
# Name: duayPuvk, dtype: int64
# McphZ    7101
# FmBLH    1102
# Name: hnrnuMte, dtype: int64
# bIVzQ    8062
# fOYQs     141
# Name: CbzSWtkF, dtype: int64
# JUIeR    8002
# AlOmz     201
# Name: LrQXqVUj, dtype: int64
# qQocg    6949
# HfxcF    1254
# Name: XDDOZFWf, dtype: int64
# gFTzO    5009
# YBnSQ    3194
# Name: CIGUXrRQ, dtype: int64
# FAceq    7843
# ycFFK     360
# Name: ccAHraiP, dtype: int64
# zQUnD    7560
# QaUlf     643
# Name: QayGNSmS, dtype: int64
# vSqQC    8185
# atYJj      18
# Name: CtFxPQPT, dtype: int64
# vZiEt    7908
# pyvgk     295
# Name: ePtrWTFd, dtype: int64
# qxdnm    6682
# BdSqi    1521
# Name: tbsBPHFD, dtype: int64
# nkDDJ    7291
# AakrE     912
# Name: naDKOzdk, dtype: int64
# EzaJv    8153
# luwoR      50
# Name: lTAXSTys, dtype: int64
# toKrg    4793
# gVjDv    3410
# Name: DNAfxPzs, dtype: int64
# KNFyN    8147
# tuhCX      56
# Name: GYTJWlaF, dtype: int64
# lKjvc    5329
# NyloK    2874
# Name: xkUFKUoW, dtype: int64
# aFKPY    8011
# cDtZG     192
# Name: QzqNzAJE, dtype: int64
# LDfpY    7699
# OUnra     504
# Name: dEpQghsA, dtype: int64
# nkwue    7713
# sqtPf     490
# Name: jVDpuAmP, dtype: int64
# iNJOu    8187
# VxMyV      16
# Name: mnIQKNOM, dtype: int64
# bfxJR    8134
# GMXrx      69
# Name: bhFgAObo, dtype: int64
# IkIWR    5448
# HRpuZ    2755
# Name: SeZULMCT, dtype: int64
# XNUiY    3704
# rwjPU    2406
# TpPTi    2093
# Name: AtGRGAYi, dtype: int64
# HGYnr    8105
# rwsVh      98
# Name: NitzgUzY, dtype: int64
# EyXxl    5485
# UPXKK    1595
# IIoXE    1123
# Name: YlZCqMNw, dtype: int64
# EBImk    7752
# LzdSI     451
# Name: FGDcbVBN, dtype: int64
# CkZDJ    6394
# OnSaH    1809
# Name: rYvVKPAF, dtype: int64
# bOZlo    8119
# jznhi      84
# Name: WTFJilSZ, dtype: int64
# IBdTc    7755
# YKjEy     448
# Name: NBfffJUe, dtype: int64
# uZJuw    5252
# QfQGE    2358
# zdYLD     593
# Name: wnESwOiN, dtype: int64
# QoQeZ    7238
# ZVfEw     964
# UnNNe       1
# Name: rfDBJtIz, dtype: int64
# AXgBD    4333
# QyySG    3870
# Name: mvgxfsRb, dtype: int64
# JHrHU    8181
# kHVqC      22
# Name: BwkgSxCk, dtype: int64
# MRwGf    8007
# lhohM     196
# Name: KHzKOKPw, dtype: int64
# HhERQ    5562
# MvlHX    2641
# Name: UXfyiodk, dtype: int64
# hIvXl    7230
# dxbrH     964
# lEsZp       9
# Name: EftwspgZ, dtype: int64
# HlFcn    8199
# zhfzx       4
# Name: pQmBvlkz, dtype: int64
# kpQGr    5820
# ypBwu    2383
# Name: mycoyYwl, dtype: int64
# yCngx    7175
# eTXuS     964
# LaWZy      64
# Name: ySkAFOzx, dtype: int64
# CPYVU    5229
# QsGjO    1600
# cbMrz     733
# icswM     325
# JzIcQ     308
# fGvpk       8
# Name: dkPWxwSF, dtype: int64
# QxVfQ    8182
# XPkPf      21
# Name: bSaLisbO, dtype: int64
# BSdHw    8034
# JpJAL     169
# Name: wKcZtLNv, dtype: int64
# IGJGf    8033
# nAWgP     170
# Name: mBlWbDmc, dtype: int64
# hbVPO    7923
# IBEsC     280
# Name: szowPwNq, dtype: int64
# KJmKx    6722
# IEECo    1481
# Name: ULMvnWcn, dtype: int64
# IwRaw    4622
# rLgDV    1003
# jYUYQ     817
# XlVqM     542
# AaeZZ     465
# ZqWZh     298
# ZOaZy     181
# mFeaF     102
# hLjkt      52
# MAkoX      45
# xVCqV      39
# Uxyzc      35
# OofXq       2
# Name: BfGjiYom, dtype: int64
# zrNex    8026
# QdGLg     177
# Name: iWEFJYkR, dtype: int64
# rckPT    7204
# aDvUR     999
# Name: ogHwwdzc, dtype: int64
# Pbejz    7178
# gGMPn    1025
# Name: BCehjxAl, dtype: int64
# EVgBS    8180
# wSjgH      23
# Name: CHAQHqqr, dtype: int64
# WHbWp    7587
# dQnUX     616
# Name: nqndbwXP, dtype: int64
# TmEwV    7123
# WMWIa     964
# nEMgq     116
# Name: uZGqTQUP, dtype: int64
# RYppC    6210
# PkqbM    1993
# Name: phwExnuQ, dtype: int64
# EZCEl    6913
# slsIB    1290
# Name: SzUcfjnr, dtype: int64
# NSTIW    7237
# aBMet     964
# Enjzh       2
# Name: PXtHzrqw, dtype: int64
# wxvvO    7199
# rDezK    1004
# Name: CNkSTLvx, dtype: int64
# vPKPO    6230
# teImp     898
# TCxKr     752
# sCBZQ     228
# VNvbZ      77
# xBZqe       8
# cMGvm       6
# tsilP       2
# MkATH       1
# VmIxP       1
# Name: tHFrzjai, dtype: int64
# fNGQN    6782
# ACTli    1421
# Name: MKozKLvT, dtype: int64
# Kkfas    5979
# ioNum    2224
# Name: pjHvJhoZ, dtype: int64
# hGOlE    8058
# OwRVU     145
# Name: zkbPtFyO, dtype: int64
# eXQfr    6721
# odZZU    1482
# Name: xZBEXWPR, dtype: int64
# jWKad    7672
# jubgz     531
# Name: dyGFeFAg, dtype: int64
# nsNYE    8175
# vqjDd      28
# Name: HfOrdgBo, dtype: int64
# AUBhx    6168
# hAYSL    1071
# ZdeVO     964
# Name: pKPTBZZq, dtype: int64
# kKdqK    5642
# iiEDW    2561
# Name: bCYWWTxH, dtype: int64
# NBpDn    5292
# mYOPT    2911
# Name: EQKKRGkR, dtype: int64
# gZaHx    7288
# AtKGe     915
# Name: ZmJZXnoA, dtype: int64
# fHiYi    6706
# XqDYC    1497
# Name: YKwvJgoP, dtype: int64
# LgmAO    8154
# ANUno      49
# Name: dAaIakDk, dtype: int64
# YakVl    8190
# uoglh      13
# Name: rnJOTwVD, dtype: int64
# UlAvd    8200
# ypjDA       3
# Name: xNUUjCIL, dtype: int64
# FzYmh    7232
# deAox     964
# fEkHo       7
# Name: JMNvdasy, dtype: int64
# YHvZN    8077
# UHHXz     126
# Name: MBQcYnjc, dtype: int64
# iArDW    8121
# PfCly      82
# Name: cCsFudxF, dtype: int64
# HXYrB    4245
# GMGRq    2994
# BTuQn     964
# Name: muIetHMK, dtype: int64
# jmsRI    8182
# iqptO      21
# Name: hJrMTBVd, dtype: int64
# SPzFf    8116
# IfJGv      87
# Name: TJUYOoXU, dtype: int64
# ZsSNu    5758
# sAtFf    2437
# fgUcH       8
# Name: ishdUooQ, dtype: int64
# tPaEK    8117
# IlvvB      86
# Name: tjrOpVkX, dtype: int64
# fJrRy    8134
# IPNiH      69
# Name: cWNZCMRB, dtype: int64
# lVtXj    8163
# yOtiS      40
# Name: cgJgOfCA, dtype: int64
# SexDN    7527
# nBfiS     676
# Name: ItpCDLDM, dtype: int64
# ENzpE    7687
# IOpTr     516
# Name: gOGWzlYC, dtype: int64
# BMWoB    5340
# oniXa    2863
# Name: ptEAnCSs, dtype: int64
# ttIeY    8153
# AnmcJ      50
# Name: HDCjCTRd, dtype: int64
# Ujijg    5813
# faBdF    2390
# Name: lOujHrCk, dtype: int64
# ZxCEl    7400
# lfIIh     803
# Name: MARfVwUE, dtype: int64
# MzfpW    7758
# WuPOk     445
# Name: orfSPOJX, dtype: int64
# bGDLK    7385
# CaKpe     818
# Name: OKMtkqdQ, dtype: int64
# DYgTc    7967
# wreZR     236
# Name: QBJeqwPF, dtype: int64
# szIiM    6645
# bujmy    1558
# Name: qTginJts, dtype: int64
# ljNoc    7726
# tZYzi     477
# Name: JzhdOhzb, dtype: int64
# jVUJV    8162
# GXiqH      41
# Name: THDtJuYh, dtype: int64
# zKnUs    7823
# CIAdN     380
# Name: QqoiIXtI, dtype: int64
# XkLSK    7897
# fGhVW     306
# Name: XVwajTfe, dtype: int64
# TLIpf    7578
# gTwcN     625
# Name: jwEuQQve, dtype: int64
# DRvSE    7873
# KmfbL     330
# Name: rQAsGegu, dtype: int64
# YfHbD    8198
# HQYUq       5
# Name: nKoaotpH, dtype: int64
# SWTnt    4712
# DfvmQ    3491
# Name: kLkPtNnh, dtype: int64
# ymHWD    8172
# BtRty      31
# Name: TzPdCEPV, dtype: int64
# rKtpo    5711
# tbyeH    1528
# dzqlr     964
# Name: CtHqaXhY, dtype: int64
# qFmHi    5180
# HbuZo    3023
# Name: DbUNVFwv, dtype: int64
# GEhZM    7265
# lrJCa     938
# Name: FmSlImli, dtype: int64
# rdNWR    6130
# rYSEv    2073
# Name: UsENDgsH, dtype: int64
# -3     1437
# -1     1375
# -5     1331
# -7     1065
#  1      844
# -9      723
#  3      596
# -11     419
# -13     219
# -15     104
# -17      43
# -19      35
# -21       4
# -23       2
# -29       2
# -25       2
# -31       1
# -27       1
# Name: TiwRslOh, dtype: int64
# DatRI    7850
# amCbL     353
# Name: mNrEOmgq, dtype: int64
# FAwZM    5575
# FZPxd    2628
# Name: PWShFLnY, dtype: int64
# SduuS    4374
# znnto    3351
# JYIAk     478
# Name: uRFXnNKV, dtype: int64
# DaWhn    7973
# shjTF     230
# Name: lFExzVaF, dtype: int64
# vKNoE    8084
# MsGDR     119
# Name: CVCsOVew, dtype: int64
# WBZrK    7336
# apDeO     867
# Name: tlxXCDiW, dtype: int64
# UbHra    6749
# daGYP    1454
# Name: IKqsuNvV, dtype: int64
# cKUPi    8191
# fQxZN      12
# Name: ztGMreNV, dtype: int64
# VgUWq    6148
# luOlq    1091
# wYFnn     964
# Name: CqqwKRSn, dtype: int64
# TlGhm    8089
# lsZvk     114
# Name: YUExUvhq, dtype: int64
# qFnRN    7237
# hlrrk     966
# Name: uVnApIlJ, dtype: int64
# TMgjA    8160
# fMLWp      43
# Name: fsXLyyco, dtype: int64
# tXjkt    5485
# JYRII    2221
# TiyXa     497
# Name: UXhTXbuS, dtype: int64
# mXeMx    7221
# fpoGk     964
# PjSQE      18
# Name: yaHLJxDD, dtype: int64
# guZuT    5252
# NATrp    2913
# xaQVo      38
# Name: zuMWFXax, dtype: int64
# uAbfX    7832
# YfcLB     371
# Name: qlZMvcWc, dtype: int64
# eoQfm    6008
# beVRD    2195
# Name: dqRtXzav, dtype: int64
# DozQi    7987
# zvDKy     216
# Name: ALbGNqKm, dtype: int64
# BErcV    6853
# CcnDz    1350
# Name: ktBqxSwa, dtype: int64
# dZLEj    8159
# Dmsgc      44
# Name: NqPjMmKP, dtype: int64
# Tpxgz    8188
# JpItw      15
# Name: tOWnWxYe, dtype: int64
# sEGZl    8146
# ZtWvn      57
# Name: RvTenIlS, dtype: int64
# KSJgh    6491
# OQJGG    1712
# Name: GIMIxlmv, dtype: int64
# eZUdE    6044
# CHoQY    2159
# Name: wKVwRQIp, dtype: int64
# KOglf    7794
# Wszpj     409
# Name: ncjMNgfp, dtype: int64
# SaBuU    3225
# PVFaP    2172
# QPXBo    1108
# GvSso    1021
# iLMNs     677
# Name: UaXLYMMh, dtype: int64
# BaOCK    5263
# lUYjh    2897
# SUjRo      26
# UGNXO       9
# EUFGq       5
# XsbpB       3
# Name: vRIvQXtC, dtype: int64
# lidWB    8083
# mpDne     120
# Name: bKtkhUWD, dtype: int64
# yNYhF    5297
# LqSiB    2906
# Name: RJFKdmYJ, dtype: int64
# JJjQh    4323
# PVguv    2916
# NIhUk     964
# Name: gllMXToa, dtype: int64
# YzyAB    7854
# Xhnzw     349
# Name: HhKXJWno, dtype: int64
# PPQFv    8102
# dgNdq     101
# Name: VFTkSOrq, dtype: int64
# CVqoC    7661
# ahmeC     542
# Name: tAYCAXge, dtype: int64
# nyJgy    6511
# EyPIN    1692
# Name: WAFKMNwv, dtype: int64
# DlKdC    7991
# oUocy     212
# Name: mHzqKSuN, dtype: int64
# BPDVj    7924
# cUIwE     118
# Plypt      68
# KGGBe      34
# OYmHr      18
# BzKTi      13
# mxfzY      11
# ACFXG       4
# EAPwG       3
# Fgjtq       3
# ZBMyY       2
# ujWYB       2
# NRTfh       2
# qRkFm       1
# Name: UjuNwfjv, dtype: int64
# kfyIl    6128
# ImUfE    2075
# Name: aWlBVrkK, dtype: int64
# TorQt    7640
# cGRjt     563
# Name: cDkXTaWP, dtype: int64
# UtgfX    7943
# VbSEa     260
# Name: hnmsRSvN, dtype: int64
# eABnh    6908
# ybHKD    1295
# Name: ZzUrQSMj, dtype: int64
# IHYKX    7092
# wPGlI     964
# xqXhV     147
# Name: GHmAeUhZ, dtype: int64
# hxaxk    5844
# bsSvo    1395
# CEvAs     964
# Name: VBjVVDwp, dtype: int64
# cTdqL    8167
# tVlsB      36
# Name: RMbjnrlm, dtype: int64
# bgCry    6949
# lMOhc    1254
# Name: kZVpcgJL, dtype: int64
# rpmnk    8145
# wjqLD      58
# Name: zvjiUrCR, dtype: int64
# XXDhf    7854
# FDtgc     349
# Name: BIofZdtd, dtype: int64
# wxJis    5776
# AZwXA    2427
# Name: QZiSWCCB, dtype: int64
# JqHnW    8196
# ezRNB       7
# Name: sDGibZrP, dtype: int64
# MaXfS    7173
# jkHEU    1030
# Name: CsGvKKBJ, dtype: int64
# HxnJy    3640
# USRak    3599
# etZsD     964
# Name: OLpGAaEu, dtype: int64
# idRwx    7943
# jXsPl     260
# Name: LrDrWRjC, dtype: int64
# UyAms    6199
# LPtkN    2004
# Name: JCDeZBXq, dtype: int64
# vkbkA    8097
# WKNwg     106
# Name: HGPWuGlV, dtype: int64
# qQxrL    8141
# qCEuA      62
# Name: GDUPaBQs, dtype: int64
# AITFl    7383
# GAZGl     820
# Name: WuwrCsIY, dtype: int64
# cecIq    5433
# aQeIm    2770
# Name: AlDbXTlZ, dtype: int64
# A    8203
# Name: country, dtype: int64

# %% [markdown]
# ##### Drop country and poor in the training set

# %%
ay_train = np.ravel(a_train.poor)

# %%
ay_train
# Out:
# array([False, False,  True, ...,  True,  True, False], dtype=bool)

# %%
by_train = np.ravel(b_train.poor)

# %%
cy_train = np.ravel(c_train.poor)

# %% [markdown]
# ###### Convert only the categorical values

# %%
for i in list(a_train.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(a_train)
    lc.transform(a_train)

# %%
for i in list(b_train.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(b_train)
    lc.transform(b_train)

# %%
for i in list(c_train.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(c_train)
    lc.transform(c_train)

# %%
# from sklearn.preprocessing import LabelEncoder
# a_train = a_train.apply(LabelEncoder().fit_transform)

# %%
# Standardize features
def standardize(df, numeric_only=True):
    numeric = df.select_dtypes(include=['int64', 'float64'])
    
    # subtracy mean and divide by std
    df[numeric.columns] = (numeric - numeric.mean()) / numeric.std()
    
    return df
    

def pre_process_data(df, enforce_cols=None):
    print("Input shape:\t{}".format(df.shape))
        

    df = standardize(df)
    print("After standardization {}".format(df.shape))
        
#     # create dummy variables for categoricals
#     df = pd.get_dummies(df)
#     print("After converting categoricals:\t{}".format(df.shape))
    

    # match test set and training set columns
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns, enforce_cols)
        to_add = np.setdiff1d(enforce_cols, df.columns)

        df.drop(to_drop, axis=1, inplace=True)
        df = df.assign(**{c: 0 for c in to_add})
    
    df.fillna(0, inplace=True)
    
    return df

# %%
print("Country A")
aX_train = pre_process_data(a_train.drop(['poor','country'], axis=1))


print("\nCountry B")
bX_train = pre_process_data(b_train.drop(['poor','country'], axis=1))

print("\nCountry C")
cX_train = pre_process_data(c_train.drop(['poor','country'], axis=1))
# Out:
# Country A
# Input shape:	(8203, 343)
# After standardization (8203, 343)
#
# Country B
# Input shape:	(3255, 440)
# After standardization (3255, 440)
#
# Country C
# Input shape:	(6469, 162)
# After standardization (6469, 162)

# %%
from sklearn.ensemble import RandomForestClassifier

def train_model(features, labels, **kwargs):
    
    # instantiate model
    model = RandomForestClassifier(n_estimators=500, random_state=0)
    
    # train model
    model.fit(features, labels)
    
    # get a (not-very-useful) sense of performance
    accuracy = model.score(features, labels)
    print("In-sample accuracy: {0:}".format(accuracy))
    
    return model

# %%
model_a = train_model(aX_train, ay_train)
# Out:
# In-sample accuracy: 1.0

# %%
model_b = train_model(bX_train, by_train)
# Out:
# In-sample accuracy: 1.0

# %%
model_c = train_model(cX_train, cy_train)
# Out:
# In-sample accuracy: 1.0

# %%
# load test data
a_test = pd.read_csv(data_paths['A']['test'], index_col='id')
b_test = pd.read_csv(data_paths['B']['test'], index_col='id')
c_test = pd.read_csv(data_paths['C']['test'], index_col='id')

# %%
for i in list(a_test.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(a_test)
    lc.transform(a_test)

# %%
for i in list(b_test.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(b_test)
    lc.transform(b_test)

# %%
for i in list(c_test.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(c_test)
    lc.transform(c_test)

# %%
# process the test data
a_test = pre_process_data(a_test, enforce_cols=aX_train.columns)
b_test = pre_process_data(b_test, enforce_cols=bX_train.columns)
c_test = pre_process_data(c_test, enforce_cols=cX_train.columns)
# Out:
# Input shape:	(4041, 344)
# After standardization (4041, 344)
# Input shape:	(1604, 441)
# After standardization (1604, 441)
# Input shape:	(3187, 163)
# After standardization (3187, 163)

# %%
a_preds = model_a.predict_proba(a_test)
b_preds = model_b.predict_proba(b_test)
c_preds = model_c.predict_proba(c_test)

# %%
a_preds
# Out:
# array([[ 0.46 ,  0.54 ],
#        [ 0.898,  0.102],
#        [ 0.508,  0.492],
#        ...,
#        [ 0.174,  0.826],
#        [ 0.68 ,  0.32 ],
#        [ 0.268,  0.732]])

# %%
def make_country_sub(preds, test_feat, country):
    # make sure we code the country correctly
    country_codes = ['A', 'B', 'C']
    
    # get just the poor probabilities
    country_sub = pd.DataFrame(data=preds[:, 1],  # proba p=1
                               columns=['poor'], 
                               index=test_feat.index)

    
    # add the country code for joining later
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
# convert preds to data frames
a_sub = make_country_sub(a_preds, a_test, 'A')
b_sub = make_country_sub(b_preds, b_test, 'B')
c_sub = make_country_sub(c_preds, c_test, 'C')

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
submission.shape
# Out:
# (8832, 2)

# %%
submission.to_csv('submission_label_count_500.csv')
