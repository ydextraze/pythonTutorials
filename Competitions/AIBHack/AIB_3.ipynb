# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore') 

# sk learn import 
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cross_validation import KFold, cross_val_score
from sklearn.metrics import make_scorer
from sklearn.grid_search import GridSearchCV
from sklearn.feature_selection import VarianceThreshold, RFE, SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, VotingClassifier, RandomForestClassifier, AdaBoostClassifier
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
train_1 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\training.txt", sep="\t", encoding = 'iso-8859-1')
test_1 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\AibHack\data\testing.txt", sep="\t", encoding = 'iso-8859-1')

# %%
#Join the datasets
train = train_1.append(test_1,ignore_index = True)

# %%
train_2 = train[pd.notnull(train['EnergyRatingCat'])]

# %%
cats = []
for col in train.columns.values:
    if train[col].dtype == 'object':
        cats.append(col)

# %%
df_cont = train.drop(cats, axis=1)
df_cat = train[cats]

# %% [markdown]
# ### Feature Engineering

# %%
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
train.loc[:, "SecSHEfficiency"] = train.loc[:, "SecSHEfficiency"].fillna(train['SecSHEfficiency'].median())
train.loc[:, "MainWHEfficiency"] = train.loc[:, "MainWHEfficiency"].fillna(train['MainWHEfficiency'].median())
train.loc[:, "SecSHEfficiency"] = train.loc[:, "SecSHEfficiency"].fillna(train['SecSHEfficiency'].median())
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
train.loc[:, "MainWHAdj"] = train.loc[:, "MainWHAdj"].fillna(train['MainWHAdj'].median())
train.loc[:, "SecSHFuel"] = train.loc[:, "SecSHFuel"].fillna(train['SecSHFuel'].median())
train.loc[:, "SecWHFuel"] = train.loc[:, "SecWHFuel"].fillna(train['SecWHFuel'].median())
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
train.loc[:, "TempAdj"] = train.loc[:, "TempAdj"].fillna(train['TempAdj'].median())

# %%
#drop columns
del train['StorageLoss']
del train['DeclaredLoss']
del train['SolarWaterHeating']
del train['SummerElectricImm']
del train['Combi']
del train['KeepHot']
del train['VolWaterStorage']
del train['TempFac']
del train['TempFacMult']
del train['HWInsulationType']
del train['HWInsulationThickness']
del train['AreaAperture']
del train['ZeroLossCollEff']
del train['CollHeatLoss']

# %%
#drop columns 458880
del train['SolarRadiation']
del train['Overshading']
del train['DedicatedSolarVol']
del train['SolarPumpElect']
del train['SolarHeatFrac']
del train['LargestRoofTypeArea']
del train['LargestRoofType']
del train['SecSpacePrimaryEnergy']
del train['FuelTypeFirstBoiler']
del train['EffFirstHeatGenPlant']
del train['PercFirstHeat']
del train['FuelTypeSecondBoiler']
del train['FuelTypeThirdBoiler']
del train['EffThirdHeatGenPlant']
del train['PercThirdHeat']
del train['HeatingSystemSolarSpace']
#del train['TotPrimaryEnergyFac']

# %%
train.loc[:, "FirstEnerType"] = train.loc[:, "FirstEnerType"].fillna("None")
train.loc[:, "FirstEnerTypeDescr"] = train.loc[:, "FirstEnerTypeDescr"].fillna("None")
train.loc[:, "FirstEnerType"] = train.loc[:, "FirstEnerType"].fillna("None")
train.loc[:, "FirstEnerTypeDescr"] = train.loc[:, "FirstEnerTypeDescr"].fillna("None")
train.loc[:, "FirstEnerType"] = train.loc[:, "FirstEnerType"].fillna("None")
train.loc[:, "FirstEnerTypeDescr"] = train.loc[:, "FirstEnerTypeDescr"].fillna("None")

train.loc[:, "PercLowEnergy"] = train.loc[:, "PercLowEnergy"].fillna("No")
train.loc[:, "ProdSecondEnerConvFac"] = train.loc[:, "ProdSecondEnerConvFac"].fillna("No")
train.loc[:, "ConsSecondEnerComment"] = train.loc[:, "ConsSecondEnerComment"].fillna("No")
train.loc[:, "SecondEnerTypeDescr"] = train.loc[:, "SecondEnerTypeDescr"].fillna("No")
train.loc[:, "ProdSecondEnerComment"] = train.loc[:, "ProdSecondEnerComment"].fillna("No")
train.loc[:, "ProdSecondEnerDelivered"] = train.loc[:, "ProdSecondEnerDelivered"].fillna("No")

#train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(0)
train.loc[:, "ProdFirstEnerComment"] = train.loc[:, "ProdFirstEnerComment"].fillna("No")
train.loc[:, "ProdFirstEnerDelivered"] = train.loc[:, "ProdFirstEnerDelivered"].fillna("No")
train.loc[:, "ProdFirstEnerConvFac"] = train.loc[:, "ProdFirstEnerConvFac"].fillna("No")
train.loc[:, "ConsFirstEnerComment"] = train.loc[:, "ConsFirstEnerComment"].fillna("No")
#train.loc[:, "MainSHEfficiency"] = train.loc[:, "MainSHEfficiency"].fillna("No")
train.loc[:, "PrimaryMainWaterEnergy"] = train.loc[:, "PrimaryMainWaterEnergy"].fillna(train['PrimaryMainWaterEnergy'].median())
train.loc[:, "PrimaryMainSpaceEnergy"] = train.loc[:, "PrimaryMainSpaceEnergy"].fillna(train['PrimaryMainSpaceEnergy'].median())
train.loc[:, "MainWaterCO2"] = train.loc[:, "MainWaterCO2"].fillna(train['MainWaterCO2'].median())
train.loc[:, "MainSpaceCO2"] = train.loc[:, "MainSpaceCO2"].fillna(train['MainSpaceCO2'].median())
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
#train.loc[:, "PercLowEnergy"] = train.loc[:, "PercLowEnergy"].fillna(train['PercLowEnergy'].median())
#train.loc[:, "SecSpaceEnergy"] = train.loc[:, "SecSpaceEnergy"].fillna(train['SecSpaceEnergy'].median())
train.loc[:, "SecWaterEnergy"] = train.loc[:, "SecWaterEnergy"].fillna(train['SecWaterEnergy'].median())
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
train.loc[:, "TempAdj"] = train.loc[:, "TempAdj"].fillna(train['TempAdj'].median())
train.loc[:, "TotPrimaryEnergyFac"] = train.loc[:, "TotPrimaryEnergyFac"].fillna(train['TotPrimaryEnergyFac'].median())

# %%
train.loc[:, "ConsThirdEnerComment"] = train.loc[:, "ConsThirdEnerComment"].fillna("No")
#train.loc[:, "ProdThirdEnerConvFac"] = train.loc[:, "ProdThirdEnerConvFac"].fillna("No")


train.loc[:, "SecSpaceEnergy"] = train.loc[:, "SecSpaceEnergy"].fillna("No")
train.loc[:, "ThirdEnerTypeDescr"] = train.loc[:, "ThirdEnerTypeDescr"].fillna("No")
train.loc[:, "ProdThirdEnerComment"] = train.loc[:, "ProdThirdEnerComment"].fillna("No")
train.loc[:, "ProdThirdEnerDelivered"] = train.loc[:, "ProdThirdEnerDelivered"].fillna("No")
train.loc[:, "ProdThirdEnerConvFac"] = train.loc[:, "ProdThirdEnerConvFac"].fillna("No")
#train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(0)
train.loc[:, "TotCO2Emissions"] = train.loc[:, "TotCO2Emissions"].fillna(train['TotCO2Emissions'].median())
train.loc[:, "PrimaryEnergySecondarySpace"] = train.loc[:, "PrimaryEnergySecondarySpace"].fillna(train['TotCO2Emissions'].median())

# %%
train.loc[:, "TotEnergy"] = train.loc[:, "TotEnergy"].fillna('No')
#train.loc[:, "TotEnergy"] = train.loc[:, "TotEnergy"].fillna(train['TotEnergy'].median())
train.loc[:, "SecSpaceCO2"] = train.loc[:, "SecSpaceCO2"].fillna(train['SecSpaceCO2'].median())

# %%
train.loc[:, "ConsThirdEnerComment"] = train.loc[:, "ConsThirdEnerComment"].fillna("No")
#train.loc[:, "ProdThirdEnerConvFac"] = train.loc[:, "ProdThirdEnerConvFac"].fillna("No")


train.loc[:, "SecSpaceEnergy"] = train.loc[:, "SecSpaceEnergy"].fillna("No")
train.loc[:, "ThirdEnerTypeDescr"] = train.loc[:, "ThirdEnerTypeDescr"].fillna("No")
train.loc[:, "ProdThirdEnerComment"] = train.loc[:, "ProdThirdEnerComment"].fillna("No")
train.loc[:, "ProdThirdEnerDelivered"] = train.loc[:, "ProdThirdEnerDelivered"].fillna("No")
train.loc[:, "ProdThirdEnerConvFac"] = train.loc[:, "ProdThirdEnerConvFac"].fillna("No")
#train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(0)
train.loc[:, "TotCO2Emissions"] = train.loc[:, "TotCO2Emissions"].fillna(train['TotCO2Emissions'].median())
train.loc[:, "PrimaryEnergySecondarySpace"] = train.loc[:, "PrimaryEnergySecondarySpace"].fillna(train['TotCO2Emissions'].median())

# %%
train.loc[:, "MainSHFuel"] = train.loc[:, "MainSHFuel"].fillna("No")
train.loc[:, "MainWHFuel"] = train.loc[:, "MainWHFuel"].fillna("No")
train.loc[:, "PrimaryLoss"] = train.loc[:, "PrimaryLoss"].fillna("No")
#train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(0)
train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(train['AvgWallU'].median())
#train.loc[:, "MainSHFuel"] = train.loc[:, "MainSHFuel"].fillna(train['MainSHFuel'].median())
#train.loc[:, "MainWHFuel"] = train.loc[:, "MainWHFuel"].fillna(train['MainWHFuel'].median())
train.loc[:, "MainSHEfficiency"] = train.loc[:, "MainSHEfficiency"].fillna(train['MainSHEfficiency'].median())
train.loc[:, "MainSHAdj"] = train.loc[:, "MainSHAdj"].fillna(train['MainSHAdj'].median())
#train.loc[:, "PrimaryLoss"] = train.loc[:, "PrimaryLoss"].fillna(train['PrimaryLoss'].median())
train.loc[:, "EffSecondHeatGenPlant"] = train.loc[:, "EffSecondHeatGenPlant"].fillna(train['EffSecondHeatGenPlant'].median())
train.loc[:, "PercSecondHeat"] = train.loc[:, "PercSecondHeat"].fillna(train['PercSecondHeat'].median())

# %%
target = train[['EnergyRatingCat','EnergyRatingCont']]

# %%
data_cl = train.copy() # create a copy of data frame
target = data_cl[['EnergyRatingCat','EnergyRatingCont']].copy()

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAIN SET INFORMATION")
print ("========================\n")

for column in train:
    # Find all the unique feature values
    uniq = train[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 17):
        print("~~Listing up to 17 unique values~~")
    print (uniq[0:17])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAIN SET INFORMATION
# ========================
#
# 'BuildingID' has 623776 unique values
# ~~Listing up to 17 unique values~~
# [190835 523113 271393 585961 624083  30231 350444 592196 365924 303002
#  634938 300824 449623 379988  68299 597104 163298]
#
# -----------------------------------------------------------------------
#
# 'County' has 56 unique values
# ~~Listing up to 17 unique values~~
# ['Co. Wexford' 'Co. Clare' 'Co. Kerry' 'Co. Cork' 'Co. Laois' 'Cork City'
#  'Co. Carlow' 'Co. Offaly' 'Co. Donegal' 'Co. Meath' 'Co. Cavan' 'Dublin 4'
#  'Co. Galway' 'Dublin 14' 'Dublin 6' 'Co. Roscommon' 'Dublin 17']
#
# -----------------------------------------------------------------------
#
# 'Type' has 12 unique values
# ['Mid-terrace house' 'Detached house' 'Semi-detached house'
#  'Ground-floor apartment' 'Mid-floor apartment' 'End of terrace house'
#  'Top-floor apartment' 'House' 'Maisonette' 'Apartment' 'Basement Dwelling'
#  nan]
#
# -----------------------------------------------------------------------
#
# 'Year' has 253 unique values
# ~~Listing up to 17 unique values~~
# ['Y1890.0' 'Y1901.0' 'Y1968.0' 'Y2002.0' 'Y2007.0' 'Y2003.0' 'Y2000.0'
#  'Y1989.0' 'Y1900.0' 'Y1980.0' 'Y2001.0' 'Y1990.0' 'Y1950.0' 'Y2005.0'
#  'Y1987.0' 'Y1965.0' 'Y1999.0']
#
# -----------------------------------------------------------------------
#
# 'RatingType' has 4 unique values
# ['Existing       ' 'Final          ' 'Provisional    ' nan]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCat' has 16 unique values
# ['F ' 'G ' 'D2' 'C2' 'B3' 'B2' 'C1' 'E2' 'C3' 'E1' 'D1' 'B1' 'A3' 'A2' 'A1'
#  nan]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCont' has 62484 unique values
# ~~Listing up to 17 unique values~~
# [ 418.42  520.35  281.33  188.17  134.95  108.77  156.65  369.22  287.42
#   219.05  747.86  329.39  242.38  171.26  191.7   394.69  175.42]
#
# -----------------------------------------------------------------------
#
# 'GroundFloorArea' has 32526 unique values
# ~~Listing up to 17 unique values~~
# ['52.04 sq. m' '147.44 sq. m' '104.84 sq. m' '95.31 sq. m' '283.87 sq. m'
#  '94.4 sq. m' '76.15 sq. m' '91.41 sq. m' '125.61 sq. m' '124.66 sq. m'
#  '80.0 sq. m' '160.7 sq. m' '69.68 sq. m' '159.39 sq. m' '99.29 sq. m'
#  '208.69 sq. m' '40.37 sq. m']
#
# -----------------------------------------------------------------------
#
# 'AvgWallU' has 271 unique values
# ~~Listing up to 17 unique values~~
# [ 2.1   2.01  0.38  0.55  0.34  0.31  1.94  1.09  0.29  0.58  0.52  0.57
#   1.76  0.3   1.25  0.35  0.21]
#
# -----------------------------------------------------------------------
#
# 'AvgRoofU' has 293 unique values
# ~~Listing up to 17 unique values~~
# [ 2.3   0.75  0.13  0.26  0.    0.15  0.4   0.49  0.45  0.72  0.25  0.33
#   0.61  0.37  0.27  0.23  0.17]
#
# -----------------------------------------------------------------------
#
# 'AvgFloorU' has 146 unique values
# ~~Listing up to 17 unique values~~
# [ 0.61  0.94  0.68  0.34  0.41  0.24  0.    0.44  0.57  0.69  0.64  0.42
#   0.51  0.48  0.73  0.36  0.84]
#
# -----------------------------------------------------------------------
#
# 'AvgWindowU' has 534 unique values
# ~~Listing up to 17 unique values~~
# [ 2.71  2.63  2.81  2.8   3.1   1.82  2.7   3.4   4.8   2.96  3.27  3.33
#   2.21  4.63  1.51  3.07  2.6 ]
#
# -----------------------------------------------------------------------
#
# 'AvgDoorU' has 561 unique values
# ~~Listing up to 17 unique values~~
# [ 3.    3.96  0.    3.03  3.01  3.11  1.31  2.85  4.69  1.96  3.07  1.36
#   2.7   1.52  2.75  3.38  3.45]
#
# -----------------------------------------------------------------------
#
# 'ExposedWallArea' has 29422 unique values
# ~~Listing up to 17 unique values~~
# [  32.78  211.22   94.41   89.5   254.15   41.31   56.25  102.29   93.97
#   100.99   89.94  167.32   72.35   68.61   93.06  157.85   25.36]
#
# -----------------------------------------------------------------------
#
# 'ExposedRoofArea' has 27213 unique values
# ~~Listing up to 17 unique values~~
# [  73.08   93.4   104.84   42.9   173.21    0.     49.66  125.61   62.2
#    80.     84.87   34.84   57.72   52.12  181.68   40.37  109.  ]
#
# -----------------------------------------------------------------------
#
# 'TotFloorArea' has 24188 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4     0.     49.72  125.61
#    64.38   80.     84.87   34.84   76.64   52.12  181.68   74.58]
#
# -----------------------------------------------------------------------
#
# 'TotWindowArea' has 9704 unique values
# ~~Listing up to 17 unique values~~
# [  7.08  37.    17.9   13.92  42.86  14.15  11.65   7.2   19.6   16.71
#   13.34  30.6   16.33  11.61  15.51  38.84   5.33]
#
# -----------------------------------------------------------------------
#
# 'TotDoorArea' has 1818 unique values
# ~~Listing up to 17 unique values~~
# [ 2.05  5.95  0.    2.6   5.49  2.1   1.85  6.08  3.7   4.27  3.74  3.68
#   3.45  4.56  1.8   2.21  8.65]
#
# -----------------------------------------------------------------------
#
# 'NStoreys' has 10 unique values
# [  2.   1.   3.   4.   5.   0.  nan   6.   8.   7.]
#
# -----------------------------------------------------------------------
#
# 'MainSHFuel' has 20 unique values
# ~~Listing up to 17 unique values~~
# ['Heating Oil                   ' 'Mains Gas                     '
#  'Solid Multi-Fuel              ' 'Electricity                   '
#  'Bulk LPG (propane or butane)  ' 'Bottled LPG                   '
#  'Sod Peat                      ' 'Wood Pellets (bulk supply for '
#  'Manufactured Smokeless Fuel   ' 'No' 'House Coal                    '
#  'Wood Logs                     ' 'Wood Pellets (in bags for seco'
#  'Peat Briquettes               ' 'Electricity - Standard Domesti'
#  'Anthracite                    ' 'Electricity - Off-peak Night-R']
#
# -----------------------------------------------------------------------
#
# 'MainWHFuel' has 21 unique values
# ~~Listing up to 17 unique values~~
# ['Heating Oil                   ' 'Mains Gas                     '
#  'Solid Multi-Fuel              ' 'Electricity                   '
#  'Bulk LPG (propane or butane)  ' 'Bottled LPG                   '
#  'Wood Pellets (bulk supply for ' 'Wood Logs                     '
#  'Manufactured Smokeless Fuel   ' 'No' 'House Coal                    '
#  'Sod Peat                      ' 'Wood Pellets (in bags for seco'
#  'Anthracite                    ' 'Peat Briquettes               '
#  'Electricity - Standard Domesti' 'Electricity - Off-peak Night-R']
#
# -----------------------------------------------------------------------
#
# 'MainSHEfficiency' has 879 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.    85.    90.7   80.3   45.    79.1   78.1
#    79.9  100.    90.3   78.9   90.1   85.3   90.2]
#
# -----------------------------------------------------------------------
#
# 'SharedMPRN' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'BuildingReg' has 5 unique values
# [  0.   1.   2.   3.  nan]
#
# -----------------------------------------------------------------------
#
# 'MainSHAdj' has 62 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969  0.7    1.01   1.02   0.85   0.9    0.75   0.956
#   0.957  0.965  0.96   1.03   1.007  0.86   0.955]
#
# -----------------------------------------------------------------------
#
# 'SecSHFrac' has 34 unique values
# ~~Listing up to 17 unique values~~
# [ 0.1   0.    0.2   0.15  0.5   0.05  0.01  0.3   0.35  0.25  0.19  0.02
#   0.17  0.27  0.13  0.33  0.24]
#
# -----------------------------------------------------------------------
#
# 'SecSHEfficiency' has 530 unique values
# ~~Listing up to 17 unique values~~
# [  65.    55.    60.    30.     0.    20.    90.    63.    72.   100.    40.
#    50.    70.    45.    58.    79.    74.1]
#
# -----------------------------------------------------------------------
#
# 'MainWHEfficiency' has 1063 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.    92.4   90.7   80.3   45.    79.1   78.1
#    79.9  100.    85.    90.3   85.3   78.9   90.1]
#
# -----------------------------------------------------------------------
#
# 'MainWHAdj' has 39 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969  1.01   1.02   0.7    0.9    0.75   0.94   0.96   1.03
#   0.86   0.     0.97   1.05   0.8    0.72 ]
#
# -----------------------------------------------------------------------
#
# 'SecSHFuel' has 20 unique values
# ~~Listing up to 17 unique values~~
# [  1.00000000e+00   1.50000000e+01   8.00000000e+00   2.00000000e+00
#    6.00000000e+00   1.10000000e+01   2.80000000e+01   5.00000000e+00
#    4.00000000e+00   9.00000000e+00   3.00000000e+00   1.00000000e+01
#    7.00000000e+00   1.20000000e+01   1.40000000e+01   1.60000000e+01
#    2.80300000e+04]
#
# -----------------------------------------------------------------------
#
# 'SecWHFuel' has 4 unique values
# [ 28.   1.  16.  18.]
#
# -----------------------------------------------------------------------
#
# 'NChimneys' has 12 unique values
# [  0.   1.   2.   4.   3.   6.   5.   7.   9.  nan   8.  10.]
#
# -----------------------------------------------------------------------
#
# 'NOpenFlues' has 12 unique values
# [  1.   0.   2.   3.   4.   6.  10.   5.   7.   9.  nan   8.]
#
# -----------------------------------------------------------------------
#
# 'NFansVents' has 32 unique values
# ~~Listing up to 17 unique values~~
# [  1.   0.   5.   3.   7.   9.   2.   6.   4.  10.  20.  12.   8.  13.  11.
#   14.  26.]
#
# -----------------------------------------------------------------------
#
# 'DLobby' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'VentMethod' has 7 unique values
# ['Natural vent.' 'Bal.whole mech.vent heat recvr'
#  'Whole house extract vent.' 'Bal.whole mech.vent no heat re'
#  'Pos input vent.- loft' 'Pos input vent.- outside' nan]
#
# -----------------------------------------------------------------------
#
# 'WallStructure' has 5 unique values
# ['Masonry                       ' 'Insulated Conctete Form       '
#  'Timber or Steel Frame         ' 'Please select                 ' nan]
#
# -----------------------------------------------------------------------
#
# 'SuspWoodFloor' has 4 unique values
# ['No                            ' 'Yes (Unsealed)                '
#  'Yes (Sealed)                  ' nan]
#
# -----------------------------------------------------------------------
#
# 'PercDraughtStripped' has 102 unique values
# ~~Listing up to 17 unique values~~
# [ 100.   80.   92.    6.   83.   50.   94.   93.   97.   89.   90.   95.
#    66.    0.   91.   85.   88.]
#
# -----------------------------------------------------------------------
#
# 'NShelteredSides' has 6 unique values
# [  3.   0.   1.   2.   4.  nan]
#
# -----------------------------------------------------------------------
#
# 'PermTest' has 3 unique values
# ['NO' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'PermTestResult' has 438 unique values
# ~~Listing up to 17 unique values~~
# [ 0.     0.16   0.135  0.08   0.21   0.116  0.44   0.167  0.19   0.3    0.25
#   0.149  0.15   0.068  0.056  0.14   0.1  ]
#
# -----------------------------------------------------------------------
#
# 'TempAdj' has 42 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    0.6   0.3   0.45 -0.15 -0.1  -0.25  0.1   0.5   1.    0.06  0.95
#   0.08  2.    0.35  0.03  3.  ]
#
# -----------------------------------------------------------------------
#
# 'ControlCat' has 5 unique values
# [  1.   3.   2.  nan   0.]
#
# -----------------------------------------------------------------------
#
# 'ResponseCat' has 7 unique values
# [  1.   3.   4.   2.   5.   0.  nan]
#
# -----------------------------------------------------------------------
#
# 'NCHPumps' has 17 unique values
# [  1.   2.   0.   4.   3.   5.   9.  nan  10.   6.   8.   7.  11.  20.  12.
#   17.  13.]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat1' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat2' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'OilPumpIn' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'NGasFans' has 10 unique values
# [  0.   1.   2.  nan   9.   3.   4.  11.  10.  14.]
#
# -----------------------------------------------------------------------
#
# 'WarmAir' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'Underfloor' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'DistLoss' has 6598 unique values
# ~~Listing up to 17 unique values~~
# [ 224.033  428.635  343.987  323.551  626.674  321.558  280.853  315.078
#   386.601  384.691  289.659  452.725  265.984  450.399  332.191  531.309
#   195.291]
#
# -----------------------------------------------------------------------
#
# 'PrimaryLoss' has 10 unique values
# ['Boiler with insulated primary ' 'Boiler with uninsulated primar'
#  'Combi boiler                  ' 'No' 'Electric immersion heater     '
#  'Separate boiler and thermal st' 'Community heating             '
#  'CPSU (including electric CPSU)' 'None                          '
#  'Boiler and thermal store withi']
#
# -----------------------------------------------------------------------
#
# 'CylinderThermostat' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'CombiCylinder' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'SolarPumpPower' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'Charging' has 3 unique values
# ['NO ' 'YES' nan]
#
# -----------------------------------------------------------------------
#
# 'LightingEnergy' has 237078 unique values
# ~~Listing up to 17 unique values~~
# [  274.752  1210.888   865.756   477.396  1678.062   851.96    687.254
#    453.736   719.855   939.422   631.75   1348.795   314.431  1337.8
#    492.851  1497.325   255.037]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansEnergy' has 7940 unique values
# ~~Listing up to 17 unique values~~
# [  230.      175.      130.      360.        0.      565.     2229.02
#    757.019   390.      275.       45.      576.961   100.      188.417
#    490.      305.      758.984]
#
# -----------------------------------------------------------------------
#
# 'MainWaterEnergy' has 455725 unique values
# ~~Listing up to 17 unique values~~
# [ 2595.201  4966.751  6486.081  4188.472  5885.092  2363.526  4053.687
#   5688.331  6462.168  4176.838  5659.353  4532.1    3286.202  5265.891
#   4577.569  9817.104  3452.983]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceEnergy' has 592057 unique values
# ~~Listing up to 17 unique values~~
# ['13700.589' '"52025.518"' '15704.271999999999' '7995.825' '24401.932'
#  '4449.424' '4673.279' '19807.038' '"19272.466"' '10660.1' '38369.354'
#  '34178.684' '6518.878000000001' '12034.993999999999' '8654.046999999999'
#  '48668.757000000005' '1930.009']
#
# -----------------------------------------------------------------------
#
# 'PrimaryLightingEnergy' has 237078 unique values
# ~~Listing up to 17 unique values~~
# [  741.83   3269.398  2337.541  1288.969  4530.767  2300.292  1855.586
#   1225.087  1943.609  2536.439  1705.725  3641.747   848.964  3612.06
#   1330.698  4042.778   688.6  ]
#
# -----------------------------------------------------------------------
#
# 'PrimaryPumpsFansEnergy' has 7940 unique values
# ~~Listing up to 17 unique values~~
# [  621.      472.5     351.      972.        0.     1525.5    6018.354
#   2043.951  1053.      742.5     121.5    1557.795   270.      508.726
#   1323.      823.5    2049.257]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainWaterEnergy' has 456230 unique values
# ~~Listing up to 17 unique values~~
# [  2854.721   5463.426   7134.689   4607.319   6473.601   2599.879
#    4459.056   6257.164   7108.385   4594.522   6225.288   4985.31
#    3614.822   5792.48    5035.326  10798.814   3798.281]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainSpaceEnergy' has 531000 unique values
# ~~Listing up to 17 unique values~~
# [ 15070.648  57228.07   17274.699  11220.776  26842.125   4894.366
#    5140.607  21787.742  21199.713  11726.11   42206.289  37596.552
#    7170.766  13238.493   9519.452  53535.633   2123.01 ]
#
# -----------------------------------------------------------------------
#
# 'LightingCO2' has 226889 unique values
# ~~Listing up to 17 unique values~~
# [  176.666   778.601   556.681   306.966  1078.994   547.81    441.904
#    291.752   462.867   604.048   406.215   867.275   202.179   860.205
#    316.903   962.78    163.989]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansCO2' has 7923 unique values
# ~~Listing up to 17 unique values~~
# [  147.89    112.525    83.59    231.48      0.      363.295  1433.26
#    486.763   250.77    176.825    28.935   370.986    64.3     121.152
#    315.07    196.115   488.027]
#
# -----------------------------------------------------------------------
#
# 'MainWaterCO2' has 415526 unique values
# ~~Listing up to 17 unique values~~
# [  705.895  1350.956  1764.214   850.26   1194.674   479.796   822.898
#   2098.994  1757.71    847.898  2088.301  1232.731   893.847  1068.976
#    929.247  2670.252   700.956]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceCO2' has 570050 unique values
# ~~Listing up to 17 unique values~~
# [  3726.56   14150.941   4271.562   1623.152   4953.592    903.233
#     948.676   7308.797   5242.111   2164.     14158.292   9296.602
#    1773.135   2443.104   1756.772  13237.902    391.792]
#
# -----------------------------------------------------------------------
#
# 'AreaGroundFloor' has 23812 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4    76.15   49.72  125.61
#    64.38   80.     84.87   34.84   54.39   52.12  181.6    40.37]
#
# -----------------------------------------------------------------------
#
# 'HeightGroundFloor' has 516 unique values
# ~~Listing up to 17 unique values~~
# [ 2.25  2.85  2.43  2.44  2.5   2.6   2.47  2.58  2.42  2.45  2.53  2.61
#   2.63  2.7   2.66  2.59  2.46]
#
# -----------------------------------------------------------------------
#
# 'AreaFirstFloor' has 15954 unique values
# ~~Listing up to 17 unique values~~
# [   0.     50.67   42.9   110.66   41.69   60.28   75.83   34.84   56.51
#    47.17   27.09    4.     45.02   41.49   66.7    37.28   58.71]
#
# -----------------------------------------------------------------------
#
# 'HeightFirstFloor' has 507 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    2.55  2.65  2.72  2.74  2.69  2.84  2.64  2.67  2.68  2.41  2.45
#   2.79  1.84  2.77  2.62  2.71]
#
# -----------------------------------------------------------------------
#
# 'AreaSecondFloor' has 7283 unique values
# ~~Listing up to 17 unique values~~
# [  0.    48.49  30.5   84.72  48.25  23.    52.44  11.76  59.74  20.83
#   15.45  52.93  47.8   37.64  44.27  32.15  60.9 ]
#
# -----------------------------------------------------------------------
#
# 'BridgingFac' has 77 unique values
# ~~Listing up to 17 unique values~~
# [ 0.15   0.11   0.08   0.033  0.09   0.04   0.032  0.052  0.055  0.043
#   0.05   0.06   0.057  0.049  0.051  0.063  0.035]
#
# -----------------------------------------------------------------------
#
# 'MassCat' has 6 unique values
# ['Medium              ' 'Medium-high         ' 'High                '
#  'Medium-low          ' 'Low                 ' nan]
#
# -----------------------------------------------------------------------
#
# 'PercLowEnergy' has 204 unique values
# ~~Listing up to 17 unique values~~
# [83.0 18.0 17.0 89.0 69.0 0.0 90.0 73.0 33.0 25.0 14.0 100.0 41.0 60.0 24.0
#  63.0 20.0]
#
# -----------------------------------------------------------------------
#
# 'TotEnergy' has 597195 unique values
# ~~Listing up to 17 unique values~~
# [19628.788 66036.461 25220.061 15146.598 32140.086 7839.91 9589.22
#  28587.863999999998 31431.226000000002 21542.311 52037.098 44685.685
#  13229.996000000001 22294.917999999998 16332.216 71352.924 5813.029]
#
# -----------------------------------------------------------------------
#
# 'SecSpaceEnergy' has 495024 unique values
# ~~Listing up to 17 unique values~~
# [1906.3729999999998 6495.307 1933.9520000000002 2309.905 0.0
#  1650.5870000000002 4746.737 4447.630999999999 6394.892 3610.671
#  1965.3210000000001 3481.2329999999997 2432.749 11139.738000000001 2666.1
#  5855.486999999999 746.377]
#
# -----------------------------------------------------------------------
#
# 'SecWaterEnergy' has 49966 unique values
# ~~Listing up to 17 unique values~~
# [  9.21873000e+02   1.10799700e+03   0.00000000e+00   8.58172000e+02
#    1.14332000e+03   8.51749000e+02   6.55435000e+02   9.15164000e+02
#    9.77014000e+02   1.38624909e+07   7.37554000e+02   1.05878300e+03
#    1.10828300e+03   1.11943100e+03   1.42805100e+03   1.25467700e+03
#    8.61461000e+02]
#
# -----------------------------------------------------------------------
#
# 'PercLivingArea' has 263818 unique values
# ~~Listing up to 17 unique values~~
# ['33.4935%' '11.0079%' '18.0465%' '18.1513%' '12.1887%' '37.2881%'
#  '30.8601%' '14.1888%' '15.0864%' '17.8485%' '19.125%' '18.463%' '32.9219%'
#  '13.6771%' '17.9575%' '21.1222%' '32.7966%']
#
# -----------------------------------------------------------------------
#
# 'SecSpaceCO2' has 457749 unique values
# ~~Listing up to 17 unique values~~
# [    0.     2396.768   713.628   905.483   609.067  1751.546   902.869
#   2359.715  1332.338   725.203  1364.643   897.684  4366.777   983.791
#   2160.675   275.413   509.179]
#
# -----------------------------------------------------------------------
#
# 'SecWaterCO2' has 47928 unique values
# ~~Listing up to 17 unique values~~
# [  5.92764000e+02   7.12442000e+02   0.00000000e+00   5.51805000e+02
#    7.35155000e+02   5.47675000e+02   4.21445000e+02   5.88450000e+02
#    6.28220000e+02   8.91358163e+06   4.74247000e+02   6.80797000e+02
#    7.12626000e+02   7.19794000e+02   9.18237000e+02   8.06757000e+02
#    5.53919000e+02]
#
# -----------------------------------------------------------------------
#
# 'SecWaterPrimaryEnergy' has 49965 unique values
# ~~Listing up to 17 unique values~~
# [  2.48905700e+03   2.99159200e+03   0.00000000e+00   2.31706400e+03
#    3.08696400e+03   2.29972200e+03   1.76967500e+03   2.47094300e+03
#    2.63793800e+03   3.74287253e+07   1.99139600e+03   2.85871400e+03
#    2.99236400e+03   3.02246400e+03   3.85573800e+03   3.38762800e+03
#    2.32594500e+03]
#
# -----------------------------------------------------------------------
#
# 'UpgradeHES' has 18 unique values
# ~~Listing up to 17 unique values~~
# [  0.00000000e+00   1.00000000e+00   2.53170900e+03   2.19522000e+02
#               nan   1.22509600e+03   1.93064600e+03   1.13734000e+03
#    3.67538500e+03   5.59848800e+03   1.58066100e+03   2.88868700e+03
#    2.32932800e+03   9.71851500e+03   2.96038000e+03   9.16422000e+02
#    1.08697800e+03]
#
# -----------------------------------------------------------------------
#
# 'RoofAreaRoom' has 9724 unique values
# ~~Listing up to 17 unique values~~
# [ 18.35   0.    28.42  20.08  91.42  80.94  15.89  48.75  14.81  18.97
#   18.06  62.1   19.74  49.47  44.66  85.    51.47]
#
# -----------------------------------------------------------------------
#
# 'RatingPurpose' has 17 unique values
# ['Unknown' 'Sale' 'Grant Support' 'Private Letting'
#  'Social housing letting' 'Other' 'New dwelling for owner occupat' '0.000'
#  '1189.526' nan '5144.259' '1' '5910.142' '0' '4816.418' '2792.423'
#  '4083.602']
#
# -----------------------------------------------------------------------
#
# 'AssessmentDate' has 3218 unique values
# ~~Listing up to 17 unique values~~
# ['Jun 17 2011 12:00AM' 'Apr 14 2015 12:00AM' 'Jun 28 2012 12:00AM'
#  'Nov 25 2015 12:00AM' 'May 30 2016 12:00AM' 'May 13 2009 12:00AM'
#  'Jun 29 2013 12:00AM' 'Jan 21 2016 12:00AM' 'Sep 10 2013 12:00AM'
#  'Dec 12 2012 12:00AM' 'Jun 27 2016 12:00AM' 'Nov 19 2012 12:00AM'
#  'Jul 29 2014 12:00AM' 'Nov  1 2013 12:00AM' 'Oct 30 2009 12:00AM'
#  'Feb 10 2016 12:00AM' 'Feb 28 2011 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'FirstEnerType' has 13 unique values
# [1.0 2.0 3.0 'None' '1' '2' '3' 'Feb 20 2014 12:00AM' 0.0 'Other' 'Unknown'
#  'Mar 18 2014 12:00AM' 'Mar 10 2014 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'FirstEnerTypeDescr' has 14 unique values
# ['Renewable Thermal' 'Renewable Electrical' 'Not Renewable' 'None' '1'
#  '0.000' 'Feb 19 2014 12:00AM' 'Apr  2 2014 12:00AM' 'Apr 20 2010 12:00AM'
#  'Mar 24 2014 12:00AM' 'Nov 12 2009 12:00AM' 'Apr 15 2010 12:00AM'
#  'Mar  6 2014 12:00AM' 'Apr  7 2014 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerComment' has 1183 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'Solar PV' 'solar' 'PV S 30deg 4  panel 1289' 'PV'
#  'Suntech 5 Panel PV System' 'Solar PV array' 'Renewable Contribution'
#  'solar space' '1.3  kWp Photovoltaic' '3 Joule Pulsa 260 PV Panels' 'pv'
#  '1.04 kWp (4# 260Wp) PV - South' 'PV panels' 'Photovoltaic'
#  'HEAT PUMP RENEWABLE CONTRIB' '3 No. Suntech 250w PV cells']
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerDelivered' has 1621 unique values
# ~~Listing up to 17 unique values~~
# [0.0 723.0 525.0 'No' 118.0 859.0 708.8 804.0 766.0 817.0 556.0 670.2 414.0
#  474.0 737.1519999999999 627.1 531.6]
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerConvFac' has 33 unique values
# ~~Listing up to 17 unique values~~
# [0.0 2.45 1.0 'No' 1.1 2.19 2.37 2.42 2.7 '0' '2.37' '2.19' '2.42' '2.45'
#  '1.1' '2.7' 'Renewable Thermal']
#
# -----------------------------------------------------------------------
#
# 'ConsFirstEnerComment' has 81 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'solar' '0' 'None' 'Heat Pump' 'Solar' 'Pup' '75' 'none'
#  'By electric pump' 'electricity' 'solar thermal' 'Heat pump' 'Electricity'
#  '1289' 'NONE' 'PS260M-20/U']
#
# -----------------------------------------------------------------------
#
# 'SecondEnerTypeDescr' has 6 unique values
# ['Renewable Thermal' 'No' 'Not Renewable' 'Renewable Electrical' '1' '0']
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerComment' has 105 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'PV e/w 30deg  4 panels 709' 'Heat Pump' 'Solar PV'
#  'Renewable Thermal' 0.0 'heat pump' '0' 'HP contribution'
#  'PV 2 panels W 30deg ' '1# 250Wp West Facing' '2PV'
#  'PV 2 PANELS SOUTH @ 45 429' 'Add Part L Contribution from H'
#  'PV S 30deg  5 panels 1074' '8 Panels   45 Deg E/W 1339' 'Heat Recovery']
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerDelivered' has 87 unique values
# ~~Listing up to 17 unique values~~
# [0.0 'No' 1040.0 865.0 738.0 368.0 709.0 177.2 561.86 429.6 429.0 375.0
#  1339.0 '0' 'Renewable Thermal' '709' 2538.0]
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerConvFac' has 16 unique values
# [0.0 'No' 2.19 1.1 2.7 '0' 'Renewable Thermal' '2.19' 0.1 2.18 2.37 2.42
#  2.45 '2.37' '2.13' 1.0]
#
# -----------------------------------------------------------------------
#
# 'ConsSecondEnerComment' has 17 unique values
# ['No' 0.0 '6 Panels   45 Deg E/W 1004' 'Electricity' '859 (5 panels 1074)'
#  893.0 'None' '260w' '893' 'none' '1  panels 201' 532.0 '613' '0' 'Solar'
#  '5 panels 1206' 613.0]
#
# -----------------------------------------------------------------------
#
# 'ThirdEnerTypeDescr' has 6 unique values
# ['Renewable Thermal' 'No' 'Not Renewable' 'Renewable Electrical' '1' '0']
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerComment' has 38 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'PV e/w 30deg  2 panels 354' 'm' 'Renewable Thermal' 0.0 'heat pump'
#  'Add Part L Contribution from H' 'PV 30deg  2 panels ' '1' '0'
#  'PV 1 panels se 30deg' 'PV ne 2 panels ' 'PV 1 panel S 30deg' 'cooker c'
#  'Sunstream 3.7 Wind Turbine' 'e' 1.0]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerDelivered' has 19 unique values
# ~~Listing up to 17 unique values~~
# [0.0 'No' 354.0 385.65 '0' 'Renewable Thermal' '354' 741.0 204.0 258.0
#  530.0 394.0 485.0 201.0 7171.0 615.65 3.34]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerConvFac' has 9 unique values
# [0.0 'No' 2.19 '0' 'Renewable Thermal' 2.37 2.45 2.7 1.1]
#
# -----------------------------------------------------------------------
#
# 'ConsThirdEnerComment' has 5 unique values
# ['No' 0.0 '1592  6 panels 1327 for 5 pane' '1592  6 panels' 'none']
#
# -----------------------------------------------------------------------
#
# 'EffSecondHeatGenPlant' has 42 unique values
# ~~Listing up to 17 unique values~~
# [   0.    85.    92.   270.    75.   150.    80.    63.   100.    20.   294.
#    91.1  105.    65.    30.    91.9  302.2]
#
# -----------------------------------------------------------------------
#
# 'PercSecondHeat' has 61 unique values
# ~~Listing up to 17 unique values~~
# [  0.  10.  62.  50.  38.  30.  58.  20.  34.  36.  53.  14.  28.  46.  24.
#   40.  33.]
#
# -----------------------------------------------------------------------
#
# 'TotPrimaryEnergyFac' has 383 unique values
# ~~Listing up to 17 unique values~~
# [ 1.444  1.291  1.513  1.54   1.392  1.231  1.051  1.343  1.283  1.642
#   1.242  1.658  1.309  0.904  1.246  1.352  0.762]
#
# -----------------------------------------------------------------------
#
# 'TotCO2Emissions' has 266 unique values
# ~~Listing up to 17 unique values~~
# [ 0.266  0.029  0.279  0.284  0.344  0.227  0.198  0.248  0.237  0.303
#   0.229  0.306  0.03   0.195  0.269  0.031  0.164]
#
# -----------------------------------------------------------------------
#
# 'PrimaryEnergySecondarySpace' has 442958 unique values
# ~~Listing up to 17 unique values~~
# [     0.      7144.838   2127.347   2771.886   1815.646   5221.411
#    4892.394   7034.381   3971.738   2161.853   4177.48    2676.024
#   13367.686   2932.71    6441.036    821.015   1517.878]
#
# -----------------------------------------------------------------------
#
# 'EnergyMainWater' has 455725 unique values
# ~~Listing up to 17 unique values~~
# [ 2335.6809  4470.0759  5837.4729  3769.6248  5296.5828  2127.1734
#   3648.3183  5119.4979  5815.9512  3759.1542  5093.4177  4078.89    2957.5818
#   4739.3019  4119.8121  8835.3936  3107.6847]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# ['County has 15 missing', 'Type has 15 missing', 'RatingType has 15 missing', 'EnergyRatingCat has 159274 missing', 'EnergyRatingCont has 159274 missing', 'AvgRoofU has 15 missing', 'AvgFloorU has 15 missing', 'AvgWindowU has 15 missing', 'AvgDoorU has 15 missing', 'ExposedWallArea has 15 missing', 'ExposedRoofArea has 15 missing', 'TotFloorArea has 15 missing', 'TotWindowArea has 15 missing', 'TotDoorArea has 15 missing', 'NStoreys has 15 missing', 'SharedMPRN has 15 missing', 'BuildingReg has 15 missing', 'NChimneys has 15 missing', 'NOpenFlues has 15 missing', 'NFansVents has 15 missing', 'DLobby has 15 missing', 'VentMethod has 15 missing', 'WallStructure has 15 missing', 'SuspWoodFloor has 15 missing', 'PercDraughtStripped has 15 missing', 'NShelteredSides has 15 missing', 'PermTest has 15 missing', 'PermTestResult has 15 missing', 'ControlCat has 15 missing', 'ResponseCat has 15 missing', 'NCHPumps has 15 missing', 'BoilerStat1 has 15 missing', 'BoilerStat2 has 15 missing', 'OilPumpIn has 15 missing', 'NGasFans has 15 missing', 'WarmAir has 15 missing', 'Underfloor has 15 missing', 'DistLoss has 15 missing', 'CylinderThermostat has 15 missing', 'CombiCylinder has 15 missing', 'SolarPumpPower has 15 missing', 'Charging has 15 missing', 'LightingEnergy has 15 missing', 'PumpsAndFansEnergy has 15 missing', 'MainWaterEnergy has 15 missing', 'MainSpaceEnergy has 11 missing', 'PrimaryLightingEnergy has 15 missing', 'PrimaryPumpsFansEnergy has 15 missing', 'LightingCO2 has 15 missing', 'PumpsAndFansCO2 has 15 missing', 'AreaGroundFloor has 15 missing', 'HeightGroundFloor has 15 missing', 'AreaFirstFloor has 15 missing', 'HeightFirstFloor has 15 missing', 'AreaSecondFloor has 15 missing', 'BridgingFac has 15 missing', 'MassCat has 15 missing', 'SecWaterCO2 has 15 missing', 'SecWaterPrimaryEnergy has 15 missing', 'UpgradeHES has 15 missing', 'RoofAreaRoom has 15 missing', 'RatingPurpose has 15 missing', 'AssessmentDate has 15 missing', 'EnergyMainWater has 15 missing']
#
#
# Features with non-numeric values:
# ['County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat', 'GroundFloorArea', 'MainSHFuel', 'MainWHFuel', 'SharedMPRN', 'DLobby', 'VentMethod', 'WallStructure', 'SuspWoodFloor', 'PermTest', 'TempAdj', 'BoilerStat1', 'BoilerStat2', 'OilPumpIn', 'WarmAir', 'Underfloor', 'PrimaryLoss', 'CylinderThermostat', 'CombiCylinder', 'SolarPumpPower', 'Charging', 'MainWaterEnergy', 'MainSpaceEnergy', 'PrimaryMainWaterEnergy', 'PrimaryMainSpaceEnergy', 'MainWaterCO2', 'MainSpaceCO2', 'MassCat', 'PercLowEnergy', 'TotEnergy', 'SecSpaceEnergy', 'SecWaterEnergy', 'PercLivingArea', 'SecSpaceCO2', 'SecWaterCO2', 'SecWaterPrimaryEnergy', 'RatingPurpose', 'AssessmentDate', 'FirstEnerType', 'FirstEnerTypeDescr', 'ProdFirstEnerComment', 'ProdFirstEnerDelivered', 'ProdFirstEnerConvFac', 'ConsFirstEnerComment', 'SecondEnerTypeDescr', 'ProdSecondEnerComment', 'ProdSecondEnerDelivered', 'ProdSecondEnerConvFac', 'ConsSecondEnerComment', 'ThirdEnerTypeDescr', 'ProdThirdEnerComment', 'ProdThirdEnerDelivered', 'ProdThirdEnerConvFac', 'ConsThirdEnerComment', 'PrimaryEnergySecondarySpace', 'EnergyMainWater']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
train.loc[:, "County"] = train.loc[:, "County"].fillna("None")
train.loc[:, "Type"] = train.loc[:, "Type"].fillna("None")
train.loc[:, "RatingType"] = train.loc[:, "RatingType"].fillna("None")
train.loc[:, "FirstEnerTypeDescr"] = train.loc[:, "FirstEnerTypeDescr"].fillna("None")
train.loc[:, "FirstEnerType"] = train.loc[:, "FirstEnerType"].fillna("None")
train.loc[:, "FirstEnerTypeDescr"] = train.loc[:, "FirstEnerTypeDescr"].fillna("None")

train.loc[:, "PercLowEnergy"] = train.loc[:, "PercLowEnergy"].fillna("No")
train.loc[:, "ProdSecondEnerConvFac"] = train.loc[:, "ProdSecondEnerConvFac"].fillna("No")
train.loc[:, "ConsSecondEnerComment"] = train.loc[:, "ConsSecondEnerComment"].fillna("No")
train.loc[:, "SecondEnerTypeDescr"] = train.loc[:, "SecondEnerTypeDescr"].fillna("No")
train.loc[:, "ProdSecondEnerComment"] = train.loc[:, "ProdSecondEnerComment"].fillna("No")
train.loc[:, "ProdSecondEnerDelivered"] = train.loc[:, "ProdSecondEnerDelivered"].fillna("No")

#train.loc[:, "AvgWallU"] = train.loc[:, "AvgWallU"].fillna(0)
train.loc[:, "ProdFirstEnerComment"] = train.loc[:, "ProdFirstEnerComment"].fillna("No")
train.loc[:, "ProdFirstEnerDelivered"] = train.loc[:, "ProdFirstEnerDelivered"].fillna("No")
train.loc[:, "ProdFirstEnerConvFac"] = train.loc[:, "ProdFirstEnerConvFac"].fillna("No")
train.loc[:, "ConsFirstEnerComment"] = train.loc[:, "ConsFirstEnerComment"].fillna("No")
#train.loc[:, "MainSHEfficiency"] = train.loc[:, "MainSHEfficiency"].fillna("No")
train.loc[:, "PrimaryMainWaterEnergy"] = train.loc[:, "PrimaryMainWaterEnergy"].fillna(train['PrimaryMainWaterEnergy'].median())
train.loc[:, "PrimaryMainSpaceEnergy"] = train.loc[:, "PrimaryMainSpaceEnergy"].fillna(train['PrimaryMainSpaceEnergy'].median())
train.loc[:, "MainWaterCO2"] = train.loc[:, "MainWaterCO2"].fillna(train['MainWaterCO2'].median())
train.loc[:, "MainSpaceCO2"] = train.loc[:, "MainSpaceCO2"].fillna(train['MainSpaceCO2'].median())
train.loc[:, "SecSHFrac"] = train.loc[:, "SecSHFrac"].fillna(train['SecSHFrac'].median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5e0b63141bb9> in <module>()
# ----> 1 df_cat.columns
#
# NameError: name 'df_cat' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

# %%
class_le = LabelEncoder()

# %%
train['County'] = class_le.fit_transform(train['County'].values)
train['Type'] = class_le.fit_transform(train['Type'].values)
train['RatingType'] = class_le.fit_transform(train['RatingType'].values)
train['EnergyRatingCat'] = class_le.fit_transform(train['EnergyRatingCat'].values)
train['GroundFloorArea'] = class_le.fit_transform(train['GroundFloorArea'].values)
train['MainSHFuel'] = class_le.fit_transform(train['MainSHFuel'].values)
train['MainWHFuel'] = class_le.fit_transform(train['MainWHFuel'].values)
train['SharedMPRN'] = class_le.fit_transform(train['SharedMPRN'].values)
train['DLobby'] = class_le.fit_transform(train['DLobby'].values)
train['VentMethod'] = class_le.fit_transform(train['VentMethod'].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6ef4b27a6975> in <module>()
# ----> 1 train['County'] = class_le.fit_transform(train['County'].values)
#       2 train['Type'] = class_le.fit_transform(train['Type'].values)
#       3 train['RatingType'] = class_le.fit_transform(train['RatingType'].values)
#       4 train['EnergyRatingCat'] = class_le.fit_transform(train['EnergyRatingCat'].values)
#       5 train['GroundFloorArea'] = class_le.fit_transform(train['GroundFloorArea'].values)
#
# C:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     125         y = column_or_1d(y, warn=True)
#     126         _check_numpy_unicode_bug(y)
# --> 127         self.classes_, y = np.unique(y, return_inverse=True)
#     128         return y
#     129
#
# C:\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts)
#     193
#     194     if optional_indices:
# --> 195         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     196         aux = ar[perm]
#     197     else:
#
# TypeError: unorderable types: str() > float()

# %%
train['WallStructure'] = class_le.fit_transform(train['WallStructure'].values)
train['SuspWoodFloor'] = class_le.fit_transform(train['SuspWoodFloor'].values)
train['PermTest'] = class_le.fit_transform(train['PermTest'].values)
train['BoilerStat1'] = class_le.fit_transform(train['BoilerStat1'].values)
train['BoilerStat2'] = class_le.fit_transform(train['BoilerStat2'].values)
train['OilPumpIn'] = class_le.fit_transform(train['OilPumpIn'].values)
train['WarmAir'] = class_le.fit_transform(train['WarmAir'].values)
train['Underfloor'] = class_le.fit_transform(train['Underfloor'].values)
#train['StorageLoss'] = class_le.fit_transform(train['StorageLoss'].values)
#train['DeclaredLoss'] = class_le.fit_transform(train['DeclaredLoss'].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6c39d289147d> in <module>()
# ----> 1 train['WallStructure'] = class_le.fit_transform(train['WallStructure'].values)
#       2 train['SuspWoodFloor'] = class_le.fit_transform(train['SuspWoodFloor'].values)
#       3 train['PermTest'] = class_le.fit_transform(train['PermTest'].values)
#       4 train['BoilerStat1'] = class_le.fit_transform(train['BoilerStat1'].values)
#       5 train['BoilerStat2'] = class_le.fit_transform(train['BoilerStat2'].values)
#
# C:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit_transform(self, y)
#     125         y = column_or_1d(y, warn=True)
#     126         _check_numpy_unicode_bug(y)
# --> 127         self.classes_, y = np.unique(y, return_inverse=True)
#     128         return y
#     129
#
# C:\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts)
#     193
#     194     if optional_indices:
# --> 195         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     196         aux = ar[perm]
#     197     else:
#
# TypeError: unorderable types: str() > float()

# %%
cats_1 = []
for col in train.columns.values:
    if train[col].dtype == 'object':
        cats_1.append(col)

# %%
df_cat_1 = train[cats_1]

# %%
df_cat_1.columns
# Out:
# Index(['County', 'Type', 'Year', 'RatingType', 'EnergyRatingCat',
#        'GroundFloorArea', 'MainSHFuel', 'MainWHFuel', 'SharedMPRN', 'DLobby',
#        'VentMethod', 'WallStructure', 'SuspWoodFloor', 'PermTest',
#        'BoilerStat1', 'BoilerStat2', 'OilPumpIn', 'WarmAir', 'Underfloor',
#        'PrimaryLoss', 'CylinderThermostat', 'CombiCylinder', 'SolarPumpPower',
#        'Charging', 'MainSpaceEnergy', 'MassCat', 'PercLowEnergy', 'TotEnergy',
#        'SecSpaceEnergy', 'PercLivingArea', 'RatingPurpose', 'AssessmentDate',
#        'FirstEnerType', 'FirstEnerTypeDescr', 'ProdFirstEnerComment',
#        'ProdFirstEnerDelivered', 'ProdFirstEnerConvFac',
#        'ConsFirstEnerComment', 'SecondEnerTypeDescr', 'ProdSecondEnerComment',
#        'ProdSecondEnerDelivered', 'ProdSecondEnerConvFac',
#        'ConsSecondEnerComment', 'ThirdEnerTypeDescr', 'ProdThirdEnerComment',
#        'ProdThirdEnerDelivered', 'ProdThirdEnerConvFac',
#        'ConsThirdEnerComment'],
#       dtype='object')

# %%
train['Year'] = class_le.fit_transform(train['Year'].values)
train['Charging'] = class_le.fit_transform(train['Charging'].values)
train['MainSpaceEnergy'] = class_le.fit_transform(train['MainSpaceEnergy'].values)
train['MassCat'] = class_le.fit_transform(train['MassCat'].values)
#train['TotEnergy'] = class_le.fit_transform(train['TotEnergy'].values)
#train['SecSpaceEnergy'] = class_le.fit_transform(train['SecSpaceEnergy'].values)
train['PercLivingArea'] = class_le.fit_transform(train['PercLivingArea'].values)
train['RatingPurpose'] = class_le.fit_transform(train['RatingPurpose'].values)
train['PrimaryLoss'] = class_le.fit_transform(train['PrimaryLoss'].values)
#train['DeclaredLoss'] = class_le.fit_transform(train['DeclaredLoss'].values)

# %%
train['AssessmentDate'] = class_le.fit_transform(train['AssessmentDate'].values)
#train['FirstEnerType'] = class_le.fit_transform(train['FirstEnerType'].values)
train['FirstEnerTypeDescr'] = class_le.fit_transform(train['FirstEnerTypeDescr'].values)
#train['ProdFirstEnerDelivered'] = class_le.fit_transform(train['ProdFirstEnerDelivered'].values)
#train['ProdFirstEnerComment'] = class_le.fit_transform(train['ProdFirstEnerComment'].values)
#train['ProdFirstEnerConvFac'] = class_le.fit_transform(train['ProdFirstEnerConvFac'].values)
#train['ConsFirstEnerComment'] = class_le.fit_transform(train['ConsFirstEnerComment'].values)
train['SecondEnerTypeDescr'] = class_le.fit_transform(train['SecondEnerTypeDescr'].values)
#train['ProdSecondEnerComment'] = class_le.fit_transform(train['ProdSecondEnerComment'].values)
#train['DeclaredLoss'] = class_le.fit_transform(train['DeclaredLoss'].values)

# %%
#train['ProdSecondEnerDelivered'] = class_le.fit_transform(train['ProdSecondEnerDelivered'].values)
#train['ProdSecondEnerConvFac'] = class_le.fit_transform(train['ProdSecondEnerConvFac'].values)
#train['ConsSecondEnerComment'] = class_le.fit_transform(train['ConsSecondEnerComment'].values)
train['MassCat'] = class_le.fit_transform(train['MassCat'].values)
train['ThirdEnerTypeDescr'] = class_le.fit_transform(train['ThirdEnerTypeDescr'].values)
#train['SecSpaceEnergy'] = class_le.fit_transform(train['SecSpaceEnergy'].values)
#train['ProdThirdEnerComment'] = class_le.fit_transform(train['ProdThirdEnerComment'].values)
#train['ProdThirdEnerDelivered'] = class_le.fit_transform(train['ProdThirdEnerDelivered'].values)
#train['ProdThirdEnerDelivered'] = class_le.fit_transform(train['ProdThirdEnerDelivered'].values)
#train['ConsThirdEnerComment'] = class_le.fit_transform(train['ConsThirdEnerComment'].values)

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAIN SET INFORMATION")
print ("========================\n")

for column in train:
    # Find all the unique feature values
    uniq = train[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 17):
        print("~~Listing up to 17 unique values~~")
    print (uniq[0:17])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(train[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAIN SET INFORMATION
# ========================
#
# 'BuildingID' has 464502 unique values
# ~~Listing up to 17 unique values~~
# [190835 523113 271393 585961 624083  30231 350444 592196 365924 303002
#  634938 300824 449623 379988  68299 597104 163298]
#
# -----------------------------------------------------------------------
#
# 'County' has 55 unique values
# ~~Listing up to 17 unique values~~
# [24  2  7  3 10 26  0 18  4 16  1 45  6 32 47 19 35]
#
# -----------------------------------------------------------------------
#
# 'Type' has 11 unique values
# [ 8  2  9  4  7  3 10  5  6  0  1]
#
# -----------------------------------------------------------------------
#
# 'Year' has 248 unique values
# ~~Listing up to 17 unique values~~
# [121 132 199 233 238 234 231 220 131 211 232 221 181 236 218 196 230]
#
# -----------------------------------------------------------------------
#
# 'RatingType' has 3 unique values
# [0 1 2]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCat' has 15 unique values
# [13 14 10  7  5  4  6 12  8 11  9  3  2  1  0]
#
# -----------------------------------------------------------------------
#
# 'EnergyRatingCont' has 62483 unique values
# ~~Listing up to 17 unique values~~
# [ 418.42  520.35  281.33  188.17  134.95  108.77  156.65  369.22  287.42
#   219.05  747.86  329.39  242.38  171.26  191.7   394.69  175.42]
#
# -----------------------------------------------------------------------
#
# 'GroundFloorArea' has 30695 unique values
# ~~Listing up to 17 unique values~~
# [25583  4889   501 30213 18530 30118 28255 29817  2630  2535 28648  6338
#  27573  6142 30621 11367 23594]
#
# -----------------------------------------------------------------------
#
# 'AvgWallU' has 270 unique values
# ~~Listing up to 17 unique values~~
# [ 2.1   2.01  0.38  0.55  0.34  0.31  1.94  1.09  0.29  0.58  0.52  0.57
#   1.76  0.3   1.25  0.35  0.21]
#
# -----------------------------------------------------------------------
#
# 'AvgRoofU' has 279 unique values
# ~~Listing up to 17 unique values~~
# [ 2.3   0.75  0.13  0.26  0.    0.15  0.4   0.49  0.45  0.72  0.25  0.33
#   0.61  0.37  0.27  0.23  0.17]
#
# -----------------------------------------------------------------------
#
# 'AvgFloorU' has 139 unique values
# ~~Listing up to 17 unique values~~
# [ 0.61  0.94  0.68  0.34  0.41  0.24  0.    0.44  0.57  0.69  0.64  0.42
#   0.51  0.48  0.73  0.36  0.84]
#
# -----------------------------------------------------------------------
#
# 'AvgWindowU' has 528 unique values
# ~~Listing up to 17 unique values~~
# [ 2.71  2.63  2.81  2.8   3.1   1.82  2.7   3.4   4.8   2.96  3.27  3.33
#   2.21  4.63  1.51  3.07  2.6 ]
#
# -----------------------------------------------------------------------
#
# 'AvgDoorU' has 548 unique values
# ~~Listing up to 17 unique values~~
# [ 3.    3.96  0.    3.03  3.01  3.11  1.31  2.85  4.69  1.96  3.07  1.36
#   2.7   1.52  2.75  3.38  3.45]
#
# -----------------------------------------------------------------------
#
# 'ExposedWallArea' has 28004 unique values
# ~~Listing up to 17 unique values~~
# [  32.78  211.22   94.41   89.5   254.15   41.31   56.25  102.29   93.97
#   100.99   89.94  167.32   72.35   68.61   93.06  157.85   25.36]
#
# -----------------------------------------------------------------------
#
# 'ExposedRoofArea' has 25836 unique values
# ~~Listing up to 17 unique values~~
# [  73.08   93.4   104.84   42.9   173.21    0.     49.66  125.61   62.2
#    80.     84.87   34.84   57.72   52.12  181.68   40.37  109.  ]
#
# -----------------------------------------------------------------------
#
# 'TotFloorArea' has 22949 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4     0.     49.72  125.61
#    64.38   80.     84.87   34.84   76.64   52.12  181.68   74.58]
#
# -----------------------------------------------------------------------
#
# 'TotWindowArea' has 9162 unique values
# ~~Listing up to 17 unique values~~
# [  7.08  37.    17.9   13.92  42.86  14.15  11.65   7.2   19.6   16.71
#   13.34  30.6   16.33  11.61  15.51  38.84   5.33]
#
# -----------------------------------------------------------------------
#
# 'TotDoorArea' has 1693 unique values
# ~~Listing up to 17 unique values~~
# [ 2.05  5.95  0.    2.6   5.49  2.1   1.85  6.08  3.7   4.27  3.74  3.68
#   3.45  4.56  1.8   2.21  8.65]
#
# -----------------------------------------------------------------------
#
# 'NStoreys' has 9 unique values
# [ 2.  1.  3.  4.  5.  0.  6.  8.  7.]
#
# -----------------------------------------------------------------------
#
# 'MainSHFuel' has 20 unique values
# ~~Listing up to 17 unique values~~
# [ 8 10 15  4  3  2 14 18 11 12  9 17 19 13  7  0  5]
#
# -----------------------------------------------------------------------
#
# 'MainWHFuel' has 21 unique values
# ~~Listing up to 17 unique values~~
# [ 9 11 16  5  4  3 19 18 12 13 10 15 20  0 14  8  6]
#
# -----------------------------------------------------------------------
#
# 'MainSHEfficiency' has 816 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.    85.    90.7   80.3   45.    79.1   78.1
#    79.9  100.    90.3   78.9   90.1   85.3   90.2]
#
# -----------------------------------------------------------------------
#
# 'SharedMPRN' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'BuildingReg' has 4 unique values
# [ 0.  1.  2.  3.]
#
# -----------------------------------------------------------------------
#
# 'MainSHAdj' has 55 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969  0.7    1.01   1.02   0.85   0.9    0.75   0.956
#   0.957  0.965  0.96   1.03   1.007  0.86   0.955]
#
# -----------------------------------------------------------------------
#
# 'SecSHFrac' has 32 unique values
# ~~Listing up to 17 unique values~~
# [ 0.1   0.    0.2   0.15  0.5   0.05  0.01  0.3   0.35  0.25  0.19  0.02
#   0.17  0.27  0.13  0.33  0.24]
#
# -----------------------------------------------------------------------
#
# 'SecSHEfficiency' has 488 unique values
# ~~Listing up to 17 unique values~~
# [  65.    55.    60.    30.     0.    20.    90.    63.    72.   100.    40.
#    50.    70.    45.    58.    79.    74.1]
#
# -----------------------------------------------------------------------
#
# 'MainWHEfficiency' has 961 unique values
# ~~Listing up to 17 unique values~~
# [  85.7   65.    70.    78.    92.4   90.7   80.3   45.    79.1   78.1
#    79.9  100.    85.    90.3   85.3   78.9   90.1]
#
# -----------------------------------------------------------------------
#
# 'MainWHAdj' has 38 unique values
# ~~Listing up to 17 unique values~~
# [ 0.95   1.     0.969  1.01   1.02   0.7    0.9    0.75   0.94   0.96   1.03
#   0.86   0.     0.97   1.05   0.8    0.72 ]
#
# -----------------------------------------------------------------------
#
# 'SecSHFuel' has 20 unique values
# ~~Listing up to 17 unique values~~
# [  1.00000000e+00   1.50000000e+01   8.00000000e+00   2.00000000e+00
#    6.00000000e+00   1.10000000e+01   2.80000000e+01   5.00000000e+00
#    4.00000000e+00   9.00000000e+00   3.00000000e+00   1.00000000e+01
#    7.00000000e+00   1.20000000e+01   1.40000000e+01   1.60000000e+01
#    2.80300000e+04]
#
# -----------------------------------------------------------------------
#
# 'SecWHFuel' has 4 unique values
# [ 28.   1.  16.  18.]
#
# -----------------------------------------------------------------------
#
# 'NChimneys' has 11 unique values
# [  0.   1.   2.   4.   3.   6.   5.   7.   9.   8.  10.]
#
# -----------------------------------------------------------------------
#
# 'NOpenFlues' has 11 unique values
# [  1.   0.   2.   3.   4.   6.  10.   5.   7.   9.   8.]
#
# -----------------------------------------------------------------------
#
# 'NFansVents' has 31 unique values
# ~~Listing up to 17 unique values~~
# [  1.   0.   5.   3.   7.   9.   2.   6.   4.  10.  20.  12.   8.  13.  11.
#   14.  26.]
#
# -----------------------------------------------------------------------
#
# 'DLobby' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'VentMethod' has 6 unique values
# [2 0 5 1 3 4]
#
# -----------------------------------------------------------------------
#
# 'WallStructure' has 4 unique values
# [1 0 3 2]
#
# -----------------------------------------------------------------------
#
# 'SuspWoodFloor' has 3 unique values
# [0 2 1]
#
# -----------------------------------------------------------------------
#
# 'PercDraughtStripped' has 101 unique values
# ~~Listing up to 17 unique values~~
# [ 100.   80.   92.    6.   83.   50.   94.   93.   97.   89.   90.   95.
#    66.    0.   91.   85.   88.]
#
# -----------------------------------------------------------------------
#
# 'NShelteredSides' has 5 unique values
# [ 3.  0.  1.  2.  4.]
#
# -----------------------------------------------------------------------
#
# 'PermTest' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'PermTestResult' has 420 unique values
# ~~Listing up to 17 unique values~~
# [ 0.     0.16   0.135  0.08   0.21   0.116  0.44   0.167  0.19   0.3    0.25
#   0.149  0.15   0.068  0.056  0.14   0.1  ]
#
# -----------------------------------------------------------------------
#
# 'TempAdj' has 38 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    0.6   0.3   0.45 -0.15 -0.1  -0.25  0.1   0.5   1.    0.06  0.95
#   0.08  2.    0.35  0.03  3.  ]
#
# -----------------------------------------------------------------------
#
# 'ControlCat' has 4 unique values
# [ 1.  3.  2.  0.]
#
# -----------------------------------------------------------------------
#
# 'ResponseCat' has 6 unique values
# [ 1.  3.  4.  2.  5.  0.]
#
# -----------------------------------------------------------------------
#
# 'NCHPumps' has 16 unique values
# [  1.   2.   0.   4.   3.   5.   9.  10.   6.   8.   7.  11.  20.  12.  17.
#   13.]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat1' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'BoilerStat2' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'OilPumpIn' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'NGasFans' has 7 unique values
# [  0.   1.   2.   9.   3.   4.  11.]
#
# -----------------------------------------------------------------------
#
# 'WarmAir' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'Underfloor' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'DistLoss' has 6569 unique values
# ~~Listing up to 17 unique values~~
# [ 224.033  428.635  343.987  323.551  626.674  321.558  280.853  315.078
#   386.601  384.691  289.659  452.725  265.984  450.399  332.191  531.309
#   195.291]
#
# -----------------------------------------------------------------------
#
# 'PrimaryLoss' has 10 unique values
# [1 2 4 7 6 9 5 3 8 0]
#
# -----------------------------------------------------------------------
#
# 'CylinderThermostat' has 2 unique values
# ['NO ' 'YES']
#
# -----------------------------------------------------------------------
#
# 'CombiCylinder' has 2 unique values
# ['NO ' 'YES']
#
# -----------------------------------------------------------------------
#
# 'SolarPumpPower' has 2 unique values
# ['NO ' 'YES']
#
# -----------------------------------------------------------------------
#
# 'Charging' has 2 unique values
# [0 1]
#
# -----------------------------------------------------------------------
#
# 'LightingEnergy' has 194741 unique values
# ~~Listing up to 17 unique values~~
# [  274.752  1210.888   865.756   477.396  1678.062   851.96    687.254
#    453.736   719.855   939.422   631.75   1348.795   314.431  1337.8
#    492.851  1497.325   255.037]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansEnergy' has 6259 unique values
# ~~Listing up to 17 unique values~~
# [  230.      175.      130.      360.        0.      565.     2229.02
#    757.019   390.      275.       45.      576.961   100.      188.417
#    490.      305.      758.984]
#
# -----------------------------------------------------------------------
#
# 'MainWaterEnergy' has 355020 unique values
# ~~Listing up to 17 unique values~~
# [ 2595.201  4966.751  6486.081  4188.472  5885.092  2363.526  4053.687
#   5688.331  6462.168  4176.838  5659.353  4532.1    3286.202  5265.891
#   4577.569  9817.104  3452.983]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceEnergy' has 444312 unique values
# ~~Listing up to 17 unique values~~
# [137423  32414 166797 398634 242154 307198 313085 211237  18429  83387
#  290763 279065 361899 109184 414343 318318 206788]
#
# -----------------------------------------------------------------------
#
# 'PrimaryLightingEnergy' has 194741 unique values
# ~~Listing up to 17 unique values~~
# [  741.83   3269.398  2337.541  1288.969  4530.767  2300.292  1855.586
#   1225.087  1943.609  2536.439  1705.725  3641.747   848.964  3612.06
#   1330.698  4042.778   688.6  ]
#
# -----------------------------------------------------------------------
#
# 'PrimaryPumpsFansEnergy' has 6259 unique values
# ~~Listing up to 17 unique values~~
# [  621.      472.5     351.      972.        0.     1525.5    6018.354
#   2043.951  1053.      742.5     121.5    1557.795   270.      508.726
#   1323.      823.5    2049.257]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainWaterEnergy' has 355269 unique values
# ~~Listing up to 17 unique values~~
# [  2854.721   5463.426   7134.689   4607.319   6473.601   2599.879
#    4459.056   6257.164   7108.385   4594.522   6225.288   4985.31
#    3614.822   5792.48    5035.326  10798.814   3798.281]
#
# -----------------------------------------------------------------------
#
# 'PrimaryMainSpaceEnergy' has 398591 unique values
# ~~Listing up to 17 unique values~~
# [ 15070.648  57228.07   17274.699  11212.092  26842.125   4894.366
#    5140.607  21787.742  21199.713  11726.11   42206.289  37596.552
#    7170.766  13238.493   9519.452  53535.633   2123.01 ]
#
# -----------------------------------------------------------------------
#
# 'LightingCO2' has 187948 unique values
# ~~Listing up to 17 unique values~~
# [  176.666   778.601   556.681   306.966  1078.994   547.81    441.904
#    291.752   462.867   604.048   406.215   867.275   202.179   860.205
#    316.903   962.78    163.989]
#
# -----------------------------------------------------------------------
#
# 'PumpsAndFansCO2' has 6247 unique values
# ~~Listing up to 17 unique values~~
# [  147.89    112.525    83.59    231.48      0.      363.295  1433.26
#    486.763   250.77    176.825    28.935   370.986    64.3     121.152
#    315.07    196.115   488.027]
#
# -----------------------------------------------------------------------
#
# 'MainWaterCO2' has 330175 unique values
# ~~Listing up to 17 unique values~~
# [  705.895  1350.956  1764.214   850.26   1194.674   479.796   822.898
#   2098.994  1757.71    847.898  2088.301  1232.731   893.847  1068.976
#    929.247  2670.252   700.956]
#
# -----------------------------------------------------------------------
#
# 'MainSpaceCO2' has 431656 unique values
# ~~Listing up to 17 unique values~~
# [  3726.56   14150.941   4271.562   1623.152   4953.592    903.233
#     948.676   7308.797   5242.111   2164.     14158.292   9296.602
#    1773.135   2443.104   1756.772  13237.902    391.792]
#
# -----------------------------------------------------------------------
#
# 'AreaGroundFloor' has 22628 unique values
# ~~Listing up to 17 unique values~~
# [  33.69   96.77  104.84   52.41  173.21   94.4    76.15   49.72  125.61
#    64.38   80.     84.87   34.84   54.39   52.12  181.6    40.37]
#
# -----------------------------------------------------------------------
#
# 'HeightGroundFloor' has 470 unique values
# ~~Listing up to 17 unique values~~
# [ 2.25  2.85  2.43  2.44  2.5   2.6   2.47  2.58  2.42  2.45  2.53  2.61
#   2.63  2.7   2.66  2.59  2.46]
#
# -----------------------------------------------------------------------
#
# 'AreaFirstFloor' has 14997 unique values
# ~~Listing up to 17 unique values~~
# [   0.     50.67   42.9   110.66   41.69   60.28   75.83   34.84   56.51
#    47.17   27.09    4.     45.02   41.49   66.7    37.28   58.71]
#
# -----------------------------------------------------------------------
#
# 'HeightFirstFloor' has 474 unique values
# ~~Listing up to 17 unique values~~
# [ 0.    2.55  2.65  2.72  2.74  2.69  2.84  2.64  2.67  2.68  2.41  2.45
#   2.79  1.84  2.77  2.62  2.71]
#
# -----------------------------------------------------------------------
#
# 'AreaSecondFloor' has 6552 unique values
# ~~Listing up to 17 unique values~~
# [  0.    48.49  30.5   84.72  48.25  23.    52.44  11.76  59.74  20.83
#   15.45  52.93  47.8   37.64  44.27  32.15  60.9 ]
#
# -----------------------------------------------------------------------
#
# 'BridgingFac' has 74 unique values
# ~~Listing up to 17 unique values~~
# [ 0.15   0.11   0.08   0.033  0.09   0.04   0.032  0.052  0.055  0.043
#   0.05   0.06   0.057  0.049  0.051  0.063  0.035]
#
# -----------------------------------------------------------------------
#
# 'MassCat' has 5 unique values
# [2 3 0 4 1]
#
# -----------------------------------------------------------------------
#
# 'PercLowEnergy' has 204 unique values
# ~~Listing up to 17 unique values~~
# [83.0 18.0 17.0 89.0 69.0 0.0 90.0 73.0 33.0 25.0 14.0 100.0 41.0 60.0 24.0
#  63.0 20.0]
#
# -----------------------------------------------------------------------
#
# 'TotEnergy' has 447949 unique values
# ~~Listing up to 17 unique values~~
# [19628.788 66036.461 25220.061 15146.598 32140.086 7839.91 9589.22
#  28587.863999999998 31431.226000000002 21542.311 52037.098 44685.685
#  13229.996000000001 22294.917999999998 16332.216 71352.924 5813.029]
#
# -----------------------------------------------------------------------
#
# 'SecSpaceEnergy' has 373376 unique values
# ~~Listing up to 17 unique values~~
# [1906.3729999999998 6495.307 1933.9520000000002 2309.905 0.0
#  1650.5870000000002 4746.737 4447.630999999999 6394.892 3610.671
#  1965.3210000000001 3481.2329999999997 2432.749 11139.738000000001 2666.1
#  5855.486999999999 746.377]
#
# -----------------------------------------------------------------------
#
# 'SecWaterEnergy' has 44023 unique values
# ~~Listing up to 17 unique values~~
# [  9.21873000e+02   1.10799700e+03   0.00000000e+00   8.58172000e+02
#    1.14332000e+03   8.51749000e+02   6.55435000e+02   9.15164000e+02
#    9.77014000e+02   1.38624909e+07   7.37554000e+02   1.05878300e+03
#    1.10828300e+03   1.11943100e+03   1.42805100e+03   1.25467700e+03
#    8.61461000e+02]
#
# -----------------------------------------------------------------------
#
# 'PercLivingArea' has 225237 unique values
# ~~Listing up to 17 unique values~~
# [147752   7354  69721  70684  16744 160198 139161  34119  42264  67919
#   79143  73461 145910  29509  68906  94126 145500]
#
# -----------------------------------------------------------------------
#
# 'SecSpaceCO2' has 351340 unique values
# ~~Listing up to 17 unique values~~
# [    0.     2396.768   713.628   905.483   609.067  1751.546   902.869
#   2359.715  1332.338   725.203  1364.643   897.684  4366.777   983.791
#   2160.675   275.413   509.179]
#
# -----------------------------------------------------------------------
#
# 'SecWaterCO2' has 42368 unique values
# ~~Listing up to 17 unique values~~
# [  5.92764000e+02   7.12442000e+02   0.00000000e+00   5.51805000e+02
#    7.35155000e+02   5.47675000e+02   4.21445000e+02   5.88450000e+02
#    6.28220000e+02   8.91358163e+06   4.74247000e+02   6.80797000e+02
#    7.12626000e+02   7.19794000e+02   9.18237000e+02   8.06757000e+02
#    5.53919000e+02]
#
# -----------------------------------------------------------------------
#
# 'SecWaterPrimaryEnergy' has 44021 unique values
# ~~Listing up to 17 unique values~~
# [  2.48905700e+03   2.99159200e+03   0.00000000e+00   2.31706400e+03
#    3.08696400e+03   2.29972200e+03   1.76967500e+03   2.47094300e+03
#    2.63793800e+03   3.74287253e+07   1.99139600e+03   2.85871400e+03
#    2.99236400e+03   3.02246400e+03   3.85573800e+03   3.38762800e+03
#    2.32594500e+03]
#
# -----------------------------------------------------------------------
#
# 'UpgradeHES' has 11 unique values
# [  0.00000000e+00   1.00000000e+00   2.53170900e+03   2.19522000e+02
#    1.22509600e+03   1.93064600e+03   1.13734000e+03   3.67538500e+03
#    5.59848800e+03   1.58066100e+03   2.88868700e+03]
#
# -----------------------------------------------------------------------
#
# 'RoofAreaRoom' has 8843 unique values
# ~~Listing up to 17 unique values~~
# [ 18.35   0.    28.42  20.08  91.42  80.94  15.89  48.75  14.81  18.97
#   18.06  62.1   19.74  49.47  44.66  85.    51.47]
#
# -----------------------------------------------------------------------
#
# 'RatingPurpose' has 14 unique values
# [13 11  7 10 12  9  8  1  3  5  2  6  0  4]
#
# -----------------------------------------------------------------------
#
# 'AssessmentDate' has 3195 unique values
# ~~Listing up to 17 unique values~~
# [1723  122 1819 2594 2375 2216 1829 1214 3009  637 1814 2541 1559 2390 2904
#   878 1031]
#
# -----------------------------------------------------------------------
#
# 'FirstEnerType' has 12 unique values
# [1.0 2.0 3.0 'None' '1' '2' '3' 'Feb 20 2014 12:00AM' 0.0 'Other' 'Unknown'
#  'Mar 18 2014 12:00AM']
#
# -----------------------------------------------------------------------
#
# 'FirstEnerTypeDescr' has 11 unique values
# [10  9  7  6  1  0  4  2  3  5  8]
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerComment' has 1012 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'Solar PV' 'solar' 'PV S 30deg 4  panel 1289' 'PV'
#  'Suntech 5 Panel PV System' 'Solar PV array' 'Renewable Contribution'
#  'solar space' '1.3  kWp Photovoltaic' '3 Joule Pulsa 260 PV Panels' 'pv'
#  '1.04 kWp (4# 260Wp) PV - South' 'PV panels' 'Photovoltaic'
#  'HEAT PUMP RENEWABLE CONTRIB' '3 No. Suntech 250w PV cells']
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerDelivered' has 1356 unique values
# ~~Listing up to 17 unique values~~
# [0.0 723.0 525.0 'No' 118.0 859.0 708.8 804.0 766.0 817.0 556.0 670.2 414.0
#  474.0 737.1519999999999 627.1 531.6]
#
# -----------------------------------------------------------------------
#
# 'ProdFirstEnerConvFac' has 28 unique values
# ~~Listing up to 17 unique values~~
# [0.0 2.45 1.0 'No' 1.1 2.19 2.37 2.42 2.7 '0' '2.37' '2.19' '2.42' '2.45'
#  '1.1' '2.7' 'Renewable Thermal']
#
# -----------------------------------------------------------------------
#
# 'ConsFirstEnerComment' has 69 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'solar' '0' 'None' 'Heat Pump' 'Solar' 'Pup' '75' 'none'
#  'By electric pump' 'electricity' 'solar thermal' 'Heat pump' 'Electricity'
#  '1289' 'NONE' 'PS260M-20/U']
#
# -----------------------------------------------------------------------
#
# 'SecondEnerTypeDescr' has 6 unique values
# [5 2 3 4 1 0]
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerComment' has 85 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'PV e/w 30deg  4 panels 709' 'Heat Pump' 'Solar PV'
#  'Renewable Thermal' 0.0 'heat pump' '0' 'HP contribution'
#  'PV 2 panels W 30deg ' '1# 250Wp West Facing' '2PV'
#  'PV 2 PANELS SOUTH @ 45 429' 'Add Part L Contribution from H'
#  'PV S 30deg  5 panels 1074' '8 Panels   45 Deg E/W 1339' 'Heat Recovery']
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerDelivered' has 64 unique values
# ~~Listing up to 17 unique values~~
# [0.0 'No' 1040.0 865.0 738.0 368.0 709.0 177.2 561.86 429.6 429.0 375.0
#  1339.0 '0' 'Renewable Thermal' '709' 2538.0]
#
# -----------------------------------------------------------------------
#
# 'ProdSecondEnerConvFac' has 15 unique values
# [0.0 'No' 2.19 1.1 2.7 '0' 'Renewable Thermal' '2.19' 0.1 2.18 2.37 2.42
#  2.45 '2.37' '2.13']
#
# -----------------------------------------------------------------------
#
# 'ConsSecondEnerComment' has 17 unique values
# ['No' 0.0 '6 Panels   45 Deg E/W 1004' 'Electricity' '859 (5 panels 1074)'
#  893.0 'None' '260w' '893' 'none' '1  panels 201' 532.0 '613' '0' 'Solar'
#  '5 panels 1206' 613.0]
#
# -----------------------------------------------------------------------
#
# 'ThirdEnerTypeDescr' has 6 unique values
# [5 2 3 4 1 0]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerComment' has 32 unique values
# ~~Listing up to 17 unique values~~
# ['No' 'PV e/w 30deg  2 panels 354' 'm' 'Renewable Thermal' 0.0 'heat pump'
#  'Add Part L Contribution from H' 'PV 30deg  2 panels ' '1' '0'
#  'PV 1 panels se 30deg' 'PV ne 2 panels ' 'PV 1 panel S 30deg' 'cooker c'
#  'Sunstream 3.7 Wind Turbine' 'e' 1.0]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerDelivered' has 16 unique values
# [0.0 'No' 354.0 385.65 '0' 'Renewable Thermal' '354' 741.0 204.0 258.0
#  530.0 394.0 485.0 201.0 7171.0 615.65]
#
# -----------------------------------------------------------------------
#
# 'ProdThirdEnerConvFac' has 8 unique values
# [0.0 'No' 2.19 '0' 'Renewable Thermal' 2.37 2.45 2.7]
#
# -----------------------------------------------------------------------
#
# 'ConsThirdEnerComment' has 5 unique values
# ['No' 0.0 '1592  6 panels 1327 for 5 pane' '1592  6 panels' 'none']
#
# -----------------------------------------------------------------------
#
# 'EffSecondHeatGenPlant' has 39 unique values
# ~~Listing up to 17 unique values~~
# [   0.    85.    92.   270.    75.   150.    80.    63.   100.    20.   294.
#    91.1  105.    65.    30.    91.9  302.2]
#
# -----------------------------------------------------------------------
#
# 'PercSecondHeat' has 58 unique values
# ~~Listing up to 17 unique values~~
# [  0.  10.  62.  50.  38.  30.  58.  20.  34.  36.  53.  14.  28.  46.  24.
#   40.  33.]
#
# -----------------------------------------------------------------------
#
# 'TotPrimaryEnergyFac' has 343 unique values
# ~~Listing up to 17 unique values~~
# [ 1.444  1.291  1.513  1.54   1.392  1.231  1.051  1.343  1.283  1.642
#   1.242  1.658  1.309  0.904  1.246  1.352  0.762]
#
# -----------------------------------------------------------------------
#
# 'TotCO2Emissions' has 251 unique values
# ~~Listing up to 17 unique values~~
# [ 0.266  0.029  0.279  0.284  0.344  0.227  0.198  0.248  0.237  0.303
#   0.229  0.306  0.03   0.195  0.269  0.031  0.164]
#
# -----------------------------------------------------------------------
#
# 'PrimaryEnergySecondarySpace' has 333910 unique values
# ~~Listing up to 17 unique values~~
# [     0.      7144.838   2127.347   2771.886   1815.646   5221.411
#    4892.394   7034.381   3971.738   2161.853   4177.48    2676.024
#   13367.686   2932.71    6441.036    821.015   1517.878]
#
# -----------------------------------------------------------------------
#
# 'EnergyMainWater' has 355020 unique values
# ~~Listing up to 17 unique values~~
# [ 2335.6809  4470.0759  5837.4729  3769.6248  5296.5828  2127.1734
#   3648.3183  5119.4979  5815.9512  3759.1542  5093.4177  4078.89    2957.5818
#   4739.3019  4119.8121  8835.3936  3107.6847]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# []
#
#
# Features with non-numeric values:
# ['EnergyRatingCont', 'TempAdj', 'CylinderThermostat', 'CombiCylinder', 'SolarPumpPower', 'MainWaterEnergy', 'PrimaryMainWaterEnergy', 'PrimaryMainSpaceEnergy', 'MainWaterCO2', 'MainSpaceCO2', 'PercLowEnergy', 'TotEnergy', 'SecSpaceEnergy', 'SecWaterEnergy', 'SecSpaceCO2', 'SecWaterCO2', 'SecWaterPrimaryEnergy', 'FirstEnerType', 'ProdFirstEnerComment', 'ProdFirstEnerDelivered', 'ProdFirstEnerConvFac', 'ConsFirstEnerComment', 'ProdSecondEnerComment', 'ProdSecondEnerDelivered', 'ProdSecondEnerConvFac', 'ConsSecondEnerComment', 'ProdThirdEnerComment', 'ProdThirdEnerDelivered', 'ProdThirdEnerConvFac', 'ConsThirdEnerComment', 'PrimaryEnergySecondarySpace', 'EnergyMainWater']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
# Separate dataset for validation
unknown_mask = train[['EnergyRatingCat','EnergyRatingCont']].isnull()
data_submit = data_cl[unknown_mask]

# Separate dataset for training
X = data_cl[~unknown_mask]
Y = target[~unknown_mask]

# %%
X['EnergyRatingCat'] = X['EnergyRatingCat'].replace({"Nan" : -1, "A1" : 15 , "A3" : 13, "A2" : 14,"B1" : 12, "B2" : 11, "B3" : 10, "C1" : 9 , "C2" : 8, "C3" : 7,"D1" : 6, "D2" : 5,"D3" : 4, "E1" : 3 , "E2" : 2, "F" : 1,"G" : 0})

# %%
Y
# Out:
#        EnergyRatingCat  EnergyRatingCont
# 11708              NaN               NaN
# 23821              NaN               NaN
# 61157              NaN               NaN
# 82063              NaN               NaN
# 111091             NaN               NaN
# 140098             NaN               NaN
# 144394             NaN               NaN
# 202716             NaN               NaN
# 213631             NaN               NaN
# 221437             NaN               NaN
# 231657             NaN               NaN
# 364814             NaN               NaN
# 464514             NaN               NaN
# 464515             NaN               NaN
# 464516             NaN               NaN
# 464517             NaN               NaN
# 464518             NaN               NaN
# 464519             NaN               NaN
# 464520             NaN               NaN
# 464521             NaN               NaN
# 464522             NaN               NaN
# 464523             NaN               NaN
# 464524             NaN               NaN
# 464525             NaN               NaN
# 464526             NaN               NaN
# 464527             NaN               NaN
# 464528             NaN               NaN
# 464529             NaN               NaN
# 464530             NaN               NaN
# 464531             NaN               NaN
# ...                ...               ...
# 623746             NaN               NaN
# 623747             NaN               NaN
# 623748             NaN               NaN
# 623749             NaN               NaN
# 623750             NaN               NaN
# 623751             NaN               NaN
# 623752             NaN               NaN
# 623753             NaN               NaN
# 623754             NaN               NaN
# 623755             NaN               NaN
# 623756             NaN               NaN
# 623757             NaN               NaN
# 623758             NaN               NaN
# 623759             NaN               NaN
# 623760             NaN               NaN
# 623761             NaN               NaN
# 623762             NaN               NaN
# 623763             NaN               NaN
# 623764             NaN               NaN
# 623765             NaN               NaN
# 623766             NaN               NaN
# 623767             NaN               NaN
# 623768             NaN               NaN
# 623769             NaN               NaN
# 623770             NaN               NaN
# 623771             NaN               NaN
# 623772             NaN               NaN
# 623773             NaN               NaN
# 623774             NaN               NaN
# 623775             NaN               NaN
#
# [159274 rows x 2 columns]

# %%
#Variance Threshold
#Find all features with more than 90% variance in values.
threshold = 0.90
vt = VarianceThreshold().fit(X)

# Find feature names
feat_var_threshold = data_cl.columns[vt.variances_ > threshold * (1-threshold)]
feat_var_threshold
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e0cffdb3ce0f> in <module>()
#       2 #Find all features with more than 90% variance in values.
#       3 threshold = 0.90
# ----> 4 vt = VarianceThreshold().fit(X)
#       5
#       6 # Find feature names
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_selection\variance_threshold.py in fit(self, X, y)
#      62         self
#      63         """
# ---> 64         X = check_array(X, ('csr', 'csc'), dtype=np.float64)
#      65
#      66         if hasattr(X, "toarray"):   # sparse matrix
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'F '
