# %%
# http://contrib.scikit-learn.org/categorical-encoding/polynomial.html

# %%
#http://drivendata.co/blog/worldbank-poverty-benchmark/

# %matplotlib inline

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# data directory
DATA_DIR = os.path.join(r'C:\Users\piush\Desktop\Dataset\world_bank_poverty_data\household')

# %%
data_paths = {'A': {'train': os.path.join(DATA_DIR,  'A_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'A_hhold_test.csv')}, 
              
              'B': {'train': os.path.join(DATA_DIR,  'B_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'B_hhold_test.csv')}, 
              
              'C': {'train': os.path.join(DATA_DIR,  'C_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'C_hhold_test.csv')}}

# %%
# load training data
a_train = pd.read_csv(data_paths['A']['train'], index_col='id')
b_train = pd.read_csv(data_paths['B']['train'], index_col='id')
c_train = pd.read_csv(data_paths['C']['train'], index_col='id')

# %% [markdown]
# ##### Drop country and poor in the training set

# %%
ay_train = np.ravel(a_train.poor)

# %%
a_train = a_train.drop('poor',axis = 1)

# %%
a_train.shape
# Out:
# (8203, 344)

# %%
by_train = np.ravel(b_train.poor)

# %%
b_train.shape
# Out:
# (3255, 442)

# %%
b_train = b_train.drop('poor',axis = 1)

# %%
b_train.shape
# Out:
# (3255, 441)

# %%
cy_train = np.ravel(c_train.poor)

# %%
c_train = c_train.drop('poor',axis = 1)

# %%
len(list(a_train.columns.values))
# Out:
# 344

# %% [markdown]
# ###### Convert only the categorical values

# %%
encoder = ce.OneHotEncoder(cols= list(a_train.columns.values))
encoder.fit(a_train, ay_train)
aX_cleaned = encoder.transform(a_train)

# %%
encoder = ce.OneHotEncoder(cols= list(b_train.columns.values))
encoder.fit(b_train, by_train)
bX_cleaned = encoder.transform(b_train)

# %%
encoder = ce.OneHotEncoder(cols= list(c_train.columns.values))
encoder.fit(c_train, cy_train)
cX_cleaned = encoder.transform(c_train)

# %%
#encoder.fit(a_train, ay_train)

# %%
#aX_cleaned = encoder.transform(a_train)

# %%
aX_cleaned.head(2)
# Out:
#        wBXbHZmp_0  wBXbHZmp_1  wBXbHZmp_-1  SlDKnCuu_0  SlDKnCuu_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        SlDKnCuu_-1  KAJOWiiw_0  KAJOWiiw_1  KAJOWiiw_2  KAJOWiiw_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           1           0           0            0
#
#        DsKacCdL_0  DsKacCdL_1  DsKacCdL_-1  rtPrBBPl_0  rtPrBBPl_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        rtPrBBPl_-1  tMJrvvut_0  tMJrvvut_1  tMJrvvut_-1  jdetlNNF_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        jdetlNNF_1  jdetlNNF_-1  maLAYXwi_0  maLAYXwi_1  maLAYXwi_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           0           1           0
#
#        maLAYXwi_-1  vwpsXRGk_0  vwpsXRGk_1  vwpsXRGk_2  vwpsXRGk_3  \
# id
# 46107            0           1           0           0           0
# 82739            0           0           1           0           0
#
#        vwpsXRGk_4  vwpsXRGk_5  vwpsXRGk_6  vwpsXRGk_7  vwpsXRGk_8  vwpsXRGk_9  \
# id
# 46107           0           0           0           0           0           0
# 82739           0           0           0           0           0           0
#
#        vwpsXRGk_10  vwpsXRGk_11  vwpsXRGk_12  vwpsXRGk_13  vwpsXRGk_14  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        vwpsXRGk_15  vwpsXRGk_16  vwpsXRGk_17  vwpsXRGk_18  vwpsXRGk_19  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        vwpsXRGk_20  vwpsXRGk_21  vwpsXRGk_22  vwpsXRGk_23  vwpsXRGk_24  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        vwpsXRGk_25  vwpsXRGk_26  vwpsXRGk_27  vwpsXRGk_28  vwpsXRGk_29  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        vwpsXRGk_30  vwpsXRGk_-1  sArDRIyX_0  sArDRIyX_1  sArDRIyX_-1  \
# id
# 46107            0            0           1           0            0
# 82739            0            0           1           0            0
#
#        goxNwvnG_0  goxNwvnG_1  goxNwvnG_-1  TYhoEiNm_0  TYhoEiNm_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        TYhoEiNm_-1  bgfNZfcj_0  bgfNZfcj_1  bgfNZfcj_-1  sYIButva_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        sYIButva_1  sYIButva_-1  VZtBaoXL_0  VZtBaoXL_1  VZtBaoXL_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           1           0           0
#
#        VZtBaoXL_-1  GUvFHPNA_0  GUvFHPNA_1  GUvFHPNA_-1  zFkComtB_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        zFkComtB_1  zFkComtB_2  zFkComtB_-1  fxbqfEWb_0  fxbqfEWb_1  \
# id
# 46107           0           0            0           1           0
# 82739           0           0            0           1           0
#
#        fxbqfEWb_-1  HDMHzGif_0  HDMHzGif_1  HDMHzGif_-1  zzwlWZZC_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        zzwlWZZC_1  zzwlWZZC_-1  nGTepfos_0  nGTepfos_1  nGTepfos_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           0           1            0
#
#        DxLvCGgv_0  DxLvCGgv_1  DxLvCGgv_-1  CbABToOI_0  CbABToOI_1  \
# id
# 46107           1           0            0           1           0
# 82739           0           1            0           0           1
#
#        CbABToOI_2  CbABToOI_-1  qgMygRvX_0  qgMygRvX_1  qgMygRvX_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           1           0           0
#
#        qgMygRvX_3  qgMygRvX_4  qgMygRvX_5  qgMygRvX_6  qgMygRvX_7  qgMygRvX_8  \
# id
# 46107           0           0           0           0           0           0
# 82739           0           0           0           0           0           0
#
#        qgMygRvX_-1  fhKiXuMY_0  fhKiXuMY_1  fhKiXuMY_-1  uSKnVaKV_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        uSKnVaKV_1  uSKnVaKV_-1  hESBInAl_0  hESBInAl_1  hESBInAl_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           1           0           0
#
#        hESBInAl_-1  nzTeWUeM_0  nzTeWUeM_1  nzTeWUeM_2  nzTeWUeM_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           0           1           0            0
#
#        BbKZUYsB_0  BbKZUYsB_1  BbKZUYsB_-1  UCnazcxd_0  UCnazcxd_1  \
# id
# 46107           1           0            0           1           0
# 82739           0           1            0           0           1
#
#        UCnazcxd_-1  hTraVEWP_0  hTraVEWP_1  hTraVEWP_-1  aCfsveTu_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        aCfsveTu_1  aCfsveTu_-1  EfkPrfXa_0  EfkPrfXa_1  EfkPrfXa_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        NrvxpdMQ_0  NrvxpdMQ_1  NrvxpdMQ_-1  nEsgxvAq_0  nEsgxvAq_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           0           1
#
#        nEsgxvAq_2  nEsgxvAq_3  nEsgxvAq_4  nEsgxvAq_5  nEsgxvAq_6  nEsgxvAq_7  \
# id
# 46107           0           0           0           0           0           0
# 82739           0           0           0           0           0           0
#
#        nEsgxvAq_8  nEsgxvAq_9  nEsgxvAq_10  nEsgxvAq_-1  FcekeISI_0  \
# id
# 46107           0           0            0            0           1
# 82739           0           0            0            0           0
#
#        FcekeISI_1  FcekeISI_2  FcekeISI_-1  NmAVTtfA_0  NmAVTtfA_1  \
# id
# 46107           0           0            0           1           0
# 82739           1           0            0           1           0
#
#        NmAVTtfA_-1  YTdCRVJt_0  YTdCRVJt_1  YTdCRVJt_2  YTdCRVJt_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           1           0           0            0
#
#        QyBloWXZ_0  QyBloWXZ_1  QyBloWXZ_-1  NGOnRdqc_0  NGOnRdqc_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        NGOnRdqc_-1  HKMQJANN_0  HKMQJANN_1  HKMQJANN_2  HKMQJANN_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           0           1           0            0
#
#        ZRrposmO_0  ZRrposmO_1  ZRrposmO_-1  wakWLjkG_0  wakWLjkG_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           0           1
#
#        wakWLjkG_-1  vmZttwFZ_0  vmZttwFZ_1  vmZttwFZ_-1  dkoIJCbY_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        dkoIJCbY_1  dkoIJCbY_-1  NrUWfvEq_0  NrUWfvEq_1  NrUWfvEq_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           1           0           0
#
#        NrUWfvEq_-1  WqhniYIc_0  WqhniYIc_1  WqhniYIc_-1  yHbEDILT_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        yHbEDILT_1  yHbEDILT_-1  EJgrQqET_0  EJgrQqET_1  EJgrQqET_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           0           1            0
#
#        nGMEgWyl_0  nGMEgWyl_1  nGMEgWyl_-1  IIEHQNUc_0  IIEHQNUc_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        IIEHQNUc_-1  HfKRIwMb_0  HfKRIwMb_1  HfKRIwMb_-1  NRVuZwXK_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           0           1            0           1
#
#        NRVuZwXK_1  NRVuZwXK_2  NRVuZwXK_3  NRVuZwXK_4  NRVuZwXK_5  NRVuZwXK_6  \
# id
# 46107           0           0           0           0           0           0
# 82739           0           0           0           0           0           0
#
#        NRVuZwXK_7  NRVuZwXK_8  NRVuZwXK_-1  UCAmikjV_0  UCAmikjV_1  \
# id
# 46107           0           0            0           1           0
# 82739           0           0            0           1           0
#
#        UCAmikjV_-1  UGbBCHRE_0  UGbBCHRE_1  UGbBCHRE_-1  uJYGhXqG_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           0
#
#        uJYGhXqG_1  uJYGhXqG_-1  bxKGlBYX_0  bxKGlBYX_1  bxKGlBYX_-1  \
# id
# 46107           0            0           1           0            0
# 82739           1            0           1           0            0
#
#        nCzVgxgY_0  nCzVgxgY_1  nCzVgxgY_-1  ltcNxFzI_0  ltcNxFzI_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           0           1
#
#        ltcNxFzI_2  ltcNxFzI_3  ltcNxFzI_-1  WbEDLWBH_0  WbEDLWBH_1  \
# id
# 46107           0           0            0           1           0
# 82739           0           0            0           1           0
#
#        WbEDLWBH_-1  IBPMYJlv_0  IBPMYJlv_1  IBPMYJlv_-1  MxOgekdE_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        MxOgekdE_1     ...      QqoiIXtI_1  QqoiIXtI_-1  XVwajTfe_0  \
# id                    ...
# 46107           0     ...               0            0           1
# 82739           0     ...               0            0           1
#
#        XVwajTfe_1  XVwajTfe_-1  jwEuQQve_0  jwEuQQve_1  jwEuQQve_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        rQAsGegu_0  rQAsGegu_1  rQAsGegu_-1  nKoaotpH_0  nKoaotpH_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        nKoaotpH_-1  kLkPtNnh_0  kLkPtNnh_1  kLkPtNnh_-1  TzPdCEPV_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        TzPdCEPV_1  TzPdCEPV_-1  CtHqaXhY_0  CtHqaXhY_1  CtHqaXhY_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           0           1           0
#
#        CtHqaXhY_-1  DbUNVFwv_0  DbUNVFwv_1  DbUNVFwv_-1  FmSlImli_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           0
#
#        FmSlImli_1  FmSlImli_-1  UsENDgsH_0  UsENDgsH_1  UsENDgsH_-1  \
# id
# 46107           0            0           1           0            0
# 82739           1            0           1           0            0
#
#        TiwRslOh_0  TiwRslOh_1  TiwRslOh_2  TiwRslOh_3  TiwRslOh_4  TiwRslOh_5  \
# id
# 46107           1           0           0           0           0           0
# 82739           0           1           0           0           0           0
#
#        TiwRslOh_6  TiwRslOh_7  TiwRslOh_8  TiwRslOh_9  TiwRslOh_10  \
# id
# 46107           0           0           0           0            0
# 82739           0           0           0           0            0
#
#        TiwRslOh_11  TiwRslOh_12  TiwRslOh_13  TiwRslOh_14  TiwRslOh_15  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        TiwRslOh_16  TiwRslOh_17  TiwRslOh_-1  mNrEOmgq_0  mNrEOmgq_1  \
# id
# 46107            0            0            0           1           0
# 82739            0            0            0           1           0
#
#        mNrEOmgq_-1  PWShFLnY_0  PWShFLnY_1  PWShFLnY_-1  uRFXnNKV_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        uRFXnNKV_1  uRFXnNKV_2  uRFXnNKV_-1  lFExzVaF_0  lFExzVaF_1  \
# id
# 46107           0           0            0           1           0
# 82739           0           0            0           1           0
#
#        lFExzVaF_-1  CVCsOVew_0  CVCsOVew_1  CVCsOVew_-1  tlxXCDiW_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        tlxXCDiW_1  tlxXCDiW_-1  IKqsuNvV_0  IKqsuNvV_1  IKqsuNvV_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        ztGMreNV_0  ztGMreNV_1  ztGMreNV_-1  CqqwKRSn_0  CqqwKRSn_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           0           1
#
#        CqqwKRSn_2  CqqwKRSn_-1  YUExUvhq_0  YUExUvhq_1  YUExUvhq_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        uVnApIlJ_0  uVnApIlJ_1  uVnApIlJ_-1  fsXLyyco_0  fsXLyyco_1  \
# id
# 46107           1           0            0           1           0
# 82739           0           1            0           1           0
#
#        fsXLyyco_-1  UXhTXbuS_0  UXhTXbuS_1  UXhTXbuS_2  UXhTXbuS_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           1           0           0            0
#
#        yaHLJxDD_0  yaHLJxDD_1  yaHLJxDD_2  yaHLJxDD_-1  zuMWFXax_0  \
# id
# 46107           1           0           0            0           1
# 82739           0           1           0            0           1
#
#        zuMWFXax_1  zuMWFXax_2  zuMWFXax_-1  qlZMvcWc_0  qlZMvcWc_1  \
# id
# 46107           0           0            0           1           0
# 82739           0           0            0           1           0
#
#        qlZMvcWc_-1  dqRtXzav_0  dqRtXzav_1  dqRtXzav_-1  ALbGNqKm_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           0           1            0           1
#
#        ALbGNqKm_1  ALbGNqKm_-1  ktBqxSwa_0  ktBqxSwa_1  ktBqxSwa_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        NqPjMmKP_0  NqPjMmKP_1  NqPjMmKP_-1  tOWnWxYe_0  tOWnWxYe_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        tOWnWxYe_-1  RvTenIlS_0  RvTenIlS_1  RvTenIlS_-1  GIMIxlmv_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        GIMIxlmv_1  GIMIxlmv_-1  wKVwRQIp_0  wKVwRQIp_1  wKVwRQIp_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        ncjMNgfp_0  ncjMNgfp_1  ncjMNgfp_-1  UaXLYMMh_0  UaXLYMMh_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        UaXLYMMh_2  UaXLYMMh_3  UaXLYMMh_4  UaXLYMMh_-1  vRIvQXtC_0  \
# id
# 46107           0           0           0            0           1
# 82739           0           0           0            0           1
#
#        vRIvQXtC_1  vRIvQXtC_2  vRIvQXtC_3  vRIvQXtC_4  vRIvQXtC_5  \
# id
# 46107           0           0           0           0           0
# 82739           0           0           0           0           0
#
#        vRIvQXtC_-1  bKtkhUWD_0  bKtkhUWD_1  bKtkhUWD_-1  RJFKdmYJ_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        RJFKdmYJ_1  RJFKdmYJ_-1  gllMXToa_0  gllMXToa_1  gllMXToa_2  \
# id
# 46107           0            0           1           0           0
# 82739           0            0           0           1           0
#
#        gllMXToa_-1  HhKXJWno_0  HhKXJWno_1  HhKXJWno_-1  VFTkSOrq_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        VFTkSOrq_1  VFTkSOrq_-1  tAYCAXge_0  tAYCAXge_1  tAYCAXge_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        WAFKMNwv_0  WAFKMNwv_1  WAFKMNwv_-1  mHzqKSuN_0  mHzqKSuN_1  \
# id
# 46107           1           0            0           1           0
# 82739           0           1            0           1           0
#
#        mHzqKSuN_-1  UjuNwfjv_0  UjuNwfjv_1  UjuNwfjv_2  UjuNwfjv_3  \
# id
# 46107            0           1           0           0           0
# 82739            0           1           0           0           0
#
#        UjuNwfjv_4  UjuNwfjv_5  UjuNwfjv_6  UjuNwfjv_7  UjuNwfjv_8  UjuNwfjv_9  \
# id
# 46107           0           0           0           0           0           0
# 82739           0           0           0           0           0           0
#
#        UjuNwfjv_10  UjuNwfjv_11  UjuNwfjv_12  UjuNwfjv_13  UjuNwfjv_-1  \
# id
# 46107            0            0            0            0            0
# 82739            0            0            0            0            0
#
#        aWlBVrkK_0  aWlBVrkK_1  aWlBVrkK_-1  cDkXTaWP_0  cDkXTaWP_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        cDkXTaWP_-1  hnmsRSvN_0  hnmsRSvN_1  hnmsRSvN_-1  ZzUrQSMj_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           0
#
#        ZzUrQSMj_1  ZzUrQSMj_-1  GHmAeUhZ_0  GHmAeUhZ_1  GHmAeUhZ_2  \
# id
# 46107           0            0           1           0           0
# 82739           1            0           0           1           0
#
#        GHmAeUhZ_-1  VBjVVDwp_0  VBjVVDwp_1  VBjVVDwp_2  VBjVVDwp_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           0           1           0            0
#
#        RMbjnrlm_0  RMbjnrlm_1  RMbjnrlm_-1  kZVpcgJL_0  kZVpcgJL_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        kZVpcgJL_-1  zvjiUrCR_0  zvjiUrCR_1  zvjiUrCR_-1  BIofZdtd_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        BIofZdtd_1  BIofZdtd_-1  QZiSWCCB_0  QZiSWCCB_1  QZiSWCCB_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           0           1            0
#
#        sDGibZrP_0  sDGibZrP_1  sDGibZrP_-1  CsGvKKBJ_0  CsGvKKBJ_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           1           0
#
#        CsGvKKBJ_-1  OLpGAaEu_0  OLpGAaEu_1  OLpGAaEu_2  OLpGAaEu_-1  \
# id
# 46107            0           1           0           0            0
# 82739            0           0           1           0            0
#
#        LrDrWRjC_0  LrDrWRjC_1  LrDrWRjC_-1  JCDeZBXq_0  JCDeZBXq_1  \
# id
# 46107           1           0            0           1           0
# 82739           1           0            0           0           1
#
#        JCDeZBXq_-1  HGPWuGlV_0  HGPWuGlV_1  HGPWuGlV_-1  GDUPaBQs_0  \
# id
# 46107            0           1           0            0           1
# 82739            0           1           0            0           1
#
#        GDUPaBQs_1  GDUPaBQs_-1  WuwrCsIY_0  WuwrCsIY_1  WuwrCsIY_-1  \
# id
# 46107           0            0           1           0            0
# 82739           0            0           1           0            0
#
#        AlDbXTlZ_0  AlDbXTlZ_1  AlDbXTlZ_-1  country_0  country_-1
# id
# 46107           1           0            0          1           0
# 82739           0           1            0          1           0
#
# [2 rows x 1247 columns]

# %%
# from sklearn.preprocessing import LabelEncoder
# a_train = a_train.apply(LabelEncoder().fit_transform)

# %%
# Standardize features
def standardize(df, numeric_only=True):
    numeric = df.select_dtypes(include=['int64', 'float64'])
    
    # subtracy mean and divide by std
    df[numeric.columns] = (numeric - numeric.mean()) / numeric.std()
    
    return df
    

def pre_process_data(df, enforce_cols=None):
    print("Input shape:\t{}".format(df.shape))
        

    df = standardize(df)
    print("After standardization {}".format(df.shape))
        
#     # create dummy variables for categoricals
#     df = pd.get_dummies(df)
#     print("After converting categoricals:\t{}".format(df.shape))
    

    # match test set and training set columns
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns, enforce_cols)
        to_add = np.setdiff1d(enforce_cols, df.columns)

        df.drop(to_drop, axis=1, inplace=True)
        df = df.assign(**{c: 0 for c in to_add})
    
    df.fillna(0, inplace=True)
    
    return df

# %%
print("Country A")
aX_train = pre_process_data(aX_cleaned)


print("\nCountry B")
bX_train = pre_process_data(bX_cleaned)

print("\nCountry C")
cX_train = pre_process_data(cX_cleaned)
# Out:
# Country A
# Input shape:	(8203, 1247)
# After standardization (8203, 1247)
#
# Country B
# Input shape:	(3255, 2476)
# After standardization (3255, 2476)
#
# Country C
# Input shape:	(6469, 16711)
# After standardization (6469, 16711)

# %%
from sklearn.ensemble import RandomForestClassifier

def train_model(features, labels, **kwargs):
    
    # instantiate model
    model = RandomForestClassifier(n_estimators=50, random_state=0)
    
    # train model
    model.fit(features, labels)
    
    # get a (not-very-useful) sense of performance
    accuracy = model.score(features, labels)
    print("In-sample accuracy: {0:}".format(accuracy))
    
    return model

# %%
model_a = train_model(aX_train, ay_train)
# Out:
# In-sample accuracy: 1.0

# %%
model_b = train_model(bX_train, by_train)
# Out:
# In-sample accuracy: 0.9993855606758832

# %%
model_c = train_model(cX_train, cy_train)
# Out:
# In-sample accuracy: 0.9998454166022569

# %%
# load test data
a_test = pd.read_csv(data_paths['A']['test'], index_col='id')
b_test = pd.read_csv(data_paths['B']['test'], index_col='id')
c_test = pd.read_csv(data_paths['C']['test'], index_col='id')

# %%
encoder = ce.OneHotEncoder(cols= list(a_test.columns.values))
encoder.fit(a_test)
aX_cleaned_test = encoder.transform(a_test)

# %%
encoder = ce.OneHotEncoder(cols= list(b_test.columns.values))
encoder.fit(b_test)
bX_cleaned_test = encoder.transform(b_test)

# %%
encoder = ce.OneHotEncoder(cols= list(c_test.columns.values))
encoder.fit(c_test)
cX_cleaned_test = encoder.transform(c_test)

# %%
# process the test data
a_test = pre_process_data(aX_cleaned_test, enforce_cols=aX_train.columns)
b_test = pre_process_data(bX_cleaned_test, enforce_cols=bX_train.columns)
c_test = pre_process_data(cX_cleaned_test, enforce_cols=cX_train.columns)
# Out:
# Input shape:	(4041, 1236)
# After standardization (4041, 1236)
# Input shape:	(1604, 2394)
# After standardization (1604, 2394)
# Input shape:	(3187, 9522)
# After standardization (3187, 9522)

# %%
a_preds = model_a.predict_proba(a_test)
b_preds = model_b.predict_proba(b_test)
c_preds = model_c.predict_proba(c_test)

# %%
def make_country_sub(preds, test_feat, country):
    # make sure we code the country correctly
    country_codes = ['A', 'B', 'C']
    
    # get just the poor probabilities
    country_sub = pd.DataFrame(data=preds[:, 1],  # proba p=1
                               columns=['poor'], 
                               index=test_feat.index)

    
    # add the country code for joining later
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
# convert preds to data frames
a_sub = make_country_sub(a_preds, a_test, 'A')
b_sub = make_country_sub(b_preds, b_test, 'B')
c_sub = make_country_sub(c_preds, c_test, 'C')

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
submission.head()
# Out:
#       country  poor
# id
# 418         A  0.26
# 41249       A  0.28
# 16205       A  0.20
# 97501       A  0.20
# 67756       A  0.32

# %%
submission.to_csv('submission_OneHotEncoder.csv')
