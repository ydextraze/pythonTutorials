# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set(style="white", color_codes=True)

# %matplotlib inline

# %% [markdown]
# What is Statbank API?
#
# The Central Statistics Office (CSO) StatBank Application Programming Interface (API) provides access to StatBank data in JSON-stat format. This dissemination tool allows developers machine to machine access to CSO StatBank data. Details about JSON-stat can be found at this web address http://json-stat.org/.
#
# The majority of StatBank tables are available in JSON-stat format, on the StatBank API. StatBank tables with over 150,000 data points are not available in the StatBank API and a message to this effect is presented when you select the JSON table e.g. TDM04 is not available. A list of the StatBank tables that are unavailable are presented here.
#
# If you encounter any difficulties please email databank@cso.ie.
#
# CSO wish you every success using this new data dissemination tool and we welcome your feedback at databank@cso.ie.
#
# Download Data
#
# To download a StatBank table in JSON-stat please click here
#
# There is a list of themes that follow a similar structure to StatBank. Select the theme and subtheme you are interested in and the data tables available will be displayed. Tables are listed as Key Tables, Current Tables and Archived Tables to assist with appropriate selection. The final theme PSSN, is the data hosted by the CSO for other government departments through the CSO Public Sector Statistics Network. Remember tables with over 150,000 data points though listed are not available for download with this application. Details about JSON-stat can be found at this web address http://json-stat.org/ .
#
#
# http://www.cso.ie/webserviceclient/
# http://www.cso.ie/webserviceclient/DatasetListing.aspx

# %% [markdown]
# pyjstat is a python library for JSON-stat formatted data manipulation which allows reading and writing JSON-stat [1] format with python,using the DataFrame structures provided by the widely accepted pandas library [2]. The JSON-stat format is a simple lightweight JSON format for data dissemination, currently in its 2.0 version. Pyjstat is inspired in rjstat [3], a library to read and write JSON-stat with R, by ajschumacher. Note that, like in the rjstat project, not all features are supported (i.e. not all metadata are converted). pyjstat is provided under the Apache License 2.0.
#
# [1]	http://json-stat.org/ for JSON-stat information
# [2]	http://pandas.pydata.org for Python Data Analysis Library information
# [3]	https://github.com/ajschumacher/rjstat for rjstat library information
# This library was first developed to work with Python 2.7. With some fixes (thanks to @andrekittredge), now it works with Python 3.4 too.
#
# https://pypi.python.org/pypi/pyjstat/

# %% [markdown]
# ###### Residential Dwelling Property Transactions by County, Dwelling Status, Stamp Duty Event, Type of Buyer, Type of Sale, Month and Statistic

# %% [markdown]
# ###### Variables
#
# * County (27) -- for all counties
# * Dwelling Status (3)
# * Stamp Duty Event (2)
# * Type of Buyer (6)
# * Type of Sale (3)
# * Time (87)
# * Contents (4)

# %%
from pyjstat import pyjstat
# read from json-stat
url = 'http://www.cso.ie/StatbankServices/StatbankServices.svc/jsonservice/responseinstance/HPM02'
dataset = pyjstat.Dataset.read(url)
df = dataset.write('dataframe')
print(df)
# Out:
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTP connection (1): www.cso.ie
#                County        Dwelling Status Stamp Duty Event  \
# 0        All Counties  All Dwelling Statuses          Filings
# 1        All Counties  All Dwelling Statuses          Filings
# 2        All Counties  All Dwelling Statuses          Filings
# 3        All Counties  All Dwelling Statuses          Filings
# 4        All Counties  All Dwelling Statuses          Filings
# 5        All Counties  All Dwelling Statuses          Filings
# 6        All Counties  All Dwelling Statuses          Filings
# 7        All Counties  All Dwelling Statuses          Filings
# 8        All Counties  All Dwelling Statuses          Filings
# 9        All Counties  All Dwelling Statuses          Filings
# 10       All Counties  All Dwelling Statuses          Filings
# 11       All Counties  All Dwelling Statuses          Filings
# 12       All Counties  All Dwelling Statuses          Filings
# 13       All Counties  All Dwelling Statuses          Filings
# 14       All Counties  All Dwelling Statuses          Filings
# 15       All Counties  All Dwelling Statuses          Filings
# 16       All Counties  All Dwelling Statuses          Filings
# 17       All Counties  All Dwelling Statuses          Filings
# 18       All Counties  All Dwelling Statuses          Filings
# 19       All Counties  All Dwelling Statuses          Filings
# 20       All Counties  All Dwelling Statuses          Filings
# 21       All Counties  All Dwelling Statuses          Filings
# 22       All Counties  All Dwelling Statuses          Filings
# 23       All Counties  All Dwelling Statuses          Filings
# 24       All Counties  All Dwelling Statuses          Filings
# 25       All Counties  All Dwelling Statuses          Filings
# 26       All Counties  All Dwelling Statuses          Filings
# 27       All Counties  All Dwelling Statuses          Filings
# 28       All Counties  All Dwelling Statuses          Filings
# 29       All Counties  All Dwelling Statuses          Filings
# ...               ...                    ...              ...
# 1014738      Monaghan               Existing       Executions
# 1014739      Monaghan               Existing       Executions
# 1014740      Monaghan               Existing       Executions
# 1014741      Monaghan               Existing       Executions
# 1014742      Monaghan               Existing       Executions
# 1014743      Monaghan               Existing       Executions
# 1014744      Monaghan               Existing       Executions
# 1014745      Monaghan               Existing       Executions
# 1014746      Monaghan               Existing       Executions
# 1014747      Monaghan               Existing       Executions
# 1014748      Monaghan               Existing       Executions
# 1014749      Monaghan               Existing       Executions
# 1014750      Monaghan               Existing       Executions
# 1014751      Monaghan               Existing       Executions
# 1014752      Monaghan               Existing       Executions
# 1014753      Monaghan               Existing       Executions
# 1014754      Monaghan               Existing       Executions
# 1014755      Monaghan               Existing       Executions
# 1014756      Monaghan               Existing       Executions
# 1014757      Monaghan               Existing       Executions
# 1014758      Monaghan               Existing       Executions
# 1014759      Monaghan               Existing       Executions
# 1014760      Monaghan               Existing       Executions
# 1014761      Monaghan               Existing       Executions
# 1014762      Monaghan               Existing       Executions
# 1014763      Monaghan               Existing       Executions
# 1014764      Monaghan               Existing       Executions
# 1014765      Monaghan               Existing       Executions
# 1014766      Monaghan               Existing       Executions
# 1014767      Monaghan               Existing       Executions
#
#                Type of Buyer    Type of Sale    Month  \
# 0            All Buyer Types  All Sale Types  2010M01
# 1            All Buyer Types  All Sale Types  2010M01
# 2            All Buyer Types  All Sale Types  2010M01
# 3            All Buyer Types  All Sale Types  2010M01
# 4            All Buyer Types  All Sale Types  2010M02
# 5            All Buyer Types  All Sale Types  2010M02
# 6            All Buyer Types  All Sale Types  2010M02
# 7            All Buyer Types  All Sale Types  2010M02
# 8            All Buyer Types  All Sale Types  2010M03
# 9            All Buyer Types  All Sale Types  2010M03
# 10           All Buyer Types  All Sale Types  2010M03
# 11           All Buyer Types  All Sale Types  2010M03
# 12           All Buyer Types  All Sale Types  2010M04
# 13           All Buyer Types  All Sale Types  2010M04
# 13       Value of Sales (Euro Million)     347.5
# 14          Average Sale Price  (Euro)  192083.0
# 15                 Median Price (Euro)  171000.0
# 16            Volume of Sales (Number)    2052.0
# 17       Value of Sales (Euro Million)     386.4
# 18          Average Sale Price  (Euro)  188316.0
# 19                 Median Price (Euro)  172750.0
# 20            Volume of Sales (Number)    2062.0
# 21       Value of Sales (Euro Million)     393.6
# 22          Average Sale Price  (Euro)  190881.0
# 23                 Median Price (Euro)  170000.0
# 24            Volume of Sales (Number)    2249.0
# 25       Value of Sales (Euro Million)     446.2
# 26          Average Sale Price  (Euro)  198395.0
# 27                 Median Price (Euro)  177000.0
# 28            Volume of Sales (Number)    2324.0
# 29       Value of Sales (Euro Million)     456.7
# ...                                ...       ...
# 1014738     Average Sale Price  (Euro)       NaN
# 1014739            Median Price (Euro)       NaN
# 1014740       Volume of Sales (Number)       0.0
# 1014741  Value of Sales (Euro Million)       0.0
# 1014742     Average Sale Price  (Euro)       NaN
# 1014743            Median Price (Euro)       NaN
# 1014744       Volume of Sales (Number)       0.0
# 1014745  Value of Sales (Euro Million)       0.0
# 1014746     Average Sale Price  (Euro)       NaN
# 1014747            Median Price (Euro)       NaN
# 1014748       Volume of Sales (Number)       0.0
# 1014749  Value of Sales (Euro Million)       0.0
# 1014750     Average Sale Price  (Euro)       NaN
# 1014751            Median Price (Euro)       NaN
# 1014752       Volume of Sales (Number)       7.0
# 1014753  Value of Sales (Euro Million)       0.4
# 1014754     Average Sale Price  (Euro)   50714.0
# 1014755            Median Price (Euro)   40000.0
# 1014756       Volume of Sales (Number)       0.0
# 1014757  Value of Sales (Euro Million)       0.0
# 1014758     Average Sale Price  (Euro)       NaN
# 1014759            Median Price (Euro)       NaN
# 1014760       Volume of Sales (Number)       0.0
# 1014761  Value of Sales (Euro Million)       0.0
# 1014762     Average Sale Price  (Euro)       NaN
# 1014763            Median Price (Euro)       NaN
# 1014764       Volume of Sales (Number)       0.0
# 1014765  Value of Sales (Euro Million)       0.0
# 1014766     Average Sale Price  (Euro)       NaN
# 1014767            Median Price (Euro)       NaN
#
# [1014768 rows x 8 columns]

# %%
df1 = pd.DataFrame.from_records(df)

# %%
#select dublin
df_dublin = df1.ix[(df['County'] == 'Dublin')]

# %%
df_dublin.head(8)
df_dublin = df_dublin.drop("County" , axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-e46ca0425042> in <module>()
#       1 df_dublin.head(8)
# ----> 2 df_dublin = df_dublin.drop("County" , axis = 1)
#       3 df_dublin.set_index("Month")
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3225             if errors != 'ignore':
#    3226                 raise ValueError('labels %s not contained in axis' %
# -> 3227                                  labels[mask])
#    3228             indexer = indexer[~mask]
#    3229         return self.delete(indexer)
#
# ValueError: labels ['County'] not contained in axis

# %%
#http://pbpython.com/pandas-pivot-table-explained.html
pd.pivot_table(df_dublin,index=["Statistic","Month"])
# Out:
#                                             value
# Statistic                  Month
# Average Sale Price  (Euro) 2010M01  287752.515464
#                            2010M02  238884.192308
#                            2010M03  248683.805825
#                            2010M04  238374.951923
#                            2010M05  383442.519608
#                            2010M06  380223.142857
#                            2010M07  224647.142857
#                            2010M08  268089.626263
#                            2010M09  445920.009434
#                            2010M10  221755.962264
#                            2010M11  185450.650485
#                            2010M12  234692.648148
#                            2011M01  219869.283019
#                            2011M02  204631.663551
#                            2011M03  232526.364486
#                            2011M04  194254.130841
#                            2011M05  206891.971963
#                            2011M06  214624.869159
#                            2011M07  242282.771429
#                            2011M08  207490.632075
#                            2011M09  233149.379630
#                            2011M10  232583.480392
#                            2011M11  199569.873786
#                            2011M12  184856.796117
#                            2012M01  224710.262136
#                            2012M02  230074.428571
#                            2012M03  200256.115385
#                            2012M04  177435.688679
#                            2012M05  200923.869159
#                            2012M06  203702.905660
# ...                                           ...
# Volume of Sales (Number)   2014M10     376.148148
#                            2014M11     269.296296
#                            2014M12     391.703704
#                            2015M01     326.333333
#                            2015M02     276.481481
#                            2015M03     251.777778
#                            2015M04     239.666667
#                            2015M05     265.666667
#                            2015M06     314.037037
#                            2015M07     319.333333
#                            2015M08     255.851852
#                            2015M09     291.185185
#                            2015M10     272.074074
#                            2015M11     269.518519
#                            2015M12     318.740741
#                            2016M01     212.703704
#                            2016M02     269.074074
#                            2016M03     244.666667
#                            2016M04     242.074074
#                            2016M05     251.296296
#                            2016M06     263.777778
#                            2016M07     278.925926
#                            2016M08     297.555556
#                            2016M09     304.296296
#                            2016M10     293.518519
#                            2016M11     308.740741
#                            2016M12     395.074074
#                            2017M01     294.555556
#                            2017M02     233.962963
#                            2017M03     225.074074
#
# [348 rows x 1 columns]

# %%
df_dublin = df_dublin.set_index("Month")

# %%
df_dublin.head()
# Out:
#                Dwelling Status Stamp Duty Event    Type of Buyer  \
# Month
# 2010M01  All Dwelling Statuses          Filings  All Buyer Types
# 2010M01  All Dwelling Statuses          Filings  All Buyer Types
# 2010M01  All Dwelling Statuses          Filings  All Buyer Types
# 2010M01  All Dwelling Statuses          Filings  All Buyer Types
# 2010M02  All Dwelling Statuses          Filings  All Buyer Types
#
#            Type of Sale                      Statistic     value
# Month
# 2010M01  All Sale Types       Volume of Sales (Number)     360.0
# 2010M01  All Sale Types  Value of Sales (Euro Million)     119.0
# 2010M01  All Sale Types     Average Sale Price  (Euro)  330459.0
# 2010M01  All Sale Types            Median Price (Euro)  264549.0
# 2010M02  All Sale Types       Volume of Sales (Number)     507.0

# %%
df_dublin = df_dublin.sort_index(ascending= True)

# %%
df_dublin.loc[df_dublin["Statistic"] == "Average Sale Price  (Euro)"]
# Out:
#                Dwelling Status Stamp Duty Event  \
# Month
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing       Executions
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01  All Dwelling Statuses       Executions
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses       Executions
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses       Executions
# 2010M01               Existing          Filings
# 2010M01               Existing          Filings
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing       Executions
# 2010M01  All Dwelling Statuses          Filings
# 2010M01               Existing       Executions
# ...                        ...              ...
# 2017M03               Existing       Executions
# 2017M03               Existing       Executions
# 2017M03               Existing          Filings
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New          Filings
# 2017M03               Existing       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03               Existing          Filings
# 2017M03               Existing          Filings
# 2017M03               Existing          Filings
# 2017M03               Existing          Filings
# 2017M03               Existing          Filings
# 2017M03               Existing          Filings
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03                    New       Executions
# 2017M03               Existing          Filings
#
#                                              Type of Buyer    Type of Sale  \
# Month
# 2010M01                     Household Buyer - Non-Occupier          Market
# 2010M01                     Household Buyer - Non-Occupier      Non-Market
# 2010M01                     Household Buyer - Non-Occupier  All Sale Types
# 2010M01                                Non-Household Buyer  All Sale Types
# 2010M01            Household Buyer - Former Owner-Occupier      Non-Market
# 2010M01            Household Buyer - Former Owner-Occupier          Market
# 2010M01                                Non-Household Buyer          Market
# 2010M01                     Household Buyer - Non-Occupier  All Sale Types
# 2010M01                                Non-Household Buyer      Non-Market
# 2010M01                                Non-Household Buyer  All Sale Types
# 2010M01                     Household Buyer - Non-Occupier          Market
# 2010M01                     Household Buyer - Non-Occupier      Non-Market
# 2010M01                                Non-Household Buyer          Market
# 2010M01                                    All Buyer Types          Market
# 2010M01                              Household Buyer - All      Non-Market
# 2010M01                              Household Buyer - All          Market
# 2010M01                                    All Buyer Types      Non-Market
# 2010M01                              Household Buyer - All  All Sale Types
# 2010M01                                    All Buyer Types      Non-Market
# 2010M01            Household Buyer - Former Owner-Occupier  All Sale Types
# 2010M01                                Non-Household Buyer      Non-Market
# 37595  Carlow  All Dwelling Statuses          Filings  All Buyer Types
# 37599  Carlow  All Dwelling Statuses          Filings  All Buyer Types
# 37603  Carlow  All Dwelling Statuses          Filings  All Buyer Types
#
#          Type of Sale    Month            Statistic     value
# 37587  All Sale Types  2010M01  Median Price (Euro)  176750.0
# 37591  All Sale Types  2010M02  Median Price (Euro)  140332.0
# 37595  All Sale Types  2010M03  Median Price (Euro)   82500.0
# 37599  All Sale Types  2010M04  Median Price (Euro)   57000.0
# 37603  All Sale Types  2010M05  Median Price (Euro)  133000.0

# %%
df2.groupby(['County']).groups.keys()
# Out:
# dict_keys(['Mayo', 'Limerick', 'Leitrim', 'Kilkenny', 'Kerry', 'Clare', 'Cavan', 'Louth', 'Tipperary', 'Kildare', 'Laois', 'Galway', 'Wicklow', 'Sligo', 'Offaly', 'Carlow', 'Meath', 'Donegal', 'Waterford', 'Roscommon', 'Cork', 'Wexford', 'Westmeath', 'Monaghan', 'Dublin', 'Longford'])

# %%
#this creates a series
df2.groupby('County')['value'].mean()
# Out:
# County
# Carlow        95805.629025
# Cavan         74782.863636
# Clare         90007.278562
# Cork         123952.165747
# Donegal       76947.792565
# Dublin       196899.081294
# Galway       119431.228270
# Kerry         99206.845771
# Kildare      152096.277813
# Kilkenny     107529.880663
# Laois         82127.440678
# Leitrim       70550.621939
# Limerick      95017.405943
# Longford      61316.245078
# Louth        101292.775719
# Mayo          81134.687697
# Meath        130949.518757
# Monaghan      83970.351882
# Offaly        82788.970629
# Roscommon     64470.435536
# Sligo         96591.236086
# Tipperary     83664.246036
# Waterford     89573.954161
# Westmeath     83469.881221
# Wexford       96231.365000
# Wicklow      175307.903325
# Name: value, dtype: float64

# %% [markdown]
# http://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %%
#convert the series to a dataframe
df3 = df3.to_frame('Mean Price').reset_index()

# %%
df3
# Out:
#        County     Mean Price
# 0      Carlow   95805.629025
# 1       Cavan   74782.863636
# 2       Clare   90007.278562
# 3        Cork  123952.165747
# 4     Donegal   76947.792565
# 5      Dublin  196899.081294
# 6      Galway  119431.228270
# 7       Kerry   99206.845771
# 8     Kildare  152096.277813
# 9    Kilkenny  107529.880663
# 10      Laois   82127.440678
# 11    Leitrim   70550.621939
# 12   Limerick   95017.405943
# 13   Longford   61316.245078
# 14      Louth  101292.775719
# 15       Mayo   81134.687697
# 16      Meath  130949.518757
# 17   Monaghan   83970.351882
# 18     Offaly   82788.970629
# 19  Roscommon   64470.435536
# 20      Sligo   96591.236086
# 21  Tipperary   83664.246036
# 22  Waterford   89573.954161
# 23  Westmeath   83469.881221
# 24    Wexford   96231.365000
# 25    Wicklow  175307.903325

# %%
print ("\n\n---------------------")
print ("TRAIN SET INFORMATION")
print ("---------------------")
print ("Shape of training set:", df2.shape, "\n")
print ("Column Headers:", list(df2.columns.values), "\n")
print (df2.dtypes)
# Out:
# ---------------------
# TRAIN SET INFORMATION
# ---------------------
# Shape of training set: (977184, 8)
#
# Column Headers: ['County', 'Dwelling Status', 'Stamp Duty Event', 'Type of Buyer', 'Type of Sale', 'Month', 'Statistic', 'value']
#
# County               object
# Dwelling Status      object
# Stamp Duty Event     object
# Type of Buyer        object
# Type of Sale         object
# Month                object
# Statistic            object
# value               float64
# dtype: object

# %%
import re
missing_values = []
nonumeric_values = []

print ("TRAINING SET INFORMATION")
print ("========================\n")

for column in df2:
    # Find all the unique feature values
    uniq = df2[column].unique()
    print ("'{}' has {} unique values" .format(column,uniq.size))
    if (uniq.size > 10):
        print("~~Listing up to 10 unique values~~")
    print (uniq[0:10])
    print ("\n-----------------------------------------------------------------------\n")
    
    # Find features with missing values
    if (True in pd.isnull(uniq)):
        s = "{} has {} missing" .format(column, pd.isnull(df2[column]).sum())
        missing_values.append(s)
    
    # Find features with non-numeric values
    for i in range (1, np.prod(uniq.shape)):
        if (re.match('nan', str(uniq[i]))):
            break
        if not (re.search('(^\d+\.?\d*$)|(^\d*\.?\d+$)', str(uniq[i]))):
            nonumeric_values.append(column)
            break
  
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
print ("Features with missing values:\n{}\n\n" .format(missing_values))
print ("Features with non-numeric values:\n{}" .format(nonumeric_values))
print ("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# TRAINING SET INFORMATION
# ========================
#
# 'County' has 26 unique values
# ~~Listing up to 10 unique values~~
# ['Carlow' 'Dublin' 'Kildare' 'Kilkenny' 'Laois' 'Longford' 'Louth' 'Meath'
#  'Offaly' 'Westmeath']
#
# -----------------------------------------------------------------------
#
# 'Dwelling Status' has 3 unique values
# ['All Dwelling Statuses' 'New' 'Existing']
#
# -----------------------------------------------------------------------
#
# 'Stamp Duty Event' has 2 unique values
# ['Filings' 'Executions']
#
# -----------------------------------------------------------------------
#
# 'Type of Buyer' has 6 unique values
# ['All Buyer Types' 'Household Buyer - All'
#  'Household Buyer - First-Time Buyer Owner-Occupier'
#  'Household Buyer - Former Owner-Occupier' 'Household Buyer - Non-Occupier'
#  'Non-Household Buyer']
#
# -----------------------------------------------------------------------
#
# 'Type of Sale' has 3 unique values
# ['All Sale Types' 'Market' 'Non-Market']
#
# -----------------------------------------------------------------------
#
# 'Month' has 87 unique values
# ~~Listing up to 10 unique values~~
# ['2010M01' '2010M02' '2010M03' '2010M04' '2010M05' '2010M06' '2010M07'
#  '2010M08' '2010M09' '2010M10']
#
# -----------------------------------------------------------------------
#
# 'Statistic' has 4 unique values
# ['Volume of Sales (Number)' 'Value of Sales (Euro Million)'
#  'Average Sale Price  (Euro)' 'Median Price (Euro)']
#
# -----------------------------------------------------------------------
#
# 'value' has 85618 unique values
# ~~Listing up to 10 unique values~~
# [  8.00000000e+00   1.50000000e+00   1.90438000e+05   1.76750000e+05
#    1.40000000e+01   1.80000000e+00   1.28619000e+05   1.40332000e+05
#    2.00000000e+01   2.10000000e+00]
#
# -----------------------------------------------------------------------
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Features with missing values:
# ['value has 100062 missing']
#
#
# Features with non-numeric values:
# ['County', 'Dwelling Status', 'Stamp Duty Event', 'Type of Buyer', 'Type of Sale', 'Month', 'Statistic']
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
df2.Statistic
# Out:
# 37584           Volume of Sales (Number)
# 37585      Value of Sales (Euro Million)
# 37586         Average Sale Price  (Euro)
# 37587                Median Price (Euro)
# 37588           Volume of Sales (Number)
# 37589      Value of Sales (Euro Million)
# 37590         Average Sale Price  (Euro)
# 37591                Median Price (Euro)
# 37592           Volume of Sales (Number)
# 37593      Value of Sales (Euro Million)
# 37594         Average Sale Price  (Euro)
# 37595                Median Price (Euro)
# 37596           Volume of Sales (Number)
# 37597      Value of Sales (Euro Million)
# 37598         Average Sale Price  (Euro)
# 37599                Median Price (Euro)
# 37600           Volume of Sales (Number)
# 37601      Value of Sales (Euro Million)
# 37602         Average Sale Price  (Euro)
# 37603                Median Price (Euro)
# 37604           Volume of Sales (Number)
# 37605      Value of Sales (Euro Million)
# 37606         Average Sale Price  (Euro)
# 37607                Median Price (Euro)
# 37608           Volume of Sales (Number)
# 37609      Value of Sales (Euro Million)
# 37610         Average Sale Price  (Euro)
# 37611                Median Price (Euro)
# 37612           Volume of Sales (Number)
# 37613      Value of Sales (Euro Million)
#                        ...
# 1014738       Average Sale Price  (Euro)
# 1014739              Median Price (Euro)
# 1014740         Volume of Sales (Number)
# 1014741    Value of Sales (Euro Million)
# 1014742       Average Sale Price  (Euro)
# 1014743              Median Price (Euro)
# 1014744         Volume of Sales (Number)
# 1014745    Value of Sales (Euro Million)
# 1014746       Average Sale Price  (Euro)
# 1014747              Median Price (Euro)
# 1014748         Volume of Sales (Number)
# 1014749    Value of Sales (Euro Million)
# 1014750       Average Sale Price  (Euro)
# 1014751              Median Price (Euro)
# 1014752         Volume of Sales (Number)
# 1014753    Value of Sales (Euro Million)
# 1014754       Average Sale Price  (Euro)
# 1014755              Median Price (Euro)
# 1014756         Volume of Sales (Number)
# 1014757    Value of Sales (Euro Million)
# 1014758       Average Sale Price  (Euro)
# 1014759              Median Price (Euro)
# 1014760         Volume of Sales (Number)
# 1014761    Value of Sales (Euro Million)
# 1014762       Average Sale Price  (Euro)
# 1014763              Median Price (Euro)
# 1014764         Volume of Sales (Number)
# 1014765    Value of Sales (Euro Million)
# 1014766       Average Sale Price  (Euro)
# 1014767              Median Price (Euro)
# Name: Statistic, dtype: object

# %%
for value1 in df2.County:
    df3 = df2.loc[(df2['County'] == 'value1') & (df2['Statistic'] == 'Median Price (Euro)')]

# %%
df3.value.mean()
# Out:
# 95805.6290250779

# %%
df3
# Out:
#        County        Dwelling Status Stamp Duty Event        Type of Buyer  \
# 37587  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37591  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37595  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37599  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37603  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37607  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37611  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37615  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37619  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37623  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37627  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37631  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37635  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37639  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37643  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37647  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37651  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37655  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37659  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37663  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37667  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37671  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37675  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37679  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37683  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37687  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37691  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37695  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37699  Carlow  All Dwelling Statuses          Filings      All Buyer Types
# 37667  All Sale Types  2011M09  Median Price (Euro)   60000.0
# 37671  All Sale Types  2011M10  Median Price (Euro)   80500.0
# 37675  All Sale Types  2011M11  Median Price (Euro)   52500.0
# 37679  All Sale Types  2011M12  Median Price (Euro)       0.0
# 37683  All Sale Types  2012M01  Median Price (Euro)   85000.0
# 37687  All Sale Types  2012M02  Median Price (Euro)  100000.0
# 37691  All Sale Types  2012M03  Median Price (Euro)   80000.0
# 37695  All Sale Types  2012M04  Median Price (Euro)   65000.0
# 37699  All Sale Types  2012M05  Median Price (Euro)   70000.0
# 37703  All Sale Types  2012M06  Median Price (Euro)   20000.0
# ...               ...      ...                  ...       ...
# 75051      Non-Market  2014M10  Median Price (Euro)       NaN
# 75055      Non-Market  2014M11  Median Price (Euro)       NaN
# 75059      Non-Market  2014M12  Median Price (Euro)   75045.0
# 75063      Non-Market  2015M01  Median Price (Euro)       NaN
# 75067      Non-Market  2015M02  Median Price (Euro)       NaN
# 75071      Non-Market  2015M03  Median Price (Euro)       NaN
# 75075      Non-Market  2015M04  Median Price (Euro)       NaN
# 75079      Non-Market  2015M05  Median Price (Euro)       NaN
# 75083      Non-Market  2015M06  Median Price (Euro)       NaN
# 75087      Non-Market  2015M07  Median Price (Euro)       NaN
# 75091      Non-Market  2015M08  Median Price (Euro)       NaN
# 75095      Non-Market  2015M09  Median Price (Euro)       NaN
# 75099      Non-Market  2015M10  Median Price (Euro)       NaN
# 75103      Non-Market  2015M11  Median Price (Euro)       0.0
# 75107      Non-Market  2015M12  Median Price (Euro)    5000.0
# 75111      Non-Market  2016M01  Median Price (Euro)       NaN
# 75115      Non-Market  2016M02  Median Price (Euro)       NaN
# 75119      Non-Market  2016M03  Median Price (Euro)   45000.0
# 75123      Non-Market  2016M04  Median Price (Euro)       NaN
# 75127      Non-Market  2016M05  Median Price (Euro)       NaN
# 75131      Non-Market  2016M06  Median Price (Euro)       NaN
# 75135      Non-Market  2016M07  Median Price (Euro)       NaN
# 75139      Non-Market  2016M08  Median Price (Euro)       NaN
# 75143      Non-Market  2016M09  Median Price (Euro)       NaN
# 75147      Non-Market  2016M10  Median Price (Euro)       NaN
# 75151      Non-Market  2016M11  Median Price (Euro)       NaN
# 75155      Non-Market  2016M12  Median Price (Euro)       NaN
# 75159      Non-Market  2017M01  Median Price (Euro)       NaN
# 75163      Non-Market  2017M02  Median Price (Euro)       NaN
# 75167      Non-Market  2017M03  Median Price (Euro)       NaN
#
# [9396 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.cm

from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %%
fig, ax = plt.subplots(figsize=(10,20))
m = Basemap(resolution='c', # c, l, i, h, f or None
            projection='merc',
            lat_0=0, lon_0= 0,
            llcrnrlon=-10.49, llcrnrlat= 51.25, urcrnrlon=-5.8, urcrnrlat=54.56)

# %%
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()
