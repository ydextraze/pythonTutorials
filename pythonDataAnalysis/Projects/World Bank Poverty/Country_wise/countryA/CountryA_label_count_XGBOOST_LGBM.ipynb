# %% [markdown]
# ###### XGBOOST Parameter tuning
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
#http://drivendata.co/blog/worldbank-poverty-benchmark/

# %matplotlib inline

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# data directory
DATA_DIR = os.path.join(r'C:\Users\piush\Desktop\Dataset\world_bank_poverty_data\household')

# %%
data_paths = {'A': {'train': os.path.join(DATA_DIR,  'A_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'A_hhold_test.csv')}, 
              
              'B': {'train': os.path.join(DATA_DIR,  'B_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'B_hhold_test.csv')}, 
              
              'C': {'train': os.path.join(DATA_DIR,  'C_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'C_hhold_test.csv')}}

# %%
# load training data
a_train = pd.read_csv(data_paths['A']['train'], index_col='id')
b_train = pd.read_csv(data_paths['B']['train'], index_col='id')
c_train = pd.read_csv(data_paths['C']['train'], index_col='id')

# %%
# load test data
a_test = pd.read_csv(data_paths['A']['test'], index_col='id')
b_test = pd.read_csv(data_paths['B']['test'], index_col='id')
c_test = pd.read_csv(data_paths['C']['test'], index_col='id')

# %%
a_train.shape
# Out:
# (8203, 345)

# %%
a_test.shape
# Out:
# (4041, 344)

# %%
df = pd.concat([a_train,a_test])

# %%
class LabelCount(object):

    def __init__(self, columns, new_column=False):
        self.count_dict = {}
        self.columns = columns
        self.new_column = new_column
        
    
    def fit(self, df):

        for column in self.columns:
            count = df[column].value_counts()
            
            self.count_dict[column] = count.to_dict()
        
    def transform(self, df):
        for column in self.columns:
            
            new_column_name = column
            
            if self.new_column:
                new_column_name = column + "_label_count"

            missing = 1
            df[new_column_name] = df[column].apply(lambda x : self.count_dict[column].get(x, missing))

# %% [markdown]
# ###### Label Count

# %%
for i in list(df.select_dtypes(include=['object']).columns.values):
    lc = LabelCount([i])
    lc.fit(df)
    lc.transform(df)

# %%
y = a_train['poor']

# %%
df = df.drop(['poor','country'], axis = 1)

# %%
train_c = df[:len(a_train)]

# %%
train_c.shape
# Out:
# (8203, 343)

# %%
train = df[:len(a_train)]

# %%
test = df[len(a_train):]

# %% [markdown]
# ##### Standard Scalar processing

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
scaler = MinMaxScaler()
scaler.fit(df)

train_data_scaled = scaler.transform(train)
test_data_scaled = scaler.transform(test)

# %% [markdown]
# ###### Emsembling

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
class Ensemble(object):
    def __init__(self, n_splits, stacker, base_models):
        self.n_splits = n_splits
        self.stacker = stacker
        self.base_models = base_models

    def fit_predict(self, X, y, T):
        X = np.array(X)
        y = np.array(y)
        T = np.array(T)

        folds = list(StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=2016).split(X, y))

        S_train = np.zeros((X.shape[0], len(self.base_models)))
        S_test = np.zeros((T.shape[0], len(self.base_models)))
        for i, clf in enumerate(self.base_models):

            S_test_i = np.zeros((T.shape[0], self.n_splits))

            for j, (train_idx, test_idx) in enumerate(folds):
                X_train = X[train_idx]
                y_train = y[train_idx]
                X_holdout = X[test_idx]
#                y_holdout = y[test_idx]

                print ("Fit %s fold %d" % (str(clf).split('(')[0], j+1))
                clf.fit(X_train, y_train)
#                cross_score = cross_val_score(clf, X_train, y_train, cv=3, scoring='roc_auc')
#                print("    cross_score: %.5f" % (cross_score.mean()))
                y_pred = clf.predict_proba(X_holdout)[:,1]                

                S_train[test_idx, i] = y_pred
                S_test_i[:, j] = clf.predict_proba(T)[:,1]
            S_test[:, i] = S_test_i.mean(axis=1)

        results = cross_val_score(self.stacker, S_train, y, cv=3, scoring='neg_log_loss')
        print("Stacker score: %.5f" % (results.mean()))

        self.stacker.fit(S_train, y)
        res = self.stacker.predict_proba(S_test)[:,1]
        return res

# %%
from sklearn import model_selection
from sklearn.metrics import log_loss

#from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from xgboost import XGBClassifier

from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier


lgb_params = {}
lgb_params['learning_rate'] = 0.02
lgb_params['n_estimators'] = 650
lgb_params['max_bin'] = 10
lgb_params['subsample'] = 0.8
lgb_params['subsample_freq'] = 10
lgb_params['colsample_bytree'] = 0.8   
lgb_params['min_child_samples'] = 500
lgb_params['random_state'] = 99


lgb_params2 = {}
lgb_params2['n_estimators'] = 1090
lgb_params2['learning_rate'] = 0.02
lgb_params2['colsample_bytree'] = 0.3   
lgb_params2['subsample'] = 0.7
lgb_params2['subsample_freq'] = 2
lgb_params2['num_leaves'] = 16
lgb_params2['random_state'] = 99


lgb_params3 = {}
lgb_params3['n_estimators'] = 1100
lgb_params3['max_depth'] = 4
lgb_params3['learning_rate'] = 0.02
lgb_params3['random_state'] = 99

#incorporated one more layer of my defined lgb params 
lgb_params4 = {}
lgb_params4['n_estimators'] = 1450
lgb_params4['max_bin'] = 20
lgb_params4['max_depth'] = 6
lgb_params4['learning_rate'] = 0.25 # shrinkage_rate
lgb_params4['boosting_type'] = 'gbdt'
lgb_params4['objective'] = 'binary'
lgb_params4['min_data'] = 500         # min_data_in_leaf
lgb_params4['min_hessian'] = 0.05     # min_sum_hessian_in_leaf
lgb_params4['verbose'] = 0

lgb_model = LGBMClassifier(**lgb_params)

lgb_model2 = LGBMClassifier(**lgb_params2)

lgb_model3 = LGBMClassifier(**lgb_params3)

lgb_model4 = LGBMClassifier(**lgb_params4)

log_model = XGBClassifier(max_depth=100, learning_rate=0.5, n_estimators=50, 
                      silent=True, objective='binary:logistic',  
                      gamma=0.1, min_child_weight=1, max_delta_step=0.5, 
                      subsample=1, colsample_bytree=1, colsample_bylevel=1, 
                      reg_alpha=0, reg_lambda=1, scale_pos_weight= 1, 
                      base_score=0.3)

a = []
for i in range(2,40):
    stack = Ensemble(n_splits= i,
        stacker = log_model,
        base_models = (lgb_model, lgb_model2, lgb_model3, lgb_model4))        
        
    y_pred = stack.fit_predict(train_data_scaled, y, test_data_scaled) 
    a.append(y_pred)
# Out:
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Stacker score: -0.42716
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Stacker score: -0.41893
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Stacker score: -0.43287
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Stacker score: -0.41930
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Stacker score: -0.42092
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Stacker score: -0.42885
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Stacker score: -0.41383
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Stacker score: -0.42310
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Stacker score: -0.42629
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Stacker score: -0.42495
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Stacker score: -0.42331
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Stacker score: -0.41354
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Stacker score: -0.41364
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Stacker score: -0.42390
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Stacker score: -0.41945
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Stacker score: -0.41606
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Stacker score: -0.41420
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Stacker score: -0.42797
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Stacker score: -0.41580
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Stacker score: -0.42889
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Stacker score: -0.41246
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Stacker score: -0.42331
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Stacker score: -0.41885
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Stacker score: -0.40281
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Stacker score: -0.42863
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Stacker score: -0.41529
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Stacker score: -0.42296
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 1
# ...
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Stacker score: -0.43668
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Stacker score: -0.41736
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Stacker score: -0.42144
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 39
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 39
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 39
# Fit LGBMClassifier fold 1
# Fit LGBMClassifier fold 2
# Fit LGBMClassifier fold 3
# Fit LGBMClassifier fold 4
# Fit LGBMClassifier fold 5
# Fit LGBMClassifier fold 6
# Fit LGBMClassifier fold 7
# Fit LGBMClassifier fold 8
# Fit LGBMClassifier fold 9
# Fit LGBMClassifier fold 10
# Fit LGBMClassifier fold 11
# Fit LGBMClassifier fold 12
# Fit LGBMClassifier fold 13
# Fit LGBMClassifier fold 14
# Fit LGBMClassifier fold 15
# Fit LGBMClassifier fold 16
# Fit LGBMClassifier fold 17
# Fit LGBMClassifier fold 18
# Fit LGBMClassifier fold 19
# Fit LGBMClassifier fold 20
# Fit LGBMClassifier fold 21
# Fit LGBMClassifier fold 22
# Fit LGBMClassifier fold 23
# Fit LGBMClassifier fold 24
# Fit LGBMClassifier fold 25
# Fit LGBMClassifier fold 26
# Fit LGBMClassifier fold 27
# Fit LGBMClassifier fold 28
# Fit LGBMClassifier fold 29
# Fit LGBMClassifier fold 30
# Fit LGBMClassifier fold 31
# Fit LGBMClassifier fold 32
# Fit LGBMClassifier fold 33
# Fit LGBMClassifier fold 34
# Fit LGBMClassifier fold 35
# Fit LGBMClassifier fold 36
# Fit LGBMClassifier fold 37
# Fit LGBMClassifier fold 38
# Fit LGBMClassifier fold 39
# Stacker score: -0.41767

# %%
a = pd.DataFrame(a).T

# %%
a_stack.to_csv("a_stack.csv")

# %%
a_stack['mean'] = a_stack.mean(axis=1)
a_stack['id'] = a_test.index
a_stack['country'] = "A"
a_sub_1 = a_stack[['id','country','mean']]
a_sub_1.to_csv("a_sub_1.csv")

# %%
a_sub_1.shape
# Out:
# (4041, 3)

# %%
a_stack_11 = pd.DataFrame(a).T

# %%
mean = a_stack_11.T.mean(axis = 1)

# %%
lgbsub = pd.DataFrame()
lgbsub['id'] = a_test.index
lgbsub['country'] = "A"
lgbsub['poor'] = mean

# %%
lgbsub.shape
# Out:
# (4041, 3)

# %%
a_stack_11['id'] = a_test.index
a_stack_11['country'] = "A"
a_sub_2 = a_stack_11[['id','country','mean']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-34d83cf3b471> in <module>()
# ----> 1 a_stack_11['id'] = a_test.index
#       2 a_stack_11['country'] = "A"
#       3 a_sub_2 = a_stack_11[['id','country','mean']]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2415         else:
#    2416             # set column
# -> 2417             self._set_item(key, value)
#    2418
#    2419     def _setitem_slice(self, key, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2481
#    2482         self._ensure_valid_index(value)
# -> 2483         value = self._sanitize_column(key, value)
#    2484         NDFrame._set_item(self, key, value)
#    2485
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value)
#    2636
#    2637             # turn me into an ndarray
# -> 2638             value = _sanitize_index(value, self.index, copy=False)
#    2639             if not isinstance(value, (np.ndarray, Index)):
#    2640                 if isinstance(value, list) and len(value) > 0:
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_index(data, index, copy)
#    2796
#    2797     if len(data) != len(index):
# -> 2798         raise ValueError('Length of values does not match length of ' 'index')
#    2799
#    2800     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
lgbsub = pd.DataFrame()
lgbsub['id'] = a_test.index
lgbsub['country'] = "A"
lgbsub['poor'] = y_pred
lgbsub.to_csv('lgb_esm_submission_A_60.csv', index=False)

# %%
# 10: -0.426
# 15: -0.413
#20: -0.427
#25: -0.4188
#30: -.4106
#35: -.41989
#40: -.42346
#45: -.42558
#50: -.42391
#55 : -.42468
