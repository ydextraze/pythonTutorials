# %%
# http://contrib.scikit-learn.org/categorical-encoding/polynomial.html

# %%
#http://drivendata.co/blog/worldbank-poverty-benchmark/

# %matplotlib inline

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import category_encoders as ce
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# data directory
DATA_DIR = os.path.join(r'C:\Users\piush\Desktop\Dataset\world_bank_poverty_data\household')

# %%
data_paths = {'A': {'train': os.path.join(DATA_DIR,  'A_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'A_hhold_test.csv')}, 
              
              'B': {'train': os.path.join(DATA_DIR,  'B_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'B_hhold_test.csv')}, 
              
              'C': {'train': os.path.join(DATA_DIR,  'C_hhold_train.csv'), 
                    'test':  os.path.join(DATA_DIR,  'C_hhold_test.csv')}}

# %%
# load training data
a_train = pd.read_csv(data_paths['A']['train'], index_col='id')
b_train = pd.read_csv(data_paths['B']['train'], index_col='id')
c_train = pd.read_csv(data_paths['C']['train'], index_col='id')

# %% [markdown]
# ##### Drop country and poor in the training set

# %%
ay_train = np.ravel(a_train.poor)

# %%
by_train = np.ravel(b_train.poor)

# %%
cy_train = np.ravel(c_train.poor)

# %% [markdown]
# ###### Convert only the categorical values

# %%
encoder = ce.PolynomialEncoder(cols= list(a_train.select_dtypes(include=['object']).columns.values))
encoder.fit(a_train, ay_train)
aX_cleaned = encoder.transform(a_train)

# %%
encoder = ce.PolynomialEncoder(cols= list(b_train.select_dtypes(include=['object']).columns.values))
encoder.fit(b_train, by_train)
bX_cleaned = encoder.transform(b_train)

# %%
encoder = ce.PolynomialEncoder(cols= list(c_train.select_dtypes(include=['object']).columns.values))
encoder.fit(c_train, cy_train)
cX_cleaned = encoder.transform(c_train)

# %%
#encoder.fit(a_train, ay_train)

# %%
#aX_cleaned = encoder.transform(a_train)

# %%
aX_cleaned.head(2)
# Out:
#        col_wBXbHZmp_0  col_wBXbHZmp_1  col_SlDKnCuu_0  col_SlDKnCuu_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_KAJOWiiw_0  col_KAJOWiiw_1  col_KAJOWiiw_2  col_DsKacCdL_0  \
# id
# 46107             1.0       -0.707107        0.408248             1.0
# 82739             1.0       -0.707107        0.408248             1.0
#
#        col_DsKacCdL_1  col_rtPrBBPl_0  col_rtPrBBPl_1  col_tMJrvvut_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_tMJrvvut_1  col_jdetlNNF_0  col_jdetlNNF_1  col_maLAYXwi_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_maLAYXwi_1  col_maLAYXwi_2  col_vwpsXRGk_0  col_vwpsXRGk_1  \
# id
# 46107   -7.071068e-01        0.408248             1.0       -0.301207
# 82739   -5.551115e-17       -0.816497             1.0       -0.281127
#
#        col_vwpsXRGk_2  col_vwpsXRGk_3  col_vwpsXRGk_4  col_vwpsXRGk_5  \
# id
# 46107        0.364529       -0.391413        0.389812   -3.662402e-01
# 82739        0.291623       -0.234848        0.129937   -1.670704e-15
#
#        col_vwpsXRGk_6  col_vwpsXRGk_7  col_vwpsXRGk_8  col_vwpsXRGk_9  \
# id
# 46107        0.327273       -0.279382        0.228407       -0.179078
# 82739       -0.130909        0.242131       -0.319769        0.358156
#
#        col_vwpsXRGk_10  col_vwpsXRGk_11  col_vwpsXRGk_12  col_vwpsXRGk_13  \
# id
# 46107         0.134739        -0.097306         0.067435        -0.044824
# 82739        -0.359304         0.330839        -0.283228         0.227107
#
#        col_vwpsXRGk_14  col_vwpsXRGk_15  col_vwpsXRGk_16  col_vwpsXRGk_17  \
# id
# 46107         0.028552        -0.017410         0.010148        -0.005644
# 82739        -0.171315         0.121872        -0.081860         0.051926
#
#        col_vwpsXRGk_18  col_vwpsXRGk_19  col_vwpsXRGk_20  col_vwpsXRGk_21  \
# id
# 46107         0.002989        -0.001503         0.000716        -0.000322
# 82739        -0.031087         0.017540        -0.009307         0.004630
#
#        col_vwpsXRGk_22  col_vwpsXRGk_23  col_vwpsXRGk_24  col_vwpsXRGk_25  \
# id
# 46107         0.000136        -0.000053         0.000019        -0.000006
# 82739        -0.002150         0.000928        -0.000369         0.000134
#
#        col_vwpsXRGk_26  col_vwpsXRGk_27  col_vwpsXRGk_28  col_vwpsXRGk_29  \
# id
# 46107         0.000002    -5.238172e-07     1.202458e-07    -2.233598e-08
# 82739        -0.000044     1.267638e-05    -3.134408e-06     6.254073e-07
#
#        col_vwpsXRGk_30  col_sArDRIyX_0  col_sArDRIyX_1  col_goxNwvnG_0  \
# id
# 46107     2.907817e-09             1.0       -0.707107             1.0
# 82739    -8.723498e-08             1.0       -0.707107             1.0
#
#        col_goxNwvnG_1  col_TYhoEiNm_0  col_TYhoEiNm_1  col_bgfNZfcj_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_bgfNZfcj_1  col_sYIButva_0  col_sYIButva_1  col_VZtBaoXL_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_VZtBaoXL_1  col_VZtBaoXL_2  col_GUvFHPNA_0  col_GUvFHPNA_1  \
# id
# 46107       -0.707107        0.408248             1.0       -0.707107
# 82739       -0.707107        0.408248             1.0       -0.707107
#
#        col_zFkComtB_0  col_zFkComtB_1  col_zFkComtB_2  col_fxbqfEWb_0  \
# id
# 46107             1.0       -0.707107        0.408248             1.0
# 82739             1.0       -0.707107        0.408248             1.0
#
#        col_fxbqfEWb_1  col_HDMHzGif_0  col_HDMHzGif_1  col_zzwlWZZC_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_zzwlWZZC_1  col_nGTepfos_0  col_nGTepfos_1  col_DxLvCGgv_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_DxLvCGgv_1  col_CbABToOI_0  col_CbABToOI_1  col_CbABToOI_2  \
# id
# 46107       -0.707107             1.0   -7.071068e-01        0.408248
# 82739        0.707107             1.0   -5.551115e-17       -0.816497
#
#        col_qgMygRvX_0  col_qgMygRvX_1  col_qgMygRvX_2  col_qgMygRvX_3  \
# id
# 46107             1.0       -0.516398        0.531816       -0.444949
# 82739             1.0       -0.516398        0.531816       -0.444949
#
#        col_qgMygRvX_4  col_qgMygRvX_5  col_qgMygRvX_6  col_qgMygRvX_7  \
# id
# 46107        0.312893         -0.1849        0.089893       -0.034139
# 82739        0.312893         -0.1849        0.089893       -0.034139
#
#        col_qgMygRvX_8  col_fhKiXuMY_0  col_fhKiXuMY_1  col_uSKnVaKV_0  \
# id
# 46107        0.008815             1.0       -0.707107             1.0
# 82739        0.008815             1.0       -0.707107             1.0
#
#        col_uSKnVaKV_1  col_hESBInAl_0  col_hESBInAl_1  col_hESBInAl_2  \
# id
# 46107       -0.707107             1.0       -0.707107        0.408248
# 82739       -0.707107             1.0       -0.707107        0.408248
#
#        col_nzTeWUeM_0  col_nzTeWUeM_1  col_nzTeWUeM_2  col_BbKZUYsB_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_BbKZUYsB_1  col_UCnazcxd_0  col_UCnazcxd_1  col_hTraVEWP_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739        0.707107             1.0        0.707107             1.0
#
#        col_hTraVEWP_1  col_aCfsveTu_0  col_aCfsveTu_1  col_EfkPrfXa_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_EfkPrfXa_1  col_NrvxpdMQ_0  col_NrvxpdMQ_1  col_FcekeISI_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_FcekeISI_1  col_FcekeISI_2  col_NmAVTtfA_0  col_NmAVTtfA_1  \
# id
# 46107   -7.071068e-01        0.408248             1.0       -0.707107
# 82739   -5.551115e-17       -0.816497             1.0       -0.707107
#
#        col_YTdCRVJt_0  col_YTdCRVJt_1  col_YTdCRVJt_2  col_QyBloWXZ_0  \
# id
# 46107             1.0       -0.707107        0.408248             1.0
# 82739             1.0       -0.707107        0.408248             1.0
#
#        col_QyBloWXZ_1  col_NGOnRdqc_0  col_NGOnRdqc_1  col_HKMQJANN_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_HKMQJANN_1  col_HKMQJANN_2  col_ZRrposmO_0  col_ZRrposmO_1  \
# id
# 46107   -7.071068e-01        0.408248             1.0       -0.707107
# 82739   -5.551115e-17       -0.816497             1.0       -0.707107
#
#        col_wakWLjkG_0  col_wakWLjkG_1  col_vmZttwFZ_0  col_vmZttwFZ_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0        0.707107             1.0       -0.707107
#
#        col_dkoIJCbY_0  col_dkoIJCbY_1  col_NrUWfvEq_0  col_NrUWfvEq_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_NrUWfvEq_2  col_WqhniYIc_0  col_WqhniYIc_1  col_yHbEDILT_0  \
# id
# 46107        0.408248             1.0       -0.707107             1.0
# 82739        0.408248             1.0       -0.707107             1.0
#
#        col_yHbEDILT_1  col_EJgrQqET_0  col_EJgrQqET_1  col_nGMEgWyl_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_nGMEgWyl_1  col_IIEHQNUc_0  col_IIEHQNUc_1  col_HfKRIwMb_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_HfKRIwMb_1  col_NRVuZwXK_0  col_NRVuZwXK_1  col_NRVuZwXK_2  \
# id
# 46107       -0.707107             1.0       -0.516398        0.531816
# 82739        0.707107             1.0       -0.516398        0.531816
#
#        col_NRVuZwXK_3  col_NRVuZwXK_4  col_NRVuZwXK_5  col_NRVuZwXK_6  \
# id
# 46107       -0.444949        0.312893         -0.1849        0.089893
# 82739       -0.444949        0.312893         -0.1849        0.089893
#
#        col_NRVuZwXK_7  col_NRVuZwXK_8  col_UCAmikjV_0  col_UCAmikjV_1  \
# id
# 46107       -0.034139        0.008815             1.0       -0.707107
# 82739       -0.034139        0.008815             1.0       -0.707107
#
#        col_UGbBCHRE_0  col_UGbBCHRE_1  col_uJYGhXqG_0  col_uJYGhXqG_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_bxKGlBYX_0  col_bxKGlBYX_1  col_nCzVgxgY_0  col_nCzVgxgY_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_ltcNxFzI_0  col_ltcNxFzI_1  col_ltcNxFzI_2  col_ltcNxFzI_3  \
# id
# 46107             1.0       -0.670820             0.5       -0.223607
# 82739             1.0       -0.223607            -0.5        0.670820
#
#        col_WbEDLWBH_0  col_WbEDLWBH_1  col_IBPMYJlv_0  col_IBPMYJlv_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_MxOgekdE_0  col_MxOgekdE_1  col_ggNglVqE_0  col_ggNglVqE_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_YDgWYWcJ_0  col_YDgWYWcJ_1  col_SqGRfEuW_0  col_SqGRfEuW_1  \
# id
# 46107             1.0       -0.707107             1.0   -7.071068e-01
# 82739             1.0       -0.707107             1.0   -5.551115e-17
#
#        col_SqGRfEuW_2  col_WiwmbjGW_0  col_WiwmbjGW_1  col_WiwmbjGW_2  \
# id
# 46107        0.408248             1.0       -0.707107        0.408248
# 82739       -0.816497             1.0       -0.707107        0.408248
#
#        col_benRXROb_0  col_benRXROb_1  col_cOSBrarW_0  col_cOSBrarW_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_JwtIxvKg_0  col_JwtIxvKg_1  col_lRGpWehf_0  col_lRGpWehf_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_dSALvhyd_0  col_dSALvhyd_1  col_gfmfEyjQ_0  col_gfmfEyjQ_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_gfmfEyjQ_2  col_WbxAxHul_0  col_WbxAxHul_1  col_FlBqizNL_0  \
# id
# 46107        0.408248             1.0       -0.707107             1.0
# 82739        0.408248             1.0       -0.707107             1.0
#
#        col_FlBqizNL_1  col_bEPKkJXP_0  col_bEPKkJXP_1  col_KjkrfGLD_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739        0.707107             1.0       -0.707107             1.0
#
#        col_KjkrfGLD_1  col_KjkrfGLD_2  col_KjkrfGLD_3  col_KjkrfGLD_4  \
# id
# 46107       -0.540062        0.540062        -0.43082        0.282038
# 82739       -0.540062        0.540062        -0.43082        0.282038
#
#        col_KjkrfGLD_5  col_KjkrfGLD_6  col_KjkrfGLD_7  col_JbjHTYUM_0  \
# id
# 46107       -0.149786        0.061546        -0.01707             1.0
# 82739       -0.149786        0.061546        -0.01707             1.0
#
#        col_JbjHTYUM_1  col_JbjHTYUM_2  col_HmDAlkAH_0  col_HmDAlkAH_1  \
# id
# 46107   -7.071068e-01        0.408248             1.0       -0.707107
# 82739   -5.551115e-17       -0.816497             1.0       -0.707107
#
#        col_HmDAlkAH_2  col_cqUmYeAp_0  col_cqUmYeAp_1  col_cqUmYeAp_2  \
# id
# 46107        0.408248             1.0       -0.597614        0.545545
# 82739        0.408248             1.0       -0.358569       -0.109109
#
#        col_cqUmYeAp_3  col_cqUmYeAp_4  col_cqUmYeAp_5  col_sFWbFEso_0  \
# id
# 46107       -0.372678        0.188982       -0.062994             1.0
# 82739        0.521749       -0.566947        0.314970             1.0
#
#        col_sFWbFEso_1  col_fHUZugEd_0  col_fHUZugEd_1  col_tZKoAqgl_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_tZKoAqgl_1  col_TqrXZaOw_0  col_TqrXZaOw_1  col_galsfNtg_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_galsfNtg_1  col_VIRwrkXp_0  col_VIRwrkXp_1  col_dsIjcEFe_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_dsIjcEFe_1  col_OybQOufM_0  col_OybQOufM_1  col_ihGjxdDj_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_ihGjxdDj_1  col_gwhBRami_0  col_gwhBRami_1  col_FGYOIJbC_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739        0.707107             1.0       -0.707107             1.0
#
#        col_FGYOIJbC_1  col_bPOwgKnT_0      ...       col_tHFrzjai_5  \
# id                                         ...
# 46107       -0.707107             1.0      ...            -0.214834
# 82739       -0.707107             1.0      ...            -0.214834
#
#        col_tHFrzjai_6  col_tHFrzjai_7  col_tHFrzjai_8  col_tHFrzjai_9  \
# id
# 46107        0.116775       -0.052694        0.018699       -0.004535
# 82739        0.116775       -0.052694        0.018699       -0.004535
#
#        col_MKozKLvT_0  col_MKozKLvT_1  col_pjHvJhoZ_0  col_pjHvJhoZ_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_zkbPtFyO_0  col_zkbPtFyO_1  col_xZBEXWPR_0  col_xZBEXWPR_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_dyGFeFAg_0  col_dyGFeFAg_1  col_HfOrdgBo_0  col_HfOrdgBo_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_pKPTBZZq_0  col_pKPTBZZq_1  col_pKPTBZZq_2  col_bCYWWTxH_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_bCYWWTxH_1  col_EQKKRGkR_0  col_EQKKRGkR_1  col_ZmJZXnoA_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_ZmJZXnoA_1  col_YKwvJgoP_0  col_YKwvJgoP_1  col_dAaIakDk_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_dAaIakDk_1  col_rnJOTwVD_0  col_rnJOTwVD_1  col_xNUUjCIL_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_xNUUjCIL_1  col_JMNvdasy_0  col_JMNvdasy_1  col_JMNvdasy_2  \
# id
# 46107       -0.707107             1.0   -7.071068e-01        0.408248
# 82739       -0.707107             1.0   -5.551115e-17       -0.816497
#
#        col_MBQcYnjc_0  col_MBQcYnjc_1  col_cCsFudxF_0  col_cCsFudxF_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_muIetHMK_0  col_muIetHMK_1  col_muIetHMK_2  col_hJrMTBVd_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_hJrMTBVd_1  col_TJUYOoXU_0  col_TJUYOoXU_1  col_ishdUooQ_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_ishdUooQ_1  col_ishdUooQ_2  col_tjrOpVkX_0  col_tjrOpVkX_1  \
# id
# 46107       -0.707107        0.408248             1.0       -0.707107
# 82739       -0.707107        0.408248             1.0       -0.707107
#
#        col_cWNZCMRB_0  col_cWNZCMRB_1  col_cgJgOfCA_0  col_cgJgOfCA_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_ItpCDLDM_0  col_ItpCDLDM_1  col_gOGWzlYC_0  col_gOGWzlYC_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_ptEAnCSs_0  col_ptEAnCSs_1  col_HDCjCTRd_0  col_HDCjCTRd_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0        0.707107             1.0       -0.707107
#
#        col_lOujHrCk_0  col_lOujHrCk_1  col_MARfVwUE_0  col_MARfVwUE_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_orfSPOJX_0  col_orfSPOJX_1  col_OKMtkqdQ_0  col_OKMtkqdQ_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_QBJeqwPF_0  col_QBJeqwPF_1  col_qTginJts_0  col_qTginJts_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_JzhdOhzb_0  col_JzhdOhzb_1  col_THDtJuYh_0  col_THDtJuYh_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_QqoiIXtI_0  col_QqoiIXtI_1  col_XVwajTfe_0  col_XVwajTfe_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_jwEuQQve_0  col_jwEuQQve_1  col_rQAsGegu_0  col_rQAsGegu_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_nKoaotpH_0  col_nKoaotpH_1  col_kLkPtNnh_0  col_kLkPtNnh_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_TzPdCEPV_0  col_TzPdCEPV_1  col_CtHqaXhY_0  col_CtHqaXhY_1  \
# id
# 46107             1.0       -0.707107             1.0   -7.071068e-01
# 82739             1.0       -0.707107             1.0   -5.551115e-17
#
#        col_CtHqaXhY_2  col_DbUNVFwv_0  col_DbUNVFwv_1  col_FmSlImli_0  \
# id
# 46107        0.408248             1.0       -0.707107             1.0
# 82739       -0.816497             1.0       -0.707107             1.0
#
#        col_FmSlImli_1  col_UsENDgsH_0  col_UsENDgsH_1  col_mNrEOmgq_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739        0.707107             1.0       -0.707107             1.0
#
#        col_mNrEOmgq_1  col_PWShFLnY_0  col_PWShFLnY_1  col_uRFXnNKV_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_uRFXnNKV_1  col_uRFXnNKV_2  col_lFExzVaF_0  col_lFExzVaF_1  \
# id
# 46107       -0.707107        0.408248             1.0       -0.707107
# 82739       -0.707107        0.408248             1.0       -0.707107
#
#        col_CVCsOVew_0  col_CVCsOVew_1  col_tlxXCDiW_0  col_tlxXCDiW_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_IKqsuNvV_0  col_IKqsuNvV_1  col_ztGMreNV_0  col_ztGMreNV_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_CqqwKRSn_0  col_CqqwKRSn_1  col_CqqwKRSn_2  col_YUExUvhq_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_YUExUvhq_1  col_uVnApIlJ_0  col_uVnApIlJ_1  col_fsXLyyco_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_fsXLyyco_1  col_UXhTXbuS_0  col_UXhTXbuS_1  col_UXhTXbuS_2  \
# id
# 46107       -0.707107             1.0       -0.707107        0.408248
# 82739       -0.707107             1.0       -0.707107        0.408248
#
#        col_yaHLJxDD_0  col_yaHLJxDD_1  col_yaHLJxDD_2  col_zuMWFXax_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_zuMWFXax_1  col_zuMWFXax_2  col_qlZMvcWc_0  col_qlZMvcWc_1  \
# id
# 46107       -0.707107        0.408248             1.0       -0.707107
# 82739       -0.707107        0.408248             1.0       -0.707107
#
#        col_dqRtXzav_0  col_dqRtXzav_1  col_ALbGNqKm_0  col_ALbGNqKm_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0        0.707107             1.0       -0.707107
#
#        col_ktBqxSwa_0  col_ktBqxSwa_1  col_NqPjMmKP_0  col_NqPjMmKP_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_tOWnWxYe_0  col_tOWnWxYe_1  col_RvTenIlS_0  col_RvTenIlS_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_GIMIxlmv_0  col_GIMIxlmv_1  col_wKVwRQIp_0  col_wKVwRQIp_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_ncjMNgfp_0  col_ncjMNgfp_1  col_UaXLYMMh_0  col_UaXLYMMh_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.632456
# 82739             1.0       -0.707107             1.0       -0.632456
#
#        col_UaXLYMMh_2  col_UaXLYMMh_3  col_UaXLYMMh_4  col_vRIvQXtC_0  \
# id
# 46107        0.534522       -0.316228        0.119523             1.0
# 82739        0.534522       -0.316228        0.119523             1.0
#
#        col_vRIvQXtC_1  col_vRIvQXtC_2  col_vRIvQXtC_3  col_vRIvQXtC_4  \
# id
# 46107       -0.597614        0.545545       -0.372678        0.188982
# 82739       -0.597614        0.545545       -0.372678        0.188982
#
#        col_vRIvQXtC_5  col_bKtkhUWD_0  col_bKtkhUWD_1  col_RJFKdmYJ_0  \
# id
# 46107       -0.062994             1.0       -0.707107             1.0
# 82739       -0.062994             1.0       -0.707107             1.0
#
#        col_RJFKdmYJ_1  col_gllMXToa_0  col_gllMXToa_1  col_gllMXToa_2  \
# id
# 46107       -0.707107             1.0   -7.071068e-01        0.408248
# 82739       -0.707107             1.0   -5.551115e-17       -0.816497
#
#        col_HhKXJWno_0  col_HhKXJWno_1  col_VFTkSOrq_0  col_VFTkSOrq_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_tAYCAXge_0  col_tAYCAXge_1  col_WAFKMNwv_0  col_WAFKMNwv_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_mHzqKSuN_0  col_mHzqKSuN_1  col_UjuNwfjv_0  col_UjuNwfjv_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.430946
# 82739             1.0       -0.707107             1.0       -0.430946
#
#        col_UjuNwfjv_2  col_UjuNwfjv_3  col_UjuNwfjv_4  col_UjuNwfjv_5  \
# id
# 46107        0.481812       -0.458578        0.387569       -0.294896
# 82739        0.481812       -0.458578        0.387569       -0.294896
#
#        col_UjuNwfjv_6  col_UjuNwfjv_7  col_UjuNwfjv_8  col_UjuNwfjv_9  \
# id
# 46107        0.202756       -0.125744        0.069909       -0.034459
# 82739        0.202756       -0.125744        0.069909       -0.034459
#
#        col_UjuNwfjv_10  col_UjuNwfjv_11  col_UjuNwfjv_12  col_UjuNwfjv_13  \
# id
# 46107          0.01479        -0.005362          0.00155         -0.00031
# 82739          0.01479        -0.005362          0.00155         -0.00031
#
#        col_aWlBVrkK_0  col_aWlBVrkK_1  col_cDkXTaWP_0  col_cDkXTaWP_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_hnmsRSvN_0  col_hnmsRSvN_1  col_ZzUrQSMj_0  col_ZzUrQSMj_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_GHmAeUhZ_0  col_GHmAeUhZ_1  col_GHmAeUhZ_2  col_VBjVVDwp_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_VBjVVDwp_1  col_VBjVVDwp_2  col_RMbjnrlm_0  col_RMbjnrlm_1  \
# id
# 46107   -7.071068e-01        0.408248             1.0       -0.707107
# 82739   -5.551115e-17       -0.816497             1.0       -0.707107
#
#        col_kZVpcgJL_0  col_kZVpcgJL_1  col_zvjiUrCR_0  col_zvjiUrCR_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_BIofZdtd_0  col_BIofZdtd_1  col_QZiSWCCB_0  col_QZiSWCCB_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0        0.707107
#
#        col_sDGibZrP_0  col_sDGibZrP_1  col_CsGvKKBJ_0  col_CsGvKKBJ_1  \
# id
# 46107             1.0       -0.707107             1.0       -0.707107
# 82739             1.0       -0.707107             1.0       -0.707107
#
#        col_OLpGAaEu_0  col_OLpGAaEu_1  col_OLpGAaEu_2  col_LrDrWRjC_0  \
# id
# 46107             1.0   -7.071068e-01        0.408248             1.0
# 82739             1.0   -5.551115e-17       -0.816497             1.0
#
#        col_LrDrWRjC_1  col_JCDeZBXq_0  col_JCDeZBXq_1  col_HGPWuGlV_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0        0.707107             1.0
#
#        col_HGPWuGlV_1  col_GDUPaBQs_0  col_GDUPaBQs_1  col_WuwrCsIY_0  \
# id
# 46107       -0.707107             1.0       -0.707107             1.0
# 82739       -0.707107             1.0       -0.707107             1.0
#
#        col_WuwrCsIY_1  col_AlDbXTlZ_0  col_AlDbXTlZ_1  col_country_0  \
# id
# 46107       -0.707107             1.0       -0.707107            1.0
# 82739       -0.707107             1.0        0.707107            1.0
#
#        col_nEsgxvAq  col_OMtioXZZ  col_YFMZwKrU  col_poor  col_TiwRslOh
# id
# 46107         -16.0            21          -2.0     False            -7
# 82739         -10.0            12          -3.0     False            -1
#
# [2 rows x 860 columns]

# %%
aX_cleaned['col_poor'].value_counts()
# Out:
# False    4500
# True     3703
# Name: col_poor, dtype: int64

# %%
# from sklearn.preprocessing import LabelEncoder
# a_train = a_train.apply(LabelEncoder().fit_transform)

# %%
# Standardize features
def standardize(df, numeric_only=True):
    numeric = df.select_dtypes(include=['int64', 'float64'])
    
    # subtracy mean and divide by std
    df[numeric.columns] = (numeric - numeric.mean()) / numeric.std()
    
    return df
    

def pre_process_data(df, enforce_cols=None):
    print("Input shape:\t{}".format(df.shape))
        

    df = standardize(df)
    print("After standardization {}".format(df.shape))
        
#     # create dummy variables for categoricals
#     df = pd.get_dummies(df)
#     print("After converting categoricals:\t{}".format(df.shape))
    

    # match test set and training set columns
    if enforce_cols is not None:
        to_drop = np.setdiff1d(df.columns, enforce_cols)
        to_add = np.setdiff1d(enforce_cols, df.columns)

        df.drop(to_drop, axis=1, inplace=True)
        df = df.assign(**{c: 0 for c in to_add})
    
    df.fillna(0, inplace=True)
    
    return df

# %%
print("Country A")
aX_train = pre_process_data(aX_cleaned.drop(['col_poor'], axis=1))


print("\nCountry B")
bX_train = pre_process_data(bX_cleaned.drop(['col_poor'], axis=1))

print("\nCountry C")
cX_train = pre_process_data(cX_cleaned.drop(['col_poor'], axis=1))
# Out:
# Country A
# Input shape:	(8203, 859)
# After standardization (8203, 859)
#
# Country B
# Input shape:	(3255, 1432)
# After standardization (3255, 1432)
#
# Country C
# Input shape:	(6469, 795)
# After standardization (6469, 795)

# %%
from sklearn.ensemble import RandomForestClassifier

def train_model(features, labels, **kwargs):
    
    # instantiate model
    model = RandomForestClassifier(n_estimators=50, random_state=0)
    
    # train model
    model.fit(features, labels)
    
    # get a (not-very-useful) sense of performance
    accuracy = model.score(features, labels)
    print("In-sample accuracy: {0:}".format(accuracy))
    
    return model

# %%
model_a = train_model(aX_train, ay_train)
# Out:
# In-sample accuracy: 1.0

# %%
model_b = train_model(bX_train, by_train)
# Out:
# In-sample accuracy: 0.9993855606758832

# %%
model_c = train_model(cX_train, cy_train)
# Out:
# In-sample accuracy: 1.0

# %%
# load test data
a_test = pd.read_csv(data_paths['A']['test'], index_col='id')
b_test = pd.read_csv(data_paths['B']['test'], index_col='id')
c_test = pd.read_csv(data_paths['C']['test'], index_col='id')

# %%
encoder = ce.PolynomialEncoder(cols= list(a_test.select_dtypes(include=['object']).columns.values))
encoder.fit(a_test)
aX_cleaned_test = encoder.transform(a_test)

# %%
encoder = ce.PolynomialEncoder(cols= list(b_test.select_dtypes(include=['object']).columns.values))
encoder.fit(b_test)
bX_cleaned_test = encoder.transform(b_test)

# %%
encoder = ce.PolynomialEncoder(cols= list(c_test.select_dtypes(include=['object']).columns.values))
encoder.fit(c_test)
cX_cleaned_test = encoder.transform(c_test)

# %%
# process the test data
a_test = pre_process_data(aX_cleaned_test, enforce_cols=aX_train.columns)
b_test = pre_process_data(bX_cleaned_test, enforce_cols=bX_train.columns)
c_test = pre_process_data(cX_cleaned_test, enforce_cols=cX_train.columns)
# Out:
# Input shape:	(4041, 851)
# After standardization (4041, 851)
# Input shape:	(1604, 1419)
# After standardization (1604, 1419)
# Input shape:	(3187, 773)
# After standardization (3187, 773)

# %%
a_preds = model_a.predict_proba(a_test)
b_preds = model_b.predict_proba(b_test)
c_preds = model_c.predict_proba(c_test)

# %%
def make_country_sub(preds, test_feat, country):
    # make sure we code the country correctly
    country_codes = ['A', 'B', 'C']
    
    # get just the poor probabilities
    country_sub = pd.DataFrame(data=preds[:, 1],  # proba p=1
                               columns=['poor'], 
                               index=test_feat.index)

    
    # add the country code for joining later
    country_sub["country"] = country
    return country_sub[["country", "poor"]]

# %%
# convert preds to data frames
a_sub = make_country_sub(a_preds, a_test, 'A')
b_sub = make_country_sub(b_preds, b_test, 'B')
c_sub = make_country_sub(c_preds, c_test, 'C')

# %%
submission = pd.concat([a_sub, b_sub, c_sub])

# %%
submission.head()
# Out:
#       country  poor
# id
# 418         A  0.54
# 41249       A  0.48
# 16205       A  0.42
# 97501       A  0.46
# 67756       A  0.60

# %%
submission.to_csv('submission_PolynomialEncoder.csv')
