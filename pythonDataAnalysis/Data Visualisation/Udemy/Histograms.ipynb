# %%
#standard imports
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
#plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
# to see the plot inline

# %%
#to know about histogram
url = "https://en.wikipedia.org/wiki/Histogram"

# %%
dataset1 = randn(100)

# %%
#matplotlib.pyplot and calling histogram it is divided into 10 bins always
plt.hist(dataset1)
# Out:
# (array([  4.,   5.,  13.,  24.,  21.,  18.,  11.,   0.,   3.,   1.]),
#  array([-2.3758667 , -1.83682443, -1.29778216, -0.75873989, -0.21969762,
#          0.31934465,  0.85838693,  1.3974292 ,  1.93647147,  2.47551374,
#          3.01455601]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color = 'indianred')
# Out:
# (array([  1.,   2.,   4.,   8.,  18.,  12.,  17.,   7.,   5.,   6.]),
#  array([-2.98691241, -2.48616924, -1.98542607, -1.4846829 , -0.98393972,
#         -0.48319655,  0.01754662,  0.51828979,  1.01903297,  1.51977614,
#          2.02051931]),
#  <a list of 10 Patch objects>)

# %%
#on the same plot has to be normalized with using normed
plt.hist(dataset1,normed = True, color ='indianred',alpha=0.5,bins = 20)
plt.hist(dataset2,normed = True,alpha=0.5,bins = 20)
# Out:
# (array([ 0.04992579,  0.        ,  0.09985159,  0.        ,  0.04992579,
#          0.14977738,  0.09985159,  0.29955476,  0.44933214,  0.44933214,
#          0.19970317,  0.39940634,  0.39940634,  0.44933214,  0.19970317,
#          0.14977738,  0.09985159,  0.14977738,  0.24962897,  0.04992579]),
#  array([-2.98691241, -2.73654083, -2.48616924, -2.23579765, -1.98542607,
#         -1.73505448, -1.4846829 , -1.23431131, -0.98393972, -0.73356814,
#         -0.48319655, -0.23282496,  0.01754662,  0.26791821,  0.51828979,
#          0.76866138,  1.01903297,  1.26940455,  1.51977614,  1.77014772,
#          2.02051931]),
#  <a list of 20 Patch objects>)

# %%
# use seaborne and get some information
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
#hexbins
sns.jointplot(data1,data2,kind='hex')
