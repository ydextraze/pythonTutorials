# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
# %config InlineBackend.figure_format = 'png' #set 'png' here when working on notebook
warnings.filterwarnings('ignore') 

# Set some parameters to get good visuals - style to ggplot and size to 15,10
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (4, 3)

# %%
#load the file and set the first column as the index
df1 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\LendingClub\RejectStats_2016Q3.csv\RejectStats_2016Q3.csv")

# %%
df1.head()
# Out:
#    Amount Requested Application Date          Loan Title  Risk_Score  \
# 0              4000       01/07/2016      major_purchase         NaN
# 1             20000       01/07/2016  debt_consolidation         NaN
# 2              1000       01/07/2016    renewable_energy         NaN
# 3             15000       01/07/2016    home_improvement         NaN
# 4              8500       01/07/2016  debt_consolidation         NaN
#
#   Debt-To-Income Ratio Zip Code State Employment Length  Policy Code
# 0                4.21%    750xx    TX           5 years            0
# 1                0.39%    930xx    CA          < 1 year            0
# 2               42.38%    923xx    CA           5 years            0
# 3                5.98%    910xx    CA           5 years            0
# 4               29.14%    210xx    MD          < 1 year            0

# %%
df2 = pd.read_csv(r"C:\Users\piush\Desktop\Dataset\LendingClub\LoanStats_2016Q3.csv\LoanStats_2016Q3.csv")

# %%
df2.head()
# Out:
#          id   member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  90721351  97279408.0    30000.0      30000.0          30000.0   36 months
# 1  90696323  97223035.0    10000.0      10000.0          10000.0   36 months
# 2  90945156  97512868.0    18000.0      18000.0          18000.0   36 months
# 3  90531864  97055592.0     4500.0       4500.0           4500.0   36 months
# 4  90775144  97342858.0     8800.0       8800.0           8800.0   36 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   10.99%       982.02     B        B4            ...
# 1   11.49%       329.72     B        B5            ...
# 2    8.59%       568.97     A        A5            ...
# 3   12.79%       151.17     C        C1            ...
# 4   14.49%       302.87     C        C4            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                0.0                0.0           89.5              83.3
# ...

# %%
print ("\n\n---------------------")
print ("TRAIN SET INFORMATION")
print ("---------------------")
print ("Shape of training set:", df2.shape, "\n")
print ("Column Headers:", list(df2.columns.values), "\n")
print (df2.dtypes)
# Out:
# ---------------------
# TRAIN SET INFORMATION
# ---------------------
# Shape of training set: (99124, 111)
#
# ...

# %%
print ("\n\n---------------------")
print ("TRAIN SET INFORMATION")
print ("---------------------")
print ("Shape of training set:", df1.shape, "\n")
print ("Column Headers:", list(df1.columns.values), "\n")
print (df1.dtypes)
# Out:
# ---------------------
# TRAIN SET INFORMATION
# ---------------------
# Shape of training set: (1048574, 9)
#
# Column Headers: ['Amount Requested', 'Application Date', 'Loan Title', 'Risk_Score', 'Debt-To-Income Ratio', 'Zip Code', 'State', 'Employment Length', 'Policy Code']
#
# Amount Requested          int64
# Application Date         object
# Loan Title               object
# Risk_Score              float64
# Debt-To-Income Ratio     object
# Zip Code                 object
# State                    object
# Employment Length        object
# Policy Code               int64
# dtype: object
